# %% [markdown]
# # DogFaceNet version 11: Dev version number on LFW dataset

# %% [markdown]
# ### Imports and constants

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

import os
import pickle
import numpy as np
import skimage as sk
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import tensorflow.keras.backend as K
from triplets_processing import *
import shutil
import gc

# %%
PATH = 'D:/PROGRAMMATION/Dataset/lfw/lfw_center/'
PATH_SAVE = '../output/history/'
PATH_MODEL = '../output/model/'
SIZE = (151,151,3)
VALID_SPLIT = 0.1
TEST_SPLIT = 0.1

# %% [markdown]
# ### Data pre-processing
# - Load image and labels
# - Training set, validation set (close-set) and testing (open-set)

# %%
filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
        filenames = np.append(filenames,files)
        labels = np.append(labels,np.ones(len(files))*idx)
        idx += 1
print(len(labels))
h,w,c = SIZE
images = np.empty((len(filenames),h,w,c))
for i,f in enumerate(filenames):
    images[i] = sk.io.imread(f)

# %%
# Normalization
images /= 255.0

# %%
# Resize all the images
filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
            sk.io.imsave(files[i],sk.transform.resize(sk.io.imread(files[i]),SIZE,anti_aliasing=True))
# Out:
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\util\dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-eacf206fd3c6> in <module>()
#       7         for i in range(len(files)):
#       8             files[i] = root + '/' + files[i]
# ----> 9             sk.io.imsave(files[i],sk.transform.resize(sk.io.imread(files[i]),SIZE,anti_aliasing=True))
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\io\_io.py in imsave(fname, arr, plugin, **plugin_args)
#     141     if arr.dtype == bool:
#     142         warn('%s is a boolean image: setting True to 1 and False to 0' % fname)
# --> 143     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#     144
#     145
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     212                                (plugin, kind))
#     213
# --> 214     return func(*args, **kwargs)
#     215
#     216
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\io\_plugins\pil_plugin.py in imsave(fname, arr, format_str, **kwargs)
#     257             raise ValueError("Invalid number of channels in image array.")
#     258
# --> 259     img = ndarray_to_pil(arr, format_str=format_str)
#     260     img.save(fname, format=format_str, **kwargs)
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\io\_plugins\pil_plugin.py in ndarray_to_pil(arr, format_str)
#     161     """
#     162     if arr.ndim == 3:
# --> 163         arr = img_as_ubyte(arr)
#     164         mode = {3: 'RGB', 4: 'RGBA'}[arr.shape[2]]
#     165
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\util\dtype.py in img_as_ubyte(image, force_copy)
#     490
#     491     """
# --> 492     return convert(image, np.uint8, force_copy)
#     493
#     494
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\util\dtype.py in convert(image, dtype, force_copy, uniform)
#     274                                         dtype=computation_type)
#     275                 image_out -= 1.0 / 2.
# --> 276             np.rint(image_out, out=image_out)
#     277             np.clip(image_out, imin_out, imax_out, out=image_out)
#     278         elif kind_out == 'u':
#
# KeyboardInterrupt:

# %%
# Without imread

filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
        filenames = np.append(filenames,files)
        labels = np.append(labels,np.ones(len(files))*idx)
        idx += 1
    if len(files) == 1:
        #print(root)
        shutil.rmtree(root)
print(len(labels))
filenames
# Out:
# 9164
# array(['D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0001.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0002.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0003.jpg',
#        ...,
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0002.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0003.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0004.jpg'],
#       dtype='<U112')

# %%
nbof_classes = len(np.unique(labels))
print(nbof_classes)
# Out:
# 1680

# %%
# Center all the faces
for f in filenames:
    img = sk.io.imread(f)
    img_c = img[50:201,50:201,:]
    sk.io.imsave(f,img_c)

# %%
img_c.shape
# Out:
# (151, 151, 3)

# %% [markdown]
# ### Data augmentation

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    zoom_range=0.1,
    fill_mode='nearest',
    channel_shift_range = 0.1
)

# %%
def apply_transform(images, datagen):
    """
    Apply a data preprocessing transformation to n images
    Args:
        -images
        -ImageDataGenerator
    Return:
        -images of the same shape of the inputs but transformed
    """
    for x in datagen.flow(images, batch_size=len(images), shuffle=False):
        return x

# %% [markdown]
# Open-set: test set

# %%
n = 3
cumul = np.empty(labels.shape)
cumul[0] = 1
crt_label = labels[0]
to_keep = []
for i in range(1,len(labels)):
    if labels[i] == labels[i-1]:
        cumul[i] = cumul[i-1] + 1
    else:
        cumul[i] = 1
        if cumul[i-1] >= n:
            to_keep += [labels[i-1]]
bool_keep = np.zeros(labels.shape, dtype=bool)
for i in range(len(to_keep)):
    bool_keep = np.logical_or(bool_keep,np.equal(to_keep[i],labels))
print("Ratio of kept classes: " + str(len(to_keep)/nbof_classes))
print("Ratio of kept images: " + str(len(labels[bool_keep])/len(labels)))
filenames_train = filenames[bool_keep]
labels_train = labels[bool_keep]

keep_test = np.logical_not(bool_keep)
filenames_test = filenames[keep_test]
labels_test = labels[keep_test]
# Out:
# Ratio of kept classes: 0.5357142857142857
# Ratio of kept images: 0.8295504146660847

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

filenames_test = filenames[keep_test]
labels_test = labels[keep_test]

filenames_train = filenames[keep_train]
labels_train = labels[keep_train]

print("Number of training data: " + str(len(filenames_train)))
print("Number of training classes: " + str(nbof_classes-nbof_test))
print("Number of testing data: " + str(len(filenames_test)))
print("Number of testing classes: " + str(nbof_test))
# Out:
# Number of training data: 8241
# Number of training classes: 1512
# Number of testing data: 923
# Number of testing classes: 168

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

images_test = images[keep_test]
labels_test = labels[keep_test]

images_train = images[keep_train]
labels_train = labels[keep_train]

# %%
del images
del labels
gc.collect()

# %%
def define_triplets_batch(filenames,labels,nbof_triplet = 21 * 3):
    
    triplet_train = []
    y_triplet = np.empty(nbof_triplet)
    classes = np.unique(labels)
    for i in range(0,nbof_triplet,3):
        # Pick a class and chose two pictures from this class
        classAP = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classAP)
        keep_classAP = filenames[keep]
        keep_classAP_idx = labels[keep]
        idx_image1 = np.random.randint(len(keep_classAP))
        idx_image2 = np.random.randint(len(keep_classAP))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(keep_classAP))

        triplet_train += [keep_classAP[idx_image1]]
        triplet_train += [keep_classAP[idx_image2]]
        y_triplet[i] = keep_classAP_idx[idx_image1]
        y_triplet[i+1] = keep_classAP_idx[idx_image2]
        # Pick a class for the negative picture
        classN = classes[np.random.randint(len(classes))]
        while classN==classAP:
            classN = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classN)
        keep_classN = filenames[keep]
        keep_classN_idx = labels[keep]
        idx_image3 = np.random.randint(len(keep_classN))
        triplet_train += [keep_classN[idx_image3]]
        y_triplet[i+2] = keep_classN_idx[idx_image3]
        
    return triplet_train, y_triplet

# %%
def define_hard_triplets_batch(filenames,labels,predict,nbof_triplet=21*3, use_neg=True):
    """
    Generates hard triplet for offline selection. It will consider the whole dataset.
    
    Args:
        -images: images from which the triplets will be created
        -labels: labels of the images
        -predict: predicted embeddings for the images by the trained model
        -alpha: threshold of the triplet loss
    Returns:
        -triplet
        -y_triplet: labels of the triplets
    """
    # Check if we have the right number of triplets
    assert nbof_triplet%3 == 0
    
    _,idx_classes = np.unique(labels,return_index=True)
    classes = labels[np.sort(idx_classes)]
    
    triplets = []
    y_triplets = np.empty(nbof_triplet)
    
    idx_triplets = 0
    idx_images = 0
    
    for i in range(0,nbof_triplet,3):
        # Chooses the first class randomly
        keep = np.equal(labels,classes[np.random.randint(len(classes))])
        keep_filenames = filenames[keep]
        keep_labels = labels[keep]
        
        # Chooses the first image among this class randomly
        idx_image1 = np.random.randint(len(keep_labels))
        
        
        # Computes the distance between the chosen image and the rest of the class
        dist_class = np.sum(np.square(predict[keep]-predict[keep][idx_image1]),axis=-1)
        
        idx_image2 = np.argmax(dist_class)
        
        triplets += [keep_filenames[idx_image1]]
        y_triplets[i] = keep_labels[idx_image1]
        triplets += [keep_filenames[idx_image2]]
        y_triplets[i+1] = keep_labels[idx_image2]
        
        
        # Computes the distance between the chosen image and the rest of the other classes
        not_keep = np.logical_not(keep)
        
        if use_neg:
            dist_other = np.sum(np.square(predict[not_keep]-predict[keep][idx_image1]),axis=-1)
            idx_image3 = np.argmin(dist_other) 
        else:
            idx_image3 = np.random.randint(len(filenames[not_keep]))
            
        triplets += [filenames[not_keep][idx_image3]]
        y_triplets[i+2] = labels[not_keep][idx_image3]

    return triplets, y_triplets

# %%
def load_images(filenames):
    h,w,c = SIZE
    #print(filenames)
    images = np.empty((len(filenames),h,w,c))
    for i,f in enumerate(filenames):
        #print(f)
        images[i] = sk.io.imread(f)/255.0
    return images

# %%
def image_generator(filenames, labels, batch_size=63, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_triplets_batch(filenames, labels, batch_size)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def hard_image_generator(filenames, labels, predict, batch_size=63, use_neg=True, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_hard_triplets_batch(filenames, labels, predict, batch_size, use_neg=use_neg)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
# Test normal triplets
for a,y in image_generator(filenames_train,labels_train,9):
    for i in range(3):
        for j in range(3):
            plt.subplot(3,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    break

# %%
fs = filenames_train[np.equal(labels_train,745)]
print(fs)
ise = load_images(fs)
for i in range(len(ise)):
    plt.subplot(len(ise),5,i+1)
    plt.imshow(ise[i])

# %%
# Test hard triplets
batch_predict = 32

#predict_train = np.random.random((len(labels_train),1))
predict_train = model.predict_generator(predict_generator(filenames_train, batch_predict),
                                  steps=np.ceil(len(filenames_train)/batch_predict))
disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in hard_image_generator(filenames_train,labels_train, predict_train, disp*3, use_neg=False):
    for i in range(10):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    print(y)
    break
# Out:
# [ 740.  740.  833.  805.  805.  844. 1067. 1067.  779.  613.  613.  819.
#   849.  849. 1053. 1315. 1315.  630. 1001. 1001.  637. 1617. 1617. 1311.
#  1269. 1269. 1216.  725.  725.  817.]

# %%
def predict_generator(filenames, batch_size=32):
    for i in range(0,len(filenames),batch_size):
        images_batch = load_images(filenames[i:i+batch_size])
        yield images_batch

# %%
# Test predict_generator
batch_predict = 32
predict_train = model.predict_generator(predict_generator(filenames_train, batch_predict),
                                  steps=np.ceil(len(filenames_train)/batch_predict))
print(len(predict_train))
# Out:
# 8241

# %% [markdown]
# Triplet test definition

# %%
h,w,c = SIZE
images_test = np.empty((len(filenames_test),h,w,c))
for i,f in enumerate(filenames_test):
    images_test[i] = sk.io.imread(f)

# %%
#triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %% [markdown]
# ### Loss definition

# %%
alpha = 0.3
def triplet(y_true,y_pred):
    
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)

    return K.sum(tf.nn.relu(ap - an + alpha))

# %% [markdown]
# ### Metric definition

# %%
def triplet_acc(y_true,y_pred):
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)
    
    return K.less(ap+alpha,an)

# %% [markdown]
# ### Model definition

# %%
# inception net small

emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v25: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(64, (7, 7), strides=(2,2), use_bias=False, padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3,3),strides=(2,2))(x)

for layer in [128,256]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, padding='same')(x)
    r = BatchNormalization()(x)
    r = Activation('relu')(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    r = Add()([r,x])
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Add()([r,x])

    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.6)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_27 (InputLayer)           (None, 151, 151, 3)  0
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 76, 76, 64)   9408        input_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 76, 76, 64)   256         conv2d_255[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 76, 76, 64)   0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_65 (MaxPooling2D) (None, 37, 37, 64)   0           activation_255[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 19, 19, 128)  73728       max_pooling2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 19, 19, 128)  512         conv2d_256[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 19, 19, 128)  0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 19, 19, 128)  147456      activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 19, 19, 128)  512         conv2d_257[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 19, 19, 128)  0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# add_152 (Add)                   (None, 19, 19, 128)  0           activation_256[0][0]
#                                                                  activation_257[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 19, 19, 128)  147456      add_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 19, 19, 128)  512         conv2d_258[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 19, 19, 128)  0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# add_153 (Add)                   (None, 19, 19, 128)  0           add_152[0][0]
#                                                                  activation_258[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 10, 10, 256)  294912      add_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 10, 10, 256)  1024        conv2d_259[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 10, 10, 256)  0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 10, 10, 256)  589824      activation_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 10, 10, 256)  1024        conv2d_260[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 10, 10, 256)  0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# add_154 (Add)                   (None, 10, 10, 256)  0           activation_259[0][0]
#                                                                  activation_260[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 10, 10, 256)  589824      add_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 10, 10, 256)  1024        conv2d_261[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 10, 10, 256)  0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 10, 10, 256)  0           add_154[0][0]
#                                                                  activation_261[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_18 (Gl (None, 256)          0           add_155[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 256)          0           global_average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 256)          0           flatten_18[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 64)           16384       dropout_18[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 64)           0           dense_18[0][0]
# ==================================================================================================
# Total params: 1,873,856
# Trainable params: 1,871,424
# Non-trainable params: 2,432
# __________________________________________________________________________________________________

# %%
# dogfacenet_v11: VGG like
emb_size = 16

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(104, 104, 3)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(1024, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(emb_size))
model.add(Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1)))

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v12: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           (None, 151, 151, 3)  0
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 151, 151, 16) 2352        input_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 151, 151, 16) 64          conv2d_262[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 76, 76, 16)   2304        batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 76, 76, 16)   64          conv2d_263[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 76, 76, 16)   0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 76, 76, 16)   2304        dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 76, 76, 16)   64          conv2d_264[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 76, 76, 16)   0           dropout_19[0][0]
#                                                                  batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 76, 76, 16)   0           add_156[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 76, 76, 16)   2304        dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 76, 76, 16)   64          conv2d_265[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 76, 76, 16)   0           dropout_20[0][0]
#                                                                  batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 76, 76, 16)   0           add_157[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 38, 38, 32)   4608        dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 38, 38, 32)   128         conv2d_266[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 38, 38, 32)   0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 38, 38, 32)   9216        dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 38, 38, 32)   128         conv2d_267[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 38, 38, 32)   0           dropout_22[0][0]
#                                                                  batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 38, 38, 32)   0           add_158[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 38, 38, 32)   9216        dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 38, 38, 32)   128         conv2d_268[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 38, 38, 32)   0           dropout_23[0][0]
#                                                                  batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 38, 38, 32)   0           add_159[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 19, 19, 64)   18432       dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 19, 19, 64)   256         conv2d_269[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 19, 19, 64)   0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 19, 19, 64)   36864       dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 19, 19, 64)   256         conv2d_270[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 19, 19, 64)   0           dropout_25[0][0]
#                                                                  batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 19, 19, 64)   0           add_160[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 19, 19, 64)   36864       dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 19, 19, 64)   256         conv2d_271[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 19, 19, 64)   0           dropout_26[0][0]
#                                                                  batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 19, 19, 64)   0           add_161[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 10, 10, 128)  73728       dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 10, 10, 128)  512         conv2d_272[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 10, 10, 128)  0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 10, 10, 128)  147456      dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 10, 10, 128)  512         conv2d_273[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 10, 10, 128)  0           dropout_28[0][0]
#                                                                  batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 10, 10, 128)  0           add_162[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 10, 10, 128)  147456      dropout_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 10, 10, 128)  512         conv2d_274[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 10, 10, 128)  0           dropout_29[0][0]
#                                                                  batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 10, 10, 128)  0           add_163[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 5, 5, 512)    589824      dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 5, 5, 512)    2048        conv2d_275[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 5, 5, 512)    0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 5, 5, 512)    2359296     dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 5, 5, 512)    2048        conv2d_276[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 5, 5, 512)    0           dropout_31[0][0]
#                                                                  batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 5, 5, 512)    0           add_164[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 5, 5, 512)    2359296     dropout_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 5, 5, 512)    2048        conv2d_277[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 5, 5, 512)    0           dropout_32[0][0]
#                                                                  batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 5, 5, 512)    0           add_165[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_19 (Gl (None, 512)          0           dropout_33[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 512)          0           global_average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 512)          0           flatten_19[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 64)           32768       dropout_34[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 64)           0           dense_19[0][0]
# ==================================================================================================
# Total params: 5,843,376
# Trainable params: 5,838,832
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
# dogfacenet_v12: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
#     x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_29 (InputLayer)           (None, 151, 151, 3)  0
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 151, 151, 16) 2352        input_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 151, 151, 16) 64          conv2d_278[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 76, 76, 16)   2304        batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 76, 76, 16)   64          conv2d_279[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 76, 76, 16)   2304        batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 76, 76, 16)   64          conv2d_280[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 76, 76, 16)   0           batch_normalization_279[0][0]
#                                                                  batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 76, 76, 16)   2304        add_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 76, 76, 16)   64          conv2d_281[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 76, 76, 16)   0           add_166[0][0]
#                                                                  batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 38, 38, 32)   4608        add_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 38, 38, 32)   128         conv2d_282[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 38, 38, 32)   9216        batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 38, 38, 32)   128         conv2d_283[0][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 38, 38, 32)   0           batch_normalization_282[0][0]
#                                                                  batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 38, 38, 32)   9216        add_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 38, 38, 32)   128         conv2d_284[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 38, 38, 32)   0           add_168[0][0]
#                                                                  batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 19, 19, 64)   18432       add_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 19, 19, 64)   256         conv2d_285[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 19, 19, 64)   36864       batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 19, 19, 64)   256         conv2d_286[0][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 19, 19, 64)   0           batch_normalization_285[0][0]
#                                                                  batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 19, 19, 64)   36864       add_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 19, 19, 64)   256         conv2d_287[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 19, 19, 64)   0           add_170[0][0]
#                                                                  batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 10, 10, 128)  73728       add_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 10, 10, 128)  512         conv2d_288[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 10, 10, 128)  147456      batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 10, 10, 128)  512         conv2d_289[0][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 10, 10, 128)  0           batch_normalization_288[0][0]
#                                                                  batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 10, 10, 128)  147456      add_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 10, 10, 128)  512         conv2d_290[0][0]
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 10, 10, 128)  0           add_172[0][0]
#                                                                  batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 5, 5, 512)    589824      add_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 5, 5, 512)    2048        conv2d_291[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 5, 5, 512)    2359296     batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 5, 5, 512)    2048        conv2d_292[0][0]
# __________________________________________________________________________________________________
# add_174 (Add)                   (None, 5, 5, 512)    0           batch_normalization_291[0][0]
#                                                                  batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 5, 5, 512)    2359296     add_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 5, 5, 512)    2048        conv2d_293[0][0]
# __________________________________________________________________________________________________
# add_175 (Add)                   (None, 5, 5, 512)    0           add_174[0][0]
#                                                                  batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_20 (Gl (None, 512)          0           add_175[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 512)          0           global_average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 512)          0           flatten_20[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 64)           32768       dropout_35[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 64)           0           dense_20[0][0]
# ==================================================================================================
# Total params: 5,843,376
# Trainable params: 5,838,832
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.13.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
histories = []

# %%
histories += [model.fit_generator(
    hard_image_generator(filenames_train,labels_train,predict_train,3*40),
    steps_per_epoch=500,
    epochs=1,
    validation_data=image_generator(filenames_test,labels_test,3*40,False),
    validation_steps=30
)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-72466c63b2cf> in <module>()
#       1 histories += [model.fit_generator(
# ----> 2     hard_image_generator(filenames_train,labels_train,predict_train,3*40),
#       3     steps_per_epoch=500,
#       4     epochs=1,
#       5     validation_data=image_generator(filenames_test,labels_test,3*40,False),
#
# NameError: name 'predict_train' is not defined

# %%
# With hard triplet generation
for i in range(20):
    predict_train = model.predict_generator(predict_generator(filenames_train, 32),
                                  steps=np.ceil(len(filenames_train)/32))
    histories += [model.fit_generator(
        hard_image_generator(filenames_train,labels_train,predict_train,3*10,use_neg=False),
        steps_per_epoch=500,
        epochs=4,
        validation_data=image_generator(filenames_test,labels_test,3*10,False),
        validation_steps=30
    )]
    model.save(PATH_MODEL + '2019.04.15.dogfacenet_v12.lfw.'+str(i)+'.h5')
# Out:
# Epoch 1/4
# 170/500 [=========>....................] - ETA: 54:59 - loss: 2.0988 - triplet_acc: 0.50 - ETA: 28:13 - loss: 2.7460 - triplet_acc: 0.45 - ETA: 19:17 - loss: 4.3282 - triplet_acc: 0.40 - ETA: 14:50 - loss: 4.7978 - triplet_acc: 0.40 - ETA: 12:09 - loss: 4.3276 - triplet_acc: 0.46 - ETA: 10:22 - loss: 3.8977 - triplet_acc: 0.50 - ETA: 9:05 - loss: 4.8466 - triplet_acc: 0.4571 - ETA: 8:07 - loss: 4.8645 - triplet_acc: 0.437 - ETA: 7:23 - loss: 4.9908 - triplet_acc: 0.444 - ETA: 6:47 - loss: 5.2060 - triplet_acc: 0.440 - ETA: 6:17 - loss: 5.0626 - triplet_acc: 0.436 - ETA: 5:53 - loss: 4.7791 - triplet_acc: 0.458 - ETA: 5:32 - loss: 4.6046 - triplet_acc: 0.469 - ETA: 5:14 - loss: 4.5045 - triplet_acc: 0.478 - ETA: 4:59 - loss: 4.4132 - triplet_acc: 0.493 - ETA: 4:45 - loss: 4.3068 - triplet_acc: 0.506 - ETA: 4:33 - loss: 4.5622 - triplet_acc: 0.494 - ETA: 4:22 - loss: 4.7349 - triplet_acc: 0.483 - ETA: 4:13 - loss: 4.7006 - triplet_acc: 0.484 - ETA: 4:04 - loss: 4.7399 - triplet_acc: 0.480 - ETA: 3:56 - loss: 4.8080 - triplet_acc: 0.471 - ETA: 3:49 - loss: 4.6456 - triplet_acc: 0.481 - ETA: 3:43 - loss: 4.6949 - triplet_acc: 0.478 - ETA: 3:37 - loss: 4.7311 - triplet_acc: 0.470 - ETA: 3:31 - loss: 4.7162 - triplet_acc: 0.476 - ETA: 3:28 - loss: 4.6534 - triplet_acc: 0.480 - ETA: 3:25 - loss: 4.6027 - triplet_acc: 0.488 - ETA: 3:22 - loss: 4.6635 - triplet_acc: 0.478 - ETA: 3:19 - loss: 4.6296 - triplet_acc: 0.479 - ETA: 3:17 - loss: 4.5218 - triplet_acc: 0.483 - ETA: 3:14 - loss: 4.5135 - triplet_acc: 0.490 - ETA: 3:12 - loss: 4.5387 - triplet_acc: 0.484 - ETA: 3:10 - loss: 4.5559 - triplet_acc: 0.481 - ETA: 3:08 - loss: 4.4966 - triplet_acc: 0.485 - ETA: 3:06 - loss: 4.4401 - triplet_acc: 0.491 - ETA: 3:04 - loss: 4.4634 - triplet_acc: 0.488 - ETA: 3:02 - loss: 4.4062 - triplet_acc: 0.494 - ETA: 3:00 - loss: 4.3362 - triplet_acc: 0.500 - ETA: 2:59 - loss: 4.3236 - triplet_acc: 0.497 - ETA: 2:57 - loss: 4.3650 - triplet_acc: 0.502 - ETA: 2:55 - loss: 4.4468 - triplet_acc: 0.492 - ETA: 2:54 - loss: 4.4385 - triplet_acc: 0.495 - ETA: 2:53 - loss: 4.4049 - triplet_acc: 0.500 - ETA: 2:51 - loss: 4.4465 - triplet_acc: 0.490 - ETA: 2:50 - loss: 4.4186 - triplet_acc: 0.488 - ETA: 2:49 - loss: 4.4325 - triplet_acc: 0.489 - ETA: 2:47 - loss: 4.3909 - triplet_acc: 0.493 - ETA: 2:46 - loss: 4.3957 - triplet_acc: 0.487 - ETA: 2:45 - loss: 4.3828 - triplet_acc: 0.487 - ETA: 2:44 - loss: 4.3509 - triplet_acc: 0.488 - ETA: 2:43 - loss: 4.3713 - triplet_acc: 0.484 - ETA: 2:42 - loss: 4.4094 - triplet_acc: 0.480 - ETA: 2:41 - loss: 4.3901 - triplet_acc: 0.481 - ETA: 2:40 - loss: 4.3486 - triplet_acc: 0.485 - ETA: 2:39 - loss: 4.3612 - triplet_acc: 0.485 - ETA: 2:38 - loss: 4.4008 - triplet_acc: 0.480 - ETA: 2:37 - loss: 4.3692 - triplet_acc: 0.480 - ETA: 2:36 - loss: 4.3746 - triplet_acc: 0.481 - ETA: 2:35 - loss: 4.3834 - triplet_acc: 0.481 - ETA: 2:35 - loss: 4.3309 - triplet_acc: 0.486 - ETA: 2:34 - loss: 4.3388 - triplet_acc: 0.483 - ETA: 2:34 - loss: 4.3132 - triplet_acc: 0.482 - ETA: 2:33 - loss: 4.3143 - triplet_acc: 0.476 - ETA: 2:32 - loss: 4.3023 - triplet_acc: 0.473 - ETA: 2:32 - loss: 4.2906 - triplet_acc: 0.472 - ETA: 2:31 - loss: 4.2534 - triplet_acc: 0.477 - ETA: 2:30 - loss: 4.2337 - triplet_acc: 0.477 - ETA: 2:30 - loss: 4.2231 - triplet_acc: 0.476 - ETA: 2:29 - loss: 4.1816 - triplet_acc: 0.478 - ETA: 2:28 - loss: 4.2013 - triplet_acc: 0.474 - ETA: 2:27 - loss: 4.1973 - triplet_acc: 0.474 - ETA: 2:27 - loss: 4.1924 - triplet_acc: 0.475 - ETA: 2:26 - loss: 4.1870 - triplet_acc: 0.475 - ETA: 2:26 - loss: 4.1850 - triplet_acc: 0.475 - ETA: 2:25 - loss: 4.2284 - triplet_acc: 0.470 - ETA: 2:24 - loss: 4.2182 - triplet_acc: 0.472 - ETA: 2:24 - loss: 4.2624 - triplet_acc: 0.468 - ETA: 2:23 - loss: 4.2871 - triplet_acc: 0.466 - ETA: 2:23 - loss: 4.3098 - triplet_acc: 0.462 - ETA: 2:22 - loss: 4.3049 - triplet_acc: 0.462 - ETA: 2:21 - loss: 4.2860 - triplet_acc: 0.463 - ETA: 2:21 - loss: 4.2825 - triplet_acc: 0.465 - ETA: 2:20 - loss: 4. ...
# 229/500 [============>.................] - ETA: 1:45 - loss: 4.2132 - triplet_acc: 0.440 - ETA: 1:44 - loss: 4.2106 - triplet_acc: 0.441 - ETA: 1:44 - loss: 4.1981 - triplet_acc: 0.441 - ETA: 1:44 - loss: 4.1963 - triplet_acc: 0.441 - ETA: 1:43 - loss: 4.1972 - triplet_acc: 0.440 - ETA: 1:43 - loss: 4.1912 - triplet_acc: 0.440 - ETA: 1:43 - loss: 4.1823 - triplet_acc: 0.441 - ETA: 1:42 - loss: 4.1811 - triplet_acc: 0.440 - ETA: 1:42 - loss: 4.1762 - triplet_acc: 0.441 - ETA: 1:42 - loss: 4.1711 - triplet_acc: 0.441 - ETA: 1:41 - loss: 4.1639 - triplet_acc: 0.441 - ETA: 1:41 - loss: 4.1663 - triplet_acc: 0.440 - ETA: 1:41 - loss: 4.1712 - triplet_acc: 0.439 - ETA: 1:40 - loss: 4.1791 - triplet_acc: 0.439 - ETA: 1:40 - loss: 4.1813 - triplet_acc: 0.438 - ETA: 1:39 - loss: 4.1830 - triplet_acc: 0.438 - ETA: 1:39 - loss: 4.2006 - triplet_acc: 0.437 - ETA: 1:39 - loss: 4.1961 - triplet_acc: 0.436 - ETA: 1:38 - loss: 4.1766 - triplet_acc: 0.439 - ETA: 1:38 - loss: 4.1644 - triplet_acc: 0.439 - ETA: 1:38 - loss: 4.1562 - triplet_acc: 0.441 - ETA: 1:37 - loss: 4.1551 - triplet_acc: 0.441 - ETA: 1:37 - loss: 4.1671 - triplet_acc: 0.440 - ETA: 1:37 - loss: 4.1585 - triplet_acc: 0.440 - ETA: 1:36 - loss: 4.1585 - triplet_acc: 0.440 - ETA: 1:36 - loss: 4.1458 - triplet_acc: 0.441 - ETA: 1:36 - loss: 4.1449 - triplet_acc: 0.440 - ETA: 1:35 - loss: 4.1600 - triplet_acc: 0.441 - ETA: 1:35 - loss: 4.1618 - triplet_acc: 0.440 - ETA: 1:34 - loss: 4.1696 - triplet_acc: 0.439 - ETA: 1:34 - loss: 4.1624 - triplet_acc: 0.439 - ETA: 1:34 - loss: 4.1637 - triplet_acc: 0.439 - ETA: 1:33 - loss: 4.1561 - triplet_acc: 0.439 - ETA: 1:33 - loss: 4.1629 - triplet_acc: 0.438 - ETA: 1:33 - loss: 4.1516 - triplet_acc: 0.439 - ETA: 1:32 - loss: 4.1399 - triplet_acc: 0.440 - ETA: 1:32 - loss: 4.1232 - triplet_acc: 0.442 - ETA: 1:32 - loss: 4.1209 - triplet_acc: 0.441 - ETA: 1:31 - loss: 4.1323 - triplet_acc: 0.441 - ETA: 1:31 - loss: 4.1317 - triplet_acc: 0.441 - ETA: 1:31 - loss: 4.1206 - triplet_acc: 0.442 - ETA: 1:30 - loss: 4.1262 - triplet_acc: 0.442 - ETA: 1:30 - loss: 4.1221 - triplet_acc: 0.442 - ETA: 1:30 - loss: 4.1229 - triplet_acc: 0.442 - ETA: 1:29 - loss: 4.1190 - triplet_acc: 0.441 - ETA: 1:29 - loss: 4.1264 - triplet_acc: 0.440 - ETA: 1:29 - loss: 4.1244 - triplet_acc: 0.439 - ETA: 1:28 - loss: 4.1106 - triplet_acc: 0.439 - ETA: 1:28 - loss: 4.1157 - triplet_acc: 0.438 - ETA: 1:28 - loss: 4.1153 - triplet_acc: 0.438 - ETA: 1:27 - loss: 4.1148 - triplet_acc: 0.438 - ETA: 1:27 - loss: 4.1117 - triplet_acc: 0.437 - ETA: 1:27 - loss: 4.1002 - triplet_acc: 0.438 - ETA: 1:26 - loss: 4.1107 - triplet_acc: 0.437 - ETA: 1:26 - loss: 4.1141 - triplet_acc: 0.436 - ETA: 1:26 - loss: 4.1015 - triplet_acc: 0.437 - ETA: 1:25 - loss: 4.0882 - triplet_acc: 0.438 - ETA: 1:25 - loss: 4.0836 - triplet_acc: 0.439 - ETA: 1:25 - loss: 4.0933 - triplet_acc: 0.4380
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-c90871154236> in <module>()
#       8         epochs=4,
#       9         validation_data=image_generator(filenames_test,labels_test,3*10,False),
# ---> 10         validation_steps=30
#      11     )]
#      12     model.save(PATH_MODEL + '2019.04.15.dogfacenet_v12.lfw.'+str(i)+'.h5')
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     145       batch_index = 0
#     146       while steps_done < steps_per_epoch:
# --> 147         generator_output = next(output_generator)
#     148
#     149         if not hasattr(generator_output, '__len__'):
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     823           raise StopIteration()
#     824         else:
# --> 825           time.sleep(self.wait_time)
#     826
#     827     # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(1)+'.h5')

# %%
# Without hard triplet generation
#histories = []
for i in range(30):
    print("Epoch: " + str(i))
    histories += [model.fit_generator(
        image_generator(filenames_train,labels_train,3*10),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*10,False),
        validation_steps=30
    )]
# Out:
# Epoch: 0
# Epoch 1/1
# 177/300 [================>.............] - ETA: 3:27 - loss: 0.5099 - triplet_acc: 0.700 - ETA: 2:06 - loss: 1.8670 - triplet_acc: 0.600 - ETA: 1:38 - loss: 1.4862 - triplet_acc: 0.566 - ETA: 1:24 - loss: 1.3439 - triplet_acc: 0.600 - ETA: 1:16 - loss: 1.4548 - triplet_acc: 0.600 - ETA: 1:10 - loss: 1.4931 - triplet_acc: 0.583 - ETA: 1:07 - loss: 1.4119 - triplet_acc: 0.571 - ETA: 1:03 - loss: 1.4924 - triplet_acc: 0.575 - ETA: 1:01 - loss: 1.4419 - triplet_acc: 0.600 - ETA: 59s - loss: 1.4750 - triplet_acc: 0.590 - ETA: 57s - loss: 1.3884 - triplet_acc: 0.60 - ETA: 56s - loss: 1.4150 - triplet_acc: 0.59 - ETA: 56s - loss: 1.4084 - triplet_acc: 0.59 - ETA: 55s - loss: 1.5513 - triplet_acc: 0.57 - ETA: 55s - loss: 1.5303 - triplet_acc: 0.56 - ETA: 54s - loss: 1.5929 - triplet_acc: 0.56 - ETA: 54s - loss: 1.6190 - triplet_acc: 0.54 - ETA: 54s - loss: 1.6653 - triplet_acc: 0.53 - ETA: 54s - loss: 1.6851 - triplet_acc: 0.52 - ETA: 53s - loss: 1.7069 - triplet_acc: 0.51 - ETA: 53s - loss: 1.7111 - triplet_acc: 0.50 - ETA: 53s - loss: 1.6812 - triplet_acc: 0.51 - ETA: 53s - loss: 1.6392 - triplet_acc: 0.52 - ETA: 53s - loss: 1.7394 - triplet_acc: 0.51 - ETA: 52s - loss: 1.7917 - triplet_acc: 0.50 - ETA: 52s - loss: 1.7333 - triplet_acc: 0.51 - ETA: 52s - loss: 1.7180 - triplet_acc: 0.51 - ETA: 51s - loss: 1.6878 - triplet_acc: 0.51 - ETA: 51s - loss: 1.6910 - triplet_acc: 0.51 - ETA: 51s - loss: 1.6959 - triplet_acc: 0.51 - ETA: 51s - loss: 1.6974 - triplet_acc: 0.50 - ETA: 51s - loss: 1.6504 - triplet_acc: 0.52 - ETA: 51s - loss: 1.6450 - triplet_acc: 0.51 - ETA: 50s - loss: 1.6482 - triplet_acc: 0.51 - ETA: 50s - loss: 1.6124 - triplet_acc: 0.52 - ETA: 50s - loss: 1.5991 - triplet_acc: 0.52 - ETA: 49s - loss: 1.5579 - triplet_acc: 0.53 - ETA: 49s - loss: 1.5673 - triplet_acc: 0.53 - ETA: 49s - loss: 1.5540 - triplet_acc: 0.53 - ETA: 49s - loss: 1.5413 - triplet_acc: 0.53 - ETA: 49s - loss: 1.5095 - triplet_acc: 0.54 - ETA: 49s - loss: 1.4886 - triplet_acc: 0.54 - ETA: 48s - loss: 1.5137 - triplet_acc: 0.54 - ETA: 48s - loss: 1.5050 - triplet_acc: 0.54 - ETA: 48s - loss: 1.4940 - triplet_acc: 0.54 - ETA: 48s - loss: 1.4822 - triplet_acc: 0.55 - ETA: 48s - loss: 1.4690 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4519 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4695 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4693 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4471 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4785 - triplet_acc: 0.55 - ETA: 47s - loss: 1.4688 - triplet_acc: 0.55 - ETA: 46s - loss: 1.4520 - triplet_acc: 0.56 - ETA: 46s - loss: 1.4354 - triplet_acc: 0.56 - ETA: 46s - loss: 1.4404 - triplet_acc: 0.56 - ETA: 46s - loss: 1.4320 - triplet_acc: 0.56 - ETA: 46s - loss: 1.4475 - triplet_acc: 0.56 - ETA: 46s - loss: 1.4440 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4335 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4273 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4405 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4243 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4256 - triplet_acc: 0.56 - ETA: 45s - loss: 1.4222 - triplet_acc: 0.56 - ETA: 44s - loss: 1.4176 - triplet_acc: 0.56 - ETA: 44s - loss: 1.4234 - triplet_acc: 0.56 - ETA: 44s - loss: 1.4167 - triplet_acc: 0.56 - ETA: 44s - loss: 1.4017 - triplet_acc: 0.57 - ETA: 44s - loss: 1.3962 - triplet_acc: 0.57 - ETA: 43s - loss: 1.3813 - triplet_acc: 0.57 - ETA: 43s - loss: 1.3643 - triplet_acc: 0.57 - ETA: 43s - loss: 1.3562 - triplet_acc: 0.57 - ETA: 43s - loss: 1.3480 - triplet_acc: 0.57 - ETA: 43s - loss: 1.3529 - triplet_acc: 0.57 - ETA: 42s - loss: 1.3573 - triplet_acc: 0.57 - ETA: 42s - loss: 1.3809 - triplet_acc: 0.57 - ETA: 42s - loss: 1.3806 - triplet_acc: 0.57 - ETA: 42s - loss: 1.3816 - triplet_acc: 0.57 - ETA: 42s - loss: 1.3852 - triplet_acc: 0.57 - ETA: 41s - loss: 1.3781 - triplet_acc: 0.57 - ETA: 41s - loss: 1.3724 - triplet_acc: 0.57 - ETA: 41s - loss: 1.4038 - triplet_acc: 0.56 - ETA: 41s - loss: 1.3894 - triplet_acc: 0.57 - ETA: 41s - loss: 1.3894 - triplet_acc: 0.57 - ETA: 40s - loss: 1.3979 - tr ...
# Epoch: 1
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:37 - loss: 1.0176 - triplet_acc: 0.700 - ETA: 1:15 - loss: 1.5428 - triplet_acc: 0.600 - ETA: 1:09 - loss: 1.2410 - triplet_acc: 0.600 - ETA: 1:05 - loss: 1.2870 - triplet_acc: 0.600 - ETA: 1:03 - loss: 1.3168 - triplet_acc: 0.600 - ETA: 1:00 - loss: 1.1261 - triplet_acc: 0.633 - ETA: 59s - loss: 1.0956 - triplet_acc: 0.642 - ETA: 58s - loss: 1.0523 - triplet_acc: 0.63 - ETA: 57s - loss: 0.9497 - triplet_acc: 0.65 - ETA: 56s - loss: 1.0157 - triplet_acc: 0.65 - ETA: 56s - loss: 1.0746 - triplet_acc: 0.63 - ETA: 55s - loss: 1.1560 - triplet_acc: 0.61 - ETA: 55s - loss: 1.1623 - triplet_acc: 0.60 - ETA: 54s - loss: 1.1690 - triplet_acc: 0.60 - ETA: 54s - loss: 1.2257 - triplet_acc: 0.60 - ETA: 53s - loss: 1.2018 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1862 - triplet_acc: 0.61 - ETA: 53s - loss: 1.1945 - triplet_acc: 0.61 - ETA: 53s - loss: 1.2254 - triplet_acc: 0.60 - ETA: 52s - loss: 1.2530 - triplet_acc: 0.59 - ETA: 52s - loss: 1.2731 - triplet_acc: 0.59 - ETA: 51s - loss: 1.2622 - triplet_acc: 0.59 - ETA: 51s - loss: 1.2515 - triplet_acc: 0.59 - ETA: 51s - loss: 1.2374 - triplet_acc: 0.60 - ETA: 51s - loss: 1.2547 - triplet_acc: 0.60 - ETA: 51s - loss: 1.2515 - triplet_acc: 0.60 - ETA: 51s - loss: 1.2629 - triplet_acc: 0.59 - ETA: 50s - loss: 1.2253 - triplet_acc: 0.59 - ETA: 50s - loss: 1.2190 - triplet_acc: 0.60 - ETA: 50s - loss: 1.1901 - triplet_acc: 0.60 - ETA: 50s - loss: 1.1685 - triplet_acc: 0.60 - ETA: 50s - loss: 1.1543 - triplet_acc: 0.61 - ETA: 50s - loss: 1.1349 - triplet_acc: 0.62 - ETA: 49s - loss: 1.1310 - triplet_acc: 0.62 - ETA: 49s - loss: 1.1217 - triplet_acc: 0.62 - ETA: 49s - loss: 1.1004 - triplet_acc: 0.63 - ETA: 49s - loss: 1.0827 - triplet_acc: 0.62 - ETA: 49s - loss: 1.0636 - triplet_acc: 0.63 - ETA: 48s - loss: 1.0474 - triplet_acc: 0.64 - ETA: 48s - loss: 1.0510 - triplet_acc: 0.63 - ETA: 48s - loss: 1.0311 - triplet_acc: 0.64 - ETA: 48s - loss: 1.0209 - triplet_acc: 0.64 - ETA: 47s - loss: 1.0126 - triplet_acc: 0.64 - ETA: 47s - loss: 1.0029 - triplet_acc: 0.64 - ETA: 47s - loss: 1.0119 - triplet_acc: 0.64 - ETA: 47s - loss: 1.0267 - triplet_acc: 0.64 - ETA: 46s - loss: 1.0566 - triplet_acc: 0.64 - ETA: 46s - loss: 1.0479 - triplet_acc: 0.64 - ETA: 46s - loss: 1.1001 - triplet_acc: 0.64 - ETA: 46s - loss: 1.1047 - triplet_acc: 0.64 - ETA: 46s - loss: 1.0945 - triplet_acc: 0.64 - ETA: 45s - loss: 1.0849 - triplet_acc: 0.64 - ETA: 45s - loss: 1.1153 - triplet_acc: 0.63 - ETA: 45s - loss: 1.1026 - triplet_acc: 0.64 - ETA: 45s - loss: 1.0960 - triplet_acc: 0.64 - ETA: 44s - loss: 1.1139 - triplet_acc: 0.64 - ETA: 44s - loss: 1.1122 - triplet_acc: 0.64 - ETA: 44s - loss: 1.1072 - triplet_acc: 0.64 - ETA: 44s - loss: 1.1015 - triplet_acc: 0.64 - ETA: 44s - loss: 1.0934 - triplet_acc: 0.65 - ETA: 43s - loss: 1.1081 - triplet_acc: 0.64 - ETA: 43s - loss: 1.1185 - triplet_acc: 0.64 - ETA: 43s - loss: 1.1189 - triplet_acc: 0.64 - ETA: 43s - loss: 1.1368 - triplet_acc: 0.64 - ETA: 43s - loss: 1.1279 - triplet_acc: 0.64 - ETA: 42s - loss: 1.1344 - triplet_acc: 0.64 - ETA: 42s - loss: 1.1645 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1633 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1684 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1711 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1824 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1832 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1830 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1731 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1654 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1920 - triplet_acc: 0.63 - ETA: 40s - loss: 1.2105 - triplet_acc: 0.63 - ETA: 40s - loss: 1.2119 - triplet_acc: 0.63 - ETA: 40s - loss: 1.2089 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1958 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1914 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1973 - triplet_acc: 0.63 - ETA: 39s - loss: 1.1998 - triplet_acc: 0.63 - ETA: 39s - loss: 1.2042 - triplet_acc: 0.63 - ETA: 39s - loss: 1.2003 - triplet_acc: 0.63 - ETA: 39s - loss: 1.1965 - triplet_ ...
# 300/300 [==============================] - ETA: 22s - loss: 1.1777 - triplet_acc: 0.63 - ETA: 22s - loss: 1.1782 - triplet_acc: 0.63 - ETA: 22s - loss: 1.1771 - triplet_acc: 0.63 - ETA: 22s - loss: 1.1741 - triplet_acc: 0.63 - ETA: 22s - loss: 1.1764 - triplet_acc: 0.63 - ETA: 21s - loss: 1.1738 - triplet_acc: 0.63 - ETA: 21s - loss: 1.1789 - triplet_acc: 0.62 - ETA: 21s - loss: 1.1760 - triplet_acc: 0.62 - ETA: 21s - loss: 1.1773 - triplet_acc: 0.62 - ETA: 21s - loss: 1.1756 - triplet_acc: 0.62 - ETA: 20s - loss: 1.1736 - triplet_acc: 0.62 - ETA: 20s - loss: 1.1811 - triplet_acc: 0.62 - ETA: 20s - loss: 1.1818 - triplet_acc: 0.62 - ETA: 20s - loss: 1.1836 - triplet_acc: 0.62 - ETA: 20s - loss: 1.1917 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1887 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1931 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1977 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1971 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1947 - triplet_acc: 0.62 - ETA: 19s - loss: 1.1970 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2009 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2034 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2034 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2007 - triplet_acc: 0.62 - ETA: 18s - loss: 1.1990 - triplet_acc: 0.62 - ETA: 17s - loss: 1.1962 - triplet_acc: 0.62 - ETA: 17s - loss: 1.1955 - triplet_acc: 0.62 - ETA: 17s - loss: 1.2048 - triplet_acc: 0.62 - ETA: 17s - loss: 1.2149 - triplet_acc: 0.62 - ETA: 17s - loss: 1.2201 - triplet_acc: 0.62 - ETA: 17s - loss: 1.2183 - triplet_acc: 0.62 - ETA: 16s - loss: 1.2233 - triplet_acc: 0.61 - ETA: 16s - loss: 1.2245 - triplet_acc: 0.61 - ETA: 16s - loss: 1.2212 - triplet_acc: 0.62 - ETA: 16s - loss: 1.2229 - triplet_acc: 0.62 - ETA: 16s - loss: 1.2267 - triplet_acc: 0.62 - ETA: 15s - loss: 1.2229 - triplet_acc: 0.62 - ETA: 15s - loss: 1.2277 - triplet_acc: 0.62 - ETA: 15s - loss: 1.2286 - triplet_acc: 0.62 - ETA: 15s - loss: 1.2325 - triplet_acc: 0.61 - ETA: 15s - loss: 1.2363 - triplet_acc: 0.61 - ETA: 15s - loss: 1.2323 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2342 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2322 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2337 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2370 - triplet_acc: 0.61 - ETA: 14s - loss: 1.2352 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2333 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2344 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2311 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2322 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2299 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2291 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2254 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2289 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2291 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2258 - triplet_acc: 0.61 - ETA: 12s - loss: 1.2238 - triplet_acc: 0.61 - ETA: 11s - loss: 1.2219 - triplet_acc: 0.62 - ETA: 11s - loss: 1.2254 - triplet_acc: 0.61 - ETA: 11s - loss: 1.2242 - triplet_acc: 0.61 - ETA: 11s - loss: 1.2231 - triplet_acc: 0.61 - ETA: 11s - loss: 1.2249 - triplet_acc: 0.61 - ETA: 10s - loss: 1.2284 - triplet_acc: 0.61 - ETA: 10s - loss: 1.2250 - triplet_acc: 0.61 - ETA: 10s - loss: 1.2220 - triplet_acc: 0.61 - ETA: 10s - loss: 1.2236 - triplet_acc: 0.61 - ETA: 10s - loss: 1.2272 - triplet_acc: 0.61 - ETA: 9s - loss: 1.2285 - triplet_acc: 0.6162 - ETA: 9s - loss: 1.2310 - triplet_acc: 0.615 - ETA: 9s - loss: 1.2300 - triplet_acc: 0.614 - ETA: 9s - loss: 1.2310 - triplet_acc: 0.614 - ETA: 9s - loss: 1.2325 - triplet_acc: 0.613 - ETA: 9s - loss: 1.2303 - triplet_acc: 0.614 - ETA: 8s - loss: 1.2298 - triplet_acc: 0.615 - ETA: 8s - loss: 1.2310 - triplet_acc: 0.615 - ETA: 8s - loss: 1.2317 - triplet_acc: 0.614 - ETA: 8s - loss: 1.2329 - triplet_acc: 0.614 - ETA: 8s - loss: 1.2308 - triplet_acc: 0.615 - ETA: 7s - loss: 1.2331 - triplet_acc: 0.615 - ETA: 7s - loss: 1.2321 - triplet_acc: 0.615 - ETA: 7s - loss: 1.2331 - triplet_acc: 0.614 - ETA: 7s - loss: 1.2288 - triplet_acc: 0.615 - ETA: 7s - loss: 1.2256 - triplet_acc: 0.615 - ETA: 6s - loss: 1.2220 - triplet_acc: 0.616 -  ...
# Epoch: 2
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:38 - loss: 1.3725 - triplet_acc: 0.500 - ETA: 1:15 - loss: 1.0875 - triplet_acc: 0.600 - ETA: 1:10 - loss: 1.2923 - triplet_acc: 0.633 - ETA: 1:10 - loss: 1.4415 - triplet_acc: 0.625 - ETA: 1:08 - loss: 1.3871 - triplet_acc: 0.660 - ETA: 1:05 - loss: 1.5308 - triplet_acc: 0.633 - ETA: 1:03 - loss: 1.6526 - triplet_acc: 0.642 - ETA: 1:02 - loss: 1.6133 - triplet_acc: 0.650 - ETA: 1:01 - loss: 1.7501 - triplet_acc: 0.622 - ETA: 1:00 - loss: 1.7288 - triplet_acc: 0.600 - ETA: 59s - loss: 1.6754 - triplet_acc: 0.600 - ETA: 58s - loss: 1.5979 - triplet_acc: 0.60 - ETA: 58s - loss: 1.5907 - triplet_acc: 0.60 - ETA: 57s - loss: 1.5513 - triplet_acc: 0.60 - ETA: 57s - loss: 1.4893 - triplet_acc: 0.60 - ETA: 56s - loss: 1.4619 - triplet_acc: 0.60 - ETA: 56s - loss: 1.4819 - triplet_acc: 0.60 - ETA: 55s - loss: 1.4722 - triplet_acc: 0.60 - ETA: 55s - loss: 1.4109 - triplet_acc: 0.61 - ETA: 55s - loss: 1.4375 - triplet_acc: 0.60 - ETA: 54s - loss: 1.4258 - triplet_acc: 0.60 - ETA: 54s - loss: 1.3698 - triplet_acc: 0.61 - ETA: 54s - loss: 1.3354 - triplet_acc: 0.62 - ETA: 54s - loss: 1.3382 - triplet_acc: 0.62 - ETA: 53s - loss: 1.3653 - triplet_acc: 0.62 - ETA: 53s - loss: 1.4322 - triplet_acc: 0.61 - ETA: 53s - loss: 1.4241 - triplet_acc: 0.60 - ETA: 52s - loss: 1.4058 - triplet_acc: 0.61 - ETA: 52s - loss: 1.3675 - triplet_acc: 0.62 - ETA: 52s - loss: 1.3602 - triplet_acc: 0.61 - ETA: 51s - loss: 1.3894 - triplet_acc: 0.60 - ETA: 51s - loss: 1.3796 - triplet_acc: 0.61 - ETA: 51s - loss: 1.3704 - triplet_acc: 0.61 - ETA: 51s - loss: 1.3522 - triplet_acc: 0.61 - ETA: 50s - loss: 1.3753 - triplet_acc: 0.61 - ETA: 50s - loss: 1.3694 - triplet_acc: 0.61 - ETA: 50s - loss: 1.3484 - triplet_acc: 0.61 - ETA: 49s - loss: 1.3331 - triplet_acc: 0.61 - ETA: 49s - loss: 1.3218 - triplet_acc: 0.61 - ETA: 49s - loss: 1.3175 - triplet_acc: 0.62 - ETA: 49s - loss: 1.3025 - triplet_acc: 0.62 - ETA: 49s - loss: 1.2781 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2733 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2701 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2504 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2368 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2221 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2379 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2402 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2655 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2643 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2816 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2656 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2552 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2591 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2453 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2471 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2459 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2587 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2596 - triplet_acc: 0.62 - ETA: 45s - loss: 1.2432 - triplet_acc: 0.62 - ETA: 45s - loss: 1.2422 - triplet_acc: 0.62 - ETA: 45s - loss: 1.2354 - triplet_acc: 0.63 - ETA: 45s - loss: 1.2439 - triplet_acc: 0.62 - ETA: 45s - loss: 1.2365 - triplet_acc: 0.63 - ETA: 44s - loss: 1.2375 - triplet_acc: 0.62 - ETA: 44s - loss: 1.2342 - triplet_acc: 0.62 - ETA: 44s - loss: 1.2225 - triplet_acc: 0.62 - ETA: 44s - loss: 1.2222 - triplet_acc: 0.62 - ETA: 44s - loss: 1.2115 - triplet_acc: 0.63 - ETA: 44s - loss: 1.2056 - triplet_acc: 0.63 - ETA: 43s - loss: 1.1976 - triplet_acc: 0.63 - ETA: 43s - loss: 1.2142 - triplet_acc: 0.63 - ETA: 43s - loss: 1.2163 - triplet_acc: 0.62 - ETA: 43s - loss: 1.2129 - triplet_acc: 0.63 - ETA: 43s - loss: 1.2041 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1983 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1957 - triplet_acc: 0.63 - ETA: 42s - loss: 1.2027 - triplet_acc: 0.63 - ETA: 42s - loss: 1.2019 - triplet_acc: 0.63 - ETA: 42s - loss: 1.1949 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1843 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1908 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1871 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1967 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1872 -  ...
# Epoch: 3
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:37 - loss: 0.9590 - triplet_acc: 0.500 - ETA: 1:17 - loss: 0.9755 - triplet_acc: 0.550 - ETA: 1:12 - loss: 1.0259 - triplet_acc: 0.533 - ETA: 1:07 - loss: 0.8990 - triplet_acc: 0.575 - ETA: 1:04 - loss: 0.8441 - triplet_acc: 0.600 - ETA: 1:02 - loss: 0.8801 - triplet_acc: 0.583 - ETA: 1:01 - loss: 0.9042 - triplet_acc: 0.614 - ETA: 1:00 - loss: 0.9323 - triplet_acc: 0.600 - ETA: 58s - loss: 0.8847 - triplet_acc: 0.611 - ETA: 58s - loss: 1.0094 - triplet_acc: 0.60 - ETA: 57s - loss: 1.0029 - triplet_acc: 0.60 - ETA: 57s - loss: 1.1826 - triplet_acc: 0.58 - ETA: 56s - loss: 1.2218 - triplet_acc: 0.56 - ETA: 55s - loss: 1.1861 - triplet_acc: 0.57 - ETA: 55s - loss: 1.2082 - triplet_acc: 0.58 - ETA: 54s - loss: 1.1950 - triplet_acc: 0.58 - ETA: 54s - loss: 1.2469 - triplet_acc: 0.58 - ETA: 53s - loss: 1.2098 - triplet_acc: 0.59 - ETA: 53s - loss: 1.1886 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1532 - triplet_acc: 0.61 - ETA: 52s - loss: 1.1776 - triplet_acc: 0.60 - ETA: 52s - loss: 1.1363 - triplet_acc: 0.61 - ETA: 52s - loss: 1.1547 - triplet_acc: 0.61 - ETA: 52s - loss: 1.1398 - triplet_acc: 0.61 - ETA: 51s - loss: 1.1544 - triplet_acc: 0.61 - ETA: 51s - loss: 1.1446 - triplet_acc: 0.62 - ETA: 51s - loss: 1.1659 - triplet_acc: 0.62 - ETA: 51s - loss: 1.2255 - triplet_acc: 0.62 - ETA: 51s - loss: 1.2431 - triplet_acc: 0.61 - ETA: 50s - loss: 1.2416 - triplet_acc: 0.60 - ETA: 50s - loss: 1.2296 - triplet_acc: 0.60 - ETA: 50s - loss: 1.2458 - triplet_acc: 0.60 - ETA: 50s - loss: 1.2184 - triplet_acc: 0.60 - ETA: 49s - loss: 1.2480 - triplet_acc: 0.60 - ETA: 49s - loss: 1.2388 - triplet_acc: 0.60 - ETA: 49s - loss: 1.2204 - triplet_acc: 0.60 - ETA: 49s - loss: 1.2263 - triplet_acc: 0.60 - ETA: 48s - loss: 1.2197 - triplet_acc: 0.60 - ETA: 48s - loss: 1.1914 - triplet_acc: 0.61 - ETA: 48s - loss: 1.2248 - triplet_acc: 0.61 - ETA: 48s - loss: 1.2041 - triplet_acc: 0.61 - ETA: 47s - loss: 1.1769 - triplet_acc: 0.62 - ETA: 47s - loss: 1.1586 - triplet_acc: 0.62 - ETA: 47s - loss: 1.1619 - triplet_acc: 0.62 - ETA: 47s - loss: 1.1367 - triplet_acc: 0.63 - ETA: 47s - loss: 1.1333 - triplet_acc: 0.63 - ETA: 46s - loss: 1.1464 - triplet_acc: 0.62 - ETA: 46s - loss: 1.1508 - triplet_acc: 0.62 - ETA: 46s - loss: 1.1364 - triplet_acc: 0.62 - ETA: 46s - loss: 1.1346 - triplet_acc: 0.63 - ETA: 46s - loss: 1.1162 - triplet_acc: 0.63 - ETA: 45s - loss: 1.1295 - triplet_acc: 0.63 - ETA: 45s - loss: 1.1508 - triplet_acc: 0.63 - ETA: 45s - loss: 1.1788 - triplet_acc: 0.62 - ETA: 45s - loss: 1.1670 - triplet_acc: 0.63 - ETA: 45s - loss: 1.1631 - triplet_acc: 0.63 - ETA: 44s - loss: 1.1547 - triplet_acc: 0.63 - ETA: 44s - loss: 1.1347 - triplet_acc: 0.63 - ETA: 44s - loss: 1.1504 - triplet_acc: 0.63 - ETA: 44s - loss: 1.1542 - triplet_acc: 0.63 - ETA: 44s - loss: 1.1857 - triplet_acc: 0.63 - ETA: 43s - loss: 1.1797 - triplet_acc: 0.63 - ETA: 43s - loss: 1.1759 - triplet_acc: 0.63 - ETA: 43s - loss: 1.1721 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1728 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1802 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1851 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1760 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1868 - triplet_acc: 0.62 - ETA: 42s - loss: 1.2141 - triplet_acc: 0.62 - ETA: 42s - loss: 1.2014 - triplet_acc: 0.62 - ETA: 41s - loss: 1.2074 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1933 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1979 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1868 - triplet_acc: 0.63 - ETA: 41s - loss: 1.1943 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1967 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1982 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1954 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1889 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1786 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1733 - triplet_acc: 0.62 - ETA: 39s - loss: 1.1732 - triplet_acc: 0.62 - ETA: 39s - loss: 1.1643 - triplet_acc: 0.62 - ETA: 39s - loss: 1.1546 - triplet_acc: 0.63 - ETA: 39s - loss: 1.1566 - trip ...
# 300/300 [==============================] - ETA: 22s - loss: 1.2064 - triplet_acc: 0.62 - ETA: 22s - loss: 1.2002 - triplet_acc: 0.62 - ETA: 22s - loss: 1.2018 - triplet_acc: 0.62 - ETA: 21s - loss: 1.2011 - triplet_acc: 0.62 - ETA: 21s - loss: 1.2022 - triplet_acc: 0.62 - ETA: 21s - loss: 1.2003 - triplet_acc: 0.62 - ETA: 21s - loss: 1.2010 - triplet_acc: 0.62 - ETA: 21s - loss: 1.1983 - triplet_acc: 0.62 - ETA: 21s - loss: 1.2010 - triplet_acc: 0.62 - ETA: 20s - loss: 1.2010 - triplet_acc: 0.62 - ETA: 20s - loss: 1.2032 - triplet_acc: 0.62 - ETA: 20s - loss: 1.2059 - triplet_acc: 0.62 - ETA: 20s - loss: 1.2116 - triplet_acc: 0.62 - ETA: 20s - loss: 1.2093 - triplet_acc: 0.62 - ETA: 19s - loss: 1.2088 - triplet_acc: 0.62 - ETA: 19s - loss: 1.2081 - triplet_acc: 0.62 - ETA: 19s - loss: 1.2093 - triplet_acc: 0.62 - ETA: 19s - loss: 1.2054 - triplet_acc: 0.62 - ETA: 19s - loss: 1.2036 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2114 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2179 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2144 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2145 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2143 - triplet_acc: 0.62 - ETA: 18s - loss: 1.2162 - triplet_acc: 0.61 - ETA: 17s - loss: 1.2131 - triplet_acc: 0.61 - ETA: 17s - loss: 1.2094 - triplet_acc: 0.61 - ETA: 17s - loss: 1.2036 - triplet_acc: 0.62 - ETA: 17s - loss: 1.2036 - triplet_acc: 0.62 - ETA: 17s - loss: 1.1998 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1946 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1955 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1971 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1977 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1958 - triplet_acc: 0.62 - ETA: 16s - loss: 1.1989 - triplet_acc: 0.62 - ETA: 15s - loss: 1.1963 - triplet_acc: 0.62 - ETA: 15s - loss: 1.1953 - triplet_acc: 0.62 - ETA: 15s - loss: 1.1933 - triplet_acc: 0.62 - ETA: 15s - loss: 1.1983 - triplet_acc: 0.62 - ETA: 15s - loss: 1.2025 - triplet_acc: 0.62 - ETA: 14s - loss: 1.1977 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2015 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2024 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2005 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2017 - triplet_acc: 0.62 - ETA: 14s - loss: 1.2016 - triplet_acc: 0.62 - ETA: 13s - loss: 1.2058 - triplet_acc: 0.61 - ETA: 13s - loss: 1.2033 - triplet_acc: 0.62 - ETA: 13s - loss: 1.1991 - triplet_acc: 0.62 - ETA: 13s - loss: 1.2011 - triplet_acc: 0.62 - ETA: 13s - loss: 1.1990 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1950 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1956 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1955 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1927 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1933 - triplet_acc: 0.62 - ETA: 12s - loss: 1.1902 - triplet_acc: 0.62 - ETA: 11s - loss: 1.1903 - triplet_acc: 0.62 - ETA: 11s - loss: 1.1947 - triplet_acc: 0.62 - ETA: 11s - loss: 1.1896 - triplet_acc: 0.62 - ETA: 11s - loss: 1.1910 - triplet_acc: 0.62 - ETA: 11s - loss: 1.1963 - triplet_acc: 0.62 - ETA: 10s - loss: 1.1951 - triplet_acc: 0.62 - ETA: 10s - loss: 1.2005 - triplet_acc: 0.62 - ETA: 10s - loss: 1.2012 - triplet_acc: 0.62 - ETA: 10s - loss: 1.1973 - triplet_acc: 0.62 - ETA: 10s - loss: 1.1941 - triplet_acc: 0.62 - ETA: 9s - loss: 1.1917 - triplet_acc: 0.6240 - ETA: 9s - loss: 1.1970 - triplet_acc: 0.623 - ETA: 9s - loss: 1.1974 - triplet_acc: 0.623 - ETA: 9s - loss: 1.1953 - triplet_acc: 0.623 - ETA: 9s - loss: 1.1938 - triplet_acc: 0.624 - ETA: 9s - loss: 1.1985 - triplet_acc: 0.623 - ETA: 8s - loss: 1.1965 - triplet_acc: 0.623 - ETA: 8s - loss: 1.1985 - triplet_acc: 0.622 - ETA: 8s - loss: 1.1943 - triplet_acc: 0.623 - ETA: 8s - loss: 1.1982 - triplet_acc: 0.622 - ETA: 8s - loss: 1.1973 - triplet_acc: 0.622 - ETA: 7s - loss: 1.1960 - triplet_acc: 0.622 - ETA: 7s - loss: 1.1988 - triplet_acc: 0.621 - ETA: 7s - loss: 1.1952 - triplet_acc: 0.622 - ETA: 7s - loss: 1.1945 - triplet_acc: 0.621 - ETA: 7s - loss: 1.1942 - triplet_acc: 0.621 - ETA: 7s - loss: 1.1920 - triplet_acc: 0.622 - ETA: 6s - loss: 1.1889 - triplet_acc: 0.623 -  ...
# Epoch: 4
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:35 - loss: 0.2917 - triplet_acc: 0.900 - ETA: 1:17 - loss: 0.3869 - triplet_acc: 0.800 - ETA: 1:10 - loss: 1.2452 - triplet_acc: 0.700 - ETA: 1:07 - loss: 1.0386 - triplet_acc: 0.700 - ETA: 1:03 - loss: 0.8309 - triplet_acc: 0.760 - ETA: 1:01 - loss: 1.0075 - triplet_acc: 0.733 - ETA: 1:00 - loss: 1.0486 - triplet_acc: 0.685 - ETA: 59s - loss: 1.2326 - triplet_acc: 0.675 - ETA: 57s - loss: 1.2268 - triplet_acc: 0.66 - ETA: 57s - loss: 1.4071 - triplet_acc: 0.65 - ETA: 56s - loss: 1.5144 - triplet_acc: 0.62 - ETA: 56s - loss: 1.5422 - triplet_acc: 0.61 - ETA: 55s - loss: 1.4515 - triplet_acc: 0.61 - ETA: 55s - loss: 1.4314 - triplet_acc: 0.61 - ETA: 54s - loss: 1.4418 - triplet_acc: 0.61 - ETA: 54s - loss: 1.3620 - triplet_acc: 0.63 - ETA: 54s - loss: 1.3651 - triplet_acc: 0.62 - ETA: 53s - loss: 1.3694 - triplet_acc: 0.61 - ETA: 53s - loss: 1.3839 - triplet_acc: 0.60 - ETA: 53s - loss: 1.3758 - triplet_acc: 0.61 - ETA: 52s - loss: 1.4023 - triplet_acc: 0.60 - ETA: 52s - loss: 1.4150 - triplet_acc: 0.60 - ETA: 53s - loss: 1.3824 - triplet_acc: 0.60 - ETA: 53s - loss: 1.3828 - triplet_acc: 0.60 - ETA: 53s - loss: 1.3275 - triplet_acc: 0.61 - ETA: 52s - loss: 1.2979 - triplet_acc: 0.62 - ETA: 52s - loss: 1.3197 - triplet_acc: 0.62 - ETA: 52s - loss: 1.3011 - triplet_acc: 0.62 - ETA: 51s - loss: 1.3063 - triplet_acc: 0.61 - ETA: 51s - loss: 1.3235 - triplet_acc: 0.61 - ETA: 51s - loss: 1.3187 - triplet_acc: 0.61 - ETA: 50s - loss: 1.3168 - triplet_acc: 0.61 - ETA: 50s - loss: 1.3048 - triplet_acc: 0.62 - ETA: 50s - loss: 1.3308 - triplet_acc: 0.61 - ETA: 50s - loss: 1.2929 - triplet_acc: 0.62 - ETA: 50s - loss: 1.2846 - triplet_acc: 0.61 - ETA: 49s - loss: 1.2683 - triplet_acc: 0.61 - ETA: 49s - loss: 1.2727 - triplet_acc: 0.61 - ETA: 49s - loss: 1.2668 - triplet_acc: 0.61 - ETA: 49s - loss: 1.2632 - triplet_acc: 0.61 - ETA: 48s - loss: 1.2454 - triplet_acc: 0.61 - ETA: 48s - loss: 1.2203 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2184 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2389 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2646 - triplet_acc: 0.62 - ETA: 48s - loss: 1.2572 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2524 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2452 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2311 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2348 - triplet_acc: 0.62 - ETA: 47s - loss: 1.2325 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2386 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2368 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2412 - triplet_acc: 0.62 - ETA: 46s - loss: 1.2509 - triplet_acc: 0.61 - ETA: 45s - loss: 1.2483 - triplet_acc: 0.61 - ETA: 45s - loss: 1.2324 - triplet_acc: 0.61 - ETA: 45s - loss: 1.2224 - triplet_acc: 0.62 - ETA: 45s - loss: 1.2112 - triplet_acc: 0.61 - ETA: 45s - loss: 1.1951 - triplet_acc: 0.62 - ETA: 44s - loss: 1.1860 - triplet_acc: 0.61 - ETA: 44s - loss: 1.2088 - triplet_acc: 0.61 - ETA: 44s - loss: 1.1920 - triplet_acc: 0.62 - ETA: 44s - loss: 1.1815 - triplet_acc: 0.62 - ETA: 44s - loss: 1.1686 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1705 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1743 - triplet_acc: 0.61 - ETA: 43s - loss: 1.1740 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1650 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1675 - triplet_acc: 0.61 - ETA: 42s - loss: 1.1902 - triplet_acc: 0.61 - ETA: 42s - loss: 1.1835 - triplet_acc: 0.61 - ETA: 42s - loss: 1.1786 - triplet_acc: 0.61 - ETA: 42s - loss: 1.1851 - triplet_acc: 0.61 - ETA: 42s - loss: 1.1733 - triplet_acc: 0.61 - ETA: 41s - loss: 1.1774 - triplet_acc: 0.61 - ETA: 41s - loss: 1.1727 - triplet_acc: 0.61 - ETA: 41s - loss: 1.1624 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1538 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1533 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1707 - triplet_acc: 0.61 - ETA: 40s - loss: 1.1815 - triplet_acc: 0.61 - ETA: 40s - loss: 1.1724 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1740 - triplet_acc: 0.62 - ETA: 39s - loss: 1.1675 - triplet_acc: 0.62 - ETA: 39s - loss: 1.1723 - triple ...
# Epoch: 5
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:35 - loss: 0.8199 - triplet_acc: 0.600 - ETA: 1:12 - loss: 1.0315 - triplet_acc: 0.600 - ETA: 1:06 - loss: 0.8253 - triplet_acc: 0.633 - ETA: 1:03 - loss: 0.9493 - triplet_acc: 0.625 - ETA: 1:02 - loss: 0.8345 - triplet_acc: 0.660 - ETA: 59s - loss: 1.0362 - triplet_acc: 0.633 - ETA: 58s - loss: 1.0403 - triplet_acc: 0.65 - ETA: 57s - loss: 1.0811 - triplet_acc: 0.62 - ETA: 57s - loss: 1.0936 - triplet_acc: 0.61 - ETA: 56s - loss: 1.1937 - triplet_acc: 0.58 - ETA: 56s - loss: 1.1338 - triplet_acc: 0.60 - ETA: 55s - loss: 1.0765 - triplet_acc: 0.60 - ETA: 54s - loss: 1.0546 - triplet_acc: 0.59 - ETA: 54s - loss: 1.0046 - triplet_acc: 0.60 - ETA: 54s - loss: 1.0261 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1196 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1446 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1374 - triplet_acc: 0.60 - ETA: 53s - loss: 1.1926 - triplet_acc: 0.58 - ETA: 52s - loss: 1.1543 - triplet_acc: 0.59 - ETA: 52s - loss: 1.1834 - triplet_acc: 0.58 - ETA: 52s - loss: 1.1692 - triplet_acc: 0.59 - ETA: 52s - loss: 1.1963 - triplet_acc: 0.58 - ETA: 52s - loss: 1.1850 - triplet_acc: 0.58 - ETA: 52s - loss: 1.1932 - triplet_acc: 0.58 - ETA: 51s - loss: 1.1828 - triplet_acc: 0.58 - ETA: 51s - loss: 1.1971 - triplet_acc: 0.58 - ETA: 51s - loss: 1.2295 - triplet_acc: 0.57 - ETA: 50s - loss: 1.2633 - triplet_acc: 0.57 - ETA: 50s - loss: 1.2714 - triplet_acc: 0.57 - ETA: 50s - loss: 1.2605 - triplet_acc: 0.57 - ETA: 50s - loss: 1.2443 - triplet_acc: 0.57 - ETA: 50s - loss: 1.2727 - triplet_acc: 0.57 - ETA: 49s - loss: 1.2464 - triplet_acc: 0.57 - ETA: 49s - loss: 1.2559 - triplet_acc: 0.57 - ETA: 49s - loss: 1.2394 - triplet_acc: 0.57 - ETA: 48s - loss: 1.2167 - triplet_acc: 0.58 - ETA: 48s - loss: 1.2003 - triplet_acc: 0.58 - ETA: 48s - loss: 1.2039 - triplet_acc: 0.58 - ETA: 48s - loss: 1.1953 - triplet_acc: 0.59 - ETA: 48s - loss: 1.2074 - triplet_acc: 0.58 - ETA: 47s - loss: 1.1939 - triplet_acc: 0.59 - ETA: 47s - loss: 1.1923 - triplet_acc: 0.59 - ETA: 47s - loss: 1.2041 - triplet_acc: 0.59 - ETA: 47s - loss: 1.1930 - triplet_acc: 0.59 - ETA: 47s - loss: 1.1922 - triplet_acc: 0.60 - ETA: 46s - loss: 1.1830 - triplet_acc: 0.60 - ETA: 46s - loss: 1.1939 - triplet_acc: 0.60 - ETA: 46s - loss: 1.1937 - triplet_acc: 0.60 - ETA: 46s - loss: 1.1863 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2292 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2441 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2431 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2365 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2537 - triplet_acc: 0.60 - ETA: 44s - loss: 1.2511 - triplet_acc: 0.60 - ETA: 45s - loss: 1.2357 - triplet_acc: 0.60 - ETA: 44s - loss: 1.2222 - triplet_acc: 0.61 - ETA: 44s - loss: 1.2260 - triplet_acc: 0.60 - ETA: 44s - loss: 1.2061 - triplet_acc: 0.61 - ETA: 44s - loss: 1.1933 - triplet_acc: 0.61 - ETA: 44s - loss: 1.1921 - triplet_acc: 0.61 - ETA: 43s - loss: 1.1749 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1661 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1677 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1685 - triplet_acc: 0.62 - ETA: 43s - loss: 1.1525 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1490 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1437 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1343 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1370 - triplet_acc: 0.62 - ETA: 42s - loss: 1.1308 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1292 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1198 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1198 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1086 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1118 - triplet_acc: 0.62 - ETA: 41s - loss: 1.1085 - triplet_acc: 0.62 - ETA: 40s - loss: 1.1102 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1032 - triplet_acc: 0.63 - ETA: 40s - loss: 1.0994 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1030 - triplet_acc: 0.63 - ETA: 40s - loss: 1.1007 - triplet_acc: 0.63 - ETA: 39s - loss: 1.1059 - triplet_acc: 0.63 - ETA: 39s - loss: 1.0993 - triplet_acc: 0.63 - ETA: 39s - loss: 1.0989 - triplet_ac ...
# 300/300 [==============================] - ETA: 22s - loss: 1.0364 - triplet_acc: 0.64 - ETA: 22s - loss: 1.0339 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0375 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0383 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0357 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0360 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0403 - triplet_acc: 0.64 - ETA: 21s - loss: 1.0361 - triplet_acc: 0.64 - ETA: 20s - loss: 1.0370 - triplet_acc: 0.64 - ETA: 20s - loss: 1.0323 - triplet_acc: 0.64 - ETA: 20s - loss: 1.0334 - triplet_acc: 0.64 - ETA: 20s - loss: 1.0313 - triplet_acc: 0.64 - ETA: 20s - loss: 1.0367 - triplet_acc: 0.64 - ETA: 19s - loss: 1.0362 - triplet_acc: 0.64 - ETA: 19s - loss: 1.0352 - triplet_acc: 0.64 - ETA: 19s - loss: 1.0355 - triplet_acc: 0.64 - ETA: 19s - loss: 1.0306 - triplet_acc: 0.65 - ETA: 19s - loss: 1.0296 - triplet_acc: 0.65 - ETA: 19s - loss: 1.0291 - triplet_acc: 0.65 - ETA: 18s - loss: 1.0346 - triplet_acc: 0.64 - ETA: 18s - loss: 1.0337 - triplet_acc: 0.65 - ETA: 18s - loss: 1.0327 - triplet_acc: 0.65 - ETA: 18s - loss: 1.0276 - triplet_acc: 0.65 - ETA: 18s - loss: 1.0224 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0248 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0298 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0281 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0337 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0401 - triplet_acc: 0.65 - ETA: 17s - loss: 1.0387 - triplet_acc: 0.65 - ETA: 16s - loss: 1.0349 - triplet_acc: 0.65 - ETA: 16s - loss: 1.0356 - triplet_acc: 0.65 - ETA: 16s - loss: 1.0366 - triplet_acc: 0.65 - ETA: 16s - loss: 1.0393 - triplet_acc: 0.65 - ETA: 16s - loss: 1.0405 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0411 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0403 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0383 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0369 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0337 - triplet_acc: 0.65 - ETA: 15s - loss: 1.0356 - triplet_acc: 0.65 - ETA: 14s - loss: 1.0338 - triplet_acc: 0.65 - ETA: 14s - loss: 1.0427 - triplet_acc: 0.65 - ETA: 14s - loss: 1.0478 - triplet_acc: 0.65 - ETA: 14s - loss: 1.0484 - triplet_acc: 0.65 - ETA: 14s - loss: 1.0463 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0423 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0438 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0407 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0390 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0363 - triplet_acc: 0.65 - ETA: 13s - loss: 1.0365 - triplet_acc: 0.65 - ETA: 12s - loss: 1.0328 - triplet_acc: 0.65 - ETA: 12s - loss: 1.0314 - triplet_acc: 0.65 - ETA: 12s - loss: 1.0328 - triplet_acc: 0.65 - ETA: 12s - loss: 1.0319 - triplet_acc: 0.65 - ETA: 12s - loss: 1.0324 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0370 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0331 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0291 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0308 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0326 - triplet_acc: 0.65 - ETA: 11s - loss: 1.0295 - triplet_acc: 0.65 - ETA: 10s - loss: 1.0284 - triplet_acc: 0.65 - ETA: 10s - loss: 1.0292 - triplet_acc: 0.65 - ETA: 10s - loss: 1.0293 - triplet_acc: 0.65 - ETA: 10s - loss: 1.0251 - triplet_acc: 0.65 - ETA: 10s - loss: 1.0303 - triplet_acc: 0.65 - ETA: 9s - loss: 1.0330 - triplet_acc: 0.6561 - ETA: 9s - loss: 1.0355 - triplet_acc: 0.655 - ETA: 9s - loss: 1.0355 - triplet_acc: 0.655 - ETA: 9s - loss: 1.0357 - triplet_acc: 0.655 - ETA: 9s - loss: 1.0364 - triplet_acc: 0.655 - ETA: 9s - loss: 1.0350 - triplet_acc: 0.655 - ETA: 8s - loss: 1.0358 - triplet_acc: 0.655 - ETA: 8s - loss: 1.0348 - triplet_acc: 0.655 - ETA: 8s - loss: 1.0338 - triplet_acc: 0.655 - ETA: 8s - loss: 1.0323 - triplet_acc: 0.656 - ETA: 8s - loss: 1.0309 - triplet_acc: 0.655 - ETA: 7s - loss: 1.0276 - triplet_acc: 0.656 - ETA: 7s - loss: 1.0279 - triplet_acc: 0.655 - ETA: 7s - loss: 1.0302 - triplet_acc: 0.655 - ETA: 7s - loss: 1.0342 - triplet_acc: 0.655 - ETA: 7s - loss: 1.0355 - triplet_acc: 0.655 - ETA: 7s - loss: 1.0335 - triplet_acc: 0.656 - ETA: 6s - loss: 1.0391 - triplet_acc: 0.655 -  ...
# Epoch: 6
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:37 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 1:17 - loss: 0.2874 - triplet_acc: 0.8500    - ETA: 1:11 - loss: 0.6164 - triplet_acc: 0.833 - ETA: 1:07 - loss: 0.8112 - triplet_acc: 0.775 - ETA: 1:04 - loss: 1.1501 - triplet_acc: 0.700 - ETA: 1:02 - loss: 1.0459 - triplet_acc: 0.700 - ETA: 1:01 - loss: 1.4432 - triplet_acc: 0.642 - ETA: 1:00 - loss: 1.3964 - triplet_acc: 0.650 - ETA: 59s - loss: 1.4515 - triplet_acc: 0.655 - ETA: 58s - loss: 1.4168 - triplet_acc: 0.66 - ETA: 57s - loss: 1.3654 - triplet_acc: 0.66 - ETA: 56s - loss: 1.2878 - triplet_acc: 0.67 - ETA: 56s - loss: 1.2301 - triplet_acc: 0.67 - ETA: 56s - loss: 1.2293 - triplet_acc: 0.67 - ETA: 55s - loss: 1.1727 - triplet_acc: 0.69 - ETA: 55s - loss: 1.1343 - triplet_acc: 0.69 - ETA: 54s - loss: 1.1286 - triplet_acc: 0.70 - ETA: 54s - loss: 1.1117 - triplet_acc: 0.70 - ETA: 54s - loss: 1.1666 - triplet_acc: 0.70 - ETA: 54s - loss: 1.1115 - triplet_acc: 0.71 - ETA: 54s - loss: 1.0842 - triplet_acc: 0.71 - ETA: 53s - loss: 1.0845 - triplet_acc: 0.71 - ETA: 53s - loss: 1.0696 - triplet_acc: 0.71 - ETA: 53s - loss: 1.0326 - triplet_acc: 0.72 - ETA: 53s - loss: 1.0039 - triplet_acc: 0.73 - ETA: 52s - loss: 0.9744 - triplet_acc: 0.73 - ETA: 52s - loss: 0.9797 - triplet_acc: 0.73 - ETA: 52s - loss: 0.9921 - triplet_acc: 0.73 - ETA: 52s - loss: 0.9682 - triplet_acc: 0.74 - ETA: 52s - loss: 0.9733 - triplet_acc: 0.73 - ETA: 51s - loss: 0.9929 - triplet_acc: 0.72 - ETA: 51s - loss: 1.0045 - triplet_acc: 0.73 - ETA: 51s - loss: 0.9988 - triplet_acc: 0.73 - ETA: 51s - loss: 0.9841 - triplet_acc: 0.73 - ETA: 51s - loss: 0.9732 - triplet_acc: 0.73 - ETA: 50s - loss: 0.9614 - triplet_acc: 0.73 - ETA: 50s - loss: 0.9379 - triplet_acc: 0.73 - ETA: 50s - loss: 0.9480 - triplet_acc: 0.73 - ETA: 50s - loss: 0.9740 - triplet_acc: 0.72 - ETA: 49s - loss: 0.9613 - triplet_acc: 0.73 - ETA: 49s - loss: 0.9943 - triplet_acc: 0.72 - ETA: 49s - loss: 0.9784 - triplet_acc: 0.72 - ETA: 49s - loss: 1.0001 - triplet_acc: 0.71 - ETA: 48s - loss: 0.9996 - triplet_acc: 0.71 - ETA: 48s - loss: 0.9990 - triplet_acc: 0.71 - ETA: 48s - loss: 1.0085 - triplet_acc: 0.71 - ETA: 48s - loss: 1.0217 - triplet_acc: 0.70 - ETA: 48s - loss: 1.0178 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0042 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0418 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0287 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0104 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0125 - triplet_acc: 0.70 - ETA: 47s - loss: 1.0274 - triplet_acc: 0.69 - ETA: 47s - loss: 1.0350 - triplet_acc: 0.69 - ETA: 46s - loss: 1.0208 - triplet_acc: 0.69 - ETA: 46s - loss: 1.0281 - triplet_acc: 0.68 - ETA: 46s - loss: 1.0132 - triplet_acc: 0.69 - ETA: 46s - loss: 1.0084 - triplet_acc: 0.69 - ETA: 46s - loss: 1.0102 - triplet_acc: 0.69 - ETA: 45s - loss: 1.0014 - triplet_acc: 0.69 - ETA: 45s - loss: 1.0086 - triplet_acc: 0.69 - ETA: 45s - loss: 1.0262 - triplet_acc: 0.69 - ETA: 45s - loss: 1.0437 - triplet_acc: 0.68 - ETA: 44s - loss: 1.0311 - triplet_acc: 0.69 - ETA: 44s - loss: 1.0224 - triplet_acc: 0.69 - ETA: 44s - loss: 1.0124 - triplet_acc: 0.69 - ETA: 44s - loss: 1.0062 - triplet_acc: 0.69 - ETA: 44s - loss: 1.0097 - triplet_acc: 0.69 - ETA: 43s - loss: 1.0122 - triplet_acc: 0.69 - ETA: 43s - loss: 1.0260 - triplet_acc: 0.69 - ETA: 43s - loss: 1.0279 - triplet_acc: 0.69 - ETA: 43s - loss: 1.0260 - triplet_acc: 0.69 - ETA: 43s - loss: 1.0263 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0213 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0303 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0319 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0264 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0332 - triplet_acc: 0.69 - ETA: 42s - loss: 1.0306 - triplet_acc: 0.69 - ETA: 41s - loss: 1.0230 - triplet_acc: 0.69 - ETA: 41s - loss: 1.0412 - triplet_acc: 0.68 - ETA: 41s - loss: 1.0424 - triplet_acc: 0.68 - ETA: 41s - loss: 1.0448 - triplet_acc: 0.68 - ETA: 41s - loss: 1.0351 - triplet_acc: 0.68 - ETA: 40s - loss: 1.040 ...
# Epoch: 7
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:34 - loss: 1.2572 - triplet_acc: 0.600 - ETA: 1:14 - loss: 0.8637 - triplet_acc: 0.650 - ETA: 1:07 - loss: 0.8899 - triplet_acc: 0.666 - ETA: 1:03 - loss: 0.7153 - triplet_acc: 0.725 - ETA: 1:01 - loss: 0.8899 - triplet_acc: 0.700 - ETA: 1:00 - loss: 0.8007 - triplet_acc: 0.733 - ETA: 58s - loss: 0.8501 - triplet_acc: 0.757 - ETA: 57s - loss: 0.8554 - triplet_acc: 0.73 - ETA: 56s - loss: 0.9057 - triplet_acc: 0.72 - ETA: 56s - loss: 0.9448 - triplet_acc: 0.71 - ETA: 55s - loss: 0.9077 - triplet_acc: 0.72 - ETA: 54s - loss: 0.8330 - triplet_acc: 0.74 - ETA: 54s - loss: 0.7933 - triplet_acc: 0.74 - ETA: 54s - loss: 0.8283 - triplet_acc: 0.75 - ETA: 53s - loss: 0.8304 - triplet_acc: 0.75 - ETA: 53s - loss: 0.8332 - triplet_acc: 0.75 - ETA: 54s - loss: 0.8714 - triplet_acc: 0.75 - ETA: 54s - loss: 0.8775 - triplet_acc: 0.75 - ETA: 54s - loss: 0.8980 - triplet_acc: 0.73 - ETA: 53s - loss: 0.8615 - triplet_acc: 0.72 - ETA: 53s - loss: 0.8549 - triplet_acc: 0.72 - ETA: 53s - loss: 0.8736 - triplet_acc: 0.72 - ETA: 52s - loss: 0.8528 - triplet_acc: 0.72 - ETA: 52s - loss: 0.8252 - triplet_acc: 0.72 - ETA: 52s - loss: 0.8027 - triplet_acc: 0.73 - ETA: 52s - loss: 0.8184 - triplet_acc: 0.72 - ETA: 51s - loss: 0.8265 - triplet_acc: 0.72 - ETA: 51s - loss: 0.8127 - triplet_acc: 0.72 - ETA: 51s - loss: 0.8216 - triplet_acc: 0.71 - ETA: 50s - loss: 0.8201 - triplet_acc: 0.71 - ETA: 50s - loss: 0.8096 - triplet_acc: 0.71 - ETA: 50s - loss: 0.7995 - triplet_acc: 0.71 - ETA: 50s - loss: 0.8489 - triplet_acc: 0.71 - ETA: 49s - loss: 0.8383 - triplet_acc: 0.71 - ETA: 49s - loss: 0.9166 - triplet_acc: 0.70 - ETA: 49s - loss: 0.9037 - triplet_acc: 0.70 - ETA: 49s - loss: 0.9145 - triplet_acc: 0.70 - ETA: 48s - loss: 0.9231 - triplet_acc: 0.70 - ETA: 48s - loss: 0.9209 - triplet_acc: 0.70 - ETA: 48s - loss: 0.8979 - triplet_acc: 0.71 - ETA: 48s - loss: 0.9002 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8930 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8992 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8819 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8997 - triplet_acc: 0.70 - ETA: 47s - loss: 0.9003 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8929 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8874 - triplet_acc: 0.70 - ETA: 47s - loss: 0.8834 - triplet_acc: 0.70 - ETA: 46s - loss: 0.8974 - triplet_acc: 0.70 - ETA: 46s - loss: 0.8994 - triplet_acc: 0.70 - ETA: 46s - loss: 0.9103 - triplet_acc: 0.69 - ETA: 46s - loss: 0.9187 - triplet_acc: 0.69 - ETA: 46s - loss: 0.9265 - triplet_acc: 0.69 - ETA: 45s - loss: 0.9599 - triplet_acc: 0.68 - ETA: 45s - loss: 0.9666 - triplet_acc: 0.68 - ETA: 45s - loss: 0.9670 - triplet_acc: 0.68 - ETA: 45s - loss: 0.9548 - triplet_acc: 0.68 - ETA: 44s - loss: 0.9606 - triplet_acc: 0.68 - ETA: 44s - loss: 0.9493 - triplet_acc: 0.68 - ETA: 44s - loss: 0.9402 - triplet_acc: 0.68 - ETA: 44s - loss: 0.9326 - triplet_acc: 0.68 - ETA: 44s - loss: 0.9335 - triplet_acc: 0.68 - ETA: 43s - loss: 0.9353 - triplet_acc: 0.67 - ETA: 43s - loss: 0.9285 - triplet_acc: 0.68 - ETA: 43s - loss: 0.9338 - triplet_acc: 0.68 - ETA: 43s - loss: 0.9417 - triplet_acc: 0.67 - ETA: 43s - loss: 0.9279 - triplet_acc: 0.68 - ETA: 42s - loss: 0.9333 - triplet_acc: 0.68 - ETA: 42s - loss: 0.9250 - triplet_acc: 0.68 - ETA: 42s - loss: 0.9267 - triplet_acc: 0.68 - ETA: 42s - loss: 0.9184 - triplet_acc: 0.68 - ETA: 42s - loss: 0.9260 - triplet_acc: 0.68 - ETA: 41s - loss: 0.9179 - triplet_acc: 0.68 - ETA: 41s - loss: 0.9102 - triplet_acc: 0.68 - ETA: 41s - loss: 0.9059 - triplet_acc: 0.68 - ETA: 41s - loss: 0.9037 - triplet_acc: 0.68 - ETA: 41s - loss: 0.9157 - triplet_acc: 0.68 - ETA: 40s - loss: 0.9046 - triplet_acc: 0.68 - ETA: 40s - loss: 0.8933 - triplet_acc: 0.69 - ETA: 40s - loss: 0.8842 - triplet_acc: 0.69 - ETA: 40s - loss: 0.8990 - triplet_acc: 0.69 - ETA: 40s - loss: 0.8956 - triplet_acc: 0.69 - ETA: 39s - loss: 0.9030 - triplet_acc: 0.69 - ETA: 39s - loss: 0.8980 - triplet_acc: 0.69 - ETA: 39s - loss: 0.9079 - triplet_ ...
# ...
# Epoch: 17
# Epoch 1/1
# 177/300 [================>.............] - ETA: 1:42 - loss: 0.5113 - triplet_acc: 0.900 - ETA: 1:21 - loss: 1.1044 - triplet_acc: 0.800 - ETA: 1:16 - loss: 0.8262 - triplet_acc: 0.833 - ETA: 1:12 - loss: 1.0093 - triplet_acc: 0.800 - ETA: 1:10 - loss: 0.9080 - triplet_acc: 0.820 - ETA: 1:09 - loss: 0.9989 - triplet_acc: 0.800 - ETA: 1:07 - loss: 1.0364 - triplet_acc: 0.800 - ETA: 1:04 - loss: 0.9614 - triplet_acc: 0.812 - ETA: 1:03 - loss: 0.9740 - triplet_acc: 0.800 - ETA: 1:02 - loss: 0.9093 - triplet_acc: 0.810 - ETA: 1:01 - loss: 0.8427 - triplet_acc: 0.809 - ETA: 1:00 - loss: 0.8020 - triplet_acc: 0.808 - ETA: 59s - loss: 0.8147 - triplet_acc: 0.807 - ETA: 59s - loss: 0.8108 - triplet_acc: 0.80 - ETA: 59s - loss: 0.7840 - triplet_acc: 0.79 - ETA: 58s - loss: 0.7762 - triplet_acc: 0.78 - ETA: 58s - loss: 0.7789 - triplet_acc: 0.78 - ETA: 57s - loss: 0.7951 - triplet_acc: 0.77 - ETA: 57s - loss: 0.7776 - triplet_acc: 0.78 - ETA: 56s - loss: 0.7520 - triplet_acc: 0.79 - ETA: 56s - loss: 0.7747 - triplet_acc: 0.78 - ETA: 55s - loss: 0.8341 - triplet_acc: 0.77 - ETA: 55s - loss: 0.8133 - triplet_acc: 0.77 - ETA: 55s - loss: 0.8113 - triplet_acc: 0.77 - ETA: 54s - loss: 0.8175 - triplet_acc: 0.77 - ETA: 54s - loss: 0.8084 - triplet_acc: 0.77 - ETA: 53s - loss: 0.8219 - triplet_acc: 0.77 - ETA: 53s - loss: 0.8470 - triplet_acc: 0.76 - ETA: 53s - loss: 0.8419 - triplet_acc: 0.75 - ETA: 53s - loss: 0.8333 - triplet_acc: 0.76 - ETA: 53s - loss: 0.8577 - triplet_acc: 0.76 - ETA: 53s - loss: 0.8434 - triplet_acc: 0.75 - ETA: 53s - loss: 0.8475 - triplet_acc: 0.76 - ETA: 52s - loss: 0.8563 - triplet_acc: 0.75 - ETA: 52s - loss: 0.8522 - triplet_acc: 0.75 - ETA: 52s - loss: 0.8382 - triplet_acc: 0.75 - ETA: 52s - loss: 0.8568 - triplet_acc: 0.74 - ETA: 52s - loss: 0.8522 - triplet_acc: 0.75 - ETA: 51s - loss: 0.8620 - triplet_acc: 0.75 - ETA: 51s - loss: 0.8648 - triplet_acc: 0.75 - ETA: 51s - loss: 0.8508 - triplet_acc: 0.75 - ETA: 51s - loss: 0.8435 - triplet_acc: 0.75 - ETA: 51s - loss: 0.8396 - triplet_acc: 0.75 - ETA: 50s - loss: 0.8238 - triplet_acc: 0.75 - ETA: 50s - loss: 0.8568 - triplet_acc: 0.75 - ETA: 50s - loss: 0.8507 - triplet_acc: 0.75 - ETA: 50s - loss: 0.8444 - triplet_acc: 0.75 - ETA: 49s - loss: 0.8303 - triplet_acc: 0.75 - ETA: 49s - loss: 0.8141 - triplet_acc: 0.76 - ETA: 49s - loss: 0.8262 - triplet_acc: 0.75 - ETA: 49s - loss: 0.8243 - triplet_acc: 0.75 - ETA: 49s - loss: 0.8276 - triplet_acc: 0.75 - ETA: 48s - loss: 0.8133 - triplet_acc: 0.75 - ETA: 48s - loss: 0.7982 - triplet_acc: 0.76 - ETA: 48s - loss: 0.7912 - triplet_acc: 0.76 - ETA: 48s - loss: 0.7868 - triplet_acc: 0.76 - ETA: 47s - loss: 0.7974 - triplet_acc: 0.76 - ETA: 47s - loss: 0.7958 - triplet_acc: 0.76 - ETA: 47s - loss: 0.7918 - triplet_acc: 0.76 - ETA: 47s - loss: 0.7873 - triplet_acc: 0.75 - ETA: 46s - loss: 0.8035 - triplet_acc: 0.75 - ETA: 46s - loss: 0.8022 - triplet_acc: 0.75 - ETA: 46s - loss: 0.8137 - triplet_acc: 0.75 - ETA: 46s - loss: 0.8071 - triplet_acc: 0.75 - ETA: 45s - loss: 0.8151 - triplet_acc: 0.75 - ETA: 45s - loss: 0.8254 - triplet_acc: 0.75 - ETA: 45s - loss: 0.8299 - triplet_acc: 0.75 - ETA: 45s - loss: 0.8402 - triplet_acc: 0.75 - ETA: 44s - loss: 0.8377 - triplet_acc: 0.75 - ETA: 44s - loss: 0.8499 - triplet_acc: 0.75 - ETA: 44s - loss: 0.8718 - triplet_acc: 0.74 - ETA: 44s - loss: 0.8749 - triplet_acc: 0.74 - ETA: 43s - loss: 0.8737 - triplet_acc: 0.74 - ETA: 43s - loss: 0.8619 - triplet_acc: 0.74 - ETA: 43s - loss: 0.8676 - triplet_acc: 0.74 - ETA: 43s - loss: 0.8681 - triplet_acc: 0.74 - ETA: 43s - loss: 0.8676 - triplet_acc: 0.74 - ETA: 42s - loss: 0.8643 - triplet_acc: 0.74 - ETA: 42s - loss: 0.8784 - triplet_acc: 0.74 - ETA: 42s - loss: 0.8801 - triplet_acc: 0.74 - ETA: 42s - loss: 0.8872 - triplet_acc: 0.74 - ETA: 42s - loss: 0.8844 - triplet_acc: 0.74 - ETA: 41s - loss: 0.8774 - triplet_acc: 0.74 - ETA: 41s - loss: 0.8762 - triplet_acc: 0.74 - ETA: 41s - loss: 0.8882 - triplet_acc: 0.74 - ETA: 41s - loss: 0.911 ...
# 300/300 [==============================] - ETA: 23s - loss: 0.8627 - triplet_acc: 0.73 - ETA: 23s - loss: 0.8611 - triplet_acc: 0.73 - ETA: 22s - loss: 0.8569 - triplet_acc: 0.73 - ETA: 22s - loss: 0.8562 - triplet_acc: 0.73 - ETA: 22s - loss: 0.8527 - triplet_acc: 0.73 - ETA: 22s - loss: 0.8576 - triplet_acc: 0.73 - ETA: 22s - loss: 0.8544 - triplet_acc: 0.73 - ETA: 21s - loss: 0.8560 - triplet_acc: 0.73 - ETA: 21s - loss: 0.8558 - triplet_acc: 0.73 - ETA: 21s - loss: 0.8523 - triplet_acc: 0.73 - ETA: 21s - loss: 0.8516 - triplet_acc: 0.73 - ETA: 21s - loss: 0.8482 - triplet_acc: 0.73 - ETA: 20s - loss: 0.8456 - triplet_acc: 0.73 - ETA: 20s - loss: 0.8464 - triplet_acc: 0.73 - ETA: 20s - loss: 0.8476 - triplet_acc: 0.73 - ETA: 20s - loss: 0.8554 - triplet_acc: 0.73 - ETA: 20s - loss: 0.8559 - triplet_acc: 0.72 - ETA: 19s - loss: 0.8571 - triplet_acc: 0.72 - ETA: 19s - loss: 0.8536 - triplet_acc: 0.73 - ETA: 19s - loss: 0.8550 - triplet_acc: 0.72 - ETA: 19s - loss: 0.8511 - triplet_acc: 0.73 - ETA: 19s - loss: 0.8509 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8509 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8496 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8474 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8432 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8414 - triplet_acc: 0.73 - ETA: 18s - loss: 0.8399 - triplet_acc: 0.73 - ETA: 17s - loss: 0.8421 - triplet_acc: 0.73 - ETA: 17s - loss: 0.8440 - triplet_acc: 0.73 - ETA: 17s - loss: 0.8483 - triplet_acc: 0.73 - ETA: 17s - loss: 0.8448 - triplet_acc: 0.73 - ETA: 17s - loss: 0.8459 - triplet_acc: 0.73 - ETA: 16s - loss: 0.8467 - triplet_acc: 0.73 - ETA: 16s - loss: 0.8516 - triplet_acc: 0.72 - ETA: 16s - loss: 0.8572 - triplet_acc: 0.72 - ETA: 16s - loss: 0.8534 - triplet_acc: 0.72 - ETA: 16s - loss: 0.8494 - triplet_acc: 0.73 - ETA: 15s - loss: 0.8518 - triplet_acc: 0.73 - ETA: 15s - loss: 0.8502 - triplet_acc: 0.73 - ETA: 15s - loss: 0.8482 - triplet_acc: 0.73 - ETA: 15s - loss: 0.8455 - triplet_acc: 0.73 - ETA: 15s - loss: 0.8491 - triplet_acc: 0.73 - ETA: 14s - loss: 0.8521 - triplet_acc: 0.73 - ETA: 14s - loss: 0.8525 - triplet_acc: 0.72 - ETA: 14s - loss: 0.8504 - triplet_acc: 0.73 - ETA: 14s - loss: 0.8507 - triplet_acc: 0.72 - ETA: 14s - loss: 0.8512 - triplet_acc: 0.72 - ETA: 13s - loss: 0.8474 - triplet_acc: 0.73 - ETA: 13s - loss: 0.8454 - triplet_acc: 0.73 - ETA: 13s - loss: 0.8468 - triplet_acc: 0.73 - ETA: 13s - loss: 0.8486 - triplet_acc: 0.73 - ETA: 13s - loss: 0.8468 - triplet_acc: 0.73 - ETA: 13s - loss: 0.8479 - triplet_acc: 0.73 - ETA: 12s - loss: 0.8520 - triplet_acc: 0.73 - ETA: 12s - loss: 0.8614 - triplet_acc: 0.72 - ETA: 12s - loss: 0.8580 - triplet_acc: 0.72 - ETA: 12s - loss: 0.8567 - triplet_acc: 0.73 - ETA: 12s - loss: 0.8560 - triplet_acc: 0.73 - ETA: 11s - loss: 0.8594 - triplet_acc: 0.72 - ETA: 11s - loss: 0.8607 - triplet_acc: 0.72 - ETA: 11s - loss: 0.8653 - triplet_acc: 0.72 - ETA: 11s - loss: 0.8679 - triplet_acc: 0.72 - ETA: 11s - loss: 0.8718 - triplet_acc: 0.72 - ETA: 10s - loss: 0.8707 - triplet_acc: 0.72 - ETA: 10s - loss: 0.8695 - triplet_acc: 0.72 - ETA: 10s - loss: 0.8700 - triplet_acc: 0.72 - ETA: 10s - loss: 0.8696 - triplet_acc: 0.72 - ETA: 10s - loss: 0.8709 - triplet_acc: 0.72 - ETA: 9s - loss: 0.8725 - triplet_acc: 0.7271 - ETA: 9s - loss: 0.8703 - triplet_acc: 0.727 - ETA: 9s - loss: 0.8668 - triplet_acc: 0.728 - ETA: 9s - loss: 0.8651 - triplet_acc: 0.728 - ETA: 9s - loss: 0.8634 - triplet_acc: 0.729 - ETA: 9s - loss: 0.8621 - triplet_acc: 0.729 - ETA: 8s - loss: 0.8603 - triplet_acc: 0.728 - ETA: 8s - loss: 0.8616 - triplet_acc: 0.729 - ETA: 8s - loss: 0.8605 - triplet_acc: 0.729 - ETA: 8s - loss: 0.8583 - triplet_acc: 0.729 - ETA: 8s - loss: 0.8610 - triplet_acc: 0.729 - ETA: 7s - loss: 0.8599 - triplet_acc: 0.729 - ETA: 7s - loss: 0.8628 - triplet_acc: 0.729 - ETA: 7s - loss: 0.8604 - triplet_acc: 0.729 - ETA: 7s - loss: 0.8587 - triplet_acc: 0.729 - ETA: 7s - loss: 0.8596 - triplet_acc: 0.730 - ETA: 6s - loss: 0.8574 - triplet_acc: 0.730 -  ...
# Epoch: 18
# Epoch 1/1
# 148/300 [=============>................] - ETA: 1:37 - loss: 0.5420 - triplet_acc: 0.700 - ETA: 1:17 - loss: 0.5128 - triplet_acc: 0.700 - ETA: 1:10 - loss: 0.4586 - triplet_acc: 0.766 - ETA: 1:05 - loss: 0.5090 - triplet_acc: 0.700 - ETA: 1:03 - loss: 0.4833 - triplet_acc: 0.720 - ETA: 1:01 - loss: 0.6524 - triplet_acc: 0.683 - ETA: 1:00 - loss: 0.6646 - triplet_acc: 0.700 - ETA: 59s - loss: 0.6293 - triplet_acc: 0.712 - ETA: 58s - loss: 0.5777 - triplet_acc: 0.72 - ETA: 57s - loss: 0.5793 - triplet_acc: 0.72 - ETA: 57s - loss: 0.5475 - triplet_acc: 0.72 - ETA: 56s - loss: 0.5046 - triplet_acc: 0.74 - ETA: 57s - loss: 0.4718 - triplet_acc: 0.75 - ETA: 57s - loss: 0.4859 - triplet_acc: 0.75 - ETA: 56s - loss: 0.5750 - triplet_acc: 0.74 - ETA: 56s - loss: 0.5914 - triplet_acc: 0.73 - ETA: 56s - loss: 0.6478 - triplet_acc: 0.70 - ETA: 55s - loss: 0.6667 - triplet_acc: 0.70 - ETA: 55s - loss: 0.6827 - triplet_acc: 0.70 - ETA: 54s - loss: 0.6733 - triplet_acc: 0.70 - ETA: 54s - loss: 0.6590 - triplet_acc: 0.70 - ETA: 53s - loss: 0.6555 - triplet_acc: 0.70 - ETA: 53s - loss: 0.6841 - triplet_acc: 0.70 - ETA: 53s - loss: 0.6556 - triplet_acc: 0.72 - ETA: 52s - loss: 0.6358 - triplet_acc: 0.72 - ETA: 52s - loss: 0.6851 - triplet_acc: 0.71 - ETA: 52s - loss: 0.6695 - triplet_acc: 0.72 - ETA: 51s - loss: 0.6455 - triplet_acc: 0.73 - ETA: 51s - loss: 0.6447 - triplet_acc: 0.73 - ETA: 51s - loss: 0.6395 - triplet_acc: 0.73 - ETA: 50s - loss: 0.6206 - triplet_acc: 0.74 - ETA: 50s - loss: 0.6387 - triplet_acc: 0.74 - ETA: 50s - loss: 0.6399 - triplet_acc: 0.74 - ETA: 50s - loss: 0.6307 - triplet_acc: 0.74 - ETA: 49s - loss: 0.6477 - triplet_acc: 0.74 - ETA: 49s - loss: 0.6422 - triplet_acc: 0.73 - ETA: 49s - loss: 0.6288 - triplet_acc: 0.74 - ETA: 49s - loss: 0.6215 - triplet_acc: 0.74 - ETA: 48s - loss: 0.6153 - triplet_acc: 0.74 - ETA: 48s - loss: 0.6037 - triplet_acc: 0.75 - ETA: 49s - loss: 0.6119 - triplet_acc: 0.74 - ETA: 48s - loss: 0.5974 - triplet_acc: 0.75 - ETA: 48s - loss: 0.6025 - triplet_acc: 0.75 - ETA: 48s - loss: 0.6050 - triplet_acc: 0.75 - ETA: 48s - loss: 0.5947 - triplet_acc: 0.75 - ETA: 48s - loss: 0.5856 - triplet_acc: 0.75 - ETA: 48s - loss: 0.5815 - triplet_acc: 0.75 - ETA: 48s - loss: 0.5757 - triplet_acc: 0.75 - ETA: 48s - loss: 0.5854 - triplet_acc: 0.75 - ETA: 47s - loss: 0.5956 - triplet_acc: 0.75 - ETA: 47s - loss: 0.5969 - triplet_acc: 0.75 - ETA: 47s - loss: 0.5917 - triplet_acc: 0.75 - ETA: 47s - loss: 0.5821 - triplet_acc: 0.76 - ETA: 47s - loss: 0.5805 - triplet_acc: 0.76 - ETA: 47s - loss: 0.5716 - triplet_acc: 0.76 - ETA: 47s - loss: 0.5741 - triplet_acc: 0.76 - ETA: 46s - loss: 0.5781 - triplet_acc: 0.76 - ETA: 46s - loss: 0.5715 - triplet_acc: 0.76 - ETA: 46s - loss: 0.5618 - triplet_acc: 0.76 - ETA: 46s - loss: 0.5686 - triplet_acc: 0.76 - ETA: 46s - loss: 0.5740 - triplet_acc: 0.76 - ETA: 45s - loss: 0.5867 - triplet_acc: 0.76 - ETA: 45s - loss: 0.5873 - triplet_acc: 0.76 - ETA: 45s - loss: 0.6050 - triplet_acc: 0.75 - ETA: 45s - loss: 0.6059 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6161 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6259 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6175 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6191 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6102 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6051 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6012 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6089 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6022 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6007 - triplet_acc: 0.75 - ETA: 42s - loss: 0.6244 - triplet_acc: 0.75 - ETA: 42s - loss: 0.6244 - triplet_acc: 0.75 - ETA: 42s - loss: 0.6410 - triplet_acc: 0.75 - ETA: 42s - loss: 0.6330 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6262 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6264 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6235 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6244 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6203 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6168 - triplet_acc: 0.75 - ETA: 40s - loss: 0.6285 - triple ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ba50f63981d4> in <module>()
#       8         epochs=1,
#       9         validation_data=image_generator(filenames_test,labels_test,3*10,False),
# ---> 10         validation_steps=30
#      11     )]
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.npy',history_)
np.savetxt(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(0)+'.h5')

# %%
# dogfacenet_v24
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,64,128,256,512]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v23
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,128,512,1024]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    for i in range(2):
        gsize = layer//32
        branch = []
        for group in range(32):
            x = Conv2D(gsize, (1, 1), use_bias=False, padding='same')(r)
            x = BatchNormalization()(x)
            
            x = Conv2D(gsize, (3, 3), use_bias=False, activation='relu', padding='same')(x)
            x = BatchNormalization()(x)
            x = Dropout(0.5)(x)
            
            branch += [x]
        
        x = Concatenate()(branch)
        x = Conv2D(layer, (1, 1), use_bias=False, activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        r = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v18
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [32,32,64,128,512]:
    
    for channel in range(4):
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v20
# close to official resnet with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [16,32,64,128,512,1024]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # Resnet blocks
    for j in range(2):
        x = Conv2D(layer, (1, 1), padding='same')(r)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v21
# close to official resneXt with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [32,64,128,512,1024,2048]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # ResneXt blocks, group 16
    for j in range(2):
        ksize = layer//16
        branch_res = []
        
        for k in range(16):
            x = Conv2D(ksize, (1, 1), padding='same')(r)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)

            x = Conv2D(ksize, (3, 3), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            x = Dropout(0.5)(x)
            
            branch_res += [x]
        
        x = Concatenate()(branch_res)
        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.20.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug_2.16.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model.evaluate(triplet_test,y_triplet_test, batch_size=63)

# %%
from IPython.display import FileLink

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5')

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.50.h5')

# %%
FileLink(PATH_SAVE + '2018.02.27.dogfacenet_v11.hard_triplet.data_aug.10.a_0.3.npy')

# %%
model.save(PATH_MODEL + '2019.02.12.hard_triplet_trained.data_aug.0.h5')

# %%
triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %%
print(str((3*len(predict_train)+3*(nbof_classes//10 + 1),h,w,c)))

# %%
del new_images_train
del new_labels_train
del predict_train
del triplet_train, y_triplet_train
gc.collect()

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

# %%
histories = []

# %%
for i in range(6):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories += [history]

# %%
model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(1)+'.h5')

# %%
histories2 = [histories[i] for i in range(29)]

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
for i in range(2):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories2 += [history]
model.save(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(16)+'.h5')

# %%
histories = histories[:-2]

# %%
model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(0.0001),
              metrics=[triplet_acc])

# %% [markdown]
# - 14*3 epochs with lr=0.001
# - 4*3 epochs with lr=0.0005
# - 4*3 epochs with lr=0.0003
# - 4*1 epochs with lr=0.0001

# %%
 model.save(PATH_MODEL + '2019.02.28.dogfacenet_v22.hard_triplet.alpha.0.3.'+str(l)+'.h5')

# %%
histories = []

# %%
epochs = [14,4,4,4]
lr = [0.001,0.0005,0.0003,0.0001]
for l in range(1,len(lr)):
    model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(lr[l]),
              metrics=[triplet_acc])
    for k in range(epochs[l]):
        epoch_nb = k+sum(epochs[:l])
        print("Beginning epoch number: "+str(epoch_nb)+", over "+str(sum(epochs))+" epochs. \n")

        
        new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
        predict_train=model.predict(new_images_train)
        triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

        for i in range(6):
            history = model.fit(
                triplet_train,
                y_triplet_train,
                batch_size = 21*3,
                epochs = 1,
                validation_data=(triplet_test,y_triplet_test),
                shuffle=False
            )
            histories += [history]
        
        del new_images_train, new_labels_train, predict_train, triplet_train, y_triplet_train
        gc.collect()
        model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(k)+'.h5')

        loss = np.empty(0)
        val_loss = np.empty(0)
        acc = np.empty(0)
        val_acc = np.empty(0)

        for history in histories:
            loss = np.append(loss,history.history['loss'])
            val_loss = np.append(val_loss,history.history['val_loss'])
            acc = np.append(acc,history.history['triplet_acc'])
            val_acc = np.append(val_acc,history.history['val_triplet_acc'])


        history_ = np.array([loss,val_loss,acc,val_acc])
        np.save(PATH_SAVE+'2019.04.08.dogfacenet_v12.npy',history_)
        np.savetxt(PATH_SAVE+'2019.04.08.dogfacenet_v12.txt',history_)

# %%
model.save(PATH_MODEL + '2019.02.28.dogfacenet_v24.hard_triplet.alpha.0.3.'+str(0)+'.h5')

# %%
history_ = np.load(PATH_SAVE+'2018.02.28.dogfacenet_v12.hard_triplet.data_aug.5.a_0.3.npy')

# %%
loss,val_loss,acc,val_acc = history_

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
for i in range(5):
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

    model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )

    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(i+16)+'.h5')

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
history=model.fit(
    triplet_train,
    y_triplet_train,
    batch_size = 21*3,
    epochs = 1,
    validation_data=(triplet_test,y_triplet_test),
    shuffle=False
)

# %%
model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5')

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

loss = np.append(loss,history.history['loss'])
val_loss = np.append(val_loss,history.history['val_loss'])
acc = np.append(acc,history.history['triplet_acc'])
val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
histories = []
nbof_cycles = 9
for i in range(0,nbof_cycles,1):

    history=model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = nbof_cycles-i,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    
    histories += [history]
    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v10.hard_triplet_trained.data_aug.' + str(i+1) + '.h5')
    
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for i in range(len(histories)):
    history = histories[i]
    
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
# Test on new triplet integrity
print(new_y_triplet_train[-30:])
t = np.equal(new_y_triplet_train[0::3],new_y_triplet_train[1::3])
print(t)
np.sum(t.astype(np.float32))/len(t)

# %% [markdown]
# ### Evaluate it

# %% [markdown]
# #### Evaluate on verification task

# %%
NBOF_PAIRS = 5000
#NBOF_PAIRS = len(images_test)

# Create pairs
h,w,c = SIZE
pairs = np.empty((NBOF_PAIRS*2,h,w,c))
issame = np.empty(NBOF_PAIRS)
class_test = np.unique(labels_test)
for i in range(NBOF_PAIRS):
    alea = np.random.rand()
    # Pair of different dogs
    if alea < 0.5:
        # Chose the classes:
        class1 = np.random.randint(len(class_test))
        class2 = np.random.randint(len(class_test))
        while class1==class2:
            class2 = np.random.randint(len(class_test))
            
        # Extract images of this class:
        images_class1 = images_test[np.equal(labels_test,class1)]
        images_class2 = images_test[np.equal(labels_test,class2)]
        
        # Chose an image amoung these selected images
        pairs[i*2] = images_class1[np.random.randint(len(images_class1))]
        pairs[i*2+1] = images_class2[np.random.randint(len(images_class2))]
        issame[i] = 0
    # Pair of same dogs
    else:
        # Chose a class
        clas = np.random.randint(len(class_test))
        images_class = images_test[np.equal(labels_test,clas)]
        
        # Select two images from this class
        idx_image1 = np.random.randint(len(images_class))
        idx_image2 = np.random.randint(len(images_class))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(images_class))
        
        pairs[i*2] = images_class[idx_image1]
        pairs[i*2+1] = images_class[idx_image2]
        issame[i] = 1

# %%
# Test: Check the pairs
s = 10
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(5,3*n))
for i in range(s,s+n):
    plt.subplot(n,2,2*(i-s)+1)
    plt.imshow(pairs[2*i]*0.5+0.5)
    plt.subplot(n,2,2*(i-s)+2)
    plt.imshow(pairs[2*i+1]*0.5+0.5)

# %%
predict=model.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)


best = 0
best_t = 0
thresholds = np.arange(0.001,4,0.001)
for i in tqdm_notebook(range(len(thresholds))):
    less = np.less(dist, thresholds[i])
    acc = np.logical_not(np.logical_xor(less, issame))
    acc = acc.astype(float)
    out = np.sum(acc)
    out = out/len(acc)
    if out > best:
        best_t = thresholds[i]
        best = out

print("Best threshold: " + str(best_t))
print("Best accuracy: " + str(best))

# %%
# False accepted examples and False rejected examples
t = 0.68
fa = []
fr = []
for i in range(len(dist)):
    # false accepted
    if issame[i] == 0 and dist[i]<t:
        fa += [i]
    if issame[i] == 1 and dist[i]>t:
        fr += [i]

# %%
# Test: Look at wrong pairs
s = 10
sr = 20
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(11,2.8*n))
for i in range(s,s+n):
    # False accepted
    plt.subplot(n,4,4*(i-s)+1)
    plt.imshow(pairs[2*fa[i+s]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+2)
    plt.imshow(pairs[2*fa[i+s]+1])
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(n,4,4*(i-s)+3)
    plt.imshow(pairs[2*fr[i+sr]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+4)
    plt.imshow(pairs[2*fr[i+sr]+1])
    plt.xticks([])
    plt.yticks([])

# %%
len(fa)

# %%
len(fr)

# %%
threshold = 0.3
less = np.less(dist, threshold)
acc = np.logical_not(np.logical_xor(less, issame))
acc = acc.astype(float)
out = np.sum(acc)
out = out/len(acc)

print("Accuracy: " + str(out))

# %% [markdown]
# ### ROC curve

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)

# Computes the ROC depending on different thresholds

thresholds = np.arange(0.001,4,0.001)
tprs = np.empty(len(thresholds))
fprs = np.empty(len(thresholds))

p = np.sum(issame.astype(float))
n = np.sum(np.logical_not(issame).astype(float))

for i in tqdm_notebook(range(len(thresholds))):
    logical_pred = np.less(dist, thresholds[i])
    tp = np.sum(np.logical_and(logical_pred,issame).astype(float))
    fp = np.sum(np.logical_and(logical_pred,np.logical_not(issame)).astype(float))
    tprs[i] = tp/p
    fprs[i] = fp/n

# %%
np.save('roc_dogfacenet_v11.npy', [tprs, fprs])

# %%
tprs2,fprs2 = np.load('roc_dogfacenet_v12.npy')

# %%
plt.figure(figsize=(5,5))
plt.plot(fprs,tprs,label="VGG-like")
plt.plot(fprs2,tprs2,label="ResNet-like")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
#plt.title("ROC curve")

# %% [markdown]
# ### Second verification task: IN or OUT? actually I think that this task doesn't make any sense

# %%
pred_test = model.predict(images_test)

# %%
nbof_try = 30 # We will do many try on the test dataset to obtain a more precize accuracy

for propo in [0.5,0.6,0.7,0.8,0.9]:
    print("Current propotion of classes considered: " + str(propo))
    
    mean_acc = 0
    max_acc = 0
    min_acc = 1
    mean_t = 0
    
    for _ in tqdm_notebook(range(nbof_try)):
        nbof_kimages=int(propo*len(np.unique(labels_test)))
        kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
        y_kimages = np.unique(labels_test)[:nbof_kimages]

        others_pred = np.copy(pred_test)
        y_others = np.copy(labels_test)

        for i in range(nbof_kimages):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
            choice = np.random.randint(len(keep_classes_images))

            kpred[i] = others_pred[keep_classes_images[choice]]

            others_pred = np.delete(others_pred,keep_classes_images[choice],0)
            y_others = np.delete(y_others,keep_classes_images[choice],0)

        # We find the best threshold for this dataset
        best_acc = 0
        best_t = 0.01
        for threshold in np.arange(0.01,1,0.01):

            acc = 0

            class_pred = np.empty(len(others_pred))

            for i in range(len(others_pred)):
                # computes distance with the key dataset
                dist = np.sum(np.square(kpred-others_pred[i]),1)
                if np.min(dist) < threshold:
                    if y_others[i] in y_kimages:
                        acc += 1
                else:
                    if not y_others[i] in y_kimages:
                        acc += 1
            acc /= len(others_pred)

            if acc > best_acc:
                best_acc = acc
                best_t = threshold

        mean_acc += best_acc
        mean_t += best_t
        
        if best_acc > max_acc:
            max_acc = best_acc
        if best_acc < min_acc:
            min_acc = best_acc
        
    mean_acc /= nbof_try
    
    mean_t /= nbof_try
    print("Mean accuracy for in/out: " + str(mean_acc))
    print("Max accuracy for in/out: " + str(max_acc))
    print("Min accuracy for in/out: " + str(min_acc))
    print("Mean threshold for in/out: " + str(mean_t))

# %% [markdown]
# ### Face clustering

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(images_test)

# %%
predict=model.predict(images_test)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=len(np.unique(labels_test)),max_iter=2000, random_state=0,tol=0.2).fit(predict)

# %%
images_cluster = [images_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]
labels_cluster = [labels_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]

# %%
len(images_train)

# %%
len(images_test)

# %%
i = 10
length = len(images_cluster[i])
fig=plt.figure(figsize=(5,5))
for j in range(3):
    for k in range(3):
        plt.subplot(3,3,j*3+k+1)
        plt.imshow(images_cluster[i][j*3+k])
        plt.xticks([])
        plt.yticks([])
#fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.1000.png')

# %%
for i in range(len(images_cluster)):
    length = len(images_cluster[i])
    if length > 0:
        print(labels_cluster[i])
        fig=plt.figure(figsize=(length*2,2))
        for j in range(length):
            plt.subplot(1,length,j+1)
            plt.imshow(images_cluster[i][j])
            plt.xticks([])
            plt.yticks([])
        plt.show()
        #fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.'+str(i)+'.png')

# %% [markdown]
# ### Recognition: K-NN
# m is the number of images that are going to be selected for k-NN "training".

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
for m in range(1,5):
    
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)
    
    # Model prediction on the reduce dataset
    new_pred_test = model.predict(new_images_test)

    nbof_test = 1000
    mean_acc = 0
    mini = 1
    maxi = 0
    
    # Definition of K
    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # I select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)
        acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
nbof_test = 1000
mean_acc = 0
mini = 1
maxi = 0
if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# ### Recognition: k-NN top 1/2/3/4/5

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
max_rk = 5 # Top "max_rk" accuracy

for m in range(1,5):
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)

    new_pred_test = model.predict(new_images_test)

    nbof_test = 100
    mean_acc = 0
    mini = 1
    maxi = 0

    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # Second we select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)

        rk1_pred_y_others = neigh.predict(others_pred)
        pred_y_others = np.zeros((len(others_pred),max_rk))
        for i in range(len(pred_y_others)):
            pred_y_others[i][0] = rk1_pred_y_others[i]

        for i in range(1,max_rk):
            for j in range(len(pred_y_others)):
                previous_pred = [pred_y_others[j][k] for k in range(0,i)]
                to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
                for k in range(1,len(previous_pred)):
                    to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
                new_kpred = kpred[to_keep]
                new_y_kimages = y_kimages[to_keep]

                neigh.fit(new_kpred, new_y_kimages)

                pred_y_others[j][i] = neigh.predict([others_pred[j]])

        #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
        acc = 0
        for i in range(len(pred_y_others)):
            if y_others[i] in pred_y_others[i]:
                acc += 1
        acc /= len(pred_y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
m = 2
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

new_pred_test = model.predict(new_images_test)

# %%
nbof_test = 100
mean_acc = 0
mini = 1
maxi = 0
max_rk = 5

if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    
    rk1_pred_y_others = neigh.predict(others_pred)
    pred_y_others = np.zeros((len(others_pred),max_rk))
    for i in range(len(pred_y_others)):
        pred_y_others[i][0] = rk1_pred_y_others[i]

    for i in range(1,max_rk):
        for j in range(len(pred_y_others)):
            previous_pred = [pred_y_others[j][k] for k in range(0,i)]
            to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
            for k in range(1,len(previous_pred)):
                to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
            new_kpred = kpred[to_keep]
            new_y_kimages = y_kimages[to_keep]
            
            neigh.fit(new_kpred, new_y_kimages)
    
            pred_y_others[j][i] = neigh.predict([others_pred[j]])

    #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    acc = 0
    for i in range(len(pred_y_others)):
        if y_others[i] in pred_y_others[i]:
            acc += 1
    acc /= len(pred_y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# #### k-NN test part

# %%
m = 3
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

# %%
new_pred_test = model.predict(new_images_test)

# %%
# Second we select m images per classes for k-NN training
nbof_kimages=m*len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.empty(nbof_kimages, dtype=int)
y_kuniques = np.unique(new_labels_test)
for i in range(len(y_kuniques)):
    for j in range(m):
        y_kimages[i*2+j] = y_kuniques[i]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(len(y_kuniques)):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*2],y_others)]
    choices = np.empty(0,dtype=int)
    
    if len(keep_classes_images) <= m:
        print("Bug!")
        break
        
    for j in range(m):
        choice = np.random.randint(len(keep_classes_images))
        while choice in choices:
            choice = np.random.randint(len(keep_classes_images))
        choices=np.append(choices,choice)
    #print(choices)
    for j in range(m):
        kpred[i*2+j] = others_pred[keep_classes_images[choices[j]]]

    others_pred = np.delete(others_pred,keep_classes_images[choices],0)
    y_others = np.delete(y_others,keep_classes_images[choices],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=m+1, weights='distance')
neigh.fit(kpred, y_kimages)
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.unique(new_labels_test)[:nbof_kimages]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh = KNeighborsClassifier(n_neighbors=1)
    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(labels_test))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
nbof_kimages=len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.unique(new_labels_test)[:nbof_kimages]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(kpred, y_kimages)

# %%
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
mean_acc = 0
nbof_try = 1 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = y_others[i]
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %%
def find_n_mins(t,n):
    idx_mins = []
    mins = []
    for i in range(n):
        idx_crt_min = 0
        crt_min = t[0]
        for j in range(1,len(t)):
            if t[j] < crt_min:
                crt_min = t[j]
                idx_crt_min = j
        idx_mins += [idx_crt_min]
        mins += [crt_min]
        t = t[:idx_crt_min] + t[idx_crt_min+1:]
    return idx_mins, mins

# %% [markdown]
# ### Recognition: One-shot learning (deprecated: use the above part with M=1 instead)

# %%
pred_test = model.predict(images_test)

# %%
mean_acc = 0
nbof_try = 1000 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = 1
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %% [markdown]
# #### Test for one-shot learning:

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kimages=np.empty((nbof_kimages,h,w,c))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others = np.copy(images_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kimages[i] = others[keep_classes_images[choice]]
    
    others = np.delete(others,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

kpred = model.predict(kimages)

# Prediction for every other pictures
others_pred = model.predict(others)

# %%
pred_test = model.predict(images_test)

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others_pred = np.copy(pred_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
# we will use the best threshold find on verification task
threshold = 0.3

# for i in range(len(others_pred)):

acc = 0

class_pred = np.empty(len(others_pred))

for i in range(len(others_pred)):
    # computes distance with the key dataset
    dist = np.sum(np.square(kpred-others_pred[i]),1)
    if np.min(dist) < threshold:
        class_pred[i] = np.argmin(dist)
        if np.argmin(dist)==y_others[i]:
            acc += 1
    else:
        class_pred[i] = -1
        if not y_others[i] in y_kimages:
            acc += 1
        
acc /= len(others_pred)
acc

# %%
# we will find the best threshold for verification
best_acc = 0
best_t = 0.001
for threshold in np.arange(0.001,1,0.001):

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = np.argmin(dist)
            if np.argmin(dist)==y_others[i]:
                acc += 1
#             if y_others[i] in y_kimages:
#                 acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1
    acc /= len(others_pred)
    
    if acc > best_acc:
        best_acc = acc
        best_t = threshold


print(best_acc)
print(best_t)

# %%
plt.figure(figsize=(8,5))
for i in range(38):
    plt.subplot(5,8,i+1)
    plt.imshow(kimages[i])

# %%
plt.figure(figsize=(13,18))
for i in range(13*18):
    plt.subplot(18,13,i+1)
    plt.imshow(others[i])

# %% [markdown]
# ### Recognition: Re-training

# %%
s = 30.
m = 0.3
def cosine(y_true,y_pred):
    
    exp_s = K.exp(s * y_pred)
    exp_s_m = K.exp(s * (y_pred - m))
    
    masked_exp_s_m = exp_s_m * y_true
    
    inv_mask = 1. - y_true
    masked_exp_s = exp_s * inv_mask
    
    den = K.sum(masked_exp_s + masked_exp_s_m, axis=-1, keepdims=True)
    out = masked_exp_s_m / den
    out = K.sum(out,axis=-1)
    ret = - K.log(out)
    ret = K.sum(ret)
    return ret

# %%
class Cosine(tf.keras.layers.Layer):

    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(Cosine, self).__init__(**kwargs)

    def build(self, input_shape):
        shape = tf.TensorShape((input_shape[-1],self.output_dim))

        self.kernel = self.add_weight(name='kernel', 
                                      shape=shape,
                                      initializer='uniform',
                                      trainable=True)
        super(Cosine, self).build(input_shape)

    def call(self, x):
        x = tf.math.l2_normalize(x, axis=-1)
        w = tf.math.l2_normalize(self.kernel, axis=0)
        
        return K.dot(x, w)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

# %%
labels_test_exp = tf.keras.utils.to_categorical(labels_test)

# %%
#out = tf.keras.layers.Dense(128, activation='relu')(model.output)
out = Cosine(len(labels_test_exp[0]))(model.output)
#out = tf.keras.layers.Dense(24, activation='softmax')(out)
recog = tf.keras.Model(model.input,out)
for layer in model.layers: layer.trainable = False
recog.compile(tf.keras.optimizers.Adam(),loss=cosine,metrics=['accuracy'])

# %%
recog.fit(images_test,labels_test_exp,batch_size=64,epochs=30)

# %% [markdown]
# ### Observation on the heatmap

# %%
model.layers

# %%
mod3 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict3 = mod3.predict(images_train[0:100:10])

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(10,10,i*10+1)
    sk.io.imshow(images_train[i*10])
    
    for j in range(9):
        pred3 = np.mean(predict3[i][:,:,j*25:j*25+3],axis=-1)
        plt.subplot(10,10,i*10+2+j)
        sk.io.imshow(images_train[i*10])
        plt.imshow(pred3,cmap='plasma')

# %%
s = 100
mod1 = tf.keras.Model(model.layers[0].input, model.layers[1].output)
predict1 = mod1.predict(images_train[0+s:100+s:10])

mod2 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict2 = mod2.predict(images_train[0+s:100+s:10])

mod3 = tf.keras.Model(model.layers[0].input, model.layers[14].output)
predict3 = mod3.predict(images_train[0+s:100+s:10])

plt.figure(figsize=(9,20))
for i in range(10):
    pred1 = np.mean(predict1[i],axis=-1)
    pred2 = np.mean(predict2[i],axis=-1)
    pred3 = np.mean(predict3[i],axis=-1)

    
    plt.subplot(10,4,i*4+1)
    sk.io.imshow(images_train[i*10 + s])
    plt.subplot(10,4,i*4+2)
    plt.imshow(pred1,cmap='plasma')
    plt.subplot(10,4,i*4+3)
    plt.imshow(pred2,cmap='plasma')
    plt.subplot(10,4,i*4+4)
    plt.imshow(pred3,cmap='plasma')

# %%
history = model.fit_generator(
    train_datagen.flow(images_train,labels_train,batch_size = 64),
    epochs = 12,
    validation_data=(images_valid,labels_valid)
)

# %%
model.save('../output/model/dogfacenet_v6_cosine.h5')
