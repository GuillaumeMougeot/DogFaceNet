# %% [markdown]
# # DogFaceNet version 11: Dev version number on LFW dataset

# %% [markdown]
# ### Imports and constants

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

import os
import pickle
import numpy as np
import skimage as sk
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import tensorflow.keras.backend as K
from triplets_processing import *
import shutil
import gc

# %%
PATH = '../../../data/lfw_center/'
#PATH = 'D:/PROGRAMMATION/Dataset/lfw/lfw_center/'
PATH_SAVE = '../output/history/'
PATH_MODEL = '../output/model/'
SIZE = (151,151,3)
VALID_SPLIT = 0.1
TEST_SPLIT = 0.1

# %% [markdown]
# ### Data pre-processing
# - Load image and labels
# - Training set, validation set (close-set) and testing (open-set)

# %%
filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
        filenames = np.append(filenames,files)
        labels = np.append(labels,np.ones(len(files))*idx)
        idx += 1
print(len(labels))
h,w,c = SIZE
images = np.empty((len(filenames),h,w,c))
for i,f in enumerate(filenames):
    images[i] = sk.io.imread(f)

# %%
# Normalization
images /= 255.0

# %%
# Resize all the images
filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
            sk.io.imsave(files[i],sk.transform.resize(sk.io.imread(files[i]),SIZE,anti_aliasing=True))

# %%
# Without imread

filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
        filenames = np.append(filenames,files)
        labels = np.append(labels,np.ones(len(files))*idx)
        idx += 1
    if len(files) == 1:
        #print(root)
        shutil.rmtree(root)
print(len(labels))
filenames
# Out:
# 9164
# array(['D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0001.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0002.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Aaron_Peirsol/Aaron_Peirsol_0003.jpg',
#        ...,
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0002.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0003.jpg',
#        'D:/PROGRAMMATION/Dataset/lfw/lfw_center/Zoran_Djindjic/Zoran_Djindjic_0004.jpg'],
#       dtype='<U112')

# %%
nbof_classes = len(np.unique(labels))
print(nbof_classes)
# Out:
# 1680

# %%
# Center all the faces
for f in filenames:
    img = sk.io.imread(f)
    img_c = img[50:201,50:201,:]
    sk.io.imsave(f,img_c)

# %%
img_c.shape

# %% [markdown]
# ### Data augmentation

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    zoom_range=0.1,
    fill_mode='nearest',
    channel_shift_range = 0.1
)

# %%
def apply_transform(images, datagen):
    """
    Apply a data preprocessing transformation to n images
    Args:
        -images
        -ImageDataGenerator
    Return:
        -images of the same shape of the inputs but transformed
    """
    for x in datagen.flow(images, batch_size=len(images), shuffle=False):
        return x

# %% [markdown]
# Open-set: test set

# %%
n = 3
cumul = np.empty(labels.shape)
cumul[0] = 1
crt_label = labels[0]
to_keep = []
for i in range(1,len(labels)):
    if labels[i] == labels[i-1]:
        cumul[i] = cumul[i-1] + 1
    else:
        cumul[i] = 1
        if cumul[i-1] >= n:
            to_keep += [labels[i-1]]
bool_keep = np.zeros(labels.shape, dtype=bool)
for i in range(len(to_keep)):
    bool_keep = np.logical_or(bool_keep,np.equal(to_keep[i],labels))
print("Ratio of kept classes: " + str(len(to_keep)/nbof_classes))
print("Ratio of kept images: " + str(len(labels[bool_keep])/len(labels)))
filenames_train = filenames[bool_keep]
labels_train = labels[bool_keep]

keep_test = np.logical_not(bool_keep)
filenames_test = filenames[keep_test]
labels_test = labels[keep_test]

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

filenames_test = filenames[keep_test]
labels_test = labels[keep_test]

filenames_train = filenames[keep_train]
labels_train = labels[keep_train]

print("Number of training data: " + str(len(filenames_train)))
print("Number of training classes: " + str(nbof_classes-nbof_test))
print("Number of testing data: " + str(len(filenames_test)))
print("Number of testing classes: " + str(nbof_test))
# Out:
# Number of training data: 8241
# Number of training classes: 1512
# Number of testing data: 923
# Number of testing classes: 168

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

images_test = images[keep_test]
labels_test = labels[keep_test]

images_train = images[keep_train]
labels_train = labels[keep_train]

# %%
del images
del labels
gc.collect()

# %%
def define_triplets_batch(filenames,labels,nbof_triplet = 21 * 3):
    
    triplet_train = []
    y_triplet = np.empty(nbof_triplet)
    classes = np.unique(labels)
    for i in range(0,nbof_triplet,3):
        # Pick a class and chose two pictures from this class
        classAP = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classAP)
        keep_classAP = filenames[keep]
        keep_classAP_idx = labels[keep]
        idx_image1 = np.random.randint(len(keep_classAP))
        idx_image2 = np.random.randint(len(keep_classAP))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(keep_classAP))

        triplet_train += [keep_classAP[idx_image1]]
        triplet_train += [keep_classAP[idx_image2]]
        y_triplet[i] = keep_classAP_idx[idx_image1]
        y_triplet[i+1] = keep_classAP_idx[idx_image2]
        # Pick a class for the negative picture
        classN = classes[np.random.randint(len(classes))]
        while classN==classAP:
            classN = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classN)
        keep_classN = filenames[keep]
        keep_classN_idx = labels[keep]
        idx_image3 = np.random.randint(len(keep_classN))
        triplet_train += [keep_classN[idx_image3]]
        y_triplet[i+2] = keep_classN_idx[idx_image3]
        
    return triplet_train, y_triplet

# %%
def define_hard_triplets_batch(filenames,labels,predict,nbof_triplet=21*3, use_neg=True, use_pos=True):
    """
    Generates hard triplet for offline selection. It will consider the whole dataset.
    
    Args:
        -images: images from which the triplets will be created
        -labels: labels of the images
        -predict: predicted embeddings for the images by the trained model
        -alpha: threshold of the triplet loss
    Returns:
        -triplet
        -y_triplet: labels of the triplets
    """
    # Check if we have the right number of triplets
    assert nbof_triplet%3 == 0
    
    _,idx_classes = np.unique(labels,return_index=True)
    classes = labels[np.sort(idx_classes)]
    
    triplets = []
    y_triplets = np.empty(nbof_triplet)
    
    idx_triplets = 0
    idx_images = 0
    
    for i in range(0,nbof_triplet,3):
        # Chooses the first class randomly
        keep = np.equal(labels,classes[np.random.randint(len(classes))])
        keep_filenames = filenames[keep]
        keep_labels = labels[keep]
        
        # Chooses the first image among this class randomly
        idx_image1 = np.random.randint(len(keep_labels))
        
        
        # Computes the distance between the chosen image and the rest of the class
        if use_pos:
            dist_class = np.sum(np.square(predict[keep]-predict[keep][idx_image1]),axis=-1)

            idx_image2 = np.argmax(dist_class)
        else:
            idx_image2 = np.random.randint(len(keep_labels))
            i = 0
            while idx_image1==idx_image2:
                idx_image2 = np.random.randint(len(keep_labels))
                # Just to prevent endless loop:
                i += 1
                if i == 1000:
                    print("[Error: define_hard_triplets_batch] Endless loop.")
                    break
        
        triplets += [keep_filenames[idx_image1]]
        y_triplets[i] = keep_labels[idx_image1]
        triplets += [keep_filenames[idx_image2]]
        y_triplets[i+1] = keep_labels[idx_image2]
        
        
        # Computes the distance between the chosen image and the rest of the other classes
        not_keep = np.logical_not(keep)
        
        if use_neg:
            dist_other = np.sum(np.square(predict[not_keep]-predict[keep][idx_image1]),axis=-1)
            idx_image3 = np.argmin(dist_other) 
        else:
            idx_image3 = np.random.randint(len(filenames[not_keep]))
            
        triplets += [filenames[not_keep][idx_image3]]
        y_triplets[i+2] = labels[not_keep][idx_image3]

    #return triplets, y_triplets
    return np.array(triplets), y_triplets

# %%
def load_images(filenames):
    h,w,c = SIZE
    #print(filenames)
    images = np.empty((len(filenames),h,w,c))
    for i,f in enumerate(filenames):
        #print(f)
        images[i] = sk.io.imread(f)/255.0
    return images

# %%
def image_generator(filenames, labels, batch_size=63, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_triplets_batch(filenames, labels, batch_size)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def hard_image_generator(filenames, labels, predict, batch_size=63, use_neg=True, use_pos=True, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_hard_triplets_batch(filenames, labels, predict, batch_size, use_neg=use_neg, use_pos=use_pos)
        i_triplet = load_images(f_triplet)
#         for f in f_triplet:
#             print(f)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def predict_generator(filenames, batch_size=32):
    for i in range(0,len(filenames),batch_size):
        images_batch = load_images(filenames[i:i+batch_size])
        yield images_batch

# %%
def online_hard_image_generator(
    filenames,
    labels,
    model,
    batch_size=63,
    nbof_subclasses=10,
    use_neg=True,
    use_pos=True,
    use_aug=True,
    datagen=datagen):
    """
    Generator to select online hard triplets for training.
    
    Arguments:
        -filenames
        -labels
    """
    while True:
        # Select a certain amount of subclasses
        classes = np.unique(labels)
        subclasses = np.random.choice(classes,size=nbof_subclasses,replace=False)
        
        keep_classes = np.equal(labels,subclasses[0])
        for i in range(1,len(subclasses)):
            keep_classes = np.logical_or(keep_classes,np.equal(labels,subclasses[i]))
        subfilenames = filenames[keep_classes]
        sublabels = labels[keep_classes]
        predict = model.predict_generator(predict_generator(subfilenames, 32),
                                          steps=np.ceil(len(subfilenames)/32))
        
        f_triplet, y_triplet = define_hard_triplets_batch(subfilenames, sublabels, predict, batch_size, use_neg=use_neg, use_pos=use_pos)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def online_adaptive_hard_image_generator(
    filenames,
    labels,
    model,
    batch_size=63,
    nbof_subclasses=10,
    use_neg=True,
    use_pos=True,
    use_aug=True,
    datagen=datagen):
    """
    Generator to select online hard triplets for training.
    
    Include an adaptive control on the number of hard triplets included during the training.
    
    Arguments:
        -filenames
        -labels
    """
    batch_loss = batch_size
    hard_triplet_ratio = 0
    nbof_hard_triplets = 0
    while True:
        # Select a certain amount of subclasses
        classes = np.unique(labels)
        subclasses = np.random.choice(classes,size=nbof_subclasses,replace=False)
        
        keep_classes = np.equal(labels,subclasses[0])
        for i in range(1,len(subclasses)):
            keep_classes = np.logical_or(keep_classes,np.equal(labels,subclasses[i]))
        subfilenames = filenames[keep_classes]
        sublabels = labels[keep_classes]
        predict = model.predict_generator(predict_generator(subfilenames, 32),
                                          steps=np.ceil(len(subfilenames)/32))
        
        
        
        
        
        f_triplet_hard, y_triplet_hard = define_hard_triplets_batch(subfilenames, sublabels, predict, nbof_hard_triplets*3, use_neg=True, use_pos=True)
        f_triplet_soft, y_triplet_soft = define_hard_triplets_batch(subfilenames, sublabels, predict, batch_size-nbof_hard_triplets*3, use_neg=False, use_pos=False)
#         print(f_triplet_soft)
#         print("shape hard: " + str(f_triplet_hard.shape))
#         print("shape soft: " + str(f_triplet_soft.shape))
        f_triplet = np.append(f_triplet_hard,f_triplet_soft)
        y_triplet = np.append(y_triplet_hard,y_triplet_soft)
        
        # Proportion of hard triplets in the generated batch
        batch_loss = triplet_numpy(f_triplet, y_triplet)
#         print(batch_loss)
        hard_triplet_ratio = np.exp(-batch_loss * 10 / batch_size)
#         print(hard_triplet_ratio)
        nbof_hard_triplets = int(batch_size//3 * hard_triplet_ratio)
#         print(nbof_hard_triplets)
        
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
# Test normal triplets
for a,y in image_generator(filenames_train,labels_train,9):
    for i in range(3):
        for j in range(3):
            plt.subplot(3,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    break

# %%
# Test load_images
fs = filenames_train[np.equal(labels_train,745)]
print(fs)
ise = load_images(fs)
for i in range(len(ise)):
    plt.subplot(len(ise),5,i+1)
    plt.imshow(ise[i])

# %%
# Test hard triplets
batch_predict = 32

#predict_train = np.random.random((len(labels_train),1))
# predict_train = model.predict_generator(predict_generator(filenames_train, batch_predict),
#                                   steps=np.ceil(len(filenames_train)/batch_predict))
disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in hard_image_generator(filenames_train,labels_train, predict_train, disp*3, use_aug=False):
    for i in range(10):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    
    print(y)
    break

# %%
# Test online hard triplets

disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in online_hard_image_generator(filenames_train,labels_train, model, disp*3, use_neg=False):
    for i in range(disp):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    print(y)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-58eb1c03a093> in <module>()
#       3 disp = 10
#       4 plt.figure(figsize=(7,disp*2.2))
# ----> 5 for a,y in online_hard_image_generator(filenames_train,labels_train, model, disp*3, use_neg=False):
#       6     for i in range(disp):
#       7         for j in range(3):
#
# NameError: name 'online_hard_image_generator' is not defined

# %%
# Test online hard triplets

disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in online_adaptive_hard_image_generator(filenames_train,labels_train, model, disp*3):
    for i in range(disp):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    print(y)
    break
# Out:
# [ 307.  307.  782.  863. 1097.  639.  924.  924.  586.  586.  924. 1022.
#  1097. 1097. 1097. 1097. 1097. 1097. 1155. 1155. 1155. 1268. 1268. 1441.
#  1441. 1655. 1655. 1655. 1655. 1655.]

# %%
# Test predict_generator
batch_predict = 32
predict_train = model.predict_generator(predict_generator(filenames_train, batch_predict),
                                  steps=np.ceil(len(filenames_train)/batch_predict))
print(len(predict_train))

# %% [markdown]
# Triplet test definition

# %%
h,w,c = SIZE
images_test = np.empty((len(filenames_test),h,w,c))
for i,f in enumerate(filenames_test):
    images_test[i] = sk.io.imread(f)

# %%
#triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %% [markdown]
# ### Loss definition

# %%
alpha = 0.3
def triplet_numpy(y_true,y_pred):
    
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = np.sum(np.square(a-p),-1)
    an = np.sum(np.square(a-n),-1)

    return np.sum(np.maximum(ap - an + alpha,0))

# %%
alpha = 0.3
def triplet(y_true,y_pred):
    
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)

    return K.sum(tf.nn.relu(ap - an + alpha))

# %% [markdown]
# ### Metric definition

# %%
def triplet_acc(y_true,y_pred):
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)
    
    return K.less(ap+alpha,an)

# %% [markdown]
# ### Model definition

# %%
# inception net small

emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v25: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(64, (7, 7), strides=(2,2), use_bias=False, padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3,3),strides=(2,2))(x)

for layer in [128,256]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, padding='same')(x)
    r = BatchNormalization()(x)
    r = Activation('relu')(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    r = Add()([r,x])
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Add()([r,x])

    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.6)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v11: VGG like
emb_size = 16

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(104, 104, 3)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(1024, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(emb_size))
model.add(Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1)))

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v12: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 151, 151, 3)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 151, 151, 16) 2352        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 151, 151, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 76, 76, 16)   2304        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 76, 76, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 76, 76, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 76, 76, 16)   2304        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 76, 76, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 76, 76, 16)   0           dropout[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 76, 76, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 76, 76, 16)   2304        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 76, 76, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 76, 76, 16)   0           dropout_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 76, 76, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 38, 38, 32)   4608        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 38, 38, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 38, 38, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 38, 38, 32)   9216        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 38, 38, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 38, 38, 32)   0           dropout_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 38, 38, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 38, 38, 32)   9216        dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 38, 38, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 38, 38, 32)   0           dropout_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 38, 38, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 64)   18432       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 19, 19, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 19, 19, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 19, 19, 64)   36864       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 19, 19, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 64)   0           dropout_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 19, 19, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 19, 19, 64)   36864       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 19, 19, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 64)   0           dropout_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 19, 19, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 128)  73728       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 10, 10, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 10, 10, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 10, 128)  147456      dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 10, 10, 128)  0           dropout_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 10, 10, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 128)  147456      dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 10, 10, 128)  0           dropout_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 10, 10, 128)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 5, 5, 512)    589824      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 5, 5, 512)    2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 5, 5, 512)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 5, 5, 512)    2359296     dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 5, 5, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 5, 5, 512)    0           dropout_12[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 5, 5, 512)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 5, 5, 512)    2359296     dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 5, 5, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 5, 5, 512)    0           dropout_13[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 5, 5, 512)    0           add_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           dropout_14[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           32768       dropout_15[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64)           0           dense[0][0]
# ==================================================================================================
# Total params: 5,843,376
# Trainable params: 5,838,832
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
# dogfacenet_v12: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
#     x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.04.17.dogfacenet_v12.lfw.56.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
histories = []

# %%
histories += [model.fit_generator(
    online_adaptive_hard_image_generator(filenames_train,labels_train,model,3*10),
    steps_per_epoch=300,
    epochs=1,
    validation_data=image_generator(filenames_test,labels_test,3*10,False),
    validation_steps=30
)]
# Out:
# Epoch 1/1
# 170/300 [================>.............] - ETA: 21:09 - loss: 0.0000e+00 - triplet_acc: 1.00 - ETA: 11:09 - loss: 0.0349 - triplet_acc: 0.9500   - ETA: 8:00 - loss: 0.1081 - triplet_acc: 0.9333 - ETA: 6:55 - loss: 0.5137 - triplet_acc: 0.875 - ETA: 6:07 - loss: 0.5055 - triplet_acc: 0.880 - ETA: 5:36 - loss: 0.6560 - triplet_acc: 0.816 - ETA: 5:09 - loss: 0.7840 - triplet_acc: 0.814 - ETA: 4:52 - loss: 0.7226 - triplet_acc: 0.800 - ETA: 4:34 - loss: 0.9617 - triplet_acc: 0.755 - ETA: 4:19 - loss: 0.8903 - triplet_acc: 0.760 - ETA: 4:11 - loss: 0.8184 - triplet_acc: 0.772 - ETA: 4:08 - loss: 0.8464 - triplet_acc: 0.775 - ETA: 4:05 - loss: 0.8203 - triplet_acc: 0.784 - ETA: 3:56 - loss: 0.8419 - triplet_acc: 0.778 - ETA: 3:49 - loss: 0.8339 - triplet_acc: 0.766 - ETA: 3:42 - loss: 0.7963 - triplet_acc: 0.775 - ETA: 3:39 - loss: 0.7806 - triplet_acc: 0.776 - ETA: 3:36 - loss: 0.7383 - triplet_acc: 0.783 - ETA: 3:30 - loss: 0.7097 - triplet_acc: 0.784 - ETA: 3:31 - loss: 0.6946 - triplet_acc: 0.785 - ETA: 3:27 - loss: 0.6684 - triplet_acc: 0.790 - ETA: 3:24 - loss: 0.6380 - triplet_acc: 0.800 - ETA: 3:22 - loss: 0.6107 - triplet_acc: 0.804 - ETA: 3:21 - loss: 0.5852 - triplet_acc: 0.812 - ETA: 3:18 - loss: 0.5652 - triplet_acc: 0.816 - ETA: 3:16 - loss: 0.5434 - triplet_acc: 0.823 - ETA: 3:13 - loss: 0.5638 - triplet_acc: 0.822 - ETA: 3:11 - loss: 0.5436 - triplet_acc: 0.828 - ETA: 3:10 - loss: 0.5306 - triplet_acc: 0.831 - ETA: 3:08 - loss: 0.5363 - triplet_acc: 0.830 - ETA: 3:07 - loss: 0.5493 - triplet_acc: 0.825 - ETA: 3:04 - loss: 0.5324 - triplet_acc: 0.828 - ETA: 3:03 - loss: 0.5343 - triplet_acc: 0.821 - ETA: 3:01 - loss: 0.5186 - triplet_acc: 0.826 - ETA: 2:59 - loss: 0.5174 - triplet_acc: 0.825 - ETA: 2:58 - loss: 0.5030 - triplet_acc: 0.830 - ETA: 2:56 - loss: 0.5181 - triplet_acc: 0.827 - ETA: 2:54 - loss: 0.5173 - triplet_acc: 0.826 - ETA: 2:52 - loss: 0.5358 - triplet_acc: 0.817 - ETA: 2:50 - loss: 0.5264 - triplet_acc: 0.820 - ETA: 2:48 - loss: 0.5136 - triplet_acc: 0.824 - ETA: 2:46 - loss: 0.5173 - triplet_acc: 0.823 - ETA: 2:45 - loss: 0.5052 - triplet_acc: 0.827 - ETA: 2:43 - loss: 0.5008 - triplet_acc: 0.829 - ETA: 2:42 - loss: 0.5038 - triplet_acc: 0.826 - ETA: 2:43 - loss: 0.4962 - triplet_acc: 0.828 - ETA: 2:42 - loss: 0.5000 - triplet_acc: 0.827 - ETA: 2:40 - loss: 0.5035 - triplet_acc: 0.822 - ETA: 2:39 - loss: 0.4933 - triplet_acc: 0.826 - ETA: 2:38 - loss: 0.5081 - triplet_acc: 0.824 - ETA: 2:37 - loss: 0.5088 - triplet_acc: 0.825 - ETA: 2:35 - loss: 0.5204 - triplet_acc: 0.825 - ETA: 2:34 - loss: 0.5106 - triplet_acc: 0.828 - ETA: 2:34 - loss: 0.5267 - triplet_acc: 0.827 - ETA: 2:33 - loss: 0.5198 - triplet_acc: 0.829 - ETA: 2:32 - loss: 0.5354 - triplet_acc: 0.825 - ETA: 2:31 - loss: 0.5260 - triplet_acc: 0.828 - ETA: 2:29 - loss: 0.5176 - triplet_acc: 0.829 - ETA: 2:29 - loss: 0.5238 - triplet_acc: 0.827 - ETA: 2:28 - loss: 0.5237 - triplet_acc: 0.826 - ETA: 2:27 - loss: 0.5250 - triplet_acc: 0.826 - ETA: 2:26 - loss: 0.5209 - triplet_acc: 0.825 - ETA: 2:25 - loss: 0.5168 - triplet_acc: 0.825 - ETA: 2:23 - loss: 0.5088 - triplet_acc: 0.828 - ETA: 2:22 - loss: 0.5009 - triplet_acc: 0.830 - ETA: 2:22 - loss: 0.5004 - triplet_acc: 0.830 - ETA: 2:21 - loss: 0.4965 - triplet_acc: 0.831 - ETA: 2:20 - loss: 0.4953 - triplet_acc: 0.832 - ETA: 2:19 - loss: 0.4881 - triplet_acc: 0.834 - ETA: 2:17 - loss: 0.4812 - triplet_acc: 0.837 - ETA: 2:16 - loss: 0.4784 - triplet_acc: 0.836 - ETA: 2:16 - loss: 0.4979 - triplet_acc: 0.834 - ETA: 2:15 - loss: 0.4958 - triplet_acc: 0.835 - ETA: 2:14 - loss: 0.4951 - triplet_acc: 0.836 - ETA: 2:14 - loss: 0.5050 - triplet_acc: 0.834 - ETA: 2:13 - loss: 0.5022 - triplet_acc: 0.832 - ETA: 2:12 - loss: 0.4957 - triplet_acc: 0.835 - ETA: 2:11 - loss: 0.4974 - triplet_acc: 0.834 - ETA: 2:10 - loss: 0.5011 - triplet_acc: 0.834 - ETA: 2:09 - loss: 0.5112 - triplet_acc: 0.833 - ETA: 2:08 - loss: 0.5092 - triplet_acc: 0.833 - ETA: 2:07 - loss: 0.5063 - triplet_acc: 0.834 - ETA: 2:07 -  ...

# %%
# With online hard triplet generation
crt_acc = 0.8
for i in range(1000):
    print("Beginning epoch number: "+str(i))
#     if crt_acc < 0.7:
#         print("Mode 1")
#         histories += [model.fit_generator(
#             online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=False, use_neg=False, use_pos=False),
#             steps_per_epoch=300,
#             epochs=1,
#             validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
#             validation_steps=30
#         )]
#     if crt_acc < 0.78:
#         print("Mode 2")
#         histories += [model.fit_generator(
#             online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=True, use_neg=False, use_pos=True),
#             steps_per_epoch=300,
#             epochs=1,
#             validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
#             validation_steps=30
#         )]
#     else:
    print("Mode 3")
    histories += [model.fit_generator(
        online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=True, use_neg=True, use_pos=True),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
        validation_steps=30
    )]
    
    crt_acc = histories[-1].history['triplet_acc'][0]
    
    model.save(PATH_MODEL + '2019.04.15.dogfacenet_v12.lfw.'+str(117+i)+'.h5')
    
    loss = np.empty(0)
    val_loss = np.empty(0)
    acc = np.empty(0)
    val_acc = np.empty(0)

    for history in histories:
        loss = np.append(loss,history.history['loss'])
        val_loss = np.append(val_loss,history.history['val_loss'])
        acc = np.append(acc,history.history['triplet_acc'])
        val_acc = np.append(val_acc,history.history['val_triplet_acc'])


    history_ = np.array([loss,val_loss,acc,val_acc])
    np.save(PATH_SAVE+'2019.04.15.dogfacenet_v12.lfw.'+str(117+i)+'.h5',history_)
    np.savetxt(PATH_SAVE+'2019.04.15.dogfacenet_v12.lfw.'+str(117+i)+'.h5',history_)

# %%
for i in range(1000):
    histories += [model.fit_generator(
        online_hard_image_generator(filenames_train,labels_train,model,3*30),
        steps_per_epoch=500,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*30,use_aug=False),
        validation_steps=30
    )]
    model.save(PATH_MODEL + '2019.04.15.dogfacenet_v12.lfw.online.'+str(i+20)+'.h5')

# %%
# With hard triplet generation
for i in range(1000):
    predict_train = model.predict_generator(predict_generator(filenames_train, 32),
                                  steps=np.ceil(len(filenames_train)/32))
    histories += [model.fit_generator(
        hard_image_generator(filenames_train,labels_train,predict_train,3*20,use_aug=False),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
        validation_steps=30
    )]
    model.save(PATH_MODEL + '2019.04.17.dogfacenet_v12.lfw.'+str(i+6)+'.h5')
# Out:
# Epoch 1/1
# 171/300 [================>.............] - ETA: 21:55 - loss: 5.7211 - triplet_acc: 0.05 - ETA: 11:48 - loss: 7.1920 - triplet_acc: 0.05 - ETA: 8:24 - loss: 7.7592 - triplet_acc: 0.0333 - ETA: 6:42 - loss: 7.0747 - triplet_acc: 0.025 - ETA: 5:41 - loss: 6.9925 - triplet_acc: 0.070 - ETA: 5:00 - loss: 7.0181 - triplet_acc: 0.058 - ETA: 4:31 - loss: 6.7701 - triplet_acc: 0.057 - ETA: 4:09 - loss: 6.5045 - triplet_acc: 0.056 - ETA: 3:51 - loss: 6.2663 - triplet_acc: 0.088 - ETA: 3:37 - loss: 6.0275 - triplet_acc: 0.090 - ETA: 3:26 - loss: 5.7410 - triplet_acc: 0.113 - ETA: 3:16 - loss: 5.5321 - triplet_acc: 0.129 - ETA: 3:08 - loss: 5.3258 - triplet_acc: 0.161 - ETA: 3:01 - loss: 5.1419 - triplet_acc: 0.175 - ETA: 2:55 - loss: 4.9012 - triplet_acc: 0.193 - ETA: 2:50 - loss: 4.6519 - triplet_acc: 0.228 - ETA: 2:45 - loss: 4.4730 - triplet_acc: 0.247 - ETA: 2:40 - loss: 4.2864 - triplet_acc: 0.269 - ETA: 2:36 - loss: 4.1391 - triplet_acc: 0.289 - ETA: 2:33 - loss: 3.9872 - triplet_acc: 0.312 - ETA: 2:30 - loss: 3.8420 - triplet_acc: 0.335 - ETA: 2:27 - loss: 3.6925 - triplet_acc: 0.356 - ETA: 2:24 - loss: 3.5644 - triplet_acc: 0.376 - ETA: 2:21 - loss: 3.4549 - triplet_acc: 0.391 - ETA: 2:19 - loss: 3.3930 - triplet_acc: 0.404 - ETA: 2:17 - loss: 3.2886 - triplet_acc: 0.419 - ETA: 2:15 - loss: 3.2196 - triplet_acc: 0.433 - ETA: 2:13 - loss: 3.1616 - triplet_acc: 0.441 - ETA: 2:11 - loss: 3.0767 - triplet_acc: 0.450 - ETA: 2:09 - loss: 3.0409 - triplet_acc: 0.458 - ETA: 2:08 - loss: 2.9925 - triplet_acc: 0.462 - ETA: 2:06 - loss: 2.9497 - triplet_acc: 0.470 - ETA: 2:04 - loss: 2.8674 - triplet_acc: 0.483 - ETA: 2:03 - loss: 2.8018 - triplet_acc: 0.491 - ETA: 2:02 - loss: 2.7692 - triplet_acc: 0.497 - ETA: 2:00 - loss: 2.7491 - triplet_acc: 0.502 - ETA: 1:59 - loss: 2.6963 - triplet_acc: 0.509 - ETA: 1:58 - loss: 2.6334 - triplet_acc: 0.519 - ETA: 1:57 - loss: 2.5930 - triplet_acc: 0.523 - ETA: 1:56 - loss: 2.5398 - triplet_acc: 0.528 - ETA: 1:55 - loss: 2.5010 - triplet_acc: 0.530 - ETA: 1:53 - loss: 2.4678 - triplet_acc: 0.535 - ETA: 1:52 - loss: 2.4241 - triplet_acc: 0.543 - ETA: 1:51 - loss: 2.3987 - triplet_acc: 0.548 - ETA: 1:50 - loss: 2.3683 - triplet_acc: 0.554 - ETA: 1:50 - loss: 2.3456 - triplet_acc: 0.558 - ETA: 1:49 - loss: 2.3119 - triplet_acc: 0.563 - ETA: 1:48 - loss: 2.3085 - triplet_acc: 0.562 - ETA: 1:47 - loss: 2.2729 - triplet_acc: 0.567 - ETA: 1:46 - loss: 2.2335 - triplet_acc: 0.573 - ETA: 1:45 - loss: 2.2062 - triplet_acc: 0.577 - ETA: 1:44 - loss: 2.1817 - triplet_acc: 0.582 - ETA: 1:44 - loss: 2.1499 - triplet_acc: 0.586 - ETA: 1:43 - loss: 2.1341 - triplet_acc: 0.588 - ETA: 1:42 - loss: 2.1011 - triplet_acc: 0.591 - ETA: 1:41 - loss: 2.0866 - triplet_acc: 0.594 - ETA: 1:41 - loss: 2.0518 - triplet_acc: 0.600 - ETA: 1:40 - loss: 2.0313 - triplet_acc: 0.602 - ETA: 1:39 - loss: 2.0145 - triplet_acc: 0.604 - ETA: 1:39 - loss: 1.9914 - triplet_acc: 0.608 - ETA: 1:38 - loss: 1.9649 - triplet_acc: 0.612 - ETA: 1:37 - loss: 1.9369 - triplet_acc: 0.615 - ETA: 1:36 - loss: 1.9142 - triplet_acc: 0.618 - ETA: 1:36 - loss: 1.9034 - triplet_acc: 0.619 - ETA: 1:35 - loss: 1.8901 - triplet_acc: 0.620 - ETA: 1:35 - loss: 1.8684 - triplet_acc: 0.622 - ETA: 1:34 - loss: 1.8480 - triplet_acc: 0.626 - ETA: 1:33 - loss: 1.8412 - triplet_acc: 0.627 - ETA: 1:33 - loss: 1.8157 - triplet_acc: 0.632 - ETA: 1:32 - loss: 1.8008 - triplet_acc: 0.634 - ETA: 1:32 - loss: 1.7817 - triplet_acc: 0.637 - ETA: 1:31 - loss: 1.7663 - triplet_acc: 0.639 - ETA: 1:30 - loss: 1.7513 - triplet_acc: 0.641 - ETA: 1:30 - loss: 1.7505 - triplet_acc: 0.643 - ETA: 1:29 - loss: 1.7366 - triplet_acc: 0.644 - ETA: 1:29 - loss: 1.7313 - triplet_acc: 0.646 - ETA: 1:28 - loss: 1.7115 - triplet_acc: 0.649 - ETA: 1:28 - loss: 1.6978 - triplet_acc: 0.651 - ETA: 1:27 - loss: 1.6866 - triplet_acc: 0.653 - ETA: 1:26 - loss: 1.6694 - triplet_acc: 0.656 - ETA: 1:26 - loss: 1.6530 - triplet_acc: 0.657 - ETA: 1:25 - loss: 1.6367 - triplet_acc: 0.660 - ETA: 1:25 - loss: 1. ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:45 - loss: 7.6187 - triplet_acc: 0.0000e+0 - ETA: 2:14 - loss: 8.8508 - triplet_acc: 0.0000e+0 - ETA: 2:03 - loss: 8.6306 - triplet_acc: 0.0000e+0 - ETA: 1:58 - loss: 8.4414 - triplet_acc: 0.0250    - ETA: 1:54 - loss: 7.7617 - triplet_acc: 0.050 - ETA: 1:52 - loss: 7.3201 - triplet_acc: 0.066 - ETA: 1:50 - loss: 7.0766 - triplet_acc: 0.071 - ETA: 1:49 - loss: 6.7836 - triplet_acc: 0.087 - ETA: 1:48 - loss: 6.3914 - triplet_acc: 0.116 - ETA: 1:47 - loss: 6.1541 - triplet_acc: 0.115 - ETA: 1:46 - loss: 5.9434 - triplet_acc: 0.127 - ETA: 1:45 - loss: 5.6608 - triplet_acc: 0.145 - ETA: 1:44 - loss: 5.5048 - triplet_acc: 0.153 - ETA: 1:44 - loss: 5.2833 - triplet_acc: 0.171 - ETA: 1:43 - loss: 5.1061 - triplet_acc: 0.196 - ETA: 1:42 - loss: 4.8731 - triplet_acc: 0.221 - ETA: 1:42 - loss: 4.6925 - triplet_acc: 0.244 - ETA: 1:41 - loss: 4.5554 - triplet_acc: 0.258 - ETA: 1:41 - loss: 4.3844 - triplet_acc: 0.278 - ETA: 1:40 - loss: 4.3172 - triplet_acc: 0.285 - ETA: 1:40 - loss: 4.1860 - triplet_acc: 0.302 - ETA: 1:39 - loss: 4.0875 - triplet_acc: 0.318 - ETA: 1:39 - loss: 4.0032 - triplet_acc: 0.339 - ETA: 1:39 - loss: 3.9908 - triplet_acc: 0.345 - ETA: 1:38 - loss: 3.8646 - triplet_acc: 0.364 - ETA: 1:38 - loss: 3.7351 - triplet_acc: 0.382 - ETA: 1:37 - loss: 3.6677 - triplet_acc: 0.394 - ETA: 1:37 - loss: 3.5746 - triplet_acc: 0.403 - ETA: 1:36 - loss: 3.5074 - triplet_acc: 0.412 - ETA: 1:36 - loss: 3.4369 - triplet_acc: 0.421 - ETA: 1:36 - loss: 3.3624 - triplet_acc: 0.429 - ETA: 1:35 - loss: 3.2832 - triplet_acc: 0.434 - ETA: 1:35 - loss: 3.1886 - triplet_acc: 0.447 - ETA: 1:34 - loss: 3.1329 - triplet_acc: 0.454 - ETA: 1:34 - loss: 3.0619 - triplet_acc: 0.464 - ETA: 1:34 - loss: 3.0113 - triplet_acc: 0.470 - ETA: 1:33 - loss: 2.9517 - triplet_acc: 0.477 - ETA: 1:33 - loss: 2.8994 - triplet_acc: 0.482 - ETA: 1:33 - loss: 2.8408 - triplet_acc: 0.488 - ETA: 1:32 - loss: 2.8039 - triplet_acc: 0.492 - ETA: 1:32 - loss: 2.7380 - triplet_acc: 0.503 - ETA: 1:31 - loss: 2.7015 - triplet_acc: 0.509 - ETA: 1:31 - loss: 2.6637 - triplet_acc: 0.511 - ETA: 1:31 - loss: 2.6213 - triplet_acc: 0.518 - ETA: 1:30 - loss: 2.5846 - triplet_acc: 0.523 - ETA: 1:30 - loss: 2.5677 - triplet_acc: 0.529 - ETA: 1:30 - loss: 2.5259 - triplet_acc: 0.537 - ETA: 1:29 - loss: 2.4941 - triplet_acc: 0.543 - ETA: 1:29 - loss: 2.4463 - triplet_acc: 0.550 - ETA: 1:28 - loss: 2.4088 - triplet_acc: 0.554 - ETA: 1:28 - loss: 2.3784 - triplet_acc: 0.561 - ETA: 1:28 - loss: 2.3599 - triplet_acc: 0.566 - ETA: 1:27 - loss: 2.3279 - triplet_acc: 0.569 - ETA: 1:27 - loss: 2.2876 - triplet_acc: 0.575 - ETA: 1:27 - loss: 2.2492 - triplet_acc: 0.580 - ETA: 1:26 - loss: 2.2358 - triplet_acc: 0.579 - ETA: 1:26 - loss: 2.2230 - triplet_acc: 0.582 - ETA: 1:25 - loss: 2.2040 - triplet_acc: 0.584 - ETA: 1:25 - loss: 2.1679 - triplet_acc: 0.589 - ETA: 1:25 - loss: 2.1361 - triplet_acc: 0.594 - ETA: 1:24 - loss: 2.1104 - triplet_acc: 0.598 - ETA: 1:24 - loss: 2.0882 - triplet_acc: 0.602 - ETA: 1:24 - loss: 2.0564 - triplet_acc: 0.607 - ETA: 1:23 - loss: 2.0389 - triplet_acc: 0.609 - ETA: 1:23 - loss: 2.0077 - triplet_acc: 0.614 - ETA: 1:22 - loss: 1.9926 - triplet_acc: 0.618 - ETA: 1:22 - loss: 1.9683 - triplet_acc: 0.621 - ETA: 1:22 - loss: 1.9454 - triplet_acc: 0.624 - ETA: 1:21 - loss: 1.9244 - triplet_acc: 0.626 - ETA: 1:21 - loss: 1.9076 - triplet_acc: 0.628 - ETA: 1:21 - loss: 1.8847 - triplet_acc: 0.631 - ETA: 1:20 - loss: 1.8653 - triplet_acc: 0.635 - ETA: 1:20 - loss: 1.8426 - triplet_acc: 0.638 - ETA: 1:20 - loss: 1.8191 - triplet_acc: 0.642 - ETA: 1:19 - loss: 1.8129 - triplet_acc: 0.645 - ETA: 1:19 - loss: 1.7981 - triplet_acc: 0.648 - ETA: 1:18 - loss: 1.7921 - triplet_acc: 0.649 - ETA: 1:18 - loss: 1.7866 - triplet_acc: 0.650 - ETA: 1:18 - loss: 1.7716 - triplet_acc: 0.651 - ETA: 1:17 - loss: 1.7552 - triplet_acc: 0.652 - ETA: 1:17 - loss: 1.7412 - triplet_acc: 0.654 - ETA: 1:17 - loss: 1.7472 - triplet_acc: 0.654 - ETA:  ...
# 300/300 [==============================] - ETA: 44s - loss: 1.0968 - triplet_acc: 0.76 - ETA: 44s - loss: 1.0937 - triplet_acc: 0.76 - ETA: 44s - loss: 1.0876 - triplet_acc: 0.76 - ETA: 43s - loss: 1.0834 - triplet_acc: 0.76 - ETA: 43s - loss: 1.0790 - triplet_acc: 0.76 - ETA: 43s - loss: 1.0731 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0698 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0680 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0633 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0591 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0572 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0515 - triplet_acc: 0.76 - ETA: 40s - loss: 1.0474 - triplet_acc: 0.76 - ETA: 40s - loss: 1.0442 - triplet_acc: 0.76 - ETA: 39s - loss: 1.0401 - triplet_acc: 0.76 - ETA: 39s - loss: 1.0353 - triplet_acc: 0.76 - ETA: 39s - loss: 1.0321 - triplet_acc: 0.76 - ETA: 38s - loss: 1.0294 - triplet_acc: 0.76 - ETA: 38s - loss: 1.0251 - triplet_acc: 0.77 - ETA: 38s - loss: 1.0247 - triplet_acc: 0.77 - ETA: 37s - loss: 1.0199 - triplet_acc: 0.77 - ETA: 37s - loss: 1.0155 - triplet_acc: 0.77 - ETA: 37s - loss: 1.0103 - triplet_acc: 0.77 - ETA: 36s - loss: 1.0060 - triplet_acc: 0.77 - ETA: 36s - loss: 1.0013 - triplet_acc: 0.77 - ETA: 36s - loss: 0.9968 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9952 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9932 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9911 - triplet_acc: 0.77 - ETA: 34s - loss: 0.9874 - triplet_acc: 0.77 - ETA: 34s - loss: 0.9825 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9797 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9756 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9716 - triplet_acc: 0.77 - ETA: 32s - loss: 0.9682 - triplet_acc: 0.77 - ETA: 32s - loss: 0.9642 - triplet_acc: 0.78 - ETA: 32s - loss: 0.9610 - triplet_acc: 0.78 - ETA: 31s - loss: 0.9570 - triplet_acc: 0.78 - ETA: 31s - loss: 0.9533 - triplet_acc: 0.78 - ETA: 31s - loss: 0.9510 - triplet_acc: 0.78 - ETA: 30s - loss: 0.9531 - triplet_acc: 0.78 - ETA: 30s - loss: 0.9487 - triplet_acc: 0.78 - ETA: 30s - loss: 0.9457 - triplet_acc: 0.78 - ETA: 29s - loss: 0.9436 - triplet_acc: 0.78 - ETA: 29s - loss: 0.9421 - triplet_acc: 0.78 - ETA: 29s - loss: 0.9417 - triplet_acc: 0.78 - ETA: 28s - loss: 0.9381 - triplet_acc: 0.78 - ETA: 28s - loss: 0.9358 - triplet_acc: 0.78 - ETA: 27s - loss: 0.9336 - triplet_acc: 0.78 - ETA: 27s - loss: 0.9313 - triplet_acc: 0.78 - ETA: 27s - loss: 0.9281 - triplet_acc: 0.78 - ETA: 26s - loss: 0.9247 - triplet_acc: 0.78 - ETA: 26s - loss: 0.9222 - triplet_acc: 0.78 - ETA: 26s - loss: 0.9202 - triplet_acc: 0.78 - ETA: 25s - loss: 0.9162 - triplet_acc: 0.78 - ETA: 25s - loss: 0.9140 - triplet_acc: 0.78 - ETA: 25s - loss: 0.9104 - triplet_acc: 0.79 - ETA: 24s - loss: 0.9118 - triplet_acc: 0.79 - ETA: 24s - loss: 0.9092 - triplet_acc: 0.79 - ETA: 24s - loss: 0.9059 - triplet_acc: 0.79 - ETA: 23s - loss: 0.9049 - triplet_acc: 0.79 - ETA: 23s - loss: 0.9026 - triplet_acc: 0.79 - ETA: 23s - loss: 0.8993 - triplet_acc: 0.79 - ETA: 22s - loss: 0.8976 - triplet_acc: 0.79 - ETA: 22s - loss: 0.8940 - triplet_acc: 0.79 - ETA: 21s - loss: 0.8915 - triplet_acc: 0.79 - ETA: 21s - loss: 0.8881 - triplet_acc: 0.79 - ETA: 21s - loss: 0.8883 - triplet_acc: 0.79 - ETA: 20s - loss: 0.8853 - triplet_acc: 0.79 - ETA: 20s - loss: 0.8824 - triplet_acc: 0.79 - ETA: 20s - loss: 0.8798 - triplet_acc: 0.79 - ETA: 19s - loss: 0.8795 - triplet_acc: 0.79 - ETA: 19s - loss: 0.8770 - triplet_acc: 0.79 - ETA: 19s - loss: 0.8760 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8729 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8694 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8674 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8669 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8639 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8617 - triplet_acc: 0.79 - ETA: 16s - loss: 0.8591 - triplet_acc: 0.80 - ETA: 16s - loss: 0.8561 - triplet_acc: 0.80 - ETA: 15s - loss: 0.8528 - triplet_acc: 0.80 - ETA: 15s - loss: 0.8495 - triplet_acc: 0.80 - ETA: 15s - loss: 0.8463 - triplet_acc: 0.80 - ETA: 14s - loss: 0.8433 - triplet_acc: 0.80 - E ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:48 - loss: 4.4227 - triplet_acc: 0.300 - ETA: 2:16 - loss: 5.3029 - triplet_acc: 0.150 - ETA: 2:05 - loss: 6.1364 - triplet_acc: 0.133 - ETA: 2:00 - loss: 6.0138 - triplet_acc: 0.112 - ETA: 1:56 - loss: 6.0415 - triplet_acc: 0.120 - ETA: 1:54 - loss: 5.9908 - triplet_acc: 0.116 - ETA: 1:52 - loss: 5.7981 - triplet_acc: 0.114 - ETA: 1:50 - loss: 5.5023 - triplet_acc: 0.118 - ETA: 1:49 - loss: 5.4599 - triplet_acc: 0.116 - ETA: 1:48 - loss: 5.1808 - triplet_acc: 0.130 - ETA: 1:47 - loss: 4.9783 - triplet_acc: 0.150 - ETA: 1:46 - loss: 4.7764 - triplet_acc: 0.170 - ETA: 1:45 - loss: 4.5248 - triplet_acc: 0.196 - ETA: 1:44 - loss: 4.2536 - triplet_acc: 0.228 - ETA: 1:44 - loss: 4.1924 - triplet_acc: 0.240 - ETA: 1:43 - loss: 3.9860 - triplet_acc: 0.271 - ETA: 1:43 - loss: 3.8743 - triplet_acc: 0.294 - ETA: 1:42 - loss: 3.7114 - triplet_acc: 0.316 - ETA: 1:41 - loss: 3.5674 - triplet_acc: 0.334 - ETA: 1:41 - loss: 3.4863 - triplet_acc: 0.350 - ETA: 1:40 - loss: 3.3703 - triplet_acc: 0.366 - ETA: 1:40 - loss: 3.2635 - triplet_acc: 0.377 - ETA: 1:40 - loss: 3.1243 - triplet_acc: 0.400 - ETA: 1:39 - loss: 3.0365 - triplet_acc: 0.418 - ETA: 1:39 - loss: 2.9663 - triplet_acc: 0.430 - ETA: 1:38 - loss: 2.9068 - triplet_acc: 0.440 - ETA: 1:38 - loss: 2.8463 - triplet_acc: 0.455 - ETA: 1:37 - loss: 2.7632 - triplet_acc: 0.469 - ETA: 1:37 - loss: 2.6839 - triplet_acc: 0.482 - ETA: 1:37 - loss: 2.6090 - triplet_acc: 0.490 - ETA: 1:36 - loss: 2.5976 - triplet_acc: 0.496 - ETA: 1:36 - loss: 2.5345 - triplet_acc: 0.507 - ETA: 1:35 - loss: 2.5207 - triplet_acc: 0.510 - ETA: 1:35 - loss: 2.4619 - triplet_acc: 0.519 - ETA: 1:35 - loss: 2.4158 - triplet_acc: 0.524 - ETA: 1:34 - loss: 2.3651 - triplet_acc: 0.533 - ETA: 1:34 - loss: 2.3532 - triplet_acc: 0.536 - ETA: 1:33 - loss: 2.3142 - triplet_acc: 0.543 - ETA: 1:33 - loss: 2.2836 - triplet_acc: 0.548 - ETA: 1:33 - loss: 2.2771 - triplet_acc: 0.551 - ETA: 1:32 - loss: 2.2594 - triplet_acc: 0.557 - ETA: 1:32 - loss: 2.2245 - triplet_acc: 0.563 - ETA: 1:31 - loss: 2.1751 - triplet_acc: 0.570 - ETA: 1:31 - loss: 2.1270 - triplet_acc: 0.579 - ETA: 1:31 - loss: 2.0859 - triplet_acc: 0.586 - ETA: 1:30 - loss: 2.0839 - triplet_acc: 0.588 - ETA: 1:30 - loss: 2.0645 - triplet_acc: 0.590 - ETA: 1:30 - loss: 2.0388 - triplet_acc: 0.596 - ETA: 1:29 - loss: 2.0009 - triplet_acc: 0.603 - ETA: 1:29 - loss: 1.9619 - triplet_acc: 0.610 - ETA: 1:28 - loss: 1.9301 - triplet_acc: 0.614 - ETA: 1:28 - loss: 1.9057 - triplet_acc: 0.618 - ETA: 1:28 - loss: 1.8767 - triplet_acc: 0.623 - ETA: 1:27 - loss: 1.8497 - triplet_acc: 0.628 - ETA: 1:27 - loss: 1.8252 - triplet_acc: 0.633 - ETA: 1:27 - loss: 1.7968 - triplet_acc: 0.637 - ETA: 1:26 - loss: 1.7737 - triplet_acc: 0.642 - ETA: 1:26 - loss: 1.7508 - triplet_acc: 0.645 - ETA: 1:25 - loss: 1.7312 - triplet_acc: 0.650 - ETA: 1:25 - loss: 1.7079 - triplet_acc: 0.654 - ETA: 1:25 - loss: 1.6883 - triplet_acc: 0.658 - ETA: 1:24 - loss: 1.6662 - triplet_acc: 0.662 - ETA: 1:24 - loss: 1.6530 - triplet_acc: 0.665 - ETA: 1:24 - loss: 1.6518 - triplet_acc: 0.666 - ETA: 1:23 - loss: 1.6264 - triplet_acc: 0.671 - ETA: 1:23 - loss: 1.6215 - triplet_acc: 0.673 - ETA: 1:22 - loss: 1.6018 - triplet_acc: 0.676 - ETA: 1:22 - loss: 1.5782 - triplet_acc: 0.681 - ETA: 1:22 - loss: 1.5661 - triplet_acc: 0.683 - ETA: 1:21 - loss: 1.5562 - triplet_acc: 0.684 - ETA: 1:21 - loss: 1.5418 - triplet_acc: 0.685 - ETA: 1:21 - loss: 1.5204 - triplet_acc: 0.690 - ETA: 1:20 - loss: 1.5038 - triplet_acc: 0.692 - ETA: 1:20 - loss: 1.4941 - triplet_acc: 0.691 - ETA: 1:20 - loss: 1.4811 - triplet_acc: 0.692 - ETA: 1:19 - loss: 1.4680 - triplet_acc: 0.694 - ETA: 1:19 - loss: 1.4586 - triplet_acc: 0.696 - ETA: 1:18 - loss: 1.4467 - triplet_acc: 0.697 - ETA: 1:18 - loss: 1.4352 - triplet_acc: 0.698 - ETA: 1:18 - loss: 1.4250 - triplet_acc: 0.700 - ETA: 1:17 - loss: 1.4113 - triplet_acc: 0.700 - ETA: 1:17 - loss: 1.3993 - triplet_acc: 0.701 - ETA: 1:17 - loss: 1.3 ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:49 - loss: 7.2355 - triplet_acc: 0.0000e+0 - ETA: 2:16 - loss: 7.7647 - triplet_acc: 0.0000e+0 - ETA: 2:05 - loss: 7.6689 - triplet_acc: 0.0000e+0 - ETA: 1:59 - loss: 6.9114 - triplet_acc: 0.0250    - ETA: 1:56 - loss: 6.7129 - triplet_acc: 0.040 - ETA: 1:53 - loss: 6.5361 - triplet_acc: 0.033 - ETA: 1:51 - loss: 6.4804 - triplet_acc: 0.050 - ETA: 1:50 - loss: 5.9827 - triplet_acc: 0.062 - ETA: 1:49 - loss: 5.6755 - triplet_acc: 0.072 - ETA: 1:48 - loss: 5.6564 - triplet_acc: 0.075 - ETA: 1:47 - loss: 5.5701 - triplet_acc: 0.081 - ETA: 1:46 - loss: 5.2768 - triplet_acc: 0.104 - ETA: 1:45 - loss: 5.1017 - triplet_acc: 0.115 - ETA: 1:44 - loss: 4.8526 - triplet_acc: 0.139 - ETA: 1:44 - loss: 4.6555 - triplet_acc: 0.160 - ETA: 1:43 - loss: 4.5296 - triplet_acc: 0.175 - ETA: 1:43 - loss: 4.3785 - triplet_acc: 0.197 - ETA: 1:42 - loss: 4.2180 - triplet_acc: 0.213 - ETA: 1:41 - loss: 4.1115 - triplet_acc: 0.231 - ETA: 1:41 - loss: 3.9328 - triplet_acc: 0.262 - ETA: 1:40 - loss: 3.9012 - triplet_acc: 0.276 - ETA: 1:40 - loss: 3.7442 - triplet_acc: 0.300 - ETA: 1:39 - loss: 3.6172 - triplet_acc: 0.319 - ETA: 1:39 - loss: 3.5579 - triplet_acc: 0.333 - ETA: 1:39 - loss: 3.5229 - triplet_acc: 0.344 - ETA: 1:38 - loss: 3.4429 - triplet_acc: 0.355 - ETA: 1:38 - loss: 3.3434 - triplet_acc: 0.364 - ETA: 1:37 - loss: 3.2652 - triplet_acc: 0.380 - ETA: 1:37 - loss: 3.1834 - triplet_acc: 0.393 - ETA: 1:36 - loss: 3.0944 - triplet_acc: 0.405 - ETA: 1:36 - loss: 3.0074 - triplet_acc: 0.417 - ETA: 1:36 - loss: 2.9592 - triplet_acc: 0.425 - ETA: 1:35 - loss: 2.8897 - triplet_acc: 0.433 - ETA: 1:35 - loss: 2.8227 - triplet_acc: 0.447 - ETA: 1:35 - loss: 2.7546 - triplet_acc: 0.458 - ETA: 1:34 - loss: 2.7087 - triplet_acc: 0.466 - ETA: 1:34 - loss: 2.6531 - triplet_acc: 0.474 - ETA: 1:33 - loss: 2.5955 - triplet_acc: 0.484 - ETA: 1:33 - loss: 2.5393 - triplet_acc: 0.494 - ETA: 1:33 - loss: 2.4758 - triplet_acc: 0.507 - ETA: 1:32 - loss: 2.4508 - triplet_acc: 0.508 - ETA: 1:32 - loss: 2.4097 - triplet_acc: 0.514 - ETA: 1:32 - loss: 2.3735 - triplet_acc: 0.522 - ETA: 1:31 - loss: 2.3375 - triplet_acc: 0.527 - ETA: 1:31 - loss: 2.3099 - triplet_acc: 0.532 - ETA: 1:31 - loss: 2.2716 - triplet_acc: 0.537 - ETA: 1:30 - loss: 2.2364 - triplet_acc: 0.541 - ETA: 1:30 - loss: 2.1913 - triplet_acc: 0.549 - ETA: 1:29 - loss: 2.1482 - triplet_acc: 0.555 - ETA: 1:29 - loss: 2.1308 - triplet_acc: 0.557 - ETA: 1:29 - loss: 2.1096 - triplet_acc: 0.561 - ETA: 1:28 - loss: 2.0740 - triplet_acc: 0.565 - ETA: 1:28 - loss: 2.0538 - triplet_acc: 0.567 - ETA: 1:28 - loss: 2.0426 - triplet_acc: 0.565 - ETA: 1:27 - loss: 2.0228 - triplet_acc: 0.570 - ETA: 1:27 - loss: 2.0045 - triplet_acc: 0.575 - ETA: 1:27 - loss: 1.9948 - triplet_acc: 0.578 - ETA: 1:26 - loss: 1.9660 - triplet_acc: 0.582 - ETA: 1:26 - loss: 1.9428 - triplet_acc: 0.586 - ETA: 1:25 - loss: 1.9244 - triplet_acc: 0.588 - ETA: 1:25 - loss: 1.9170 - triplet_acc: 0.590 - ETA: 1:25 - loss: 1.9032 - triplet_acc: 0.595 - ETA: 1:24 - loss: 1.8832 - triplet_acc: 0.598 - ETA: 1:24 - loss: 1.8721 - triplet_acc: 0.603 - ETA: 1:24 - loss: 1.8665 - triplet_acc: 0.603 - ETA: 1:23 - loss: 1.8460 - triplet_acc: 0.607 - ETA: 1:23 - loss: 1.8284 - triplet_acc: 0.612 - ETA: 1:23 - loss: 1.8078 - triplet_acc: 0.616 - ETA: 1:22 - loss: 1.7852 - triplet_acc: 0.620 - ETA: 1:22 - loss: 1.7690 - triplet_acc: 0.623 - ETA: 1:22 - loss: 1.7537 - triplet_acc: 0.624 - ETA: 1:21 - loss: 1.7360 - triplet_acc: 0.627 - ETA: 1:21 - loss: 1.7162 - triplet_acc: 0.630 - ETA: 1:20 - loss: 1.7000 - triplet_acc: 0.633 - ETA: 1:20 - loss: 1.6856 - triplet_acc: 0.636 - ETA: 1:20 - loss: 1.6792 - triplet_acc: 0.638 - ETA: 1:19 - loss: 1.6627 - triplet_acc: 0.640 - ETA: 1:19 - loss: 1.6453 - triplet_acc: 0.644 - ETA: 1:19 - loss: 1.6389 - triplet_acc: 0.644 - ETA: 1:18 - loss: 1.6211 - triplet_acc: 0.648 - ETA: 1:18 - loss: 1.6132 - triplet_acc: 0.650 - ETA: 1:18 - loss: 1.6100 - triplet_acc: 0.651 - ETA:  ...
# 300/300 [==============================] - ETA: 45s - loss: 1.0384 - triplet_acc: 0.75 - ETA: 45s - loss: 1.0357 - triplet_acc: 0.75 - ETA: 44s - loss: 1.0300 - triplet_acc: 0.75 - ETA: 44s - loss: 1.0242 - triplet_acc: 0.75 - ETA: 44s - loss: 1.0226 - triplet_acc: 0.75 - ETA: 43s - loss: 1.0169 - triplet_acc: 0.76 - ETA: 43s - loss: 1.0210 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0164 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0117 - triplet_acc: 0.76 - ETA: 42s - loss: 1.0071 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0059 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0048 - triplet_acc: 0.76 - ETA: 41s - loss: 1.0070 - triplet_acc: 0.76 - ETA: 40s - loss: 1.0021 - triplet_acc: 0.76 - ETA: 40s - loss: 0.9972 - triplet_acc: 0.76 - ETA: 40s - loss: 0.9938 - triplet_acc: 0.76 - ETA: 39s - loss: 0.9892 - triplet_acc: 0.76 - ETA: 39s - loss: 0.9887 - triplet_acc: 0.76 - ETA: 38s - loss: 0.9843 - triplet_acc: 0.76 - ETA: 38s - loss: 0.9793 - triplet_acc: 0.76 - ETA: 38s - loss: 0.9760 - triplet_acc: 0.76 - ETA: 37s - loss: 0.9744 - triplet_acc: 0.76 - ETA: 37s - loss: 0.9711 - triplet_acc: 0.76 - ETA: 37s - loss: 0.9688 - triplet_acc: 0.76 - ETA: 36s - loss: 0.9642 - triplet_acc: 0.76 - ETA: 36s - loss: 0.9635 - triplet_acc: 0.76 - ETA: 36s - loss: 0.9605 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9581 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9573 - triplet_acc: 0.77 - ETA: 35s - loss: 0.9560 - triplet_acc: 0.77 - ETA: 34s - loss: 0.9539 - triplet_acc: 0.77 - ETA: 34s - loss: 0.9495 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9449 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9404 - triplet_acc: 0.77 - ETA: 33s - loss: 0.9399 - triplet_acc: 0.77 - ETA: 32s - loss: 0.9372 - triplet_acc: 0.77 - ETA: 32s - loss: 0.9342 - triplet_acc: 0.77 - ETA: 32s - loss: 0.9298 - triplet_acc: 0.77 - ETA: 31s - loss: 0.9273 - triplet_acc: 0.77 - ETA: 31s - loss: 0.9280 - triplet_acc: 0.77 - ETA: 31s - loss: 0.9245 - triplet_acc: 0.77 - ETA: 30s - loss: 0.9208 - triplet_acc: 0.77 - ETA: 30s - loss: 0.9190 - triplet_acc: 0.77 - ETA: 30s - loss: 0.9152 - triplet_acc: 0.77 - ETA: 29s - loss: 0.9114 - triplet_acc: 0.77 - ETA: 29s - loss: 0.9105 - triplet_acc: 0.77 - ETA: 28s - loss: 0.9078 - triplet_acc: 0.78 - ETA: 28s - loss: 0.9039 - triplet_acc: 0.78 - ETA: 28s - loss: 0.9025 - triplet_acc: 0.78 - ETA: 27s - loss: 0.8985 - triplet_acc: 0.78 - ETA: 27s - loss: 0.8966 - triplet_acc: 0.78 - ETA: 27s - loss: 0.8952 - triplet_acc: 0.78 - ETA: 26s - loss: 0.8939 - triplet_acc: 0.78 - ETA: 26s - loss: 0.8900 - triplet_acc: 0.78 - ETA: 26s - loss: 0.8874 - triplet_acc: 0.78 - ETA: 25s - loss: 0.8867 - triplet_acc: 0.78 - ETA: 25s - loss: 0.8828 - triplet_acc: 0.78 - ETA: 25s - loss: 0.8806 - triplet_acc: 0.78 - ETA: 24s - loss: 0.8771 - triplet_acc: 0.78 - ETA: 24s - loss: 0.8751 - triplet_acc: 0.78 - ETA: 23s - loss: 0.8746 - triplet_acc: 0.78 - ETA: 23s - loss: 0.8722 - triplet_acc: 0.78 - ETA: 23s - loss: 0.8691 - triplet_acc: 0.78 - ETA: 22s - loss: 0.8666 - triplet_acc: 0.78 - ETA: 22s - loss: 0.8663 - triplet_acc: 0.78 - ETA: 22s - loss: 0.8645 - triplet_acc: 0.78 - ETA: 21s - loss: 0.8621 - triplet_acc: 0.78 - ETA: 21s - loss: 0.8589 - triplet_acc: 0.78 - ETA: 21s - loss: 0.8586 - triplet_acc: 0.78 - ETA: 20s - loss: 0.8551 - triplet_acc: 0.78 - ETA: 20s - loss: 0.8527 - triplet_acc: 0.78 - ETA: 20s - loss: 0.8503 - triplet_acc: 0.79 - ETA: 19s - loss: 0.8482 - triplet_acc: 0.79 - ETA: 19s - loss: 0.8501 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8467 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8445 - triplet_acc: 0.79 - ETA: 18s - loss: 0.8424 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8400 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8366 - triplet_acc: 0.79 - ETA: 17s - loss: 0.8355 - triplet_acc: 0.79 - ETA: 16s - loss: 0.8322 - triplet_acc: 0.79 - ETA: 16s - loss: 0.8334 - triplet_acc: 0.79 - ETA: 16s - loss: 0.8325 - triplet_acc: 0.79 - ETA: 15s - loss: 0.8298 - triplet_acc: 0.79 - ETA: 15s - loss: 0.8285 - triplet_acc: 0.79 - ETA: 15s - loss: 0.8274 - triplet_acc: 0.79 - E ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:48 - loss: 7.5966 - triplet_acc: 0.050 - ETA: 2:16 - loss: 8.1986 - triplet_acc: 0.050 - ETA: 2:05 - loss: 8.6277 - triplet_acc: 0.050 - ETA: 2:00 - loss: 8.0397 - triplet_acc: 0.050 - ETA: 1:56 - loss: 7.8048 - triplet_acc: 0.070 - ETA: 1:54 - loss: 7.3555 - triplet_acc: 0.075 - ETA: 1:52 - loss: 7.0489 - triplet_acc: 0.085 - ETA: 1:51 - loss: 6.8918 - triplet_acc: 0.093 - ETA: 1:50 - loss: 6.4306 - triplet_acc: 0.133 - ETA: 1:49 - loss: 6.0845 - triplet_acc: 0.150 - ETA: 1:48 - loss: 5.5983 - triplet_acc: 0.186 - ETA: 1:47 - loss: 5.2672 - triplet_acc: 0.208 - ETA: 1:46 - loss: 5.0474 - triplet_acc: 0.238 - ETA: 1:46 - loss: 4.8312 - triplet_acc: 0.260 - ETA: 1:45 - loss: 4.6677 - triplet_acc: 0.283 - ETA: 1:44 - loss: 4.4400 - triplet_acc: 0.306 - ETA: 1:44 - loss: 4.2408 - triplet_acc: 0.317 - ETA: 1:43 - loss: 4.0569 - triplet_acc: 0.338 - ETA: 1:43 - loss: 3.9640 - triplet_acc: 0.357 - ETA: 1:42 - loss: 3.8572 - triplet_acc: 0.372 - ETA: 1:42 - loss: 3.7354 - triplet_acc: 0.385 - ETA: 1:41 - loss: 3.6415 - triplet_acc: 0.395 - ETA: 1:41 - loss: 3.4985 - triplet_acc: 0.413 - ETA: 1:40 - loss: 3.4208 - triplet_acc: 0.420 - ETA: 1:40 - loss: 3.3100 - triplet_acc: 0.432 - ETA: 1:39 - loss: 3.2286 - triplet_acc: 0.438 - ETA: 1:39 - loss: 3.1313 - triplet_acc: 0.450 - ETA: 1:39 - loss: 3.0576 - triplet_acc: 0.458 - ETA: 1:38 - loss: 2.9697 - triplet_acc: 0.470 - ETA: 1:38 - loss: 2.8848 - triplet_acc: 0.481 - ETA: 1:37 - loss: 2.8376 - triplet_acc: 0.482 - ETA: 1:37 - loss: 2.7500 - triplet_acc: 0.495 - ETA: 1:37 - loss: 2.7006 - triplet_acc: 0.500 - ETA: 1:36 - loss: 2.6312 - triplet_acc: 0.511 - ETA: 1:36 - loss: 2.5911 - triplet_acc: 0.517 - ETA: 1:35 - loss: 2.5532 - triplet_acc: 0.523 - ETA: 1:35 - loss: 2.4979 - triplet_acc: 0.531 - ETA: 1:35 - loss: 2.4397 - triplet_acc: 0.540 - ETA: 1:34 - loss: 2.3984 - triplet_acc: 0.546 - ETA: 1:34 - loss: 2.3498 - triplet_acc: 0.553 - ETA: 1:34 - loss: 2.3188 - triplet_acc: 0.558 - ETA: 1:33 - loss: 2.2655 - triplet_acc: 0.567 - ETA: 1:33 - loss: 2.2334 - triplet_acc: 0.573 - ETA: 1:32 - loss: 2.1987 - triplet_acc: 0.578 - ETA: 1:32 - loss: 2.1748 - triplet_acc: 0.580 - ETA: 1:32 - loss: 2.1330 - triplet_acc: 0.587 - ETA: 1:31 - loss: 2.0915 - triplet_acc: 0.592 - ETA: 1:31 - loss: 2.0553 - triplet_acc: 0.596 - ETA: 1:31 - loss: 2.0397 - triplet_acc: 0.599 - ETA: 1:30 - loss: 2.0148 - triplet_acc: 0.604 - ETA: 1:30 - loss: 1.9948 - triplet_acc: 0.608 - ETA: 1:29 - loss: 1.9566 - triplet_acc: 0.615 - ETA: 1:29 - loss: 1.9197 - triplet_acc: 0.622 - ETA: 1:29 - loss: 1.8901 - triplet_acc: 0.626 - ETA: 1:28 - loss: 1.8563 - triplet_acc: 0.632 - ETA: 1:28 - loss: 1.8259 - triplet_acc: 0.638 - ETA: 1:28 - loss: 1.7993 - triplet_acc: 0.642 - ETA: 1:27 - loss: 1.7820 - triplet_acc: 0.644 - ETA: 1:27 - loss: 1.7665 - triplet_acc: 0.646 - ETA: 1:26 - loss: 1.7437 - triplet_acc: 0.650 - ETA: 1:26 - loss: 1.7151 - triplet_acc: 0.655 - ETA: 1:26 - loss: 1.7204 - triplet_acc: 0.658 - ETA: 1:25 - loss: 1.6989 - triplet_acc: 0.661 - ETA: 1:25 - loss: 1.6873 - triplet_acc: 0.664 - ETA: 1:25 - loss: 1.6628 - triplet_acc: 0.668 - ETA: 1:24 - loss: 1.6402 - triplet_acc: 0.672 - ETA: 1:24 - loss: 1.6218 - triplet_acc: 0.675 - ETA: 1:24 - loss: 1.6015 - triplet_acc: 0.677 - ETA: 1:23 - loss: 1.5838 - triplet_acc: 0.681 - ETA: 1:23 - loss: 1.5661 - triplet_acc: 0.684 - ETA: 1:22 - loss: 1.5447 - triplet_acc: 0.688 - ETA: 1:22 - loss: 1.5350 - triplet_acc: 0.688 - ETA: 1:22 - loss: 1.5246 - triplet_acc: 0.687 - ETA: 1:21 - loss: 1.5050 - triplet_acc: 0.690 - ETA: 1:21 - loss: 1.4852 - triplet_acc: 0.694 - ETA: 1:21 - loss: 1.4656 - triplet_acc: 0.698 - ETA: 1:20 - loss: 1.4537 - triplet_acc: 0.700 - ETA: 1:20 - loss: 1.4373 - triplet_acc: 0.702 - ETA: 1:19 - loss: 1.4297 - triplet_acc: 0.703 - ETA: 1:19 - loss: 1.4155 - triplet_acc: 0.705 - ETA: 1:19 - loss: 1.4035 - triplet_acc: 0.707 - ETA: 1:18 - loss: 1.3903 - triplet_acc: 0.710 - ETA: 1:18 - loss: 1.3 ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:47 - loss: 7.6127 - triplet_acc: 0.0000e+0 - ETA: 2:16 - loss: 6.4889 - triplet_acc: 0.0000e+0 - ETA: 2:06 - loss: 6.7589 - triplet_acc: 0.0000e+0 - ETA: 2:00 - loss: 6.2698 - triplet_acc: 0.0375    - ETA: 1:57 - loss: 6.2918 - triplet_acc: 0.040 - ETA: 1:55 - loss: 6.1476 - triplet_acc: 0.050 - ETA: 1:53 - loss: 6.0393 - triplet_acc: 0.050 - ETA: 1:51 - loss: 5.8794 - triplet_acc: 0.050 - ETA: 1:50 - loss: 5.8411 - triplet_acc: 0.050 - ETA: 1:49 - loss: 5.7896 - triplet_acc: 0.060 - ETA: 1:48 - loss: 5.5043 - triplet_acc: 0.095 - ETA: 1:47 - loss: 5.3986 - triplet_acc: 0.112 - ETA: 1:47 - loss: 5.2794 - triplet_acc: 0.126 - ETA: 1:46 - loss: 5.0822 - triplet_acc: 0.146 - ETA: 1:45 - loss: 4.9754 - triplet_acc: 0.160 - ETA: 1:45 - loss: 4.8534 - triplet_acc: 0.171 - ETA: 1:44 - loss: 4.6866 - triplet_acc: 0.185 - ETA: 1:44 - loss: 4.5924 - triplet_acc: 0.200 - ETA: 1:43 - loss: 4.3819 - triplet_acc: 0.231 - ETA: 1:43 - loss: 4.2034 - triplet_acc: 0.255 - ETA: 1:42 - loss: 4.0761 - triplet_acc: 0.269 - ETA: 1:42 - loss: 3.9711 - triplet_acc: 0.288 - ETA: 1:41 - loss: 3.8620 - triplet_acc: 0.304 - ETA: 1:41 - loss: 3.8007 - triplet_acc: 0.316 - ETA: 1:40 - loss: 3.6927 - triplet_acc: 0.330 - ETA: 1:40 - loss: 3.5668 - triplet_acc: 0.350 - ETA: 1:39 - loss: 3.4611 - triplet_acc: 0.364 - ETA: 1:39 - loss: 3.4189 - triplet_acc: 0.373 - ETA: 1:38 - loss: 3.3144 - triplet_acc: 0.391 - ETA: 1:38 - loss: 3.2411 - triplet_acc: 0.400 - ETA: 1:38 - loss: 3.1938 - triplet_acc: 0.406 - ETA: 1:37 - loss: 3.1068 - triplet_acc: 0.420 - ETA: 1:37 - loss: 3.0358 - triplet_acc: 0.431 - ETA: 1:36 - loss: 2.9637 - triplet_acc: 0.442 - ETA: 1:36 - loss: 2.9046 - triplet_acc: 0.454 - ETA: 1:35 - loss: 2.8420 - triplet_acc: 0.463 - ETA: 1:35 - loss: 2.7865 - triplet_acc: 0.473 - ETA: 1:35 - loss: 2.7364 - triplet_acc: 0.480 - ETA: 1:34 - loss: 2.6695 - triplet_acc: 0.489 - ETA: 1:34 - loss: 2.6408 - triplet_acc: 0.496 - ETA: 1:33 - loss: 2.5928 - triplet_acc: 0.500 - ETA: 1:33 - loss: 2.5654 - triplet_acc: 0.504 - ETA: 1:33 - loss: 2.5127 - triplet_acc: 0.512 - ETA: 1:32 - loss: 2.4773 - triplet_acc: 0.517 - ETA: 1:32 - loss: 2.4356 - triplet_acc: 0.521 - ETA: 1:31 - loss: 2.3977 - triplet_acc: 0.525 - ETA: 1:31 - loss: 2.3731 - triplet_acc: 0.529 - ETA: 1:31 - loss: 2.3373 - triplet_acc: 0.536 - ETA: 1:30 - loss: 2.2932 - triplet_acc: 0.541 - ETA: 1:30 - loss: 2.2546 - triplet_acc: 0.548 - ETA: 1:30 - loss: 2.2339 - triplet_acc: 0.551 - ETA: 1:29 - loss: 2.2033 - triplet_acc: 0.555 - ETA: 1:29 - loss: 2.1764 - triplet_acc: 0.560 - ETA: 1:28 - loss: 2.1450 - triplet_acc: 0.566 - ETA: 1:28 - loss: 2.1178 - triplet_acc: 0.570 - ETA: 1:28 - loss: 2.0838 - triplet_acc: 0.575 - ETA: 1:27 - loss: 2.0703 - triplet_acc: 0.577 - ETA: 1:27 - loss: 2.0389 - triplet_acc: 0.582 - ETA: 1:27 - loss: 2.0185 - triplet_acc: 0.586 - ETA: 1:26 - loss: 2.0040 - triplet_acc: 0.588 - ETA: 1:26 - loss: 1.9745 - triplet_acc: 0.593 - ETA: 1:25 - loss: 1.9474 - triplet_acc: 0.598 - ETA: 1:25 - loss: 1.9283 - triplet_acc: 0.601 - ETA: 1:25 - loss: 1.9083 - triplet_acc: 0.603 - ETA: 1:24 - loss: 1.8961 - triplet_acc: 0.606 - ETA: 1:24 - loss: 1.8907 - triplet_acc: 0.610 - ETA: 1:24 - loss: 1.8637 - triplet_acc: 0.615 - ETA: 1:23 - loss: 1.8363 - triplet_acc: 0.621 - ETA: 1:23 - loss: 1.8249 - triplet_acc: 0.622 - ETA: 1:22 - loss: 1.7989 - triplet_acc: 0.627 - ETA: 1:22 - loss: 1.7738 - triplet_acc: 0.632 - ETA: 1:22 - loss: 1.7573 - triplet_acc: 0.634 - ETA: 1:21 - loss: 1.7362 - triplet_acc: 0.638 - ETA: 1:21 - loss: 1.7182 - triplet_acc: 0.642 - ETA: 1:21 - loss: 1.6988 - triplet_acc: 0.646 - ETA: 1:20 - loss: 1.6882 - triplet_acc: 0.647 - ETA: 1:20 - loss: 1.6698 - triplet_acc: 0.649 - ETA: 1:20 - loss: 1.6508 - triplet_acc: 0.653 - ETA: 1:19 - loss: 1.6353 - triplet_acc: 0.657 - ETA: 1:19 - loss: 1.6216 - triplet_acc: 0.658 - ETA: 1:18 - loss: 1.6173 - triplet_acc: 0.660 - ETA: 1:18 - loss: 1.6054 - triplet_acc: 0.662 - ETA:  ...
# 300/300 [==============================] - ETA: 45s - loss: 0.9965 - triplet_acc: 0.76 - ETA: 45s - loss: 0.9933 - triplet_acc: 0.76 - ETA: 44s - loss: 0.9912 - triplet_acc: 0.76 - ETA: 44s - loss: 0.9889 - triplet_acc: 0.76 - ETA: 44s - loss: 0.9837 - triplet_acc: 0.76 - ETA: 43s - loss: 0.9810 - triplet_acc: 0.76 - ETA: 43s - loss: 0.9788 - triplet_acc: 0.77 - ETA: 43s - loss: 0.9791 - triplet_acc: 0.77 - ETA: 42s - loss: 0.9737 - triplet_acc: 0.77 - ETA: 42s - loss: 0.9697 - triplet_acc: 0.77 - ETA: 41s - loss: 0.9658 - triplet_acc: 0.77 - ETA: 41s - loss: 0.9615 - triplet_acc: 0.77 - ETA: 41s - loss: 0.9592 - triplet_acc: 0.77 - ETA: 40s - loss: 0.9546 - triplet_acc: 0.77 - ETA: 40s - loss: 0.9499 - triplet_acc: 0.77 - ETA: 40s - loss: 0.9491 - triplet_acc: 0.77 - ETA: 39s - loss: 0.9454 - triplet_acc: 0.77 - ETA: 39s - loss: 0.9426 - triplet_acc: 0.77 - ETA: 39s - loss: 0.9387 - triplet_acc: 0.77 - ETA: 38s - loss: 0.9348 - triplet_acc: 0.77 - ETA: 38s - loss: 0.9299 - triplet_acc: 0.77 - ETA: 38s - loss: 0.9251 - triplet_acc: 0.78 - ETA: 37s - loss: 0.9231 - triplet_acc: 0.78 - ETA: 37s - loss: 0.9222 - triplet_acc: 0.78 - ETA: 36s - loss: 0.9177 - triplet_acc: 0.78 - ETA: 36s - loss: 0.9157 - triplet_acc: 0.78 - ETA: 36s - loss: 0.9132 - triplet_acc: 0.78 - ETA: 35s - loss: 0.9129 - triplet_acc: 0.78 - ETA: 35s - loss: 0.9106 - triplet_acc: 0.78 - ETA: 35s - loss: 0.9068 - triplet_acc: 0.78 - ETA: 34s - loss: 0.9052 - triplet_acc: 0.78 - ETA: 34s - loss: 0.9037 - triplet_acc: 0.78 - ETA: 34s - loss: 0.9002 - triplet_acc: 0.78 - ETA: 33s - loss: 0.8984 - triplet_acc: 0.78 - ETA: 33s - loss: 0.8946 - triplet_acc: 0.78 - ETA: 33s - loss: 0.8909 - triplet_acc: 0.78 - ETA: 32s - loss: 0.8883 - triplet_acc: 0.78 - ETA: 32s - loss: 0.8875 - triplet_acc: 0.78 - ETA: 31s - loss: 0.8857 - triplet_acc: 0.78 - ETA: 31s - loss: 0.8816 - triplet_acc: 0.78 - ETA: 31s - loss: 0.8816 - triplet_acc: 0.78 - ETA: 30s - loss: 0.8781 - triplet_acc: 0.79 - ETA: 30s - loss: 0.8740 - triplet_acc: 0.79 - ETA: 30s - loss: 0.8717 - triplet_acc: 0.79 - ETA: 29s - loss: 0.8704 - triplet_acc: 0.79 - ETA: 29s - loss: 0.8664 - triplet_acc: 0.79 - ETA: 29s - loss: 0.8642 - triplet_acc: 0.79 - ETA: 28s - loss: 0.8608 - triplet_acc: 0.79 - ETA: 28s - loss: 0.8569 - triplet_acc: 0.79 - ETA: 28s - loss: 0.8531 - triplet_acc: 0.79 - ETA: 27s - loss: 0.8498 - triplet_acc: 0.79 - ETA: 27s - loss: 0.8521 - triplet_acc: 0.79 - ETA: 26s - loss: 0.8499 - triplet_acc: 0.79 - ETA: 26s - loss: 0.8485 - triplet_acc: 0.79 - ETA: 26s - loss: 0.8500 - triplet_acc: 0.79 - ETA: 25s - loss: 0.8462 - triplet_acc: 0.79 - ETA: 25s - loss: 0.8454 - triplet_acc: 0.79 - ETA: 25s - loss: 0.8442 - triplet_acc: 0.79 - ETA: 24s - loss: 0.8409 - triplet_acc: 0.79 - ETA: 24s - loss: 0.8378 - triplet_acc: 0.79 - ETA: 24s - loss: 0.8346 - triplet_acc: 0.79 - ETA: 23s - loss: 0.8327 - triplet_acc: 0.79 - ETA: 23s - loss: 0.8329 - triplet_acc: 0.79 - ETA: 23s - loss: 0.8295 - triplet_acc: 0.80 - ETA: 22s - loss: 0.8260 - triplet_acc: 0.80 - ETA: 22s - loss: 0.8249 - triplet_acc: 0.80 - ETA: 21s - loss: 0.8220 - triplet_acc: 0.80 - ETA: 21s - loss: 0.8200 - triplet_acc: 0.80 - ETA: 21s - loss: 0.8176 - triplet_acc: 0.80 - ETA: 20s - loss: 0.8147 - triplet_acc: 0.80 - ETA: 20s - loss: 0.8117 - triplet_acc: 0.80 - ETA: 20s - loss: 0.8087 - triplet_acc: 0.80 - ETA: 19s - loss: 0.8078 - triplet_acc: 0.80 - ETA: 19s - loss: 0.8064 - triplet_acc: 0.80 - ETA: 19s - loss: 0.8038 - triplet_acc: 0.80 - ETA: 18s - loss: 0.8008 - triplet_acc: 0.80 - ETA: 18s - loss: 0.7993 - triplet_acc: 0.80 - ETA: 17s - loss: 0.7961 - triplet_acc: 0.80 - ETA: 17s - loss: 0.7953 - triplet_acc: 0.80 - ETA: 17s - loss: 0.7951 - triplet_acc: 0.80 - ETA: 16s - loss: 0.7930 - triplet_acc: 0.80 - ETA: 16s - loss: 0.7914 - triplet_acc: 0.80 - ETA: 16s - loss: 0.7885 - triplet_acc: 0.80 - ETA: 15s - loss: 0.7866 - triplet_acc: 0.80 - ETA: 15s - loss: 0.7835 - triplet_acc: 0.80 - ETA: 15s - loss: 0.7820 - triplet_acc: 0.80 - E ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:53 - loss: 6.6563 - triplet_acc: 0.050 - ETA: 2:18 - loss: 6.9815 - triplet_acc: 0.075 - ETA: 2:07 - loss: 6.0410 - triplet_acc: 0.066 - ETA: 2:01 - loss: 6.0161 - triplet_acc: 0.087 - ETA: 1:57 - loss: 6.0938 - triplet_acc: 0.090 - ETA: 1:54 - loss: 6.3821 - triplet_acc: 0.083 - ETA: 1:52 - loss: 5.9938 - triplet_acc: 0.092 - ETA: 1:51 - loss: 5.8259 - triplet_acc: 0.106 - ETA: 1:49 - loss: 5.6202 - triplet_acc: 0.133 - ETA: 1:48 - loss: 5.5416 - triplet_acc: 0.135 - ETA: 1:47 - loss: 5.3274 - triplet_acc: 0.154 - ETA: 1:46 - loss: 5.1618 - triplet_acc: 0.166 - ETA: 1:46 - loss: 4.9688 - triplet_acc: 0.184 - ETA: 1:45 - loss: 4.7309 - triplet_acc: 0.214 - ETA: 1:44 - loss: 4.5501 - triplet_acc: 0.240 - ETA: 1:44 - loss: 4.4151 - triplet_acc: 0.262 - ETA: 1:43 - loss: 4.2628 - triplet_acc: 0.270 - ETA: 1:43 - loss: 4.1113 - triplet_acc: 0.280 - ETA: 1:42 - loss: 3.9450 - triplet_acc: 0.297 - ETA: 1:42 - loss: 3.7929 - triplet_acc: 0.320 - ETA: 1:41 - loss: 3.6349 - triplet_acc: 0.340 - ETA: 1:41 - loss: 3.4697 - triplet_acc: 0.370 - ETA: 1:40 - loss: 3.3514 - triplet_acc: 0.384 - ETA: 1:40 - loss: 3.2453 - triplet_acc: 0.395 - ETA: 1:39 - loss: 3.1707 - triplet_acc: 0.404 - ETA: 1:39 - loss: 3.1109 - triplet_acc: 0.413 - ETA: 1:39 - loss: 3.0350 - triplet_acc: 0.422 - ETA: 1:38 - loss: 2.9266 - triplet_acc: 0.441 - ETA: 1:38 - loss: 2.8339 - triplet_acc: 0.451 - ETA: 1:37 - loss: 2.7623 - triplet_acc: 0.458 - ETA: 1:37 - loss: 2.6915 - triplet_acc: 0.472 - ETA: 1:37 - loss: 2.6209 - triplet_acc: 0.481 - ETA: 1:36 - loss: 2.5605 - triplet_acc: 0.489 - ETA: 1:36 - loss: 2.5576 - triplet_acc: 0.494 - ETA: 1:35 - loss: 2.5303 - triplet_acc: 0.495 - ETA: 1:35 - loss: 2.4615 - triplet_acc: 0.506 - ETA: 1:35 - loss: 2.4281 - triplet_acc: 0.514 - ETA: 1:34 - loss: 2.3819 - triplet_acc: 0.518 - ETA: 1:34 - loss: 2.3443 - triplet_acc: 0.524 - ETA: 1:33 - loss: 2.3100 - triplet_acc: 0.530 - ETA: 1:33 - loss: 2.2648 - triplet_acc: 0.539 - ETA: 1:33 - loss: 2.2244 - triplet_acc: 0.542 - ETA: 1:32 - loss: 2.1804 - triplet_acc: 0.550 - ETA: 1:32 - loss: 2.1634 - triplet_acc: 0.556 - ETA: 1:31 - loss: 2.1202 - triplet_acc: 0.564 - ETA: 1:31 - loss: 2.0794 - triplet_acc: 0.572 - ETA: 1:31 - loss: 2.0631 - triplet_acc: 0.576 - ETA: 1:30 - loss: 2.0442 - triplet_acc: 0.579 - ETA: 1:30 - loss: 2.0092 - triplet_acc: 0.584 - ETA: 1:29 - loss: 1.9794 - triplet_acc: 0.590 - ETA: 1:29 - loss: 1.9561 - triplet_acc: 0.592 - ETA: 1:29 - loss: 1.9357 - triplet_acc: 0.596 - ETA: 1:28 - loss: 1.9123 - triplet_acc: 0.600 - ETA: 1:28 - loss: 1.8873 - triplet_acc: 0.602 - ETA: 1:28 - loss: 1.8538 - triplet_acc: 0.609 - ETA: 1:27 - loss: 1.8303 - triplet_acc: 0.611 - ETA: 1:27 - loss: 1.8096 - triplet_acc: 0.615 - ETA: 1:27 - loss: 1.7862 - triplet_acc: 0.620 - ETA: 1:26 - loss: 1.7642 - triplet_acc: 0.623 - ETA: 1:26 - loss: 1.7492 - triplet_acc: 0.626 - ETA: 1:25 - loss: 1.7236 - triplet_acc: 0.629 - ETA: 1:25 - loss: 1.7062 - triplet_acc: 0.633 - ETA: 1:25 - loss: 1.6854 - triplet_acc: 0.636 - ETA: 1:24 - loss: 1.6783 - triplet_acc: 0.636 - ETA: 1:24 - loss: 1.6643 - triplet_acc: 0.638 - ETA: 1:24 - loss: 1.6545 - triplet_acc: 0.640 - ETA: 1:23 - loss: 1.6384 - triplet_acc: 0.644 - ETA: 1:23 - loss: 1.6346 - triplet_acc: 0.647 - ETA: 1:22 - loss: 1.6115 - triplet_acc: 0.650 - ETA: 1:22 - loss: 1.5885 - triplet_acc: 0.655 - ETA: 1:22 - loss: 1.5661 - triplet_acc: 0.660 - ETA: 1:21 - loss: 1.5504 - triplet_acc: 0.663 - ETA: 1:21 - loss: 1.5313 - triplet_acc: 0.667 - ETA: 1:21 - loss: 1.5193 - triplet_acc: 0.668 - ETA: 1:20 - loss: 1.5003 - triplet_acc: 0.672 - ETA: 1:20 - loss: 1.4907 - triplet_acc: 0.675 - ETA: 1:20 - loss: 1.4717 - triplet_acc: 0.677 - ETA: 1:19 - loss: 1.4586 - triplet_acc: 0.679 - ETA: 1:19 - loss: 1.4438 - triplet_acc: 0.681 - ETA: 1:18 - loss: 1.4308 - triplet_acc: 0.683 - ETA: 1:18 - loss: 1.4184 - triplet_acc: 0.684 - ETA: 1:18 - loss: 1.4055 - triplet_acc: 0.686 - ETA: 1:17 - loss: 1.3 ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:47 - loss: 5.7470 - triplet_acc: 0.150 - ETA: 2:16 - loss: 6.2846 - triplet_acc: 0.075 - ETA: 2:05 - loss: 7.0097 - triplet_acc: 0.050 - ETA: 2:00 - loss: 7.2806 - triplet_acc: 0.050 - ETA: 1:56 - loss: 7.1401 - triplet_acc: 0.040 - ETA: 1:54 - loss: 6.9319 - triplet_acc: 0.033 - ETA: 1:52 - loss: 6.7418 - triplet_acc: 0.035 - ETA: 1:50 - loss: 6.4200 - triplet_acc: 0.068 - ETA: 1:49 - loss: 6.2864 - triplet_acc: 0.077 - ETA: 1:48 - loss: 6.0567 - triplet_acc: 0.085 - ETA: 1:47 - loss: 5.7804 - triplet_acc: 0.118 - ETA: 1:46 - loss: 5.5413 - triplet_acc: 0.129 - ETA: 1:45 - loss: 5.4171 - triplet_acc: 0.138 - ETA: 1:45 - loss: 5.2375 - triplet_acc: 0.164 - ETA: 1:44 - loss: 5.0404 - triplet_acc: 0.183 - ETA: 1:43 - loss: 4.8207 - triplet_acc: 0.212 - ETA: 1:43 - loss: 4.6403 - triplet_acc: 0.226 - ETA: 1:42 - loss: 4.5588 - triplet_acc: 0.247 - ETA: 1:42 - loss: 4.4073 - triplet_acc: 0.271 - ETA: 1:41 - loss: 4.2225 - triplet_acc: 0.297 - ETA: 1:41 - loss: 4.0964 - triplet_acc: 0.309 - ETA: 1:40 - loss: 3.9651 - triplet_acc: 0.322 - ETA: 1:40 - loss: 3.8470 - triplet_acc: 0.343 - ETA: 1:39 - loss: 3.7947 - triplet_acc: 0.347 - ETA: 1:39 - loss: 3.6809 - triplet_acc: 0.366 - ETA: 1:39 - loss: 3.5989 - triplet_acc: 0.380 - ETA: 1:38 - loss: 3.4945 - triplet_acc: 0.396 - ETA: 1:38 - loss: 3.3697 - triplet_acc: 0.417 - ETA: 1:37 - loss: 3.3164 - triplet_acc: 0.424 - ETA: 1:37 - loss: 3.2511 - triplet_acc: 0.435 - ETA: 1:37 - loss: 3.1893 - triplet_acc: 0.441 - ETA: 1:36 - loss: 3.1453 - triplet_acc: 0.450 - ETA: 1:36 - loss: 3.1182 - triplet_acc: 0.457 - ETA: 1:35 - loss: 3.0575 - triplet_acc: 0.463 - ETA: 1:35 - loss: 3.0236 - triplet_acc: 0.468 - ETA: 1:35 - loss: 2.9593 - triplet_acc: 0.480 - ETA: 1:34 - loss: 2.8800 - triplet_acc: 0.493 - ETA: 1:34 - loss: 2.8049 - triplet_acc: 0.505 - ETA: 1:34 - loss: 2.7710 - triplet_acc: 0.509 - ETA: 1:33 - loss: 2.7081 - triplet_acc: 0.517 - ETA: 1:33 - loss: 2.6665 - triplet_acc: 0.524 - ETA: 1:32 - loss: 2.6143 - triplet_acc: 0.533 - ETA: 1:32 - loss: 2.5750 - triplet_acc: 0.538 - ETA: 1:32 - loss: 2.5336 - triplet_acc: 0.543 - ETA: 1:31 - loss: 2.4852 - triplet_acc: 0.550 - ETA: 1:31 - loss: 2.4451 - triplet_acc: 0.554 - ETA: 1:31 - loss: 2.4102 - triplet_acc: 0.557 - ETA: 1:30 - loss: 2.3637 - triplet_acc: 0.563 - ETA: 1:30 - loss: 2.3241 - triplet_acc: 0.570 - ETA: 1:29 - loss: 2.2828 - triplet_acc: 0.577 - ETA: 1:29 - loss: 2.2430 - triplet_acc: 0.584 - ETA: 1:29 - loss: 2.2137 - triplet_acc: 0.590 - ETA: 1:28 - loss: 2.1751 - triplet_acc: 0.597 - ETA: 1:28 - loss: 2.1532 - triplet_acc: 0.599 - ETA: 1:28 - loss: 2.1229 - triplet_acc: 0.602 - ETA: 1:27 - loss: 2.1046 - triplet_acc: 0.606 - ETA: 1:27 - loss: 2.0722 - triplet_acc: 0.612 - ETA: 1:26 - loss: 2.0508 - triplet_acc: 0.617 - ETA: 1:26 - loss: 2.0537 - triplet_acc: 0.618 - ETA: 1:26 - loss: 2.0315 - triplet_acc: 0.622 - ETA: 1:25 - loss: 2.0034 - triplet_acc: 0.623 - ETA: 1:25 - loss: 1.9770 - triplet_acc: 0.627 - ETA: 1:25 - loss: 1.9456 - triplet_acc: 0.633 - ETA: 1:24 - loss: 1.9190 - triplet_acc: 0.636 - ETA: 1:24 - loss: 1.8997 - triplet_acc: 0.640 - ETA: 1:24 - loss: 1.8741 - triplet_acc: 0.643 - ETA: 1:23 - loss: 1.8483 - triplet_acc: 0.647 - ETA: 1:23 - loss: 1.8353 - triplet_acc: 0.648 - ETA: 1:22 - loss: 1.8121 - triplet_acc: 0.652 - ETA: 1:22 - loss: 1.7972 - triplet_acc: 0.655 - ETA: 1:22 - loss: 1.7746 - triplet_acc: 0.659 - ETA: 1:21 - loss: 1.7603 - triplet_acc: 0.661 - ETA: 1:21 - loss: 1.7422 - triplet_acc: 0.664 - ETA: 1:21 - loss: 1.7197 - triplet_acc: 0.668 - ETA: 1:20 - loss: 1.7031 - triplet_acc: 0.670 - ETA: 1:20 - loss: 1.6816 - triplet_acc: 0.674 - ETA: 1:20 - loss: 1.6732 - triplet_acc: 0.676 - ETA: 1:19 - loss: 1.6518 - triplet_acc: 0.680 - ETA: 1:19 - loss: 1.6349 - triplet_acc: 0.682 - ETA: 1:18 - loss: 1.6197 - triplet_acc: 0.685 - ETA: 1:18 - loss: 1.6047 - triplet_acc: 0.687 - ETA: 1:18 - loss: 1.5887 - triplet_acc: 0.689 - ETA: 1:17 - loss: 1.5 ...
# ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:47 - loss: 5.0849 - triplet_acc: 0.050 - ETA: 2:15 - loss: 5.1881 - triplet_acc: 0.100 - ETA: 2:04 - loss: 5.3596 - triplet_acc: 0.100 - ETA: 1:59 - loss: 5.2660 - triplet_acc: 0.112 - ETA: 1:55 - loss: 5.3401 - triplet_acc: 0.090 - ETA: 1:53 - loss: 5.4550 - triplet_acc: 0.075 - ETA: 1:51 - loss: 5.2269 - triplet_acc: 0.092 - ETA: 1:50 - loss: 5.0724 - triplet_acc: 0.087 - ETA: 1:49 - loss: 4.7976 - triplet_acc: 0.105 - ETA: 1:48 - loss: 4.5952 - triplet_acc: 0.130 - ETA: 1:47 - loss: 4.3443 - triplet_acc: 0.150 - ETA: 1:46 - loss: 4.1751 - triplet_acc: 0.183 - ETA: 1:45 - loss: 4.0321 - triplet_acc: 0.192 - ETA: 1:45 - loss: 3.7777 - triplet_acc: 0.228 - ETA: 1:44 - loss: 3.6510 - triplet_acc: 0.250 - ETA: 1:44 - loss: 3.5539 - triplet_acc: 0.271 - ETA: 1:43 - loss: 3.4755 - triplet_acc: 0.291 - ETA: 1:42 - loss: 3.3242 - triplet_acc: 0.316 - ETA: 1:42 - loss: 3.1648 - triplet_acc: 0.336 - ETA: 1:42 - loss: 3.0248 - triplet_acc: 0.360 - ETA: 1:41 - loss: 2.8874 - triplet_acc: 0.385 - ETA: 1:41 - loss: 2.7673 - triplet_acc: 0.406 - ETA: 1:40 - loss: 2.6706 - triplet_acc: 0.421 - ETA: 1:40 - loss: 2.5748 - triplet_acc: 0.437 - ETA: 1:39 - loss: 2.4874 - triplet_acc: 0.456 - ETA: 1:39 - loss: 2.4014 - triplet_acc: 0.473 - ETA: 1:38 - loss: 2.3273 - triplet_acc: 0.485 - ETA: 1:38 - loss: 2.2448 - triplet_acc: 0.501 - ETA: 1:38 - loss: 2.1802 - triplet_acc: 0.515 - ETA: 1:37 - loss: 2.1154 - triplet_acc: 0.528 - ETA: 1:37 - loss: 2.0643 - triplet_acc: 0.538 - ETA: 1:36 - loss: 2.0132 - triplet_acc: 0.548 - ETA: 1:36 - loss: 1.9696 - triplet_acc: 0.554 - ETA: 1:36 - loss: 1.9163 - triplet_acc: 0.560 - ETA: 1:35 - loss: 1.8615 - triplet_acc: 0.572 - ETA: 1:35 - loss: 1.8201 - triplet_acc: 0.580 - ETA: 1:35 - loss: 1.7826 - triplet_acc: 0.586 - ETA: 1:34 - loss: 1.7465 - triplet_acc: 0.593 - ETA: 1:34 - loss: 1.7201 - triplet_acc: 0.600 - ETA: 1:33 - loss: 1.6837 - triplet_acc: 0.607 - ETA: 1:33 - loss: 1.6468 - triplet_acc: 0.614 - ETA: 1:33 - loss: 1.6258 - triplet_acc: 0.620 - ETA: 1:32 - loss: 1.6066 - triplet_acc: 0.626 - ETA: 1:32 - loss: 1.5722 - triplet_acc: 0.634 - ETA: 1:31 - loss: 1.5380 - triplet_acc: 0.641 - ETA: 1:31 - loss: 1.5056 - triplet_acc: 0.647 - ETA: 1:31 - loss: 1.4735 - triplet_acc: 0.655 - ETA: 1:30 - loss: 1.4448 - triplet_acc: 0.661 - ETA: 1:30 - loss: 1.4270 - triplet_acc: 0.666 - ETA: 1:30 - loss: 1.3984 - triplet_acc: 0.673 - ETA: 1:29 - loss: 1.3752 - triplet_acc: 0.678 - ETA: 1:29 - loss: 1.3488 - triplet_acc: 0.683 - ETA: 1:28 - loss: 1.3238 - triplet_acc: 0.688 - ETA: 1:28 - loss: 1.3017 - triplet_acc: 0.692 - ETA: 1:28 - loss: 1.2781 - triplet_acc: 0.698 - ETA: 1:27 - loss: 1.2604 - triplet_acc: 0.702 - ETA: 1:27 - loss: 1.2398 - triplet_acc: 0.707 - ETA: 1:27 - loss: 1.2192 - triplet_acc: 0.711 - ETA: 1:26 - loss: 1.1985 - triplet_acc: 0.716 - ETA: 1:26 - loss: 1.1821 - triplet_acc: 0.720 - ETA: 1:25 - loss: 1.1675 - triplet_acc: 0.723 - ETA: 1:25 - loss: 1.1487 - triplet_acc: 0.726 - ETA: 1:25 - loss: 1.1358 - triplet_acc: 0.729 - ETA: 1:24 - loss: 1.1196 - triplet_acc: 0.732 - ETA: 1:24 - loss: 1.1024 - triplet_acc: 0.736 - ETA: 1:24 - loss: 1.0857 - triplet_acc: 0.740 - ETA: 1:23 - loss: 1.0724 - triplet_acc: 0.741 - ETA: 1:23 - loss: 1.0579 - triplet_acc: 0.742 - ETA: 1:22 - loss: 1.0429 - triplet_acc: 0.745 - ETA: 1:22 - loss: 1.0282 - triplet_acc: 0.748 - ETA: 1:22 - loss: 1.0147 - triplet_acc: 0.750 - ETA: 1:21 - loss: 1.0006 - triplet_acc: 0.754 - ETA: 1:21 - loss: 0.9908 - triplet_acc: 0.756 - ETA: 1:21 - loss: 0.9774 - triplet_acc: 0.759 - ETA: 1:20 - loss: 0.9670 - triplet_acc: 0.762 - ETA: 1:20 - loss: 0.9542 - triplet_acc: 0.765 - ETA: 1:20 - loss: 0.9437 - triplet_acc: 0.766 - ETA: 1:19 - loss: 0.9344 - triplet_acc: 0.768 - ETA: 1:19 - loss: 0.9278 - triplet_acc: 0.769 - ETA: 1:18 - loss: 0.9188 - triplet_acc: 0.769 - ETA: 1:18 - loss: 0.9092 - triplet_acc: 0.771 - ETA: 1:18 - loss: 0.8990 - triplet_acc: 0.773 - ETA: 1:17 - loss: 0.8 ...
# Epoch 1/1
# 172/300 [================>.............] - ETA: 2:49 - loss: 6.5266 - triplet_acc: 0.100 - ETA: 2:16 - loss: 5.7560 - triplet_acc: 0.150 - ETA: 2:05 - loss: 6.0963 - triplet_acc: 0.116 - ETA: 1:59 - loss: 5.9470 - triplet_acc: 0.137 - ETA: 1:56 - loss: 5.7935 - triplet_acc: 0.130 - ETA: 1:54 - loss: 5.5969 - triplet_acc: 0.125 - ETA: 1:52 - loss: 5.5932 - triplet_acc: 0.135 - ETA: 1:50 - loss: 5.1594 - triplet_acc: 0.181 - ETA: 1:49 - loss: 4.8547 - triplet_acc: 0.194 - ETA: 1:48 - loss: 4.6529 - triplet_acc: 0.225 - ETA: 1:47 - loss: 4.4307 - triplet_acc: 0.254 - ETA: 1:46 - loss: 4.3481 - triplet_acc: 0.258 - ETA: 1:45 - loss: 4.1103 - triplet_acc: 0.280 - ETA: 1:45 - loss: 3.8836 - triplet_acc: 0.296 - ETA: 1:44 - loss: 3.6644 - triplet_acc: 0.316 - ETA: 1:44 - loss: 3.4631 - triplet_acc: 0.346 - ETA: 1:43 - loss: 3.3197 - triplet_acc: 0.370 - ETA: 1:43 - loss: 3.1734 - triplet_acc: 0.388 - ETA: 1:42 - loss: 3.0148 - triplet_acc: 0.413 - ETA: 1:42 - loss: 2.8742 - triplet_acc: 0.437 - ETA: 1:41 - loss: 2.7706 - triplet_acc: 0.459 - ETA: 1:41 - loss: 2.6561 - triplet_acc: 0.479 - ETA: 1:40 - loss: 2.5931 - triplet_acc: 0.482 - ETA: 1:40 - loss: 2.5194 - triplet_acc: 0.500 - ETA: 1:39 - loss: 2.4416 - triplet_acc: 0.512 - ETA: 1:39 - loss: 2.3490 - triplet_acc: 0.528 - ETA: 1:38 - loss: 2.2630 - triplet_acc: 0.542 - ETA: 1:38 - loss: 2.2148 - triplet_acc: 0.553 - ETA: 1:38 - loss: 2.1384 - triplet_acc: 0.569 - ETA: 1:37 - loss: 2.0773 - triplet_acc: 0.578 - ETA: 1:37 - loss: 2.0140 - triplet_acc: 0.587 - ETA: 1:36 - loss: 1.9728 - triplet_acc: 0.593 - ETA: 1:36 - loss: 1.9203 - triplet_acc: 0.604 - ETA: 1:36 - loss: 1.8768 - triplet_acc: 0.611 - ETA: 1:35 - loss: 1.8324 - triplet_acc: 0.617 - ETA: 1:35 - loss: 1.7846 - triplet_acc: 0.626 - ETA: 1:35 - loss: 1.7500 - triplet_acc: 0.632 - ETA: 1:34 - loss: 1.7099 - triplet_acc: 0.639 - ETA: 1:34 - loss: 1.6755 - triplet_acc: 0.643 - ETA: 1:33 - loss: 1.6545 - triplet_acc: 0.648 - ETA: 1:33 - loss: 1.6142 - triplet_acc: 0.657 - ETA: 1:33 - loss: 1.5825 - triplet_acc: 0.661 - ETA: 1:32 - loss: 1.5526 - triplet_acc: 0.668 - ETA: 1:32 - loss: 1.5173 - triplet_acc: 0.676 - ETA: 1:31 - loss: 1.4856 - triplet_acc: 0.681 - ETA: 1:31 - loss: 1.4732 - triplet_acc: 0.684 - ETA: 1:31 - loss: 1.4442 - triplet_acc: 0.690 - ETA: 1:30 - loss: 1.4182 - triplet_acc: 0.694 - ETA: 1:30 - loss: 1.3931 - triplet_acc: 0.700 - ETA: 1:30 - loss: 1.3714 - triplet_acc: 0.705 - ETA: 1:29 - loss: 1.3481 - triplet_acc: 0.709 - ETA: 1:29 - loss: 1.3225 - triplet_acc: 0.714 - ETA: 1:28 - loss: 1.2975 - triplet_acc: 0.719 - ETA: 1:28 - loss: 1.2735 - triplet_acc: 0.725 - ETA: 1:28 - loss: 1.2517 - triplet_acc: 0.728 - ETA: 1:27 - loss: 1.2314 - triplet_acc: 0.732 - ETA: 1:27 - loss: 1.2143 - triplet_acc: 0.734 - ETA: 1:27 - loss: 1.2002 - triplet_acc: 0.737 - ETA: 1:26 - loss: 1.1884 - triplet_acc: 0.739 - ETA: 1:26 - loss: 1.1687 - triplet_acc: 0.743 - ETA: 1:26 - loss: 1.1551 - triplet_acc: 0.746 - ETA: 1:25 - loss: 1.1402 - triplet_acc: 0.750 - ETA: 1:25 - loss: 1.1243 - triplet_acc: 0.752 - ETA: 1:24 - loss: 1.1124 - triplet_acc: 0.755 - ETA: 1:24 - loss: 1.0977 - triplet_acc: 0.756 - ETA: 1:24 - loss: 1.0842 - triplet_acc: 0.759 - ETA: 1:23 - loss: 1.0721 - triplet_acc: 0.761 - ETA: 1:23 - loss: 1.0655 - triplet_acc: 0.762 - ETA: 1:23 - loss: 1.0543 - triplet_acc: 0.764 - ETA: 1:22 - loss: 1.0463 - triplet_acc: 0.764 - ETA: 1:22 - loss: 1.0316 - triplet_acc: 0.767 - ETA: 1:21 - loss: 1.0176 - triplet_acc: 0.770 - ETA: 1:21 - loss: 1.0072 - triplet_acc: 0.772 - ETA: 1:21 - loss: 0.9941 - triplet_acc: 0.775 - ETA: 1:20 - loss: 0.9821 - triplet_acc: 0.777 - ETA: 1:20 - loss: 0.9692 - triplet_acc: 0.780 - ETA: 1:20 - loss: 0.9604 - triplet_acc: 0.781 - ETA: 1:19 - loss: 0.9517 - triplet_acc: 0.784 - ETA: 1:19 - loss: 0.9402 - triplet_acc: 0.785 - ETA: 1:19 - loss: 0.9284 - triplet_acc: 0.788 - ETA: 1:18 - loss: 0.9169 - triplet_acc: 0.790 - ETA: 1:18 - loss: 0.9113 - triplet_acc: 0.792 - ETA: 1:17 - loss: 0.9 ...
# 258/300 [========================>.....] - ETA: 45s - loss: 0.5210 - triplet_acc: 0.87 - ETA: 45s - loss: 0.5195 - triplet_acc: 0.87 - ETA: 44s - loss: 0.5166 - triplet_acc: 0.87 - ETA: 44s - loss: 0.5136 - triplet_acc: 0.87 - ETA: 44s - loss: 0.5111 - triplet_acc: 0.87 - ETA: 43s - loss: 0.5082 - triplet_acc: 0.87 - ETA: 43s - loss: 0.5077 - triplet_acc: 0.87 - ETA: 42s - loss: 0.5049 - triplet_acc: 0.87 - ETA: 42s - loss: 0.5021 - triplet_acc: 0.87 - ETA: 42s - loss: 0.4993 - triplet_acc: 0.87 - ETA: 41s - loss: 0.4966 - triplet_acc: 0.87 - ETA: 41s - loss: 0.4939 - triplet_acc: 0.87 - ETA: 41s - loss: 0.4913 - triplet_acc: 0.87 - ETA: 40s - loss: 0.4886 - triplet_acc: 0.87 - ETA: 40s - loss: 0.4879 - triplet_acc: 0.87 - ETA: 40s - loss: 0.4853 - triplet_acc: 0.88 - ETA: 39s - loss: 0.4827 - triplet_acc: 0.88 - ETA: 39s - loss: 0.4802 - triplet_acc: 0.88 - ETA: 38s - loss: 0.4790 - triplet_acc: 0.88 - ETA: 38s - loss: 0.4780 - triplet_acc: 0.88 - ETA: 38s - loss: 0.4755 - triplet_acc: 0.88 - ETA: 37s - loss: 0.4732 - triplet_acc: 0.88 - ETA: 37s - loss: 0.4707 - triplet_acc: 0.88 - ETA: 37s - loss: 0.4683 - triplet_acc: 0.88 - ETA: 36s - loss: 0.4665 - triplet_acc: 0.88 - ETA: 36s - loss: 0.4642 - triplet_acc: 0.88 - ETA: 36s - loss: 0.4642 - triplet_acc: 0.88 - ETA: 35s - loss: 0.4619 - triplet_acc: 0.88 - ETA: 35s - loss: 0.4626 - triplet_acc: 0.88 - ETA: 35s - loss: 0.4611 - triplet_acc: 0.88 - ETA: 34s - loss: 0.4598 - triplet_acc: 0.88 - ETA: 34s - loss: 0.4577 - triplet_acc: 0.88 - ETA: 33s - loss: 0.4555 - triplet_acc: 0.88 - ETA: 33s - loss: 0.4554 - triplet_acc: 0.88 - ETA: 33s - loss: 0.4532 - triplet_acc: 0.88 - ETA: 32s - loss: 0.4511 - triplet_acc: 0.88 - ETA: 32s - loss: 0.4492 - triplet_acc: 0.88 - ETA: 32s - loss: 0.4471 - triplet_acc: 0.88 - ETA: 31s - loss: 0.4450 - triplet_acc: 0.88 - ETA: 31s - loss: 0.4429 - triplet_acc: 0.88 - ETA: 31s - loss: 0.4423 - triplet_acc: 0.88 - ETA: 30s - loss: 0.4415 - triplet_acc: 0.88 - ETA: 30s - loss: 0.4399 - triplet_acc: 0.89 - ETA: 30s - loss: 0.4382 - triplet_acc: 0.89 - ETA: 29s - loss: 0.4365 - triplet_acc: 0.89 - ETA: 29s - loss: 0.4346 - triplet_acc: 0.89 - ETA: 28s - loss: 0.4339 - triplet_acc: 0.89 - ETA: 28s - loss: 0.4320 - triplet_acc: 0.89 - ETA: 28s - loss: 0.4306 - triplet_acc: 0.89 - ETA: 27s - loss: 0.4287 - triplet_acc: 0.89 - ETA: 27s - loss: 0.4275 - triplet_acc: 0.89 - ETA: 27s - loss: 0.4259 - triplet_acc: 0.89 - ETA: 26s - loss: 0.4245 - triplet_acc: 0.89 - ETA: 26s - loss: 0.4226 - triplet_acc: 0.89 - ETA: 26s - loss: 0.4215 - triplet_acc: 0.89 - ETA: 25s - loss: 0.4198 - triplet_acc: 0.89 - ETA: 25s - loss: 0.4190 - triplet_acc: 0.89 - ETA: 25s - loss: 0.4172 - triplet_acc: 0.89 - ETA: 24s - loss: 0.4154 - triplet_acc: 0.89 - ETA: 24s - loss: 0.4189 - triplet_acc: 0.89 - ETA: 23s - loss: 0.4173 - triplet_acc: 0.89 - ETA: 23s - loss: 0.4165 - triplet_acc: 0.89 - ETA: 23s - loss: 0.4158 - triplet_acc: 0.89 - ETA: 22s - loss: 0.4148 - triplet_acc: 0.89 - ETA: 22s - loss: 0.4130 - triplet_acc: 0.89 - ETA: 22s - loss: 0.4116 - triplet_acc: 0.89 - ETA: 21s - loss: 0.4099 - triplet_acc: 0.89 - ETA: 21s - loss: 0.4082 - triplet_acc: 0.89 - ETA: 21s - loss: 0.4065 - triplet_acc: 0.89 - ETA: 20s - loss: 0.4048 - triplet_acc: 0.89 - ETA: 20s - loss: 0.4034 - triplet_acc: 0.89 - ETA: 20s - loss: 0.4029 - triplet_acc: 0.89 - ETA: 19s - loss: 0.4013 - triplet_acc: 0.89 - ETA: 19s - loss: 0.3997 - triplet_acc: 0.89 - ETA: 18s - loss: 0.3983 - triplet_acc: 0.89 - ETA: 18s - loss: 0.3971 - triplet_acc: 0.89 - ETA: 18s - loss: 0.3955 - triplet_acc: 0.89 - ETA: 17s - loss: 0.3960 - triplet_acc: 0.89 - ETA: 17s - loss: 0.3944 - triplet_acc: 0.89 - ETA: 17s - loss: 0.3929 - triplet_acc: 0.89 - ETA: 16s - loss: 0.3929 - triplet_acc: 0.89 - ETA: 16s - loss: 0.3916 - triplet_acc: 0.89 - ETA: 16s - loss: 0.3912 - triplet_acc: 0.89 - ETA: 15s - loss: 0.3896 - triplet_acc: 0.89 - ETA: 15s - loss: 0.3884 - triplet_acc: 0.89 - ETA: 15s - loss: 0.3869 - triplet_acc: 0.8994

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(1)+'.h5')

# %%
# Without hard triplet generation
#histories = []
for i in range(30):
    print("Epoch: " + str(i))
    histories += [model.fit_generator(
        image_generator(filenames_train,labels_train,3*10),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*10,False),
        validation_steps=30
    )]

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.npy',history_)
np.savetxt(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(0)+'.h5')

# %%
# dogfacenet_v24
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,64,128,256,512]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v23
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,128,512,1024]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    for i in range(2):
        gsize = layer//32
        branch = []
        for group in range(32):
            x = Conv2D(gsize, (1, 1), use_bias=False, padding='same')(r)
            x = BatchNormalization()(x)
            
            x = Conv2D(gsize, (3, 3), use_bias=False, activation='relu', padding='same')(x)
            x = BatchNormalization()(x)
            x = Dropout(0.5)(x)
            
            branch += [x]
        
        x = Concatenate()(branch)
        x = Conv2D(layer, (1, 1), use_bias=False, activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        r = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v18
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [32,32,64,128,512]:
    
    for channel in range(4):
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v20
# close to official resnet with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [16,32,64,128,512,1024]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # Resnet blocks
    for j in range(2):
        x = Conv2D(layer, (1, 1), padding='same')(r)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v21
# close to official resneXt with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [32,64,128,512,1024,2048]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # ResneXt blocks, group 16
    for j in range(2):
        ksize = layer//16
        branch_res = []
        
        for k in range(16):
            x = Conv2D(ksize, (1, 1), padding='same')(r)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)

            x = Conv2D(ksize, (3, 3), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            x = Dropout(0.5)(x)
            
            branch_res += [x]
        
        x = Concatenate()(branch_res)
        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.20.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug_2.16.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model.evaluate(triplet_test,y_triplet_test, batch_size=63)

# %%
from IPython.display import FileLink

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5')

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.50.h5')

# %%
FileLink(PATH_SAVE + '2018.02.27.dogfacenet_v11.hard_triplet.data_aug.10.a_0.3.npy')

# %%
model.save(PATH_MODEL + '2019.02.12.hard_triplet_trained.data_aug.0.h5')

# %%
triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %%
print(str((3*len(predict_train)+3*(nbof_classes//10 + 1),h,w,c)))

# %%
del new_images_train
del new_labels_train
del predict_train
del triplet_train, y_triplet_train
gc.collect()

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

# %%
histories = []

# %%
for i in range(6):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories += [history]

# %%
model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(1)+'.h5')

# %%
histories2 = [histories[i] for i in range(29)]

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
for i in range(2):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories2 += [history]
model.save(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(16)+'.h5')

# %%
histories = histories[:-2]

# %%
model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(0.0001),
              metrics=[triplet_acc])

# %% [markdown]
# - 14*3 epochs with lr=0.001
# - 4*3 epochs with lr=0.0005
# - 4*3 epochs with lr=0.0003
# - 4*1 epochs with lr=0.0001

# %%
 model.save(PATH_MODEL + '2019.02.28.dogfacenet_v22.hard_triplet.alpha.0.3.'+str(l)+'.h5')

# %%
histories = []

# %%
epochs = [14,4,4,4]
lr = [0.001,0.0005,0.0003,0.0001]
for l in range(1,len(lr)):
    model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(lr[l]),
              metrics=[triplet_acc])
    for k in range(epochs[l]):
        epoch_nb = k+sum(epochs[:l])
        print("Beginning epoch number: "+str(epoch_nb)+", over "+str(sum(epochs))+" epochs. \n")

        
        new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
        predict_train=model.predict(new_images_train)
        triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

        for i in range(6):
            history = model.fit(
                triplet_train,
                y_triplet_train,
                batch_size = 21*3,
                epochs = 1,
                validation_data=(triplet_test,y_triplet_test),
                shuffle=False
            )
            histories += [history]
        
        del new_images_train, new_labels_train, predict_train, triplet_train, y_triplet_train
        gc.collect()
        model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(k)+'.h5')

        loss = np.empty(0)
        val_loss = np.empty(0)
        acc = np.empty(0)
        val_acc = np.empty(0)

        for history in histories:
            loss = np.append(loss,history.history['loss'])
            val_loss = np.append(val_loss,history.history['val_loss'])
            acc = np.append(acc,history.history['triplet_acc'])
            val_acc = np.append(val_acc,history.history['val_triplet_acc'])


        history_ = np.array([loss,val_loss,acc,val_acc])
        np.save(PATH_SAVE+'2019.04.08.dogfacenet_v12.npy',history_)
        np.savetxt(PATH_SAVE+'2019.04.08.dogfacenet_v12.txt',history_)

# %%
model.save(PATH_MODEL + '2019.02.28.dogfacenet_v24.hard_triplet.alpha.0.3.'+str(0)+'.h5')

# %%
history_ = np.load(PATH_SAVE+'2018.02.28.dogfacenet_v12.hard_triplet.data_aug.5.a_0.3.npy')

# %%
loss,val_loss,acc,val_acc = history_

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
for i in range(5):
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

    model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )

    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(i+16)+'.h5')

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
history=model.fit(
    triplet_train,
    y_triplet_train,
    batch_size = 21*3,
    epochs = 1,
    validation_data=(triplet_test,y_triplet_test),
    shuffle=False
)

# %%
model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5')

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

loss = np.append(loss,history.history['loss'])
val_loss = np.append(val_loss,history.history['val_loss'])
acc = np.append(acc,history.history['triplet_acc'])
val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
histories = []
nbof_cycles = 9
for i in range(0,nbof_cycles,1):

    history=model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = nbof_cycles-i,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    
    histories += [history]
    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v10.hard_triplet_trained.data_aug.' + str(i+1) + '.h5')
    
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for i in range(len(histories)):
    history = histories[i]
    
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
# Test on new triplet integrity
print(new_y_triplet_train[-30:])
t = np.equal(new_y_triplet_train[0::3],new_y_triplet_train[1::3])
print(t)
np.sum(t.astype(np.float32))/len(t)

# %% [markdown]
# ### Evaluate it

# %% [markdown]
# #### Evaluate on verification task

# %%
NBOF_PAIRS = 5000
#NBOF_PAIRS = len(images_test)

# Create pairs
h,w,c = SIZE
pairs = np.empty((NBOF_PAIRS*2,h,w,c))
issame = np.empty(NBOF_PAIRS)
class_test = np.unique(labels_test)
for i in range(NBOF_PAIRS):
    alea = np.random.rand()
    # Pair of different dogs
    if alea < 0.5:
        # Chose the classes:
        class1 = np.random.randint(len(class_test))
        class2 = np.random.randint(len(class_test))
        while class1==class2:
            class2 = np.random.randint(len(class_test))
            
        # Extract images of this class:
        images_class1 = images_test[np.equal(labels_test,class1)]
        images_class2 = images_test[np.equal(labels_test,class2)]
        
        # Chose an image amoung these selected images
        pairs[i*2] = images_class1[np.random.randint(len(images_class1))]
        pairs[i*2+1] = images_class2[np.random.randint(len(images_class2))]
        issame[i] = 0
    # Pair of same dogs
    else:
        # Chose a class
        clas = np.random.randint(len(class_test))
        images_class = images_test[np.equal(labels_test,clas)]
        
        # Select two images from this class
        idx_image1 = np.random.randint(len(images_class))
        idx_image2 = np.random.randint(len(images_class))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(images_class))
        
        pairs[i*2] = images_class[idx_image1]
        pairs[i*2+1] = images_class[idx_image2]
        issame[i] = 1

# %%
# Test: Check the pairs
s = 10
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(5,3*n))
for i in range(s,s+n):
    plt.subplot(n,2,2*(i-s)+1)
    plt.imshow(pairs[2*i]*0.5+0.5)
    plt.subplot(n,2,2*(i-s)+2)
    plt.imshow(pairs[2*i+1]*0.5+0.5)

# %%
predict=model.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)


best = 0
best_t = 0
thresholds = np.arange(0.001,4,0.001)
for i in tqdm_notebook(range(len(thresholds))):
    less = np.less(dist, thresholds[i])
    acc = np.logical_not(np.logical_xor(less, issame))
    acc = acc.astype(float)
    out = np.sum(acc)
    out = out/len(acc)
    if out > best:
        best_t = thresholds[i]
        best = out

print("Best threshold: " + str(best_t))
print("Best accuracy: " + str(best))

# %%
# False accepted examples and False rejected examples
t = 0.68
fa = []
fr = []
for i in range(len(dist)):
    # false accepted
    if issame[i] == 0 and dist[i]<t:
        fa += [i]
    if issame[i] == 1 and dist[i]>t:
        fr += [i]

# %%
# Test: Look at wrong pairs
s = 10
sr = 20
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(11,2.8*n))
for i in range(s,s+n):
    # False accepted
    plt.subplot(n,4,4*(i-s)+1)
    plt.imshow(pairs[2*fa[i+s]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+2)
    plt.imshow(pairs[2*fa[i+s]+1])
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(n,4,4*(i-s)+3)
    plt.imshow(pairs[2*fr[i+sr]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+4)
    plt.imshow(pairs[2*fr[i+sr]+1])
    plt.xticks([])
    plt.yticks([])

# %%
len(fa)

# %%
len(fr)

# %%
threshold = 0.3
less = np.less(dist, threshold)
acc = np.logical_not(np.logical_xor(less, issame))
acc = acc.astype(float)
out = np.sum(acc)
out = out/len(acc)

print("Accuracy: " + str(out))

# %% [markdown]
# ### ROC curve

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)

# Computes the ROC depending on different thresholds

thresholds = np.arange(0.001,4,0.001)
tprs = np.empty(len(thresholds))
fprs = np.empty(len(thresholds))

p = np.sum(issame.astype(float))
n = np.sum(np.logical_not(issame).astype(float))

for i in tqdm_notebook(range(len(thresholds))):
    logical_pred = np.less(dist, thresholds[i])
    tp = np.sum(np.logical_and(logical_pred,issame).astype(float))
    fp = np.sum(np.logical_and(logical_pred,np.logical_not(issame)).astype(float))
    tprs[i] = tp/p
    fprs[i] = fp/n

# %%
np.save('roc_dogfacenet_v11.npy', [tprs, fprs])

# %%
tprs2,fprs2 = np.load('roc_dogfacenet_v12.npy')

# %%
plt.figure(figsize=(5,5))
plt.plot(fprs,tprs,label="VGG-like")
plt.plot(fprs2,tprs2,label="ResNet-like")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
#plt.title("ROC curve")

# %% [markdown]
# ### Second verification task: IN or OUT? actually I think that this task doesn't make any sense

# %%
pred_test = model.predict(images_test)

# %%
nbof_try = 30 # We will do many try on the test dataset to obtain a more precize accuracy

for propo in [0.5,0.6,0.7,0.8,0.9]:
    print("Current propotion of classes considered: " + str(propo))
    
    mean_acc = 0
    max_acc = 0
    min_acc = 1
    mean_t = 0
    
    for _ in tqdm_notebook(range(nbof_try)):
        nbof_kimages=int(propo*len(np.unique(labels_test)))
        kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
        y_kimages = np.unique(labels_test)[:nbof_kimages]

        others_pred = np.copy(pred_test)
        y_others = np.copy(labels_test)

        for i in range(nbof_kimages):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
            choice = np.random.randint(len(keep_classes_images))

            kpred[i] = others_pred[keep_classes_images[choice]]

            others_pred = np.delete(others_pred,keep_classes_images[choice],0)
            y_others = np.delete(y_others,keep_classes_images[choice],0)

        # We find the best threshold for this dataset
        best_acc = 0
        best_t = 0.01
        for threshold in np.arange(0.01,1,0.01):

            acc = 0

            class_pred = np.empty(len(others_pred))

            for i in range(len(others_pred)):
                # computes distance with the key dataset
                dist = np.sum(np.square(kpred-others_pred[i]),1)
                if np.min(dist) < threshold:
                    if y_others[i] in y_kimages:
                        acc += 1
                else:
                    if not y_others[i] in y_kimages:
                        acc += 1
            acc /= len(others_pred)

            if acc > best_acc:
                best_acc = acc
                best_t = threshold

        mean_acc += best_acc
        mean_t += best_t
        
        if best_acc > max_acc:
            max_acc = best_acc
        if best_acc < min_acc:
            min_acc = best_acc
        
    mean_acc /= nbof_try
    
    mean_t /= nbof_try
    print("Mean accuracy for in/out: " + str(mean_acc))
    print("Max accuracy for in/out: " + str(max_acc))
    print("Min accuracy for in/out: " + str(min_acc))
    print("Mean threshold for in/out: " + str(mean_t))

# %% [markdown]
# ### Face clustering

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(images_test)

# %%
predict=model.predict(images_test)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=len(np.unique(labels_test)),max_iter=2000, random_state=0,tol=0.2).fit(predict)

# %%
images_cluster = [images_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]
labels_cluster = [labels_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]

# %%
len(images_train)

# %%
len(images_test)

# %%
i = 10
length = len(images_cluster[i])
fig=plt.figure(figsize=(5,5))
for j in range(3):
    for k in range(3):
        plt.subplot(3,3,j*3+k+1)
        plt.imshow(images_cluster[i][j*3+k])
        plt.xticks([])
        plt.yticks([])
#fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.1000.png')

# %%
for i in range(len(images_cluster)):
    length = len(images_cluster[i])
    if length > 0:
        print(labels_cluster[i])
        fig=plt.figure(figsize=(length*2,2))
        for j in range(length):
            plt.subplot(1,length,j+1)
            plt.imshow(images_cluster[i][j])
            plt.xticks([])
            plt.yticks([])
        plt.show()
        #fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.'+str(i)+'.png')

# %% [markdown]
# ### Recognition: K-NN
# m is the number of images that are going to be selected for k-NN "training".

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
for m in range(1,5):
    
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)
    
    # Model prediction on the reduce dataset
    new_pred_test = model.predict(new_images_test)

    nbof_test = 1000
    mean_acc = 0
    mini = 1
    maxi = 0
    
    # Definition of K
    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # I select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)
        acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
nbof_test = 1000
mean_acc = 0
mini = 1
maxi = 0
if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# ### Recognition: k-NN top 1/2/3/4/5

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
max_rk = 5 # Top "max_rk" accuracy

for m in range(1,5):
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)

    new_pred_test = model.predict(new_images_test)

    nbof_test = 100
    mean_acc = 0
    mini = 1
    maxi = 0

    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # Second we select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)

        rk1_pred_y_others = neigh.predict(others_pred)
        pred_y_others = np.zeros((len(others_pred),max_rk))
        for i in range(len(pred_y_others)):
            pred_y_others[i][0] = rk1_pred_y_others[i]

        for i in range(1,max_rk):
            for j in range(len(pred_y_others)):
                previous_pred = [pred_y_others[j][k] for k in range(0,i)]
                to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
                for k in range(1,len(previous_pred)):
                    to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
                new_kpred = kpred[to_keep]
                new_y_kimages = y_kimages[to_keep]

                neigh.fit(new_kpred, new_y_kimages)

                pred_y_others[j][i] = neigh.predict([others_pred[j]])

        #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
        acc = 0
        for i in range(len(pred_y_others)):
            if y_others[i] in pred_y_others[i]:
                acc += 1
        acc /= len(pred_y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
m = 2
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

new_pred_test = model.predict(new_images_test)

# %%
nbof_test = 100
mean_acc = 0
mini = 1
maxi = 0
max_rk = 5

if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    
    rk1_pred_y_others = neigh.predict(others_pred)
    pred_y_others = np.zeros((len(others_pred),max_rk))
    for i in range(len(pred_y_others)):
        pred_y_others[i][0] = rk1_pred_y_others[i]

    for i in range(1,max_rk):
        for j in range(len(pred_y_others)):
            previous_pred = [pred_y_others[j][k] for k in range(0,i)]
            to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
            for k in range(1,len(previous_pred)):
                to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
            new_kpred = kpred[to_keep]
            new_y_kimages = y_kimages[to_keep]
            
            neigh.fit(new_kpred, new_y_kimages)
    
            pred_y_others[j][i] = neigh.predict([others_pred[j]])

    #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    acc = 0
    for i in range(len(pred_y_others)):
        if y_others[i] in pred_y_others[i]:
            acc += 1
    acc /= len(pred_y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# #### k-NN test part

# %%
m = 3
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

# %%
new_pred_test = model.predict(new_images_test)

# %%
# Second we select m images per classes for k-NN training
nbof_kimages=m*len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.empty(nbof_kimages, dtype=int)
y_kuniques = np.unique(new_labels_test)
for i in range(len(y_kuniques)):
    for j in range(m):
        y_kimages[i*2+j] = y_kuniques[i]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(len(y_kuniques)):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*2],y_others)]
    choices = np.empty(0,dtype=int)
    
    if len(keep_classes_images) <= m:
        print("Bug!")
        break
        
    for j in range(m):
        choice = np.random.randint(len(keep_classes_images))
        while choice in choices:
            choice = np.random.randint(len(keep_classes_images))
        choices=np.append(choices,choice)
    #print(choices)
    for j in range(m):
        kpred[i*2+j] = others_pred[keep_classes_images[choices[j]]]

    others_pred = np.delete(others_pred,keep_classes_images[choices],0)
    y_others = np.delete(y_others,keep_classes_images[choices],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=m+1, weights='distance')
neigh.fit(kpred, y_kimages)
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.unique(new_labels_test)[:nbof_kimages]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh = KNeighborsClassifier(n_neighbors=1)
    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(labels_test))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
nbof_kimages=len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.unique(new_labels_test)[:nbof_kimages]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(kpred, y_kimages)

# %%
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
mean_acc = 0
nbof_try = 1 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = y_others[i]
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %%
def find_n_mins(t,n):
    idx_mins = []
    mins = []
    for i in range(n):
        idx_crt_min = 0
        crt_min = t[0]
        for j in range(1,len(t)):
            if t[j] < crt_min:
                crt_min = t[j]
                idx_crt_min = j
        idx_mins += [idx_crt_min]
        mins += [crt_min]
        t = t[:idx_crt_min] + t[idx_crt_min+1:]
    return idx_mins, mins

# %% [markdown]
# ### Recognition: One-shot learning (deprecated: use the above part with M=1 instead)

# %%
pred_test = model.predict(images_test)

# %%
mean_acc = 0
nbof_try = 1000 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = 1
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %% [markdown]
# #### Test for one-shot learning:

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kimages=np.empty((nbof_kimages,h,w,c))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others = np.copy(images_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kimages[i] = others[keep_classes_images[choice]]
    
    others = np.delete(others,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

kpred = model.predict(kimages)

# Prediction for every other pictures
others_pred = model.predict(others)

# %%
pred_test = model.predict(images_test)

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others_pred = np.copy(pred_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
# we will use the best threshold find on verification task
threshold = 0.3

# for i in range(len(others_pred)):

acc = 0

class_pred = np.empty(len(others_pred))

for i in range(len(others_pred)):
    # computes distance with the key dataset
    dist = np.sum(np.square(kpred-others_pred[i]),1)
    if np.min(dist) < threshold:
        class_pred[i] = np.argmin(dist)
        if np.argmin(dist)==y_others[i]:
            acc += 1
    else:
        class_pred[i] = -1
        if not y_others[i] in y_kimages:
            acc += 1
        
acc /= len(others_pred)
acc

# %%
# we will find the best threshold for verification
best_acc = 0
best_t = 0.001
for threshold in np.arange(0.001,1,0.001):

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = np.argmin(dist)
            if np.argmin(dist)==y_others[i]:
                acc += 1
#             if y_others[i] in y_kimages:
#                 acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1
    acc /= len(others_pred)
    
    if acc > best_acc:
        best_acc = acc
        best_t = threshold


print(best_acc)
print(best_t)

# %%
plt.figure(figsize=(8,5))
for i in range(38):
    plt.subplot(5,8,i+1)
    plt.imshow(kimages[i])

# %%
plt.figure(figsize=(13,18))
for i in range(13*18):
    plt.subplot(18,13,i+1)
    plt.imshow(others[i])

# %% [markdown]
# ### Recognition: Re-training

# %%
s = 30.
m = 0.3
def cosine(y_true,y_pred):
    
    exp_s = K.exp(s * y_pred)
    exp_s_m = K.exp(s * (y_pred - m))
    
    masked_exp_s_m = exp_s_m * y_true
    
    inv_mask = 1. - y_true
    masked_exp_s = exp_s * inv_mask
    
    den = K.sum(masked_exp_s + masked_exp_s_m, axis=-1, keepdims=True)
    out = masked_exp_s_m / den
    out = K.sum(out,axis=-1)
    ret = - K.log(out)
    ret = K.sum(ret)
    return ret

# %%
class Cosine(tf.keras.layers.Layer):

    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(Cosine, self).__init__(**kwargs)

    def build(self, input_shape):
        shape = tf.TensorShape((input_shape[-1],self.output_dim))

        self.kernel = self.add_weight(name='kernel', 
                                      shape=shape,
                                      initializer='uniform',
                                      trainable=True)
        super(Cosine, self).build(input_shape)

    def call(self, x):
        x = tf.math.l2_normalize(x, axis=-1)
        w = tf.math.l2_normalize(self.kernel, axis=0)
        
        return K.dot(x, w)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

# %%
labels_test_exp = tf.keras.utils.to_categorical(labels_test)

# %%
#out = tf.keras.layers.Dense(128, activation='relu')(model.output)
out = Cosine(len(labels_test_exp[0]))(model.output)
#out = tf.keras.layers.Dense(24, activation='softmax')(out)
recog = tf.keras.Model(model.input,out)
for layer in model.layers: layer.trainable = False
recog.compile(tf.keras.optimizers.Adam(),loss=cosine,metrics=['accuracy'])

# %%
recog.fit(images_test,labels_test_exp,batch_size=64,epochs=30)

# %% [markdown]
# ### Observation on the heatmap

# %%
model.layers

# %%
mod3 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict3 = mod3.predict(images_train[0:100:10])

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(10,10,i*10+1)
    sk.io.imshow(images_train[i*10])
    
    for j in range(9):
        pred3 = np.mean(predict3[i][:,:,j*25:j*25+3],axis=-1)
        plt.subplot(10,10,i*10+2+j)
        sk.io.imshow(images_train[i*10])
        plt.imshow(pred3,cmap='plasma')

# %%
s = 100
mod1 = tf.keras.Model(model.layers[0].input, model.layers[1].output)
predict1 = mod1.predict(images_train[0+s:100+s:10])

mod2 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict2 = mod2.predict(images_train[0+s:100+s:10])

mod3 = tf.keras.Model(model.layers[0].input, model.layers[14].output)
predict3 = mod3.predict(images_train[0+s:100+s:10])

plt.figure(figsize=(9,20))
for i in range(10):
    pred1 = np.mean(predict1[i],axis=-1)
    pred2 = np.mean(predict2[i],axis=-1)
    pred3 = np.mean(predict3[i],axis=-1)

    
    plt.subplot(10,4,i*4+1)
    sk.io.imshow(images_train[i*10 + s])
    plt.subplot(10,4,i*4+2)
    plt.imshow(pred1,cmap='plasma')
    plt.subplot(10,4,i*4+3)
    plt.imshow(pred2,cmap='plasma')
    plt.subplot(10,4,i*4+4)
    plt.imshow(pred3,cmap='plasma')

# %%
history = model.fit_generator(
    train_datagen.flow(images_train,labels_train,batch_size = 64),
    epochs = 12,
    validation_data=(images_valid,labels_valid)
)

# %%
model.save('../output/model/dogfacenet_v6_cosine.h5')
