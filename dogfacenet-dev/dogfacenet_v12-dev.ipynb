# %% [markdown]
# # DogFaceNet version 12: Dev version

# %% [markdown]
# ### Imports and constants

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

import os
import pickle
import numpy as np
import skimage as sk
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import tensorflow.keras.backend as K
from triplets_processing import *
import shutil
import gc
from math import isnan

# Display specific imports
from IPython.display import clear_output

# %%
#PATH = '../../../data/lfw_center/'
PATH = '../data/dogfacenet/aligned/after_4_bis/'
PATH_SAVE = '../output/history/'
PATH_MODEL = '../output/model/'
SIZE = (224,224,3)
VALID_SPLIT = 0.1
TEST_SPLIT = 0.1

# %% [markdown]
# ### Data pre-processing
# - Load image and labels
# - Training set, validation set (close-set) and testing (open-set)

# %%
# Resize all the images
filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
            sk.io.imsave(files[i],sk.transform.resize(sk.io.imread(files[i]),SIZE,anti_aliasing=True))

# %%
# Without imread

filenames = np.empty(0)
labels = np.empty(0)
idx = 0
for root,dirs,files in os.walk(PATH):
    if len(files)>1:
        for i in range(len(files)):
            files[i] = root + '/' + files[i]
        filenames = np.append(filenames,files)
        labels = np.append(labels,np.ones(len(files))*idx)
        idx += 1
    if len(files) == 1:
        #print(root)
        shutil.rmtree(root)
print(len(labels))
filenames
# Out:
# 8363
# array(['../data/dogfacenet/aligned/after_4_bis/0/0.0.jpg',
#        '../data/dogfacenet/aligned/after_4_bis/0/0.1.jpg',
#        '../data/dogfacenet/aligned/after_4_bis/0/0.2.jpg', ...,
#        '../data/dogfacenet/aligned/after_4_bis/999/999.3.jpg',
#        '../data/dogfacenet/aligned/after_4_bis/999/999.4.jpg',
#        '../data/dogfacenet/aligned/after_4_bis/999/999.5.jpg'],
#       dtype='<U54')

# %%
nbof_classes = len(np.unique(labels))
print(nbof_classes)
# Out:
# 1393

# %%
# Center all the faces
# for f in filenames:
#     img = sk.io.imread(f)
#     img_c = img[50:201,50:201,:]
#     sk.io.imsave(f,img_c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-99df7a8c960c> in <module>()
#       3     img = sk.io.imread(f)
#       4     img_c = img[50:201,50:201,:]
# ----> 5     sk.io.imsave(f,img_c)
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\io\_io.py in imsave(fname, arr, plugin, **plugin_args)
#     137         if fname.lower().endswith(('.tiff', '.tif')):
#     138             plugin = 'tifffile'
# --> 139     if is_low_contrast(arr):
#     140         warn('%s is a low contrast image' % fname)
#     141     if arr.dtype == bool:
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\exposure\exposure.py in is_low_contrast(image, fraction_threshold, lower_percentile, upper_percentile, method)
#     499     image = np.asanyarray(image)
#     500     if image.ndim == 3 and image.shape[2] in [3, 4]:
# --> 501         image = rgb2gray(image)
#     502
#     503     dlimits = dtype_limits(image, clip_negative=False)
#
# c:\users\guillaume\anaconda3\lib\site-packages\skimage\color\colorconv.py in rgb2gray(rgb)
#     804     rgb = _prepare_colorarray(rgb[..., :3])
#     805     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
# --> 806     return np.dot(rgb, coeffs)
#     807
#     808
#
# KeyboardInterrupt:

# %% [markdown]
# ### Data augmentation

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    zoom_range=0.1,
    fill_mode='nearest',
    channel_shift_range = 0.1
)

# %%
def apply_transform(images, datagen):
    """
    Apply a data preprocessing transformation to n images
    Args:
        -images
        -ImageDataGenerator
    Return:
        -images of the same shape of the inputs but transformed
    """
    for x in datagen.flow(images, batch_size=len(images), shuffle=False):
        return x

# %% [markdown]
# Open-set: test set

# %%
n = 3
cumul = np.empty(labels.shape)
cumul[0] = 1
crt_label = labels[0]
to_keep = []
for i in range(1,len(labels)):
    if labels[i] == labels[i-1]:
        cumul[i] = cumul[i-1] + 1
    else:
        cumul[i] = 1
        if cumul[i-1] >= n:
            to_keep += [labels[i-1]]
bool_keep = np.zeros(labels.shape, dtype=bool)
for i in range(len(to_keep)):
    bool_keep = np.logical_or(bool_keep,np.equal(to_keep[i],labels))
print("Ratio of kept classes: " + str(len(to_keep)/nbof_classes))
print("Ratio of kept images: " + str(len(labels[bool_keep])/len(labels)))
filenames_train = filenames[bool_keep]
labels_train = labels[bool_keep]

keep_test = np.logical_not(bool_keep)
filenames_test = filenames[keep_test]
labels_test = labels[keep_test]

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

filenames_test = filenames[keep_test]
labels_test = labels[keep_test]

filenames_train = filenames[keep_train]
labels_train = labels[keep_train]

print("Number of training data: " + str(len(filenames_train)))
print("Number of training classes: " + str(nbof_classes-nbof_test))
print("Number of testing data: " + str(len(filenames_test)))
print("Number of testing classes: " + str(nbof_test))
# Out:
# Number of training data: 7666
# Number of training classes: 1254
# Number of testing data: 697
# Number of testing classes: 139

# %%
nbof_test = int(TEST_SPLIT*nbof_classes)

keep_test = np.less(labels,nbof_test)
keep_train = np.logical_not(keep_test)

images_test = images[keep_test]
labels_test = labels[keep_test]

images_train = images[keep_train]
labels_train = labels[keep_train]

# %%
del images
del labels
gc.collect()

# %%
def define_triplets_batch(filenames,labels,nbof_triplet = 21 * 3):
    
    triplet_train = []
    y_triplet = np.empty(nbof_triplet)
    classes = np.unique(labels)
    for i in range(0,nbof_triplet,3):
        # Pick a class and chose two pictures from this class
        classAP = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classAP)
        keep_classAP = filenames[keep]
        keep_classAP_idx = labels[keep]
        idx_image1 = np.random.randint(len(keep_classAP))
        idx_image2 = np.random.randint(len(keep_classAP))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(keep_classAP))

        triplet_train += [keep_classAP[idx_image1]]
        triplet_train += [keep_classAP[idx_image2]]
        y_triplet[i] = keep_classAP_idx[idx_image1]
        y_triplet[i+1] = keep_classAP_idx[idx_image2]
        # Pick a class for the negative picture
        classN = classes[np.random.randint(len(classes))]
        while classN==classAP:
            classN = classes[np.random.randint(len(classes))]
        keep = np.equal(labels,classN)
        keep_classN = filenames[keep]
        keep_classN_idx = labels[keep]
        idx_image3 = np.random.randint(len(keep_classN))
        triplet_train += [keep_classN[idx_image3]]
        y_triplet[i+2] = keep_classN_idx[idx_image3]
        
    return triplet_train, y_triplet

# %%
def define_hard_triplets_batch(filenames,labels,predict,nbof_triplet=21*3, use_neg=True, use_pos=True):
    """
    Generates hard triplet for offline selection. It will consider the whole dataset.
    
    Args:
        -images: images from which the triplets will be created
        -labels: labels of the images
        -predict: predicted embeddings for the images by the trained model
        -alpha: threshold of the triplet loss
    Returns:
        -triplet
        -y_triplet: labels of the triplets
    """
    # Check if we have the right number of triplets
    assert nbof_triplet%3 == 0
    
    _,idx_classes = np.unique(labels,return_index=True)
    classes = labels[np.sort(idx_classes)]
    
    triplets = []
    y_triplets = np.empty(nbof_triplet)
    
    idx_triplets = 0
    idx_images = 0
    
    for i in range(0,nbof_triplet,3):
        # Chooses the first class randomly
        keep = np.equal(labels,classes[np.random.randint(len(classes))])
        keep_filenames = filenames[keep]
        keep_labels = labels[keep]
        
        # Chooses the first image among this class randomly
        idx_image1 = np.random.randint(len(keep_labels))
        
        
        # Computes the distance between the chosen image and the rest of the class
        if use_pos:
            dist_class = np.sum(np.square(predict[keep]-predict[keep][idx_image1]),axis=-1)

            idx_image2 = np.argmax(dist_class)
        else:
            idx_image2 = np.random.randint(len(keep_labels))
            i = 0
            while idx_image1==idx_image2:
                idx_image2 = np.random.randint(len(keep_labels))
                # Just to prevent endless loop:
                i += 1
                if i == 1000:
                    print("[Error: define_hard_triplets_batch] Endless loop.")
                    break
        
        triplets += [keep_filenames[idx_image1]]
        y_triplets[i] = keep_labels[idx_image1]
        triplets += [keep_filenames[idx_image2]]
        y_triplets[i+1] = keep_labels[idx_image2]
        
        
        # Computes the distance between the chosen image and the rest of the other classes
        not_keep = np.logical_not(keep)
        
        if use_neg:
            dist_other = np.sum(np.square(predict[not_keep]-predict[keep][idx_image1]),axis=-1)
            idx_image3 = np.argmin(dist_other) 
        else:
            idx_image3 = np.random.randint(len(filenames[not_keep]))
            
        triplets += [filenames[not_keep][idx_image3]]
        y_triplets[i+2] = labels[not_keep][idx_image3]

    #return triplets, y_triplets
    return np.array(triplets), y_triplets

# %%
def define_adaptive_hard_triplets_batch(filenames,labels,predict,nbof_triplet=21*3, use_neg=True, use_pos=True):
    """
    Generates hard triplet for offline selection. It will consider the whole dataset.
    
    Args:
        -images: images from which the triplets will be created
        -labels: labels of the images
        -predict: predicted embeddings for the images by the trained model
        -alpha: threshold of the triplet loss
    Returns:
        -triplet
        -y_triplet: labels of the triplets
    """
    # Check if we have the right number of triplets
    assert nbof_triplet%3 == 0
    
    _,idx_classes = np.unique(labels,return_index=True)
    classes = labels[np.sort(idx_classes)]
    
    triplets = []
    y_triplets = np.empty(nbof_triplet)
    pred_triplets = np.empty((nbof_triplet,predict.shape[-1]))
    
    idx_triplets = 0
    idx_images = 0
    
    for i in range(0,nbof_triplet,3):
        # Chooses the first class randomly
        keep = np.equal(labels,classes[np.random.randint(len(classes))])
        keep_filenames = filenames[keep]
        keep_labels = labels[keep]
        
        # Chooses the first image among this class randomly
        idx_image1 = np.random.randint(len(keep_labels))
        
        
        # Computes the distance between the chosen image and the rest of the class
        if use_pos:
            dist_class = np.sum(np.square(predict[keep]-predict[keep][idx_image1]),axis=-1)

            idx_image2 = np.argmax(dist_class)
        else:
            idx_image2 = np.random.randint(len(keep_labels))
            j = 0
            while idx_image1==idx_image2:
                idx_image2 = np.random.randint(len(keep_labels))
                # Just to prevent endless loop:
                j += 1
                if j == 1000:
                    print("[Error: define_hard_triplets_batch] Endless loop.")
                    break
        
        triplets += [keep_filenames[idx_image1]]
        y_triplets[i] = keep_labels[idx_image1]
        pred_triplets[i] = predict[keep][idx_image1]
        triplets += [keep_filenames[idx_image2]]
        y_triplets[i+1] = keep_labels[idx_image2]
        pred_triplets[i+1] = predict[keep][idx_image2]
        
        # Computes the distance between the chosen image and the rest of the other classes
        not_keep = np.logical_not(keep)
        
        if use_neg:
            dist_other = np.sum(np.square(predict[not_keep]-predict[keep][idx_image1]),axis=-1)
            idx_image3 = np.argmin(dist_other) 
        else:
            idx_image3 = np.random.randint(len(filenames[not_keep]))
            
        triplets += [filenames[not_keep][idx_image3]]
#         if i+2 >= nbof_triplet:
#             print("[Error] Triplet index problem.")
#         if idx_image3 >= len(labels[not_keep]):
#             print("[Error] Labels index problem.")
        y_triplets[i+2] = labels[not_keep][idx_image3]
        pred_triplets[i+2] = predict[not_keep][idx_image3]

    #return triplets, y_triplets
    return np.array(triplets), y_triplets, pred_triplets

# %%
def load_images(filenames):
    h,w,c = SIZE
    #print(filenames)
    images = np.empty((len(filenames),h,w,c))
    for i,f in enumerate(filenames):
        #print(f)
        images[i] = sk.io.imread(f)/255.0
    return images

# %%
def image_generator(filenames, labels, batch_size=63, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_triplets_batch(filenames, labels, batch_size)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def hard_image_generator(filenames, labels, predict, batch_size=63, use_neg=True, use_pos=True, use_aug=True, datagen=datagen):
    while True:
        f_triplet, y_triplet = define_hard_triplets_batch(filenames, labels, predict, batch_size, use_neg=use_neg, use_pos=use_pos)
        i_triplet = load_images(f_triplet)
#         for f in f_triplet:
#             print(f)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
def predict_generator(filenames, batch_size=32):
    for i in range(0,len(filenames),batch_size):
        images_batch = load_images(filenames[i:i+batch_size])
        yield images_batch

# %%
def online_hard_image_generator(
    filenames,
    labels,
    model,
    batch_size=63,
    nbof_subclasses=10,
    use_neg=True,
    use_pos=True,
    use_aug=True,
    datagen=datagen):
    """
    Generator to select online hard triplets for training.
    
    Arguments:
        -filenames
        -labels
    """
    while True:
        # Select a certain amount of subclasses
        classes = np.unique(labels)
        subclasses = np.random.choice(classes,size=nbof_subclasses,replace=False)
        
        keep_classes = np.equal(labels,subclasses[0])
        for i in range(1,len(subclasses)):
            keep_classes = np.logical_or(keep_classes,np.equal(labels,subclasses[i]))
        subfilenames = filenames[keep_classes]
        sublabels = labels[keep_classes]
        predict = model.predict_generator(predict_generator(subfilenames, 32),
                                          steps=np.ceil(len(subfilenames)/32))
        
        f_triplet, y_triplet = define_hard_triplets_batch(subfilenames, sublabels, predict, batch_size, use_neg=use_neg, use_pos=use_pos)
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
# "Offline" online adaptive hard triplet generator
# The current loss has to be given as input
def online_adaptive_hard_image_generator(
    filenames,
    labels,
    model,
    acc,
    use_aug=True,
    batch_size=63,
    nbof_subclasses=10,
    datagen=datagen):
    """
    Generator to select online hard triplets for training.
    
    Include an adaptive control on the number of hard triplets included during the training.
    
    Arguments:
        -filenames
        -labels
    """
    batch_loss = batch_size
    hard_triplet_ratio = 0
    nbof_hard_triplets = 0
    while True:
        # Select a certain amount of subclasses
        classes = np.unique(labels)
        subclasses = np.random.choice(classes,size=nbof_subclasses,replace=False)
        
        keep_classes = np.equal(labels,subclasses[0])
        for i in range(1,len(subclasses)):
            keep_classes = np.logical_or(keep_classes,np.equal(labels,subclasses[i]))
        subfilenames = filenames[keep_classes]
        sublabels = labels[keep_classes]
        predict = model.predict_generator(predict_generator(subfilenames, 32),
                                          steps=np.ceil(len(subfilenames)/32))
        
        
        
        
        
        f_triplet_hard, y_triplet_hard, predict_hard = define_adaptive_hard_triplets_batch(subfilenames, sublabels, predict, nbof_hard_triplets*3, use_neg=True, use_pos=True)
        f_triplet_soft, y_triplet_soft, predict_soft = define_adaptive_hard_triplets_batch(subfilenames, sublabels, predict, batch_size-nbof_hard_triplets*3, use_neg=False, use_pos=False)
#         print(f_triplet_soft)
#         print("shape hard: " + str(f_triplet_hard.shape))
#         print("shape soft: " + str(f_triplet_soft.shape))
        f_triplet = np.append(f_triplet_hard,f_triplet_soft)
        y_triplet = np.append(y_triplet_hard,y_triplet_soft)

        predict = np.append(predict_hard, predict_soft, axis=0)
        
        # Proportion of hard triplets in the generated batch
#         print(predict)
#         print(batch_loss)
#         hard_triplet_ratio = np.exp(-loss * 10 / batch_size)
#         print(hard_triplet_ratio)
#         print(" " + str(hard_triplet_ratio))
        #hard_triplet_ratio = max(0,np.exp(acc-0.3)-1)
        hard_triplet_ratio = max(0,1.2/(1+np.exp(-10*acc+5.3))-0.19)

        if isnan(hard_triplet_ratio):
            hard_triplet_ratio = 0
#        print(hard_triplet_ratio == np.nan)
        nbof_hard_triplets = int(batch_size//3 * hard_triplet_ratio)
#         print(nbof_hard_triplets)
        
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
            
        # Modif for michael loss
        dict_subclass = {subclasses[i]:i for i in range(nbof_subclasses)}
        ridx_y_triplet = [dict_subclass[y_triplet[i]] for i in range(len(y_triplet))]
        
        yield (i_triplet, ridx_y_triplet)

# %%
# Doesn't work yet...
# This version of adaptive online training is suppose to adapt automatically to the loss during the training
# No need then to wait for the end of an epoch to compute the number of generated hard triplets
def online_adaptive_hard_image_generator(
    filenames,
    labels,
    model,
    batch_size=63,
    nbof_subclasses=10,
    use_neg=True,
    use_pos=True,
    use_aug=True,
    datagen=datagen):
    """
    Generator to select online hard triplets for training.
    
    Include an adaptive control on the number of hard triplets included during the training.
    
    Arguments:
        -filenames
        -labels
    """
    batch_loss = batch_size
    hard_triplet_ratio = 0
    nbof_hard_triplets = 0
    while True:
        # Select a certain amount of subclasses
        classes = np.unique(labels)
        subclasses = np.random.choice(classes,size=nbof_subclasses,replace=False)
        
        keep_classes = np.equal(labels,subclasses[0])
        for i in range(1,len(subclasses)):
            keep_classes = np.logical_or(keep_classes,np.equal(labels,subclasses[i]))
        subfilenames = filenames[keep_classes]
        sublabels = labels[keep_classes]
        predict = model.predict_generator(predict_generator(subfilenames, 32),
                                          steps=np.ceil(len(subfilenames)/32))
        
        
        
        
        
        f_triplet_hard, y_triplet_hard, predict_hard = define_adaptive_hard_triplets_batch(subfilenames, sublabels, predict, nbof_hard_triplets*3, use_neg=True, use_pos=True)
        f_triplet_soft, y_triplet_soft, predict_soft = define_adaptive_hard_triplets_batch(subfilenames, sublabels, predict, batch_size-nbof_hard_triplets*3, use_neg=False, use_pos=False)
#         print(f_triplet_soft)
#         print("shape hard: " + str(f_triplet_hard.shape))
#         print("shape soft: " + str(f_triplet_soft.shape))
        f_triplet = np.append(f_triplet_hard,f_triplet_soft)
        y_triplet = np.append(y_triplet_hard,y_triplet_soft)

        predict = np.append(predict_hard, predict_soft, axis=0)
        
        # Proportion of hard triplets in the generated batch
        print(predict)
        batch_loss = triplet_numpy(y_triplet, predict)
#         print(batch_loss)
        hard_triplet_ratio = np.exp(-batch_loss * 10 / batch_size)
#         print(hard_triplet_ratio)
        print(" " + str(hard_triplet_ratio))
        if isnan(hard_triplet_ratio):
            hard_triplet_ratio = 0
#        print(hard_triplet_ratio == np.nan)
        nbof_hard_triplets = int(batch_size//3 * hard_triplet_ratio)
#         print(nbof_hard_triplets)
        
        i_triplet = load_images(f_triplet)
        if use_aug:
            i_triplet = apply_transform(i_triplet, datagen)
        yield (i_triplet, y_triplet)

# %%
# Test normal triplets
for a,y in image_generator(filenames_train,labels_train,9):
    for i in range(3):
        for j in range(3):
            plt.subplot(3,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    break

# %%
fs = filenames_train[np.equal(labels_train,745)]
print(fs)
ise = load_images(fs)
for i in range(len(ise)):
    plt.subplot(len(ise),5,i+1)
    plt.imshow(ise[i])

# %%
# Test hard triplets
batch_predict = 32

#predict_train = np.random.random((len(labels_train),1))
predict_train = model.predict_generator(predict_generator(filenames, batch_predict),
                                  steps=np.ceil(len(filenames)/batch_predict))
disp = 1000
#plt.figure(figsize=(7,disp*2.2))
for f,a,y in hard_image_generator(filenames,labels, predict_train, disp*3, use_aug=False):
    break
for i in range(disp):
    for j in range(3):
        print(f[i*3+j])
        #plt.subplot(disp,3,3*i+j+1)
        plt.subplot(1,3,j+1)
        plt.imshow(a[i*3+j])
        plt.xticks([])
        plt.yticks([])
        
    plt.show()

# %%
# Test online hard triplets

disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in online_hard_image_generator(filenames_train,labels_train, model, disp*3, use_neg=False):
    for i in range(disp):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    print(y)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-58eb1c03a093> in <module>()
#       3 disp = 10
#       4 plt.figure(figsize=(7,disp*2.2))
# ----> 5 for a,y in online_hard_image_generator(filenames_train,labels_train, model, disp*3, use_neg=False):
#       6     for i in range(disp):
#       7         for j in range(3):
#
# NameError: name 'online_hard_image_generator' is not defined

# %%
# Test adaptive online hard triplets

disp = 10
plt.figure(figsize=(7,disp*2.2))
for a,y in online_adaptive_hard_image_generator(filenames_train,labels_train, model, disp*3):
    for i in range(disp):
        for j in range(3):
            plt.subplot(10,3,3*i+j+1)
            plt.imshow(a[i*3+j])
    print(y)
    break
# Out:
# [2, 2, 6, 8, 8, 0, 3, 3, 6, 0, 0, 9, 0, 0, 5, 0, 0, 9, 3, 3, 4, 5, 5, 0, 3, 3, 2, 4, 4, 6, 5, 5, 1, 4, 4, 0, 3, 3, 5, 7, 7, 3, 9, 9, 3, 5, 5, 8, 3, 3, 8, 5, 5, 1, 2, 2, 0, 9, 9, 7, 7, 7, 6]

# %%
# Test predict_generator
batch_predict = 32
predict_train = model.predict_generator(predict_generator(filenames_train, batch_predict),
                                  steps=np.ceil(len(filenames_train)/batch_predict))
print(len(predict_train))

# %% [markdown]
# Triplet test definition

# %%
h,w,c = SIZE
images_test = np.empty((len(filenames_test),h,w,c))
for i,f in enumerate(filenames_test):
    images_test[i] = sk.io.imread(f)

# %%
#triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %% [markdown]
# ### Loss definition

# %%
alpha = 0.3
def triplet_numpy(y_true,y_pred):
    
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = np.sum(np.square(a-p),-1)
    an = np.sum(np.square(a-n),-1)

    return np.sum(np.maximum(ap - an + alpha,0))

# %%
# y_pred = tf.constant([[2,1,2],[4,8,1],[10,3,7]],dtype=tf.float32)
# y_true = tf.constant([1,2,4.])

for a,y_true in online_adaptive_hard_image_generator(filenames_train,labels_train, model, 30):
    y_pred = tf.constant(model.predict(a))
    break
print(y_true)

extract = tf.cast(y_true, dtype=tf.int32)
classes = tf.one_hot(extract,depth=nbof_subclasses)
print(classes)
classes = tf.cast(classes, dtype=tf.float32)

# Classe matrix
cla_mat = K.dot(classes, K.transpose(classes))

# Normalizes the predictions
#y_pred_norm = K.l2_normalize(y_pred, axis=1)

# Inner cosine matrix
cos_mat = K.dot(y_pred,K.transpose(y_pred))

# Changes the scale from [-1,1] to [1,0]
cos_mat = -0.5 * cos_mat + 0.5

# Extracts the cosines of the same classes
same = cos_mat * cla_mat
print(same)
print(K.sum(cla_mat))
same = same/K.sum(cla_mat)
ret1 = K.sum(same)

# Extracts the cosines of the different classes
diff = cos_mat * (1-cla_mat)
diff = tf.nn.relu(diff-alpha/2)
ret2 = K.sum(diff)


end = ret1 + ret2
with tf.Session() as sess:
    print(sess.run([classes,K.sum(cla_mat),end]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8bce84d16161> in <module>()
#       2 # y_true = tf.constant([1,2,4.])
#       3
# ----> 4 for a,y_true in online_adaptive_hard_image_generator(filenames_train,labels_train, model, 30):
#       5     y_pred = tf.constant(model.predict(a))
#       6     break
#
# NameError: name 'model' is not defined

# %%
alpha = 0.3
nbof_subclasses = 10
def michael(y_true,y_pred):
    
    # Retrieves the classes
    extract = tf.cast(y_true, dtype=tf.int32)
    classes = tf.one_hot(extract,depth=nbof_subclasses)
    classes = tf.cast(classes, dtype=tf.float32)
    
    # Classe matrix
    cla_mat = K.dot(classes, K.transpose(classes))
    
    # Normalizes the predictions
    #y_pred_norm = K.l2_normalize(y_pred, axis=1)
    
    # Inner cosine matrix
    cos_mat = K.dot(y_pred,K.transpose(y_pred))
    
    # Changes the scale from [-1,1] to [1,0]
    cos_mat = -0.5 * cos_mat + 0.5
    
    # Extracts the cosines of the same classes
    same = cos_mat * cla_mat
    same = same/K.sum(cla_mat)
    ret1 = K.sum(same)
    
    # Extracts the cosines of the different classes
    diff = cos_mat * (1-cla_mat)
    diff = tf.nn.relu(diff-alpha/2)
    ret2 = K.sum(diff)
    
    return ret1 + ret2

# %%
alpha = 0.3
def triplet(y_true,y_pred):
    
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)

    return K.sum(tf.nn.relu(ap - an + alpha))

# %% [markdown]
# ### Metric definition

# %%
def triplet_acc(y_true,y_pred):
    a = y_pred[0::3]
    p = y_pred[1::3]
    n = y_pred[2::3]
    
    ap = K.sum(K.square(a-p),-1)
    an = K.sum(K.square(a-n),-1)
    
    return K.less(ap+alpha,an)

# %% [markdown]
# ### Model definition

# %%
emb_size = 64
from tensorflow.keras.layers import Dropout, Flatten, Dense, Lambda

base = tf.keras.applications.mobilenet_v2.MobileNetV2(input_shape=(224,224,3),include_top=False, weights=None, pooling='avg')

x = Flatten()(base.output)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(base.input,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1280)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1280)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           81920       dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 2,339,904
# Trainable params: 2,305,792
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# inception net small

emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v25: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), strides=(2,2), use_bias=False, padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3,3),strides=(2,2))(x)

for layer in [16,32,64,128,256]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, padding='same')(x)
    r = BatchNormalization()(x)
    r = Activation('relu')(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    r = Add()([r,x])
    
    x = Conv2D(layer, (3, 3), use_bias=False, padding='same')(r)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Add()([r,x])

    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.6)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 16) 2352        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 55, 55, 16)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 16)   2304        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 16)   2304        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 16)   0           activation_1[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 16)   2304        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 16)   0           add[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 32)   4608        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 32)   9216        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 32)   0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 14, 14, 32)   9216        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 32)   0           add_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 64)     18432       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 64)     256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 64)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 64)     36864       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 64)     256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 64)     0           activation_7[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 64)     36864       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 64)     256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 64)     0           add_4[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 128)    73728       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 128)    147456      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 128)    0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 128)    147456      add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 128)    0           add_6[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 2, 2, 256)    294912      add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2, 2, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2, 2, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 2, 2, 256)    589824      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 256)    0           activation_13[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 256)    589824      add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 2, 2, 256)    0           add_8[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           add_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           16384       dropout[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64)           0           dense[0][0]
# ==================================================================================================
# Total params: 1,990,064
# Trainable params: 1,987,056
# Non-trainable params: 3,008
# __________________________________________________________________________________________________
# None

# %%
# dogfacenet_v11: VGG like
emb_size = 16

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(104, 104, 3)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(1024, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(emb_size))
model.add(Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1)))

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v26: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), (2, 2), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPooling2D((3,3))(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
#     x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=michael,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 112, 112, 16) 2352        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 112, 112, 16) 64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 37, 37, 16)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 19, 19, 16)   2304        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 19, 19, 16)   64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 19, 19, 16)   2304        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 19, 19, 16)   64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 19, 19, 16)   0           batch_normalization_33[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 19, 19, 16)   2304        add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 19, 19, 16)   64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 19, 19, 16)   0           add_20[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 10, 32)   4608        add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 10, 10, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 10, 10, 32)   9216        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 10, 10, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 10, 10, 32)   0           batch_normalization_36[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 10, 10, 32)   9216        add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 10, 10, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 10, 10, 32)   0           add_22[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 5, 5, 64)     18432       add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 5, 5, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 5, 5, 64)     36864       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 5, 5, 64)     256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 5, 5, 64)     0           batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 5, 5, 64)     36864       add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 5, 5, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 5, 5, 64)     0           add_24[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 3, 3, 128)    73728       add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 3, 3, 128)    512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 3, 3, 128)    147456      batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 3, 3, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 3, 3, 128)    0           batch_normalization_42[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 3, 3, 128)    147456      add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 3, 3, 128)    512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 3, 3, 128)    0           add_26[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 2, 2, 512)    589824      add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 512)    2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 2, 2, 512)    2359296     batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 2, 2, 512)    0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 2, 2, 512)    2359296     add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 512)    2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 2, 2, 512)    0           add_28[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           add_29[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           32768       dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 5,843,376
# Trainable params: 5,838,832
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
# dogfacenet_v12: Resnet like
emb_size = 64

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=SIZE)

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [16,32,64,128,512]:

    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
#     r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
#     x = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 16) 2352        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 224, 224, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 112, 112, 16) 2304        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 112, 112, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 16) 2304        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 112, 112, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 112, 112, 16) 0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 16) 2304        add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 16) 64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 112, 112, 16) 0           add_10[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 32)   4608        add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 56, 56, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 32)   9216        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 56, 32)   128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 56, 56, 32)   0           batch_normalization_20[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 32)   9216        add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 56, 56, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 56, 56, 32)   0           add_12[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 64)   18432       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 64)   36864       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 28, 28, 64)   0           batch_normalization_23[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 64)   36864       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 28, 28, 64)   0           add_14[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  73728       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 128)  147456      batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 14, 14, 128)  0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  147456      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 14, 14, 128)  0           add_16[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 7, 7, 512)    589824      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 7, 7, 512)    2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 7, 7, 512)    2359296     batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 7, 7, 512)    2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 7, 7, 512)    0           batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 7, 7, 512)    2359296     add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 7, 7, 512)    2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 7, 7, 512)    0           add_18[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           add_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32768       dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 5,843,376
# Trainable params: 5,838,832
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.04.17.dogfacenet_v12.lfw.56.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
start = 42
model = tf.keras.models.load_model(PATH_MODEL + '2019.05.05.dogfacenet_v25.'+str(start)+'.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
histories = []

# %%
histories += [model.fit_generator(
    online_adaptive_hard_image_generator(filenames_train,labels_train,model,3*10),
    steps_per_epoch=300,
    epochs=1,
    validation_data=image_generator(filenames_test,labels_test,3*10,False),
    validation_steps=30
)]
# Out:
# Epoch 1/1
# [[ 1.15224436e-001 -1.20082699e-001  1.03202216e-001 ...  3.10387462e-002
#   -8.28063115e-002  1.45604357e-001]
#  [ 9.89971757e-002 -1.33442089e-001  1.17066681e-001 ...  2.97916327e-002
#   -7.72831813e-002  1.39511123e-001]
#  [ 1.10529706e-001 -1.05496377e-001  1.26342610e-001 ...  4.69883531e-002
#   -9.95505005e-002  1.61066934e-001]
#  ...
#  [ 6.05505415e-312  6.05505415e-312  6.05505415e-312 ...  6.05505415e-312
#    6.05505417e-312  6.05505417e-312]
#  [ 6.05505504e-312  6.05505504e-312  6.05505415e-312 ...  6.05505415e-312
#    6.05505500e-312  6.05505500e-312]
#  [ 6.05505501e-312  6.05505420e-312  6.05505415e-312 ...  6.05505421e-312
#    6.05505531e-312  6.05505420e-312]]
# c:\users\guillaume\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in square
#
# c:\users\guillaume\anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in square
#   if __name__ == '__main__':
# c:\users\guillaume\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in subtract
#   # This is added back by InteractiveShellApp.init_path()
# c:\users\guillaume\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in maximum
#   # This is added back by InteractiveShellApp.init_path()
#  nan
#   1/300 [..............................] - ETA: 7:01 - loss: 2.9182 - triplet_acc: 0.0000e+00[[ 9.76366624e-002 -1.24765687e-001  1.27820015e-001 ...  3.81399579e-002
#   -7.95533732e-002  1.38650253e-001]
#  [ 1.08099453e-001 -1.22674115e-001  1.08287379e-001 ...  4.70800176e-002
#   -9.18543637e-002  1.49052337e-001]
#  [ 9.86089632e-002 -1.05511382e-001  1.21744357e-001 ...  6.92674443e-002
#   -1.17216125e-001  1.66022167e-001]
#  ...
#  [ 6.05505415e-312  6.05505415e-312  6.05505415e-312 ...  6.05505415e-312
#    6.05505417e-312  6.05505417e-312]
#  [ 6.05505504e-312  6.05505504e-312  6.05505415e-312 ...  6.05505415e-312
#    6.05505500e-312  6.05505500e-312]
#  [ 6.05505501e-312  6.05505420e-312  6.05505415e-312 ...  6.05505421e-312
#    6.05505531e-312  6.05505420e-312]]
#  nan
#   2/300 [..............................] - ETA: 5:33 - loss: 2.6196 - triplet_acc: 0.0000e+00[[ 1.25497892e-001 -1.08412914e-001  1.23418190e-001 ...  2.24127509e-002
#   -7.13385865e-002  1.62117288e-001]
#  [ 1.23246297e-001 -1.09972477e-001  1.23187348e-001 ...  2.55861282e-002
#   -7.42435232e-002  1.58133805e-001]
#  [ 8.95818323e-002 -1.19586602e-001  1.22749902e-001 ...  4.32067662e-002
#   -8.35288987e-002  1.38679489e-001]
#  ...
#  [ 0.00000000e+000  6.04493573e-312  6.04982219e-312 ...  6.04493573e-312
#    6.04982220e-312  6.05177949e-312]
#  [ 0.00000000e+000  6.04493573e-312  6.04982221e-312 ...  6.04493573e-312
#    6.04982187e-312  6.05177949e-312]
#  [ 0.00000000e+000  6.04493573e-312  6.04982187e-312 ...  1.08646324e-311
#    6.04982693e-312  6.05177949e-312]]
#  0.37070039583314124
#   3/300 [..............................] - ETA: 5:22 - loss: 2.7069 - triplet_acc: 0.0000e+00[[ 1.14973754e-001 -9.92988124e-002  1.19138017e-001 ...  4.30505797e-002
#   -1.04358502e-001  1.68033272e-001]
#  [ 1.27844736e-001 -8.69217739e-002  1.32413328e-001 ...  3.43617722e-002
#   -9.43560153e-002  1.77981451e-001]
#  [ 1.16451785e-001 -1.06254905e-001  1.27894312e-001 ...  3.92969586e-002
#   -9.14442390e-002  1.63287625e-001]
#  ...
#  [ 2.46151512e-312  9.97338022e-313  2.35541533e-312 ...  2.05833592e-312
#    2.46151512e-312  2.41907520e-312]
#  [ 1.10343781e-312  1.14587773e-312  9.97338022e-313 ...  2.46151512e-312
#    9.97338022e-313  2.35541533e-312]
#  [ 2.16443571e-312  2.10077583e-312  2.33419537e-312 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]]
#  0.36961073779785625
#   4/300 [..............................] - ETA: 5:06 - loss: 2.7413 - triplet_acc: 0.0000e+00[[ 1.09660782e-01 -1.19867928e-01  1.15096405e-01 ...  3.94740924e-02
#   -8.37763920e-02  1.47188365e-01]
#  [ 1.22569069e-01 -9.83910859e-02  1.27216116e-01 ...  2.80104000e-02
#   -8.43611881e-02  1.59491837e-01]
#  [ 1.10834554e-01 -1.13279358e-01  1.11939535e-01 ...  3.98721769e-02
#   -9.08896625e-02  1.50514439e-01]
#  ...
#  [ 8.13364375e-08  6.92208509e-09  5.08389512e-14 ... -5.75979276e-12
#   -6.64913366e-09 -1.76962249e-10]
#  [ 1.14055282e-07  2.12428607e-09  2.43645883e-17 ... -6.36547891e-11
#   -9.49174068e-09 -1.69235631e-11]
#  [ 6.56050213e-08  4.88872850e-09  2.21198147e-14 ... -4.56897622e-12
#   -1.15041398e-08 -6.59969434e-11]]
#  0.4020206410670821
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-23b5884dd5ba> in <module>()
#       4     epochs=1,
#       5     validation_data=image_generator(filenames_test,labels_test,3*10,False),
# ----> 6     validation_steps=30
#       7 )]
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     145       batch_index = 0
#     146       while steps_done < steps_per_epoch:
# --> 147         generator_output = next(output_generator)
#     148
#     149         if not hasattr(generator_output, '__len__'):
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     823           raise StopIteration()
#     824         else:
# --> 825           time.sleep(self.wait_time)
#     826
#     827     # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %%
# With online hard triplet generation
crt_loss = 0.6
batch_size = 3*10
start = 0
for i in range(1000):
    print("Beginning epoch number: "+str(i))

    hard_triplet_ratio = np.exp(-crt_loss * 10 / batch_size)
    nbof_hard_triplets = int(batch_size//3 * hard_triplet_ratio)
    
    print("Current hard triplet ratio: " + str(hard_triplet_ratio))
    
    histories += [model.fit_generator(
        online_adaptive_hard_image_generator(filenames_train,labels_train,model,crt_loss,batch_size),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,batch_size,use_aug=False),
        validation_steps=30
#         verbose=0,
#         callbacks=[TQDMNotebookCallback()]
    )]
    
    crt_loss = histories[-1].history['loss'][0]
    
    model.save(PATH_MODEL + '2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5')
    
    loss = np.empty(0)
    val_loss = np.empty(0)
    acc = np.empty(0)
    val_acc = np.empty(0)

    for history in histories:
        loss = np.append(loss,history.history['loss'])
        val_loss = np.append(val_loss,history.history['val_loss'])
        acc = np.append(acc,history.history['triplet_acc'])
        val_acc = np.append(val_acc,history.history['val_triplet_acc'])


    history_ = np.array([loss,val_loss,acc,val_acc])
    np.save(PATH_SAVE+'2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5',history_)
    np.savetxt(PATH_SAVE+'2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5',history_)
# Out:
# Beginning epoch number: 0
# Current hard triplet ratio: 0.8187307530779818
# Epoch 1/1
# 169/300 [===============>..............] - ETA: 4:06 - loss: 0.0875 - triplet_acc: 0.900 - ETA: 3:58 - loss: 0.0840 - triplet_acc: 0.900 - ETA: 3:51 - loss: 0.5237 - triplet_acc: 0.800 - ETA: 3:48 - loss: 0.3928 - triplet_acc: 0.850 - ETA: 3:45 - loss: 0.6257 - triplet_acc: 0.800 - ETA: 3:45 - loss: 0.6105 - triplet_acc: 0.766 - ETA: 3:42 - loss: 0.8401 - triplet_acc: 0.728 - ETA: 3:39 - loss: 0.8418 - triplet_acc: 0.712 - ETA: 3:38 - loss: 0.8350 - triplet_acc: 0.711 - ETA: 3:37 - loss: 0.8436 - triplet_acc: 0.710 - ETA: 3:36 - loss: 0.7818 - triplet_acc: 0.727 - ETA: 3:35 - loss: 0.8534 - triplet_acc: 0.725 - ETA: 3:33 - loss: 0.8575 - triplet_acc: 0.723 - ETA: 3:30 - loss: 0.9709 - triplet_acc: 0.714 - ETA: 3:30 - loss: 0.9061 - triplet_acc: 0.733 - ETA: 3:28 - loss: 0.8745 - triplet_acc: 0.737 - ETA: 3:26 - loss: 0.8438 - triplet_acc: 0.735 - ETA: 3:25 - loss: 0.9251 - triplet_acc: 0.722 - ETA: 3:24 - loss: 0.8824 - triplet_acc: 0.731 - ETA: 3:23 - loss: 0.8644 - triplet_acc: 0.730 - ETA: 3:22 - loss: 0.9023 - triplet_acc: 0.733 - ETA: 3:22 - loss: 0.8793 - triplet_acc: 0.731 - ETA: 3:22 - loss: 0.8451 - triplet_acc: 0.739 - ETA: 3:21 - loss: 0.8788 - triplet_acc: 0.729 - ETA: 3:20 - loss: 0.8657 - triplet_acc: 0.736 - ETA: 3:19 - loss: 0.8376 - triplet_acc: 0.738 - ETA: 3:18 - loss: 0.8091 - triplet_acc: 0.740 - ETA: 3:17 - loss: 0.7828 - triplet_acc: 0.746 - ETA: 3:18 - loss: 0.9261 - triplet_acc: 0.737 - ETA: 3:16 - loss: 0.9314 - triplet_acc: 0.736 - ETA: 3:16 - loss: 0.9416 - triplet_acc: 0.732 - ETA: 3:14 - loss: 0.9492 - triplet_acc: 0.731 - ETA: 3:13 - loss: 0.9251 - triplet_acc: 0.736 - ETA: 3:13 - loss: 0.9310 - triplet_acc: 0.735 - ETA: 3:12 - loss: 0.9261 - triplet_acc: 0.734 - ETA: 3:12 - loss: 0.9003 - triplet_acc: 0.741 - ETA: 3:11 - loss: 0.8990 - triplet_acc: 0.740 - ETA: 3:10 - loss: 0.8933 - triplet_acc: 0.739 - ETA: 3:10 - loss: 0.8955 - triplet_acc: 0.738 - ETA: 3:09 - loss: 0.8914 - triplet_acc: 0.737 - ETA: 3:08 - loss: 0.9095 - triplet_acc: 0.729 - ETA: 3:07 - loss: 0.9148 - triplet_acc: 0.726 - ETA: 3:07 - loss: 0.9270 - triplet_acc: 0.723 - ETA: 3:06 - loss: 0.9171 - triplet_acc: 0.722 - ETA: 3:06 - loss: 0.9134 - triplet_acc: 0.724 - ETA: 3:05 - loss: 0.8941 - triplet_acc: 0.728 - ETA: 3:04 - loss: 0.8753 - triplet_acc: 0.729 - ETA: 3:03 - loss: 0.8596 - triplet_acc: 0.733 - ETA: 3:02 - loss: 0.8707 - triplet_acc: 0.730 - ETA: 3:02 - loss: 0.8539 - triplet_acc: 0.734 - ETA: 3:01 - loss: 0.8592 - triplet_acc: 0.735 - ETA: 3:00 - loss: 0.8586 - triplet_acc: 0.734 - ETA: 3:00 - loss: 0.8480 - triplet_acc: 0.735 - ETA: 3:01 - loss: 0.8486 - triplet_acc: 0.733 - ETA: 3:00 - loss: 0.8401 - triplet_acc: 0.734 - ETA: 2:59 - loss: 0.8419 - triplet_acc: 0.732 - ETA: 2:58 - loss: 0.8352 - triplet_acc: 0.728 - ETA: 2:57 - loss: 0.8303 - triplet_acc: 0.731 - ETA: 2:56 - loss: 0.8469 - triplet_acc: 0.730 - ETA: 2:56 - loss: 0.8384 - triplet_acc: 0.731 - ETA: 2:55 - loss: 0.8437 - triplet_acc: 0.727 - ETA: 2:54 - loss: 0.8368 - triplet_acc: 0.727 - ETA: 2:53 - loss: 0.8360 - triplet_acc: 0.728 - ETA: 2:52 - loss: 0.8289 - triplet_acc: 0.729 - ETA: 2:51 - loss: 0.8199 - triplet_acc: 0.730 - ETA: 2:51 - loss: 0.8222 - triplet_acc: 0.727 - ETA: 2:50 - loss: 0.8295 - triplet_acc: 0.725 - ETA: 2:49 - loss: 0.8446 - triplet_acc: 0.725 - ETA: 2:48 - loss: 0.8386 - triplet_acc: 0.726 - ETA: 2:48 - loss: 0.8312 - triplet_acc: 0.725 - ETA: 2:47 - loss: 0.8604 - triplet_acc: 0.723 - ETA: 2:46 - loss: 0.8499 - triplet_acc: 0.726 - ETA: 2:45 - loss: 0.8463 - triplet_acc: 0.726 - ETA: 2:44 - loss: 0.8425 - triplet_acc: 0.725 - ETA: 2:43 - loss: 0.8383 - triplet_acc: 0.726 - ETA: 2:43 - loss: 0.8293 - triplet_acc: 0.728 - ETA: 2:42 - loss: 0.8539 - triplet_acc: 0.726 - ETA: 2:41 - loss: 0.8494 - triplet_acc: 0.728 - ETA: 2:40 - loss: 0.8407 - triplet_acc: 0.730 - ETA: 2:39 - loss: 0.8315 - triplet_acc: 0.732 - ETA: 2:39 - loss: 0.8240 - triplet_acc: 0.734 - ETA: 2:38 - loss: 0.8139 - triplet_acc: 0.737 - ETA: 2:37 - loss: 0.8 ...
# Beginning epoch number: 1
# Current hard triplet ratio: 0.7570666411906708
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:49 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:53 - loss: 0.8675 - triplet_acc: 0.8500    - ETA: 3:41 - loss: 0.5783 - triplet_acc: 0.900 - ETA: 3:34 - loss: 0.6959 - triplet_acc: 0.850 - ETA: 3:30 - loss: 0.6188 - triplet_acc: 0.840 - ETA: 3:25 - loss: 0.7420 - triplet_acc: 0.783 - ETA: 3:24 - loss: 0.6656 - triplet_acc: 0.785 - ETA: 3:23 - loss: 0.6758 - triplet_acc: 0.787 - ETA: 3:22 - loss: 0.6960 - triplet_acc: 0.777 - ETA: 3:21 - loss: 0.6588 - triplet_acc: 0.780 - ETA: 3:21 - loss: 0.6807 - triplet_acc: 0.754 - ETA: 3:20 - loss: 0.7176 - triplet_acc: 0.758 - ETA: 3:18 - loss: 0.7294 - triplet_acc: 0.746 - ETA: 3:17 - loss: 0.7263 - triplet_acc: 0.750 - ETA: 3:16 - loss: 0.7521 - triplet_acc: 0.740 - ETA: 3:15 - loss: 0.7051 - triplet_acc: 0.756 - ETA: 3:14 - loss: 0.6879 - triplet_acc: 0.752 - ETA: 3:13 - loss: 0.7374 - triplet_acc: 0.738 - ETA: 3:12 - loss: 0.7123 - triplet_acc: 0.742 - ETA: 3:12 - loss: 0.6767 - triplet_acc: 0.755 - ETA: 3:11 - loss: 0.7378 - triplet_acc: 0.742 - ETA: 3:10 - loss: 0.7432 - triplet_acc: 0.745 - ETA: 3:09 - loss: 0.7326 - triplet_acc: 0.747 - ETA: 3:08 - loss: 0.7146 - triplet_acc: 0.750 - ETA: 3:08 - loss: 0.7131 - triplet_acc: 0.752 - ETA: 3:07 - loss: 0.7047 - triplet_acc: 0.753 - ETA: 3:06 - loss: 0.6898 - triplet_acc: 0.755 - ETA: 3:05 - loss: 0.6822 - triplet_acc: 0.757 - ETA: 3:04 - loss: 0.7043 - triplet_acc: 0.751 - ETA: 3:04 - loss: 0.6821 - triplet_acc: 0.753 - ETA: 3:02 - loss: 0.6823 - triplet_acc: 0.754 - ETA: 3:02 - loss: 0.6686 - triplet_acc: 0.756 - ETA: 3:01 - loss: 0.6786 - triplet_acc: 0.754 - ETA: 3:00 - loss: 0.6763 - triplet_acc: 0.750 - ETA: 2:59 - loss: 0.7201 - triplet_acc: 0.740 - ETA: 2:58 - loss: 0.7509 - triplet_acc: 0.738 - ETA: 2:57 - loss: 0.7335 - triplet_acc: 0.740 - ETA: 2:57 - loss: 0.7297 - triplet_acc: 0.739 - ETA: 2:56 - loss: 0.7302 - triplet_acc: 0.738 - ETA: 2:55 - loss: 0.7327 - triplet_acc: 0.742 - ETA: 2:56 - loss: 0.7179 - triplet_acc: 0.743 - ETA: 2:55 - loss: 0.7044 - triplet_acc: 0.747 - ETA: 2:54 - loss: 0.6945 - triplet_acc: 0.748 - ETA: 2:53 - loss: 0.6891 - triplet_acc: 0.750 - ETA: 2:53 - loss: 0.6827 - triplet_acc: 0.753 - ETA: 2:52 - loss: 0.6896 - triplet_acc: 0.752 - ETA: 2:51 - loss: 0.6756 - triplet_acc: 0.755 - ETA: 2:50 - loss: 0.6767 - triplet_acc: 0.752 - ETA: 2:50 - loss: 0.6629 - triplet_acc: 0.757 - ETA: 2:49 - loss: 0.6754 - triplet_acc: 0.756 - ETA: 2:48 - loss: 0.6754 - triplet_acc: 0.756 - ETA: 2:47 - loss: 0.6868 - triplet_acc: 0.751 - ETA: 2:46 - loss: 0.6857 - triplet_acc: 0.750 - ETA: 2:45 - loss: 0.6959 - triplet_acc: 0.750 - ETA: 2:45 - loss: 0.6948 - triplet_acc: 0.752 - ETA: 2:44 - loss: 0.6890 - triplet_acc: 0.751 - ETA: 2:43 - loss: 0.6867 - triplet_acc: 0.750 - ETA: 2:42 - loss: 0.6866 - triplet_acc: 0.751 - ETA: 2:42 - loss: 0.6946 - triplet_acc: 0.750 - ETA: 2:41 - loss: 0.6914 - triplet_acc: 0.753 - ETA: 2:40 - loss: 0.7071 - triplet_acc: 0.747 - ETA: 2:40 - loss: 0.6961 - triplet_acc: 0.750 - ETA: 2:39 - loss: 0.7008 - triplet_acc: 0.749 - ETA: 2:39 - loss: 0.7092 - triplet_acc: 0.746 - ETA: 2:38 - loss: 0.7025 - triplet_acc: 0.747 - ETA: 2:37 - loss: 0.6968 - triplet_acc: 0.750 - ETA: 2:36 - loss: 0.6890 - triplet_acc: 0.752 - ETA: 2:36 - loss: 0.6859 - triplet_acc: 0.752 - ETA: 2:35 - loss: 0.6858 - triplet_acc: 0.753 - ETA: 2:34 - loss: 0.6915 - triplet_acc: 0.754 - ETA: 2:33 - loss: 0.7087 - triplet_acc: 0.753 - ETA: 2:33 - loss: 0.7298 - triplet_acc: 0.751 - ETA: 2:32 - loss: 0.7409 - triplet_acc: 0.746 - ETA: 2:31 - loss: 0.7409 - triplet_acc: 0.745 - ETA: 2:31 - loss: 0.7406 - triplet_acc: 0.746 - ETA: 2:30 - loss: 0.7423 - triplet_acc: 0.746 - ETA: 2:29 - loss: 0.7470 - triplet_acc: 0.744 - ETA: 2:29 - loss: 0.7481 - triplet_acc: 0.744 - ETA: 2:28 - loss: 0.7484 - triplet_acc: 0.741 - ETA: 2:28 - loss: 0.7391 - triplet_acc: 0.745 - ETA: 2:27 - loss: 0.7589 - triplet_acc: 0.740 - ETA: 2:26 - loss: 0.7609 - triplet_acc: 0.741 - ETA: 2:26 - l ...
# 300/300 [==============================] - ETA: 1:27 - loss: 0.6841 - triplet_acc: 0.747 - ETA: 1:26 - loss: 0.6829 - triplet_acc: 0.747 - ETA: 1:26 - loss: 0.6812 - triplet_acc: 0.747 - ETA: 1:25 - loss: 0.6855 - triplet_acc: 0.746 - ETA: 1:24 - loss: 0.6850 - triplet_acc: 0.746 - ETA: 1:24 - loss: 0.6882 - triplet_acc: 0.746 - ETA: 1:23 - loss: 0.6887 - triplet_acc: 0.745 - ETA: 1:22 - loss: 0.6849 - triplet_acc: 0.746 - ETA: 1:21 - loss: 0.6871 - triplet_acc: 0.745 - ETA: 1:21 - loss: 0.6866 - triplet_acc: 0.746 - ETA: 1:20 - loss: 0.6915 - triplet_acc: 0.744 - ETA: 1:19 - loss: 0.6924 - triplet_acc: 0.742 - ETA: 1:19 - loss: 0.7085 - triplet_acc: 0.741 - ETA: 1:18 - loss: 0.7047 - triplet_acc: 0.742 - ETA: 1:17 - loss: 0.7011 - triplet_acc: 0.743 - ETA: 1:17 - loss: 0.6990 - triplet_acc: 0.743 - ETA: 1:16 - loss: 0.6965 - triplet_acc: 0.743 - ETA: 1:15 - loss: 0.6951 - triplet_acc: 0.743 - ETA: 1:15 - loss: 0.6914 - triplet_acc: 0.744 - ETA: 1:14 - loss: 0.6924 - triplet_acc: 0.744 - ETA: 1:13 - loss: 0.6972 - triplet_acc: 0.744 - ETA: 1:12 - loss: 0.7010 - triplet_acc: 0.743 - ETA: 1:12 - loss: 0.7025 - triplet_acc: 0.744 - ETA: 1:11 - loss: 0.7029 - triplet_acc: 0.743 - ETA: 1:10 - loss: 0.7035 - triplet_acc: 0.743 - ETA: 1:10 - loss: 0.7014 - triplet_acc: 0.743 - ETA: 1:09 - loss: 0.6999 - triplet_acc: 0.743 - ETA: 1:08 - loss: 0.6978 - triplet_acc: 0.743 - ETA: 1:08 - loss: 0.6943 - triplet_acc: 0.745 - ETA: 1:07 - loss: 0.6966 - triplet_acc: 0.744 - ETA: 1:06 - loss: 0.6979 - triplet_acc: 0.744 - ETA: 1:06 - loss: 0.6949 - triplet_acc: 0.745 - ETA: 1:05 - loss: 0.6943 - triplet_acc: 0.745 - ETA: 1:04 - loss: 0.6909 - triplet_acc: 0.747 - ETA: 1:04 - loss: 0.6895 - triplet_acc: 0.747 - ETA: 1:03 - loss: 0.6879 - triplet_acc: 0.747 - ETA: 1:02 - loss: 0.6849 - triplet_acc: 0.747 - ETA: 1:02 - loss: 0.6853 - triplet_acc: 0.747 - ETA: 1:01 - loss: 0.6887 - triplet_acc: 0.747 - ETA: 1:00 - loss: 0.6861 - triplet_acc: 0.747 - ETA: 1:00 - loss: 0.6828 - triplet_acc: 0.748 - ETA: 59s - loss: 0.6830 - triplet_acc: 0.748 - ETA: 58s - loss: 0.6928 - triplet_acc: 0.74 - ETA: 58s - loss: 0.6919 - triplet_acc: 0.74 - ETA: 57s - loss: 0.6992 - triplet_acc: 0.74 - ETA: 56s - loss: 0.6988 - triplet_acc: 0.74 - ETA: 55s - loss: 0.6957 - triplet_acc: 0.74 - ETA: 55s - loss: 0.6970 - triplet_acc: 0.74 - ETA: 54s - loss: 0.6981 - triplet_acc: 0.74 - ETA: 53s - loss: 0.6972 - triplet_acc: 0.74 - ETA: 53s - loss: 0.6956 - triplet_acc: 0.74 - ETA: 52s - loss: 0.6988 - triplet_acc: 0.74 - ETA: 51s - loss: 0.6992 - triplet_acc: 0.74 - ETA: 51s - loss: 0.7005 - triplet_acc: 0.74 - ETA: 50s - loss: 0.6988 - triplet_acc: 0.74 - ETA: 49s - loss: 0.6997 - triplet_acc: 0.74 - ETA: 49s - loss: 0.6988 - triplet_acc: 0.74 - ETA: 48s - loss: 0.6957 - triplet_acc: 0.74 - ETA: 47s - loss: 0.6961 - triplet_acc: 0.74 - ETA: 47s - loss: 0.6948 - triplet_acc: 0.74 - ETA: 46s - loss: 0.6994 - triplet_acc: 0.74 - ETA: 45s - loss: 0.6976 - triplet_acc: 0.74 - ETA: 45s - loss: 0.6946 - triplet_acc: 0.74 - ETA: 44s - loss: 0.6977 - triplet_acc: 0.74 - ETA: 43s - loss: 0.7040 - triplet_acc: 0.74 - ETA: 43s - loss: 0.7070 - triplet_acc: 0.74 - ETA: 42s - loss: 0.7073 - triplet_acc: 0.74 - ETA: 41s - loss: 0.7085 - triplet_acc: 0.74 - ETA: 41s - loss: 0.7095 - triplet_acc: 0.74 - ETA: 40s - loss: 0.7091 - triplet_acc: 0.74 - ETA: 39s - loss: 0.7072 - triplet_acc: 0.74 - ETA: 39s - loss: 0.7081 - triplet_acc: 0.74 - ETA: 38s - loss: 0.7079 - triplet_acc: 0.74 - ETA: 37s - loss: 0.7069 - triplet_acc: 0.74 - ETA: 37s - loss: 0.7040 - triplet_acc: 0.74 - ETA: 36s - loss: 0.7057 - triplet_acc: 0.74 - ETA: 35s - loss: 0.7065 - triplet_acc: 0.74 - ETA: 35s - loss: 0.7163 - triplet_acc: 0.74 - ETA: 34s - loss: 0.7135 - triplet_acc: 0.74 - ETA: 33s - loss: 0.7116 - triplet_acc: 0.74 - ETA: 33s - loss: 0.7148 - triplet_acc: 0.74 - ETA: 32s - loss: 0.7149 - triplet_acc: 0.74 - ETA: 31s - loss: 0.7121 - triplet_acc: 0.74 - ETA: 31s - loss: 0.7103 - triplet_acc: 0.74 - ETA: 30s - ...
# Beginning epoch number: 2
# Current hard triplet ratio: 0.7895893088573581
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:39 - loss: 0.0476 - triplet_acc: 0.800 - ETA: 3:40 - loss: 1.2214 - triplet_acc: 0.650 - ETA: 3:40 - loss: 0.8800 - triplet_acc: 0.700 - ETA: 3:34 - loss: 0.8990 - triplet_acc: 0.700 - ETA: 3:28 - loss: 1.0489 - triplet_acc: 0.660 - ETA: 3:25 - loss: 0.9115 - triplet_acc: 0.700 - ETA: 3:21 - loss: 0.7813 - triplet_acc: 0.742 - ETA: 3:18 - loss: 0.8517 - triplet_acc: 0.725 - ETA: 3:17 - loss: 0.7819 - triplet_acc: 0.733 - ETA: 3:15 - loss: 0.8158 - triplet_acc: 0.710 - ETA: 3:13 - loss: 0.7454 - triplet_acc: 0.727 - ETA: 3:12 - loss: 0.7189 - triplet_acc: 0.733 - ETA: 3:10 - loss: 0.6641 - triplet_acc: 0.746 - ETA: 3:09 - loss: 0.6994 - triplet_acc: 0.728 - ETA: 3:08 - loss: 0.6822 - triplet_acc: 0.733 - ETA: 3:07 - loss: 0.6476 - triplet_acc: 0.737 - ETA: 3:06 - loss: 0.7060 - triplet_acc: 0.729 - ETA: 3:04 - loss: 0.7001 - triplet_acc: 0.733 - ETA: 3:03 - loss: 0.7255 - triplet_acc: 0.731 - ETA: 3:03 - loss: 0.7217 - triplet_acc: 0.730 - ETA: 3:03 - loss: 0.7264 - triplet_acc: 0.728 - ETA: 3:02 - loss: 0.7095 - triplet_acc: 0.727 - ETA: 3:01 - loss: 0.6912 - triplet_acc: 0.730 - ETA: 3:00 - loss: 0.7317 - triplet_acc: 0.733 - ETA: 3:00 - loss: 0.7024 - triplet_acc: 0.744 - ETA: 2:59 - loss: 0.6972 - triplet_acc: 0.742 - ETA: 2:58 - loss: 0.6912 - triplet_acc: 0.744 - ETA: 2:57 - loss: 0.6859 - triplet_acc: 0.750 - ETA: 2:57 - loss: 0.6937 - triplet_acc: 0.744 - ETA: 2:56 - loss: 0.6755 - triplet_acc: 0.746 - ETA: 2:55 - loss: 0.6879 - triplet_acc: 0.745 - ETA: 2:54 - loss: 0.6703 - triplet_acc: 0.746 - ETA: 2:53 - loss: 0.6559 - triplet_acc: 0.751 - ETA: 2:52 - loss: 0.6403 - triplet_acc: 0.755 - ETA: 2:52 - loss: 0.6220 - triplet_acc: 0.762 - ETA: 2:52 - loss: 0.6242 - triplet_acc: 0.761 - ETA: 2:51 - loss: 0.6146 - triplet_acc: 0.762 - ETA: 2:51 - loss: 0.5994 - triplet_acc: 0.765 - ETA: 2:51 - loss: 0.6197 - triplet_acc: 0.759 - ETA: 2:51 - loss: 0.6166 - triplet_acc: 0.757 - ETA: 2:50 - loss: 0.6015 - triplet_acc: 0.763 - ETA: 2:50 - loss: 0.5939 - triplet_acc: 0.766 - ETA: 2:49 - loss: 0.6152 - triplet_acc: 0.762 - ETA: 2:48 - loss: 0.6442 - triplet_acc: 0.759 - ETA: 2:47 - loss: 0.6652 - triplet_acc: 0.762 - ETA: 2:47 - loss: 0.6700 - triplet_acc: 0.760 - ETA: 2:46 - loss: 0.6793 - triplet_acc: 0.755 - ETA: 2:45 - loss: 0.6788 - triplet_acc: 0.758 - ETA: 2:45 - loss: 0.6650 - triplet_acc: 0.761 - ETA: 2:44 - loss: 0.6517 - triplet_acc: 0.766 - ETA: 2:44 - loss: 0.6591 - triplet_acc: 0.764 - ETA: 2:43 - loss: 0.6558 - triplet_acc: 0.767 - ETA: 2:43 - loss: 0.6564 - triplet_acc: 0.767 - ETA: 2:42 - loss: 0.6636 - triplet_acc: 0.764 - ETA: 2:42 - loss: 0.6522 - triplet_acc: 0.767 - ETA: 2:41 - loss: 0.6419 - triplet_acc: 0.769 - ETA: 2:40 - loss: 0.6448 - triplet_acc: 0.768 - ETA: 2:40 - loss: 0.6445 - triplet_acc: 0.765 - ETA: 2:39 - loss: 0.6457 - triplet_acc: 0.764 - ETA: 2:38 - loss: 0.6349 - triplet_acc: 0.768 - ETA: 2:38 - loss: 0.6305 - triplet_acc: 0.770 - ETA: 2:37 - loss: 0.6281 - triplet_acc: 0.771 - ETA: 2:36 - loss: 0.6460 - triplet_acc: 0.771 - ETA: 2:36 - loss: 0.6608 - triplet_acc: 0.767 - ETA: 2:35 - loss: 0.6601 - triplet_acc: 0.766 - ETA: 2:35 - loss: 0.6545 - triplet_acc: 0.766 - ETA: 2:34 - loss: 0.6477 - triplet_acc: 0.768 - ETA: 2:33 - loss: 0.6425 - triplet_acc: 0.769 - ETA: 2:33 - loss: 0.6342 - triplet_acc: 0.771 - ETA: 2:33 - loss: 0.7086 - triplet_acc: 0.765 - ETA: 2:32 - loss: 0.7068 - triplet_acc: 0.767 - ETA: 2:31 - loss: 0.6970 - triplet_acc: 0.770 - ETA: 2:31 - loss: 0.6991 - triplet_acc: 0.769 - ETA: 2:30 - loss: 0.6896 - triplet_acc: 0.773 - ETA: 2:30 - loss: 0.6856 - triplet_acc: 0.774 - ETA: 2:29 - loss: 0.6852 - triplet_acc: 0.775 - ETA: 2:28 - loss: 0.6805 - triplet_acc: 0.776 - ETA: 2:28 - loss: 0.6904 - triplet_acc: 0.776 - ETA: 2:27 - loss: 0.6899 - triplet_acc: 0.777 - ETA: 2:26 - loss: 0.6833 - triplet_acc: 0.778 - ETA: 2:25 - loss: 0.6786 - triplet_acc: 0.777 - ETA: 2:25 - loss: 0.6711 - triplet_acc: 0.779 - ETA: 2:24 - loss: 0.6 ...
# Beginning epoch number: 3
# Current hard triplet ratio: 0.7833105810370663
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:42 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:24 - loss: 0.0375 - triplet_acc: 0.9500    - ETA: 3:20 - loss: 0.4429 - triplet_acc: 0.833 - ETA: 3:23 - loss: 0.7741 - triplet_acc: 0.750 - ETA: 3:22 - loss: 0.6763 - triplet_acc: 0.760 - ETA: 3:19 - loss: 0.5636 - triplet_acc: 0.800 - ETA: 3:16 - loss: 0.4831 - triplet_acc: 0.828 - ETA: 3:16 - loss: 0.5083 - triplet_acc: 0.800 - ETA: 3:16 - loss: 0.6646 - triplet_acc: 0.766 - ETA: 3:17 - loss: 0.7215 - triplet_acc: 0.750 - ETA: 3:16 - loss: 0.7575 - triplet_acc: 0.754 - ETA: 3:14 - loss: 0.7085 - triplet_acc: 0.766 - ETA: 3:14 - loss: 0.7397 - triplet_acc: 0.746 - ETA: 3:13 - loss: 0.8413 - triplet_acc: 0.742 - ETA: 3:12 - loss: 0.7987 - triplet_acc: 0.753 - ETA: 3:12 - loss: 0.7875 - triplet_acc: 0.750 - ETA: 3:10 - loss: 0.7705 - triplet_acc: 0.741 - ETA: 3:09 - loss: 0.7364 - triplet_acc: 0.750 - ETA: 3:09 - loss: 0.7751 - triplet_acc: 0.742 - ETA: 3:09 - loss: 0.7776 - triplet_acc: 0.735 - ETA: 3:07 - loss: 0.7649 - triplet_acc: 0.742 - ETA: 3:06 - loss: 0.7421 - triplet_acc: 0.740 - ETA: 3:06 - loss: 0.7409 - triplet_acc: 0.739 - ETA: 3:06 - loss: 0.7429 - triplet_acc: 0.741 - ETA: 3:05 - loss: 0.7937 - triplet_acc: 0.736 - ETA: 3:04 - loss: 0.7631 - triplet_acc: 0.746 - ETA: 3:03 - loss: 0.7673 - triplet_acc: 0.744 - ETA: 3:03 - loss: 0.7827 - triplet_acc: 0.739 - ETA: 3:02 - loss: 0.7591 - triplet_acc: 0.744 - ETA: 3:02 - loss: 0.7691 - triplet_acc: 0.746 - ETA: 3:00 - loss: 0.7689 - triplet_acc: 0.738 - ETA: 3:00 - loss: 0.7610 - triplet_acc: 0.737 - ETA: 2:59 - loss: 0.7932 - triplet_acc: 0.736 - ETA: 2:58 - loss: 0.7767 - triplet_acc: 0.741 - ETA: 2:58 - loss: 0.7670 - triplet_acc: 0.742 - ETA: 2:57 - loss: 0.7606 - triplet_acc: 0.738 - ETA: 2:56 - loss: 0.8258 - triplet_acc: 0.732 - ETA: 2:55 - loss: 0.8213 - triplet_acc: 0.734 - ETA: 2:55 - loss: 0.8139 - triplet_acc: 0.730 - ETA: 2:54 - loss: 0.8060 - triplet_acc: 0.732 - ETA: 2:53 - loss: 0.7864 - triplet_acc: 0.736 - ETA: 2:53 - loss: 0.7734 - triplet_acc: 0.740 - ETA: 2:52 - loss: 0.7681 - triplet_acc: 0.741 - ETA: 2:51 - loss: 0.7561 - triplet_acc: 0.743 - ETA: 2:51 - loss: 0.7501 - triplet_acc: 0.742 - ETA: 2:50 - loss: 0.7497 - triplet_acc: 0.734 - ETA: 2:49 - loss: 0.7387 - triplet_acc: 0.736 - ETA: 2:48 - loss: 0.7242 - triplet_acc: 0.735 - ETA: 2:48 - loss: 0.7107 - triplet_acc: 0.736 - ETA: 2:47 - loss: 0.7108 - triplet_acc: 0.738 - ETA: 2:46 - loss: 0.7016 - triplet_acc: 0.741 - ETA: 2:46 - loss: 0.6909 - triplet_acc: 0.744 - ETA: 2:45 - loss: 0.6800 - triplet_acc: 0.747 - ETA: 2:44 - loss: 0.6709 - triplet_acc: 0.750 - ETA: 2:44 - loss: 0.6767 - triplet_acc: 0.749 - ETA: 2:43 - loss: 0.6675 - triplet_acc: 0.750 - ETA: 2:42 - loss: 0.6681 - triplet_acc: 0.747 - ETA: 2:42 - loss: 0.6773 - triplet_acc: 0.744 - ETA: 2:41 - loss: 0.6676 - triplet_acc: 0.747 - ETA: 2:40 - loss: 0.6619 - triplet_acc: 0.750 - ETA: 2:40 - loss: 0.6584 - triplet_acc: 0.749 - ETA: 2:39 - loss: 0.6901 - triplet_acc: 0.743 - ETA: 2:38 - loss: 0.6881 - triplet_acc: 0.742 - ETA: 2:38 - loss: 0.6890 - triplet_acc: 0.743 - ETA: 2:37 - loss: 0.7250 - triplet_acc: 0.738 - ETA: 2:36 - loss: 0.7140 - triplet_acc: 0.742 - ETA: 2:36 - loss: 0.7218 - triplet_acc: 0.741 - ETA: 2:35 - loss: 0.7165 - triplet_acc: 0.744 - ETA: 2:34 - loss: 0.7113 - triplet_acc: 0.746 - ETA: 2:34 - loss: 0.7139 - triplet_acc: 0.747 - ETA: 2:33 - loss: 0.7137 - triplet_acc: 0.746 - ETA: 2:33 - loss: 0.7128 - triplet_acc: 0.745 - ETA: 2:32 - loss: 0.7051 - triplet_acc: 0.747 - ETA: 2:31 - loss: 0.6969 - triplet_acc: 0.748 - ETA: 2:30 - loss: 0.6876 - triplet_acc: 0.752 - ETA: 2:30 - loss: 0.6880 - triplet_acc: 0.751 - ETA: 2:29 - loss: 0.6869 - triplet_acc: 0.751 - ETA: 2:28 - loss: 0.6889 - triplet_acc: 0.750 - ETA: 2:28 - loss: 0.6982 - triplet_acc: 0.748 - ETA: 2:27 - loss: 0.6895 - triplet_acc: 0.751 - ETA: 2:26 - loss: 0.6810 - triplet_acc: 0.754 - ETA: 2:26 - loss: 0.6861 - triplet_acc: 0.752 - ETA: 2:25 - l ...
# 300/300 [==============================] - ETA: 1:26 - loss: 0.7098 - triplet_acc: 0.759 - ETA: 1:26 - loss: 0.7098 - triplet_acc: 0.758 - ETA: 1:25 - loss: 0.7111 - triplet_acc: 0.757 - ETA: 1:24 - loss: 0.7091 - triplet_acc: 0.758 - ETA: 1:24 - loss: 0.7060 - triplet_acc: 0.758 - ETA: 1:23 - loss: 0.7020 - triplet_acc: 0.759 - ETA: 1:22 - loss: 0.6989 - triplet_acc: 0.760 - ETA: 1:22 - loss: 0.6956 - triplet_acc: 0.761 - ETA: 1:21 - loss: 0.6945 - triplet_acc: 0.759 - ETA: 1:20 - loss: 0.6954 - triplet_acc: 0.760 - ETA: 1:20 - loss: 0.6929 - triplet_acc: 0.760 - ETA: 1:19 - loss: 0.6891 - triplet_acc: 0.761 - ETA: 1:18 - loss: 0.6853 - triplet_acc: 0.762 - ETA: 1:18 - loss: 0.6906 - triplet_acc: 0.762 - ETA: 1:17 - loss: 0.7031 - triplet_acc: 0.761 - ETA: 1:16 - loss: 0.7082 - triplet_acc: 0.760 - ETA: 1:15 - loss: 0.7078 - triplet_acc: 0.759 - ETA: 1:15 - loss: 0.7040 - triplet_acc: 0.760 - ETA: 1:14 - loss: 0.7019 - triplet_acc: 0.761 - ETA: 1:13 - loss: 0.7003 - triplet_acc: 0.761 - ETA: 1:13 - loss: 0.6981 - triplet_acc: 0.761 - ETA: 1:12 - loss: 0.6971 - triplet_acc: 0.760 - ETA: 1:11 - loss: 0.6937 - triplet_acc: 0.760 - ETA: 1:11 - loss: 0.6913 - triplet_acc: 0.761 - ETA: 1:10 - loss: 0.6879 - triplet_acc: 0.762 - ETA: 1:09 - loss: 0.6887 - triplet_acc: 0.761 - ETA: 1:09 - loss: 0.6881 - triplet_acc: 0.761 - ETA: 1:08 - loss: 0.6921 - triplet_acc: 0.762 - ETA: 1:08 - loss: 0.6916 - triplet_acc: 0.762 - ETA: 1:07 - loss: 0.6895 - triplet_acc: 0.763 - ETA: 1:06 - loss: 0.6927 - triplet_acc: 0.762 - ETA: 1:06 - loss: 0.6944 - triplet_acc: 0.762 - ETA: 1:05 - loss: 0.6919 - triplet_acc: 0.762 - ETA: 1:04 - loss: 0.6935 - triplet_acc: 0.762 - ETA: 1:04 - loss: 0.6937 - triplet_acc: 0.762 - ETA: 1:03 - loss: 0.6907 - triplet_acc: 0.762 - ETA: 1:02 - loss: 0.6880 - triplet_acc: 0.762 - ETA: 1:01 - loss: 0.6896 - triplet_acc: 0.762 - ETA: 1:01 - loss: 0.6900 - triplet_acc: 0.761 - ETA: 1:00 - loss: 0.6923 - triplet_acc: 0.760 - ETA: 59s - loss: 0.6913 - triplet_acc: 0.761 - ETA: 59s - loss: 0.6910 - triplet_acc: 0.76 - ETA: 58s - loss: 0.6930 - triplet_acc: 0.76 - ETA: 57s - loss: 0.6915 - triplet_acc: 0.76 - ETA: 57s - loss: 0.6916 - triplet_acc: 0.76 - ETA: 56s - loss: 0.6889 - triplet_acc: 0.76 - ETA: 55s - loss: 0.6860 - triplet_acc: 0.76 - ETA: 55s - loss: 0.6860 - triplet_acc: 0.76 - ETA: 54s - loss: 0.6855 - triplet_acc: 0.76 - ETA: 53s - loss: 0.6922 - triplet_acc: 0.76 - ETA: 53s - loss: 0.6891 - triplet_acc: 0.76 - ETA: 52s - loss: 0.6897 - triplet_acc: 0.76 - ETA: 51s - loss: 0.6866 - triplet_acc: 0.76 - ETA: 51s - loss: 0.6859 - triplet_acc: 0.76 - ETA: 50s - loss: 0.6882 - triplet_acc: 0.76 - ETA: 49s - loss: 0.6884 - triplet_acc: 0.76 - ETA: 49s - loss: 0.6877 - triplet_acc: 0.76 - ETA: 48s - loss: 0.6929 - triplet_acc: 0.76 - ETA: 47s - loss: 0.6899 - triplet_acc: 0.76 - ETA: 47s - loss: 0.6898 - triplet_acc: 0.76 - ETA: 46s - loss: 0.6899 - triplet_acc: 0.76 - ETA: 45s - loss: 0.6902 - triplet_acc: 0.76 - ETA: 45s - loss: 0.6883 - triplet_acc: 0.76 - ETA: 44s - loss: 0.6863 - triplet_acc: 0.76 - ETA: 43s - loss: 0.6986 - triplet_acc: 0.76 - ETA: 43s - loss: 0.6956 - triplet_acc: 0.76 - ETA: 42s - loss: 0.6939 - triplet_acc: 0.76 - ETA: 41s - loss: 0.6911 - triplet_acc: 0.76 - ETA: 41s - loss: 0.6882 - triplet_acc: 0.76 - ETA: 40s - loss: 0.6916 - triplet_acc: 0.76 - ETA: 39s - loss: 0.6954 - triplet_acc: 0.76 - ETA: 38s - loss: 0.6980 - triplet_acc: 0.75 - ETA: 38s - loss: 0.6961 - triplet_acc: 0.76 - ETA: 37s - loss: 0.6947 - triplet_acc: 0.76 - ETA: 37s - loss: 0.6952 - triplet_acc: 0.76 - ETA: 36s - loss: 0.6930 - triplet_acc: 0.76 - ETA: 35s - loss: 0.6903 - triplet_acc: 0.76 - ETA: 34s - loss: 0.6921 - triplet_acc: 0.76 - ETA: 34s - loss: 0.6902 - triplet_acc: 0.76 - ETA: 33s - loss: 0.6957 - triplet_acc: 0.76 - ETA: 32s - loss: 0.6937 - triplet_acc: 0.76 - ETA: 32s - loss: 0.6940 - triplet_acc: 0.76 - ETA: 31s - loss: 0.6940 - triplet_acc: 0.76 - ETA: 30s - loss: 0.6965 - triplet_acc: 0.75 - ETA: 30s - l ...
# Beginning epoch number: 4
# Current hard triplet ratio: 0.7836047553970164
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:28 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:25 - loss: 0.3481 - triplet_acc: 0.9000    - ETA: 3:22 - loss: 0.2321 - triplet_acc: 0.933 - ETA: 3:21 - loss: 0.5185 - triplet_acc: 0.800 - ETA: 3:20 - loss: 0.5263 - triplet_acc: 0.800 - ETA: 3:21 - loss: 1.0430 - triplet_acc: 0.716 - ETA: 3:18 - loss: 0.9221 - triplet_acc: 0.742 - ETA: 3:15 - loss: 0.8450 - triplet_acc: 0.750 - ETA: 3:14 - loss: 0.8210 - triplet_acc: 0.755 - ETA: 3:13 - loss: 0.9506 - triplet_acc: 0.720 - ETA: 3:11 - loss: 0.8642 - triplet_acc: 0.745 - ETA: 3:10 - loss: 0.8937 - triplet_acc: 0.716 - ETA: 3:09 - loss: 0.9084 - triplet_acc: 0.707 - ETA: 3:09 - loss: 0.8633 - triplet_acc: 0.714 - ETA: 3:08 - loss: 0.9021 - triplet_acc: 0.706 - ETA: 3:09 - loss: 0.8733 - triplet_acc: 0.706 - ETA: 3:07 - loss: 0.8698 - triplet_acc: 0.700 - ETA: 3:06 - loss: 0.9403 - triplet_acc: 0.688 - ETA: 3:07 - loss: 0.9437 - triplet_acc: 0.684 - ETA: 3:07 - loss: 0.9175 - triplet_acc: 0.695 - ETA: 3:07 - loss: 0.9104 - triplet_acc: 0.700 - ETA: 3:06 - loss: 0.9485 - triplet_acc: 0.695 - ETA: 3:07 - loss: 0.9433 - triplet_acc: 0.700 - ETA: 3:06 - loss: 0.9202 - triplet_acc: 0.700 - ETA: 3:06 - loss: 0.8834 - triplet_acc: 0.712 - ETA: 3:05 - loss: 0.8809 - triplet_acc: 0.715 - ETA: 3:04 - loss: 0.9793 - triplet_acc: 0.703 - ETA: 3:03 - loss: 0.9443 - triplet_acc: 0.714 - ETA: 3:02 - loss: 0.9167 - triplet_acc: 0.717 - ETA: 3:01 - loss: 0.8951 - triplet_acc: 0.723 - ETA: 3:00 - loss: 0.8778 - triplet_acc: 0.725 - ETA: 3:00 - loss: 0.8574 - triplet_acc: 0.728 - ETA: 2:59 - loss: 0.8465 - triplet_acc: 0.730 - ETA: 2:58 - loss: 0.8754 - triplet_acc: 0.729 - ETA: 2:57 - loss: 0.8713 - triplet_acc: 0.731 - ETA: 2:57 - loss: 0.8893 - triplet_acc: 0.727 - ETA: 2:57 - loss: 0.8980 - triplet_acc: 0.729 - ETA: 2:56 - loss: 0.8761 - triplet_acc: 0.734 - ETA: 2:56 - loss: 0.8955 - triplet_acc: 0.728 - ETA: 2:55 - loss: 0.8751 - triplet_acc: 0.730 - ETA: 2:54 - loss: 0.8538 - triplet_acc: 0.736 - ETA: 2:53 - loss: 0.8426 - triplet_acc: 0.733 - ETA: 2:53 - loss: 0.8230 - triplet_acc: 0.739 - ETA: 2:51 - loss: 0.8089 - triplet_acc: 0.740 - ETA: 2:51 - loss: 0.8047 - triplet_acc: 0.737 - ETA: 2:50 - loss: 0.7961 - triplet_acc: 0.739 - ETA: 2:49 - loss: 0.7845 - triplet_acc: 0.742 - ETA: 2:48 - loss: 0.7826 - triplet_acc: 0.741 - ETA: 2:48 - loss: 0.7726 - triplet_acc: 0.744 - ETA: 2:47 - loss: 0.7845 - triplet_acc: 0.740 - ETA: 2:47 - loss: 0.8134 - triplet_acc: 0.731 - ETA: 2:46 - loss: 0.8014 - triplet_acc: 0.734 - ETA: 2:46 - loss: 0.7894 - triplet_acc: 0.737 - ETA: 2:45 - loss: 0.8314 - triplet_acc: 0.733 - ETA: 2:45 - loss: 0.8362 - triplet_acc: 0.730 - ETA: 2:44 - loss: 0.8277 - triplet_acc: 0.732 - ETA: 2:43 - loss: 0.8132 - triplet_acc: 0.736 - ETA: 2:43 - loss: 0.8038 - triplet_acc: 0.737 - ETA: 2:42 - loss: 0.8063 - triplet_acc: 0.737 - ETA: 2:42 - loss: 0.7971 - triplet_acc: 0.740 - ETA: 2:41 - loss: 0.7841 - triplet_acc: 0.744 - ETA: 2:40 - loss: 0.7763 - triplet_acc: 0.746 - ETA: 2:39 - loss: 0.7820 - triplet_acc: 0.746 - ETA: 2:39 - loss: 0.7728 - triplet_acc: 0.746 - ETA: 2:38 - loss: 0.7714 - triplet_acc: 0.749 - ETA: 2:37 - loss: 0.7597 - triplet_acc: 0.753 - ETA: 2:37 - loss: 0.7561 - triplet_acc: 0.755 - ETA: 2:36 - loss: 0.7660 - triplet_acc: 0.754 - ETA: 2:35 - loss: 0.7611 - triplet_acc: 0.753 - ETA: 2:34 - loss: 0.7629 - triplet_acc: 0.752 - ETA: 2:34 - loss: 0.7521 - triplet_acc: 0.756 - ETA: 2:33 - loss: 0.7482 - triplet_acc: 0.756 - ETA: 2:32 - loss: 0.7380 - triplet_acc: 0.760 - ETA: 2:31 - loss: 0.7280 - triplet_acc: 0.763 - ETA: 2:31 - loss: 0.7232 - triplet_acc: 0.764 - ETA: 2:30 - loss: 0.7200 - triplet_acc: 0.764 - ETA: 2:29 - loss: 0.7154 - triplet_acc: 0.764 - ETA: 2:29 - loss: 0.7063 - triplet_acc: 0.767 - ETA: 2:28 - loss: 0.7093 - triplet_acc: 0.768 - ETA: 2:27 - loss: 0.7070 - triplet_acc: 0.770 - ETA: 2:27 - loss: 0.7051 - triplet_acc: 0.770 - ETA: 2:26 - loss: 0.7046 - triplet_acc: 0.769 - ETA: 2:25 - l ...
# Beginning epoch number: 5
# Current hard triplet ratio: 0.80648032909518
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:45 - loss: 0.0697 - triplet_acc: 0.900 - ETA: 3:27 - loss: 0.4393 - triplet_acc: 0.800 - ETA: 3:19 - loss: 0.5650 - triplet_acc: 0.766 - ETA: 3:23 - loss: 0.7100 - triplet_acc: 0.750 - ETA: 3:18 - loss: 0.8968 - triplet_acc: 0.740 - ETA: 3:19 - loss: 0.8128 - triplet_acc: 0.750 - ETA: 3:16 - loss: 0.9188 - triplet_acc: 0.728 - ETA: 3:15 - loss: 0.9301 - triplet_acc: 0.725 - ETA: 3:13 - loss: 0.8908 - triplet_acc: 0.733 - ETA: 3:14 - loss: 1.0767 - triplet_acc: 0.710 - ETA: 3:14 - loss: 0.9897 - triplet_acc: 0.727 - ETA: 3:13 - loss: 1.0186 - triplet_acc: 0.708 - ETA: 3:13 - loss: 1.0048 - triplet_acc: 0.707 - ETA: 3:12 - loss: 0.9941 - triplet_acc: 0.707 - ETA: 3:11 - loss: 0.9279 - triplet_acc: 0.726 - ETA: 3:11 - loss: 0.9085 - triplet_acc: 0.737 - ETA: 3:10 - loss: 0.9278 - triplet_acc: 0.735 - ETA: 3:08 - loss: 0.9221 - triplet_acc: 0.722 - ETA: 3:07 - loss: 0.9233 - triplet_acc: 0.721 - ETA: 3:06 - loss: 0.9058 - triplet_acc: 0.720 - ETA: 3:06 - loss: 0.8718 - triplet_acc: 0.728 - ETA: 3:06 - loss: 0.8501 - triplet_acc: 0.731 - ETA: 3:05 - loss: 0.8320 - triplet_acc: 0.739 - ETA: 3:04 - loss: 0.8103 - triplet_acc: 0.745 - ETA: 3:03 - loss: 0.7779 - triplet_acc: 0.756 - ETA: 3:03 - loss: 0.7511 - triplet_acc: 0.761 - ETA: 3:02 - loss: 0.7233 - triplet_acc: 0.770 - ETA: 3:01 - loss: 0.7514 - triplet_acc: 0.764 - ETA: 3:00 - loss: 0.7493 - triplet_acc: 0.758 - ETA: 3:00 - loss: 0.7341 - triplet_acc: 0.763 - ETA: 2:59 - loss: 0.7199 - triplet_acc: 0.767 - ETA: 2:58 - loss: 0.7163 - triplet_acc: 0.765 - ETA: 2:58 - loss: 0.7055 - triplet_acc: 0.769 - ETA: 2:57 - loss: 0.6847 - triplet_acc: 0.776 - ETA: 2:56 - loss: 0.6907 - triplet_acc: 0.774 - ETA: 2:55 - loss: 0.7244 - triplet_acc: 0.766 - ETA: 2:55 - loss: 0.7146 - triplet_acc: 0.767 - ETA: 2:54 - loss: 0.7056 - triplet_acc: 0.768 - ETA: 2:54 - loss: 0.6875 - triplet_acc: 0.774 - ETA: 2:53 - loss: 0.7062 - triplet_acc: 0.770 - ETA: 2:52 - loss: 0.6896 - triplet_acc: 0.773 - ETA: 2:51 - loss: 0.6972 - triplet_acc: 0.771 - ETA: 2:50 - loss: 0.6919 - triplet_acc: 0.774 - ETA: 2:49 - loss: 0.6790 - triplet_acc: 0.777 - ETA: 2:49 - loss: 0.6757 - triplet_acc: 0.777 - ETA: 2:48 - loss: 0.6610 - triplet_acc: 0.782 - ETA: 2:47 - loss: 0.6499 - triplet_acc: 0.783 - ETA: 2:47 - loss: 0.6662 - triplet_acc: 0.781 - ETA: 2:46 - loss: 0.6753 - triplet_acc: 0.779 - ETA: 2:45 - loss: 0.6637 - triplet_acc: 0.782 - ETA: 2:45 - loss: 0.7017 - triplet_acc: 0.778 - ETA: 2:44 - loss: 0.6985 - triplet_acc: 0.780 - ETA: 2:44 - loss: 0.7203 - triplet_acc: 0.775 - ETA: 2:43 - loss: 0.7989 - triplet_acc: 0.770 - ETA: 2:43 - loss: 0.8107 - triplet_acc: 0.767 - ETA: 2:42 - loss: 0.8399 - triplet_acc: 0.760 - ETA: 2:41 - loss: 0.8338 - triplet_acc: 0.761 - ETA: 2:40 - loss: 0.8359 - triplet_acc: 0.755 - ETA: 2:40 - loss: 0.8300 - triplet_acc: 0.754 - ETA: 2:39 - loss: 0.8459 - triplet_acc: 0.755 - ETA: 2:38 - loss: 0.8338 - triplet_acc: 0.754 - ETA: 2:38 - loss: 0.8297 - triplet_acc: 0.754 - ETA: 2:37 - loss: 0.8169 - triplet_acc: 0.757 - ETA: 2:36 - loss: 0.8108 - triplet_acc: 0.756 - ETA: 2:36 - loss: 0.8201 - triplet_acc: 0.755 - ETA: 2:35 - loss: 0.8086 - triplet_acc: 0.757 - ETA: 2:35 - loss: 0.8014 - triplet_acc: 0.759 - ETA: 2:34 - loss: 0.8116 - triplet_acc: 0.758 - ETA: 2:34 - loss: 0.8001 - triplet_acc: 0.760 - ETA: 2:33 - loss: 0.7939 - triplet_acc: 0.760 - ETA: 2:32 - loss: 0.7853 - triplet_acc: 0.757 - ETA: 2:31 - loss: 0.8007 - triplet_acc: 0.758 - ETA: 2:31 - loss: 0.7965 - triplet_acc: 0.756 - ETA: 2:30 - loss: 0.7935 - triplet_acc: 0.755 - ETA: 2:29 - loss: 0.7925 - triplet_acc: 0.754 - ETA: 2:28 - loss: 0.7904 - triplet_acc: 0.755 - ETA: 2:28 - loss: 0.7801 - triplet_acc: 0.758 - ETA: 2:27 - loss: 0.7802 - triplet_acc: 0.759 - ETA: 2:26 - loss: 0.7774 - triplet_acc: 0.759 - ETA: 2:26 - loss: 0.7708 - triplet_acc: 0.760 - ETA: 2:25 - loss: 0.7643 - triplet_acc: 0.761 - ETA: 2:24 - loss: 0.7722 - triplet_acc: 0.761 - ETA: 2:24 - loss: 0.7 ...
# 300/300 [==============================] - ETA: 1:26 - loss: 0.7671 - triplet_acc: 0.756 - ETA: 1:25 - loss: 0.7689 - triplet_acc: 0.755 - ETA: 1:25 - loss: 0.7699 - triplet_acc: 0.754 - ETA: 1:24 - loss: 0.7690 - triplet_acc: 0.754 - ETA: 1:23 - loss: 0.7654 - triplet_acc: 0.755 - ETA: 1:23 - loss: 0.7672 - triplet_acc: 0.755 - ETA: 1:22 - loss: 0.7629 - triplet_acc: 0.756 - ETA: 1:21 - loss: 0.7611 - triplet_acc: 0.756 - ETA: 1:21 - loss: 0.7605 - triplet_acc: 0.755 - ETA: 1:20 - loss: 0.7610 - triplet_acc: 0.755 - ETA: 1:19 - loss: 0.7596 - triplet_acc: 0.756 - ETA: 1:19 - loss: 0.7570 - triplet_acc: 0.756 - ETA: 1:18 - loss: 0.7588 - triplet_acc: 0.755 - ETA: 1:17 - loss: 0.7615 - triplet_acc: 0.753 - ETA: 1:17 - loss: 0.7642 - triplet_acc: 0.751 - ETA: 1:16 - loss: 0.7601 - triplet_acc: 0.752 - ETA: 1:15 - loss: 0.7595 - triplet_acc: 0.751 - ETA: 1:15 - loss: 0.7563 - triplet_acc: 0.752 - ETA: 1:14 - loss: 0.7528 - triplet_acc: 0.752 - ETA: 1:13 - loss: 0.7508 - triplet_acc: 0.753 - ETA: 1:13 - loss: 0.7550 - triplet_acc: 0.753 - ETA: 1:12 - loss: 0.7511 - triplet_acc: 0.754 - ETA: 1:11 - loss: 0.7514 - triplet_acc: 0.753 - ETA: 1:11 - loss: 0.7558 - triplet_acc: 0.752 - ETA: 1:10 - loss: 0.7535 - triplet_acc: 0.753 - ETA: 1:09 - loss: 0.7510 - triplet_acc: 0.753 - ETA: 1:09 - loss: 0.7539 - triplet_acc: 0.753 - ETA: 1:08 - loss: 0.7534 - triplet_acc: 0.753 - ETA: 1:07 - loss: 0.7592 - triplet_acc: 0.752 - ETA: 1:07 - loss: 0.7616 - triplet_acc: 0.752 - ETA: 1:06 - loss: 0.7593 - triplet_acc: 0.753 - ETA: 1:05 - loss: 0.7569 - triplet_acc: 0.753 - ETA: 1:05 - loss: 0.7628 - triplet_acc: 0.751 - ETA: 1:04 - loss: 0.7617 - triplet_acc: 0.751 - ETA: 1:03 - loss: 0.7604 - triplet_acc: 0.751 - ETA: 1:03 - loss: 0.7567 - triplet_acc: 0.752 - ETA: 1:02 - loss: 0.7544 - triplet_acc: 0.752 - ETA: 1:01 - loss: 0.7535 - triplet_acc: 0.752 - ETA: 1:01 - loss: 0.7509 - triplet_acc: 0.753 - ETA: 1:00 - loss: 0.7557 - triplet_acc: 0.752 - ETA: 59s - loss: 0.7539 - triplet_acc: 0.752 - ETA: 59s - loss: 0.7533 - triplet_acc: 0.75 - ETA: 58s - loss: 0.7578 - triplet_acc: 0.75 - ETA: 57s - loss: 0.7587 - triplet_acc: 0.75 - ETA: 57s - loss: 0.7652 - triplet_acc: 0.75 - ETA: 56s - loss: 0.7667 - triplet_acc: 0.74 - ETA: 55s - loss: 0.7632 - triplet_acc: 0.74 - ETA: 55s - loss: 0.7660 - triplet_acc: 0.74 - ETA: 54s - loss: 0.7679 - triplet_acc: 0.74 - ETA: 53s - loss: 0.7644 - triplet_acc: 0.75 - ETA: 53s - loss: 0.7612 - triplet_acc: 0.75 - ETA: 52s - loss: 0.7609 - triplet_acc: 0.75 - ETA: 51s - loss: 0.7627 - triplet_acc: 0.75 - ETA: 51s - loss: 0.7602 - triplet_acc: 0.75 - ETA: 50s - loss: 0.7644 - triplet_acc: 0.74 - ETA: 49s - loss: 0.7641 - triplet_acc: 0.74 - ETA: 49s - loss: 0.7619 - triplet_acc: 0.74 - ETA: 48s - loss: 0.7597 - triplet_acc: 0.75 - ETA: 47s - loss: 0.7606 - triplet_acc: 0.74 - ETA: 47s - loss: 0.7598 - triplet_acc: 0.74 - ETA: 46s - loss: 0.7565 - triplet_acc: 0.75 - ETA: 45s - loss: 0.7540 - triplet_acc: 0.75 - ETA: 45s - loss: 0.7575 - triplet_acc: 0.75 - ETA: 44s - loss: 0.7583 - triplet_acc: 0.74 - ETA: 43s - loss: 0.7600 - triplet_acc: 0.74 - ETA: 42s - loss: 0.7568 - triplet_acc: 0.75 - ETA: 42s - loss: 0.7561 - triplet_acc: 0.75 - ETA: 41s - loss: 0.7537 - triplet_acc: 0.75 - ETA: 40s - loss: 0.7511 - triplet_acc: 0.75 - ETA: 40s - loss: 0.7492 - triplet_acc: 0.75 - ETA: 39s - loss: 0.7476 - triplet_acc: 0.75 - ETA: 38s - loss: 0.7571 - triplet_acc: 0.75 - ETA: 38s - loss: 0.7623 - triplet_acc: 0.74 - ETA: 37s - loss: 0.7655 - triplet_acc: 0.74 - ETA: 36s - loss: 0.7652 - triplet_acc: 0.74 - ETA: 36s - loss: 0.7623 - triplet_acc: 0.74 - ETA: 35s - loss: 0.7635 - triplet_acc: 0.74 - ETA: 34s - loss: 0.7608 - triplet_acc: 0.74 - ETA: 34s - loss: 0.7639 - triplet_acc: 0.74 - ETA: 33s - loss: 0.7616 - triplet_acc: 0.74 - ETA: 32s - loss: 0.7630 - triplet_acc: 0.74 - ETA: 32s - loss: 0.7661 - triplet_acc: 0.74 - ETA: 31s - loss: 0.7632 - triplet_acc: 0.74 - ETA: 30s - loss: 0.7647 - triplet_acc: 0.74 - ETA: 30s - l ...
# Beginning epoch number: 6
# Current hard triplet ratio: 0.7813320158752912
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:33 - loss: 0.1136 - triplet_acc: 0.800 - ETA: 3:12 - loss: 0.2482 - triplet_acc: 0.800 - ETA: 3:17 - loss: 0.5118 - triplet_acc: 0.766 - ETA: 3:14 - loss: 0.6285 - triplet_acc: 0.700 - ETA: 3:10 - loss: 0.6088 - triplet_acc: 0.740 - ETA: 3:08 - loss: 0.5073 - triplet_acc: 0.783 - ETA: 3:06 - loss: 0.7289 - triplet_acc: 0.742 - ETA: 3:08 - loss: 0.8978 - triplet_acc: 0.712 - ETA: 3:08 - loss: 0.8446 - triplet_acc: 0.722 - ETA: 3:07 - loss: 0.8172 - triplet_acc: 0.730 - ETA: 3:08 - loss: 0.8262 - triplet_acc: 0.727 - ETA: 3:07 - loss: 0.8213 - triplet_acc: 0.725 - ETA: 3:06 - loss: 0.7841 - triplet_acc: 0.738 - ETA: 3:06 - loss: 0.8324 - triplet_acc: 0.735 - ETA: 3:05 - loss: 0.7769 - triplet_acc: 0.753 - ETA: 3:07 - loss: 0.7690 - triplet_acc: 0.756 - ETA: 3:05 - loss: 0.7727 - triplet_acc: 0.747 - ETA: 3:06 - loss: 0.8078 - triplet_acc: 0.744 - ETA: 3:05 - loss: 0.8118 - triplet_acc: 0.742 - ETA: 3:04 - loss: 0.8003 - triplet_acc: 0.745 - ETA: 3:03 - loss: 0.7822 - triplet_acc: 0.752 - ETA: 3:02 - loss: 0.7466 - triplet_acc: 0.763 - ETA: 3:01 - loss: 0.7673 - triplet_acc: 0.756 - ETA: 3:02 - loss: 0.7487 - triplet_acc: 0.758 - ETA: 3:01 - loss: 0.7297 - triplet_acc: 0.760 - ETA: 3:00 - loss: 0.7522 - triplet_acc: 0.753 - ETA: 3:00 - loss: 0.7413 - triplet_acc: 0.751 - ETA: 2:59 - loss: 0.7304 - triplet_acc: 0.757 - ETA: 2:58 - loss: 0.7158 - triplet_acc: 0.762 - ETA: 2:58 - loss: 0.7581 - triplet_acc: 0.756 - ETA: 2:58 - loss: 0.8137 - triplet_acc: 0.751 - ETA: 2:57 - loss: 0.8590 - triplet_acc: 0.746 - ETA: 2:56 - loss: 0.8558 - triplet_acc: 0.745 - ETA: 2:56 - loss: 0.8560 - triplet_acc: 0.744 - ETA: 2:55 - loss: 0.8488 - triplet_acc: 0.745 - ETA: 2:54 - loss: 0.8252 - triplet_acc: 0.752 - ETA: 2:54 - loss: 0.8425 - triplet_acc: 0.748 - ETA: 2:53 - loss: 0.8247 - triplet_acc: 0.752 - ETA: 2:52 - loss: 0.8035 - triplet_acc: 0.759 - ETA: 2:52 - loss: 0.8054 - triplet_acc: 0.757 - ETA: 2:51 - loss: 0.8233 - triplet_acc: 0.753 - ETA: 2:50 - loss: 0.8186 - triplet_acc: 0.752 - ETA: 2:49 - loss: 0.8202 - triplet_acc: 0.746 - ETA: 2:49 - loss: 0.8321 - triplet_acc: 0.745 - ETA: 2:48 - loss: 0.8616 - triplet_acc: 0.740 - ETA: 2:48 - loss: 0.8439 - triplet_acc: 0.741 - ETA: 2:47 - loss: 0.8266 - triplet_acc: 0.744 - ETA: 2:46 - loss: 0.8279 - triplet_acc: 0.743 - ETA: 2:46 - loss: 0.8168 - triplet_acc: 0.746 - ETA: 2:45 - loss: 0.8005 - triplet_acc: 0.752 - ETA: 2:44 - loss: 0.7848 - triplet_acc: 0.756 - ETA: 2:44 - loss: 0.7772 - triplet_acc: 0.757 - ETA: 2:43 - loss: 0.7661 - triplet_acc: 0.760 - ETA: 2:43 - loss: 0.7796 - triplet_acc: 0.759 - ETA: 2:42 - loss: 0.7655 - triplet_acc: 0.763 - ETA: 2:41 - loss: 0.7586 - triplet_acc: 0.760 - ETA: 2:40 - loss: 0.7558 - triplet_acc: 0.757 - ETA: 2:39 - loss: 0.7555 - triplet_acc: 0.756 - ETA: 2:39 - loss: 0.7427 - triplet_acc: 0.761 - ETA: 2:38 - loss: 0.7316 - triplet_acc: 0.763 - ETA: 2:38 - loss: 0.7447 - triplet_acc: 0.760 - ETA: 2:37 - loss: 0.7346 - triplet_acc: 0.761 - ETA: 2:36 - loss: 0.7302 - triplet_acc: 0.761 - ETA: 2:36 - loss: 0.7203 - triplet_acc: 0.764 - ETA: 2:35 - loss: 0.7139 - triplet_acc: 0.764 - ETA: 2:34 - loss: 0.7044 - triplet_acc: 0.766 - ETA: 2:34 - loss: 0.7051 - triplet_acc: 0.767 - ETA: 2:33 - loss: 0.7107 - triplet_acc: 0.766 - ETA: 2:32 - loss: 0.7083 - triplet_acc: 0.765 - ETA: 2:31 - loss: 0.7008 - triplet_acc: 0.765 - ETA: 2:31 - loss: 0.7011 - triplet_acc: 0.766 - ETA: 2:30 - loss: 0.6958 - triplet_acc: 0.766 - ETA: 2:29 - loss: 0.6863 - triplet_acc: 0.769 - ETA: 2:29 - loss: 0.7265 - triplet_acc: 0.767 - ETA: 2:28 - loss: 0.7232 - triplet_acc: 0.766 - ETA: 2:28 - loss: 0.7313 - triplet_acc: 0.767 - ETA: 2:27 - loss: 0.7329 - triplet_acc: 0.764 - ETA: 2:26 - loss: 0.7255 - triplet_acc: 0.766 - ETA: 2:26 - loss: 0.7183 - triplet_acc: 0.768 - ETA: 2:25 - loss: 0.7103 - triplet_acc: 0.770 - ETA: 2:24 - loss: 0.7078 - triplet_acc: 0.771 - ETA: 2:24 - loss: 0.7134 - triplet_acc: 0.770 - ETA: 2:23 - loss: 0.7 ...
# Beginning epoch number: 7
# Current hard triplet ratio: 0.8058278508619927
# Epoch 1/1
# 170/300 [================>.............] - ETA: 4:11 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:43 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:34 - loss: 0.0793 - triplet_acc: 0.9333    - ETA: 3:32 - loss: 0.1599 - triplet_acc: 0.900 - ETA: 3:31 - loss: 0.1279 - triplet_acc: 0.920 - ETA: 3:27 - loss: 0.1066 - triplet_acc: 0.933 - ETA: 3:23 - loss: 0.2014 - triplet_acc: 0.900 - ETA: 3:21 - loss: 0.2925 - triplet_acc: 0.875 - ETA: 3:19 - loss: 0.3191 - triplet_acc: 0.844 - ETA: 3:19 - loss: 0.4094 - triplet_acc: 0.830 - ETA: 3:18 - loss: 0.5392 - triplet_acc: 0.790 - ETA: 3:17 - loss: 0.5783 - triplet_acc: 0.783 - ETA: 3:16 - loss: 0.6184 - triplet_acc: 0.784 - ETA: 3:15 - loss: 0.5856 - triplet_acc: 0.785 - ETA: 3:15 - loss: 0.6202 - triplet_acc: 0.780 - ETA: 3:14 - loss: 0.5963 - triplet_acc: 0.781 - ETA: 3:13 - loss: 0.5770 - triplet_acc: 0.782 - ETA: 3:12 - loss: 0.5610 - triplet_acc: 0.783 - ETA: 3:10 - loss: 0.5315 - triplet_acc: 0.794 - ETA: 3:10 - loss: 0.5172 - triplet_acc: 0.790 - ETA: 3:09 - loss: 0.5627 - triplet_acc: 0.785 - ETA: 3:08 - loss: 0.5586 - triplet_acc: 0.786 - ETA: 3:07 - loss: 0.5400 - triplet_acc: 0.787 - ETA: 3:06 - loss: 0.5604 - triplet_acc: 0.783 - ETA: 3:05 - loss: 0.5827 - triplet_acc: 0.776 - ETA: 3:04 - loss: 0.6161 - triplet_acc: 0.773 - ETA: 3:04 - loss: 0.6332 - triplet_acc: 0.774 - ETA: 3:03 - loss: 0.6106 - triplet_acc: 0.782 - ETA: 3:02 - loss: 0.5904 - triplet_acc: 0.786 - ETA: 3:01 - loss: 0.5722 - triplet_acc: 0.790 - ETA: 3:01 - loss: 0.5612 - triplet_acc: 0.793 - ETA: 3:00 - loss: 0.5805 - triplet_acc: 0.790 - ETA: 2:59 - loss: 0.5735 - triplet_acc: 0.793 - ETA: 2:59 - loss: 0.5784 - triplet_acc: 0.785 - ETA: 2:58 - loss: 0.5937 - triplet_acc: 0.777 - ETA: 2:58 - loss: 0.5772 - triplet_acc: 0.783 - ETA: 2:58 - loss: 0.6054 - triplet_acc: 0.770 - ETA: 2:57 - loss: 0.5895 - triplet_acc: 0.776 - ETA: 2:56 - loss: 0.5839 - triplet_acc: 0.776 - ETA: 2:56 - loss: 0.6038 - triplet_acc: 0.772 - ETA: 2:55 - loss: 0.5942 - triplet_acc: 0.775 - ETA: 2:54 - loss: 0.6136 - triplet_acc: 0.766 - ETA: 2:53 - loss: 0.6169 - triplet_acc: 0.762 - ETA: 2:53 - loss: 0.6345 - triplet_acc: 0.761 - ETA: 2:52 - loss: 0.6318 - triplet_acc: 0.762 - ETA: 2:52 - loss: 0.6273 - triplet_acc: 0.763 - ETA: 2:51 - loss: 0.6548 - triplet_acc: 0.759 - ETA: 2:51 - loss: 0.6676 - triplet_acc: 0.758 - ETA: 2:50 - loss: 0.6586 - triplet_acc: 0.759 - ETA: 2:50 - loss: 0.6516 - triplet_acc: 0.760 - ETA: 2:49 - loss: 0.6480 - triplet_acc: 0.758 - ETA: 2:48 - loss: 0.6363 - triplet_acc: 0.761 - ETA: 2:47 - loss: 0.6315 - triplet_acc: 0.760 - ETA: 2:47 - loss: 0.6242 - triplet_acc: 0.763 - ETA: 2:47 - loss: 0.6312 - triplet_acc: 0.763 - ETA: 2:46 - loss: 0.6505 - triplet_acc: 0.760 - ETA: 2:45 - loss: 0.6420 - triplet_acc: 0.763 - ETA: 2:44 - loss: 0.6425 - triplet_acc: 0.760 - ETA: 2:43 - loss: 0.6486 - triplet_acc: 0.761 - ETA: 2:43 - loss: 0.6487 - triplet_acc: 0.763 - ETA: 2:42 - loss: 0.6543 - triplet_acc: 0.762 - ETA: 2:41 - loss: 0.6468 - triplet_acc: 0.764 - ETA: 2:40 - loss: 0.6510 - triplet_acc: 0.761 - ETA: 2:40 - loss: 0.6427 - triplet_acc: 0.764 - ETA: 2:39 - loss: 0.6340 - triplet_acc: 0.766 - ETA: 2:38 - loss: 0.6328 - triplet_acc: 0.766 - ETA: 2:37 - loss: 0.6497 - triplet_acc: 0.765 - ETA: 2:36 - loss: 0.6681 - triplet_acc: 0.763 - ETA: 2:36 - loss: 0.6621 - triplet_acc: 0.763 - ETA: 2:35 - loss: 0.6658 - triplet_acc: 0.761 - ETA: 2:34 - loss: 0.6564 - triplet_acc: 0.764 - ETA: 2:33 - loss: 0.6513 - triplet_acc: 0.765 - ETA: 2:33 - loss: 0.6753 - triplet_acc: 0.760 - ETA: 2:32 - loss: 0.6693 - triplet_acc: 0.759 - ETA: 2:31 - loss: 0.6678 - triplet_acc: 0.757 - ETA: 2:31 - loss: 0.6590 - triplet_acc: 0.760 - ETA: 2:30 - loss: 0.6676 - triplet_acc: 0.757 - ETA: 2:30 - loss: 0.6779 - triplet_acc: 0.756 - ETA: 2:29 - loss: 0.6781 - triplet_acc: 0.757 - ETA: 2:28 - loss: 0.6792 - triplet_acc: 0.756 - ETA: 2:27 - loss: 0.6791 - triplet_acc: 0.755 - ETA: 2:27 - loss: 0.6711 - triplet_acc: 0.757 - ETA: 2:26 ...
# 300/300 [==============================] - ETA: 1:26 - loss: 0.6923 - triplet_acc: 0.758 - ETA: 1:25 - loss: 0.6883 - triplet_acc: 0.759 - ETA: 1:25 - loss: 0.6868 - triplet_acc: 0.759 - ETA: 1:24 - loss: 0.6856 - triplet_acc: 0.759 - ETA: 1:23 - loss: 0.6821 - triplet_acc: 0.760 - ETA: 1:23 - loss: 0.6925 - triplet_acc: 0.758 - ETA: 1:22 - loss: 0.6912 - triplet_acc: 0.758 - ETA: 1:21 - loss: 0.6935 - triplet_acc: 0.757 - ETA: 1:21 - loss: 0.6948 - triplet_acc: 0.758 - ETA: 1:20 - loss: 0.6913 - triplet_acc: 0.758 - ETA: 1:19 - loss: 0.6886 - triplet_acc: 0.759 - ETA: 1:19 - loss: 0.6865 - triplet_acc: 0.760 - ETA: 1:18 - loss: 0.6842 - triplet_acc: 0.761 - ETA: 1:17 - loss: 0.6811 - triplet_acc: 0.762 - ETA: 1:17 - loss: 0.6800 - triplet_acc: 0.762 - ETA: 1:16 - loss: 0.6801 - triplet_acc: 0.761 - ETA: 1:15 - loss: 0.6849 - triplet_acc: 0.761 - ETA: 1:15 - loss: 0.6813 - triplet_acc: 0.762 - ETA: 1:14 - loss: 0.6793 - triplet_acc: 0.763 - ETA: 1:13 - loss: 0.6837 - triplet_acc: 0.761 - ETA: 1:12 - loss: 0.6853 - triplet_acc: 0.761 - ETA: 1:12 - loss: 0.6871 - triplet_acc: 0.760 - ETA: 1:11 - loss: 0.6954 - triplet_acc: 0.761 - ETA: 1:10 - loss: 0.6918 - triplet_acc: 0.762 - ETA: 1:10 - loss: 0.6944 - triplet_acc: 0.762 - ETA: 1:09 - loss: 0.6909 - triplet_acc: 0.763 - ETA: 1:08 - loss: 0.6876 - triplet_acc: 0.764 - ETA: 1:08 - loss: 0.7058 - triplet_acc: 0.761 - ETA: 1:07 - loss: 0.7063 - triplet_acc: 0.761 - ETA: 1:06 - loss: 0.7071 - triplet_acc: 0.760 - ETA: 1:06 - loss: 0.7036 - triplet_acc: 0.761 - ETA: 1:05 - loss: 0.7073 - triplet_acc: 0.760 - ETA: 1:04 - loss: 0.7048 - triplet_acc: 0.761 - ETA: 1:04 - loss: 0.7039 - triplet_acc: 0.761 - ETA: 1:03 - loss: 0.7021 - triplet_acc: 0.761 - ETA: 1:02 - loss: 0.6997 - triplet_acc: 0.762 - ETA: 1:02 - loss: 0.6963 - triplet_acc: 0.763 - ETA: 1:01 - loss: 0.6953 - triplet_acc: 0.763 - ETA: 1:00 - loss: 0.6923 - triplet_acc: 0.764 - ETA: 1:00 - loss: 0.6920 - triplet_acc: 0.764 - ETA: 59s - loss: 0.6950 - triplet_acc: 0.764 - ETA: 58s - loss: 0.6978 - triplet_acc: 0.76 - ETA: 58s - loss: 0.6946 - triplet_acc: 0.76 - ETA: 57s - loss: 0.6913 - triplet_acc: 0.76 - ETA: 56s - loss: 0.6990 - triplet_acc: 0.76 - ETA: 56s - loss: 0.6971 - triplet_acc: 0.76 - ETA: 55s - loss: 0.6951 - triplet_acc: 0.76 - ETA: 54s - loss: 0.6946 - triplet_acc: 0.76 - ETA: 54s - loss: 0.6974 - triplet_acc: 0.76 - ETA: 53s - loss: 0.6945 - triplet_acc: 0.76 - ETA: 52s - loss: 0.6955 - triplet_acc: 0.76 - ETA: 52s - loss: 0.6941 - triplet_acc: 0.76 - ETA: 51s - loss: 0.7001 - triplet_acc: 0.76 - ETA: 50s - loss: 0.6988 - triplet_acc: 0.76 - ETA: 50s - loss: 0.6985 - triplet_acc: 0.76 - ETA: 49s - loss: 0.6994 - triplet_acc: 0.76 - ETA: 48s - loss: 0.6993 - triplet_acc: 0.76 - ETA: 48s - loss: 0.6993 - triplet_acc: 0.76 - ETA: 47s - loss: 0.7064 - triplet_acc: 0.76 - ETA: 46s - loss: 0.7066 - triplet_acc: 0.76 - ETA: 46s - loss: 0.7122 - triplet_acc: 0.76 - ETA: 45s - loss: 0.7108 - triplet_acc: 0.76 - ETA: 44s - loss: 0.7077 - triplet_acc: 0.76 - ETA: 44s - loss: 0.7094 - triplet_acc: 0.76 - ETA: 43s - loss: 0.7101 - triplet_acc: 0.76 - ETA: 42s - loss: 0.7080 - triplet_acc: 0.76 - ETA: 42s - loss: 0.7059 - triplet_acc: 0.76 - ETA: 41s - loss: 0.7073 - triplet_acc: 0.76 - ETA: 40s - loss: 0.7047 - triplet_acc: 0.76 - ETA: 40s - loss: 0.7020 - triplet_acc: 0.76 - ETA: 39s - loss: 0.7008 - triplet_acc: 0.76 - ETA: 38s - loss: 0.7014 - triplet_acc: 0.76 - ETA: 38s - loss: 0.6992 - triplet_acc: 0.76 - ETA: 37s - loss: 0.6982 - triplet_acc: 0.76 - ETA: 36s - loss: 0.6969 - triplet_acc: 0.76 - ETA: 36s - loss: 0.6952 - triplet_acc: 0.76 - ETA: 35s - loss: 0.6932 - triplet_acc: 0.76 - ETA: 34s - loss: 0.6906 - triplet_acc: 0.76 - ETA: 34s - loss: 0.6899 - triplet_acc: 0.76 - ETA: 33s - loss: 0.6885 - triplet_acc: 0.76 - ETA: 32s - loss: 0.6909 - triplet_acc: 0.76 - ETA: 32s - loss: 0.6898 - triplet_acc: 0.76 - ETA: 31s - loss: 0.6897 - triplet_acc: 0.76 - ETA: 30s - loss: 0.6881 - triplet_acc: 0.76 - ETA: 30s - l ...
# Beginning epoch number: 8
# Current hard triplet ratio: 0.7906700068557135
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:48 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:29 - loss: 0.0343 - triplet_acc: 0.9500    - ETA: 3:25 - loss: 0.7263 - triplet_acc: 0.800 - ETA: 3:25 - loss: 0.6013 - triplet_acc: 0.800 - ETA: 3:22 - loss: 0.6322 - triplet_acc: 0.760 - ETA: 3:19 - loss: 0.6626 - triplet_acc: 0.750 - ETA: 3:18 - loss: 0.6442 - triplet_acc: 0.742 - ETA: 3:15 - loss: 0.5667 - triplet_acc: 0.762 - ETA: 3:16 - loss: 0.5981 - triplet_acc: 0.777 - ETA: 3:14 - loss: 0.7497 - triplet_acc: 0.760 - ETA: 3:13 - loss: 0.6815 - triplet_acc: 0.781 - ETA: 3:12 - loss: 0.6248 - triplet_acc: 0.800 - ETA: 3:12 - loss: 0.6371 - triplet_acc: 0.792 - ETA: 3:11 - loss: 0.6047 - triplet_acc: 0.800 - ETA: 3:11 - loss: 0.5908 - triplet_acc: 0.800 - ETA: 3:09 - loss: 0.5978 - triplet_acc: 0.806 - ETA: 3:08 - loss: 0.6228 - triplet_acc: 0.800 - ETA: 3:07 - loss: 0.6289 - triplet_acc: 0.805 - ETA: 3:05 - loss: 0.5989 - triplet_acc: 0.810 - ETA: 3:04 - loss: 0.6176 - triplet_acc: 0.805 - ETA: 3:03 - loss: 0.5882 - triplet_acc: 0.814 - ETA: 3:02 - loss: 0.6243 - triplet_acc: 0.804 - ETA: 3:02 - loss: 0.7106 - triplet_acc: 0.795 - ETA: 3:01 - loss: 0.6951 - triplet_acc: 0.800 - ETA: 3:01 - loss: 0.6776 - triplet_acc: 0.804 - ETA: 3:00 - loss: 0.6541 - triplet_acc: 0.807 - ETA: 3:00 - loss: 0.6380 - triplet_acc: 0.811 - ETA: 3:00 - loss: 0.7043 - triplet_acc: 0.803 - ETA: 3:00 - loss: 0.6829 - triplet_acc: 0.806 - ETA: 2:59 - loss: 0.6648 - triplet_acc: 0.810 - ETA: 2:58 - loss: 0.6739 - triplet_acc: 0.806 - ETA: 2:58 - loss: 0.6528 - triplet_acc: 0.812 - ETA: 2:57 - loss: 0.6347 - triplet_acc: 0.815 - ETA: 2:56 - loss: 0.6345 - triplet_acc: 0.811 - ETA: 2:55 - loss: 0.6163 - triplet_acc: 0.817 - ETA: 2:55 - loss: 0.6132 - triplet_acc: 0.816 - ETA: 2:54 - loss: 0.6185 - triplet_acc: 0.810 - ETA: 2:53 - loss: 0.6377 - triplet_acc: 0.807 - ETA: 2:53 - loss: 0.6283 - triplet_acc: 0.810 - ETA: 2:52 - loss: 0.6234 - triplet_acc: 0.810 - ETA: 2:51 - loss: 0.6215 - triplet_acc: 0.807 - ETA: 2:51 - loss: 0.6067 - triplet_acc: 0.811 - ETA: 2:50 - loss: 0.5966 - triplet_acc: 0.814 - ETA: 2:49 - loss: 0.6013 - triplet_acc: 0.811 - ETA: 2:49 - loss: 0.6172 - triplet_acc: 0.806 - ETA: 2:49 - loss: 0.6230 - triplet_acc: 0.804 - ETA: 2:48 - loss: 0.6148 - triplet_acc: 0.804 - ETA: 2:47 - loss: 0.6099 - triplet_acc: 0.804 - ETA: 2:46 - loss: 0.6223 - triplet_acc: 0.800 - ETA: 2:45 - loss: 0.6098 - triplet_acc: 0.804 - ETA: 2:45 - loss: 0.6360 - triplet_acc: 0.800 - ETA: 2:44 - loss: 0.6308 - triplet_acc: 0.801 - ETA: 2:44 - loss: 0.6323 - triplet_acc: 0.801 - ETA: 2:43 - loss: 0.6257 - triplet_acc: 0.803 - ETA: 2:42 - loss: 0.6275 - triplet_acc: 0.800 - ETA: 2:42 - loss: 0.6472 - triplet_acc: 0.798 - ETA: 2:41 - loss: 0.6441 - triplet_acc: 0.794 - ETA: 2:40 - loss: 0.6521 - triplet_acc: 0.794 - ETA: 2:40 - loss: 0.6525 - triplet_acc: 0.794 - ETA: 2:39 - loss: 0.6467 - triplet_acc: 0.791 - ETA: 2:38 - loss: 0.6361 - triplet_acc: 0.795 - ETA: 2:37 - loss: 0.6385 - triplet_acc: 0.795 - ETA: 2:37 - loss: 0.6283 - triplet_acc: 0.798 - ETA: 2:36 - loss: 0.6350 - triplet_acc: 0.795 - ETA: 2:35 - loss: 0.6376 - triplet_acc: 0.790 - ETA: 2:35 - loss: 0.6279 - triplet_acc: 0.793 - ETA: 2:34 - loss: 0.6300 - triplet_acc: 0.791 - ETA: 2:33 - loss: 0.6270 - triplet_acc: 0.791 - ETA: 2:33 - loss: 0.6297 - triplet_acc: 0.789 - ETA: 2:32 - loss: 0.6258 - triplet_acc: 0.788 - ETA: 2:31 - loss: 0.6204 - triplet_acc: 0.790 - ETA: 2:31 - loss: 0.6145 - triplet_acc: 0.791 - ETA: 2:30 - loss: 0.6170 - triplet_acc: 0.790 - ETA: 2:29 - loss: 0.6160 - triplet_acc: 0.789 - ETA: 2:29 - loss: 0.6085 - triplet_acc: 0.790 - ETA: 2:28 - loss: 0.6022 - triplet_acc: 0.792 - ETA: 2:27 - loss: 0.5944 - triplet_acc: 0.794 - ETA: 2:27 - loss: 0.5941 - triplet_acc: 0.794 - ETA: 2:26 - loss: 0.5966 - triplet_acc: 0.794 - ETA: 2:25 - loss: 0.5923 - triplet_acc: 0.796 - ETA: 2:25 - loss: 0.5879 - triplet_acc: 0.796 - ETA: 2:24 - loss: 0.5815 - triplet_acc: 0.797 - ETA: 2:23 - l ...
# Beginning epoch number: 9
# Current hard triplet ratio: 0.8170991589041698
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:42 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:27 - loss: 0.3672 - triplet_acc: 0.9500    - ETA: 3:38 - loss: 1.1441 - triplet_acc: 0.833 - ETA: 3:28 - loss: 1.1248 - triplet_acc: 0.775 - ETA: 3:22 - loss: 0.9563 - triplet_acc: 0.780 - ETA: 3:20 - loss: 0.8448 - triplet_acc: 0.800 - ETA: 3:20 - loss: 0.8653 - triplet_acc: 0.800 - ETA: 3:21 - loss: 0.8144 - triplet_acc: 0.800 - ETA: 3:19 - loss: 0.7801 - triplet_acc: 0.800 - ETA: 3:17 - loss: 0.7690 - triplet_acc: 0.810 - ETA: 3:16 - loss: 0.8335 - triplet_acc: 0.800 - ETA: 3:16 - loss: 0.8190 - triplet_acc: 0.800 - ETA: 3:14 - loss: 0.8213 - triplet_acc: 0.800 - ETA: 3:13 - loss: 0.7976 - triplet_acc: 0.800 - ETA: 3:12 - loss: 0.7648 - triplet_acc: 0.806 - ETA: 3:11 - loss: 0.7364 - triplet_acc: 0.800 - ETA: 3:10 - loss: 0.7625 - triplet_acc: 0.800 - ETA: 3:09 - loss: 0.7876 - triplet_acc: 0.788 - ETA: 3:07 - loss: 0.7543 - triplet_acc: 0.794 - ETA: 3:07 - loss: 0.8355 - triplet_acc: 0.780 - ETA: 3:07 - loss: 0.8110 - triplet_acc: 0.785 - ETA: 3:05 - loss: 0.8340 - triplet_acc: 0.781 - ETA: 3:04 - loss: 0.7977 - triplet_acc: 0.791 - ETA: 3:03 - loss: 0.8051 - triplet_acc: 0.783 - ETA: 3:03 - loss: 0.8047 - triplet_acc: 0.784 - ETA: 3:02 - loss: 0.7738 - triplet_acc: 0.792 - ETA: 3:02 - loss: 0.7786 - triplet_acc: 0.788 - ETA: 3:02 - loss: 0.7508 - triplet_acc: 0.796 - ETA: 3:01 - loss: 0.7955 - triplet_acc: 0.786 - ETA: 3:00 - loss: 0.7869 - triplet_acc: 0.786 - ETA: 3:00 - loss: 0.8454 - triplet_acc: 0.780 - ETA: 2:59 - loss: 0.8759 - triplet_acc: 0.771 - ETA: 2:59 - loss: 0.8545 - triplet_acc: 0.769 - ETA: 2:58 - loss: 0.8294 - triplet_acc: 0.776 - ETA: 2:58 - loss: 0.8154 - triplet_acc: 0.780 - ETA: 2:56 - loss: 0.7927 - triplet_acc: 0.786 - ETA: 2:55 - loss: 0.7743 - triplet_acc: 0.786 - ETA: 2:54 - loss: 0.7879 - triplet_acc: 0.786 - ETA: 2:54 - loss: 0.7746 - triplet_acc: 0.782 - ETA: 2:53 - loss: 0.7793 - triplet_acc: 0.780 - ETA: 2:53 - loss: 0.7613 - triplet_acc: 0.782 - ETA: 2:52 - loss: 0.7432 - triplet_acc: 0.785 - ETA: 2:52 - loss: 0.7571 - triplet_acc: 0.781 - ETA: 2:51 - loss: 0.7448 - triplet_acc: 0.784 - ETA: 2:51 - loss: 0.7558 - triplet_acc: 0.784 - ETA: 2:50 - loss: 0.7394 - triplet_acc: 0.789 - ETA: 2:49 - loss: 0.7301 - triplet_acc: 0.791 - ETA: 2:49 - loss: 0.7252 - triplet_acc: 0.793 - ETA: 2:48 - loss: 0.7214 - triplet_acc: 0.795 - ETA: 2:47 - loss: 0.7284 - triplet_acc: 0.796 - ETA: 2:47 - loss: 0.7178 - triplet_acc: 0.794 - ETA: 2:46 - loss: 0.7124 - triplet_acc: 0.792 - ETA: 2:45 - loss: 0.7154 - triplet_acc: 0.792 - ETA: 2:45 - loss: 0.7242 - triplet_acc: 0.790 - ETA: 2:44 - loss: 0.7296 - triplet_acc: 0.789 - ETA: 2:43 - loss: 0.7277 - triplet_acc: 0.787 - ETA: 2:43 - loss: 0.7150 - triplet_acc: 0.791 - ETA: 2:42 - loss: 0.7027 - triplet_acc: 0.794 - ETA: 2:41 - loss: 0.6978 - triplet_acc: 0.796 - ETA: 2:40 - loss: 0.6918 - triplet_acc: 0.796 - ETA: 2:40 - loss: 0.6839 - triplet_acc: 0.798 - ETA: 2:39 - loss: 0.6729 - triplet_acc: 0.801 - ETA: 2:39 - loss: 0.6871 - triplet_acc: 0.796 - ETA: 2:38 - loss: 0.7092 - triplet_acc: 0.792 - ETA: 2:38 - loss: 0.7160 - triplet_acc: 0.792 - ETA: 2:37 - loss: 0.7067 - triplet_acc: 0.793 - ETA: 2:37 - loss: 0.6986 - triplet_acc: 0.794 - ETA: 2:36 - loss: 0.7038 - triplet_acc: 0.791 - ETA: 2:36 - loss: 0.6975 - triplet_acc: 0.791 - ETA: 2:35 - loss: 0.7175 - triplet_acc: 0.787 - ETA: 2:34 - loss: 0.7198 - triplet_acc: 0.785 - ETA: 2:33 - loss: 0.7124 - triplet_acc: 0.786 - ETA: 2:33 - loss: 0.7040 - triplet_acc: 0.787 - ETA: 2:32 - loss: 0.7082 - triplet_acc: 0.786 - ETA: 2:31 - loss: 0.7139 - triplet_acc: 0.782 - ETA: 2:30 - loss: 0.7217 - triplet_acc: 0.780 - ETA: 2:30 - loss: 0.7171 - triplet_acc: 0.780 - ETA: 2:29 - loss: 0.7105 - triplet_acc: 0.782 - ETA: 2:29 - loss: 0.7119 - triplet_acc: 0.779 - ETA: 2:28 - loss: 0.7208 - triplet_acc: 0.777 - ETA: 2:27 - loss: 0.7119 - triplet_acc: 0.780 - ETA: 2:26 - loss: 0.7170 - triplet_acc: 0.778 - ETA: 2:25 - l ...
# 300/300 [==============================] - ETA: 1:26 - loss: 0.7401 - triplet_acc: 0.770 - ETA: 1:25 - loss: 0.7381 - triplet_acc: 0.771 - ETA: 1:25 - loss: 0.7397 - triplet_acc: 0.769 - ETA: 1:24 - loss: 0.7395 - triplet_acc: 0.769 - ETA: 1:23 - loss: 0.7367 - triplet_acc: 0.769 - ETA: 1:23 - loss: 0.7410 - triplet_acc: 0.768 - ETA: 1:22 - loss: 0.7395 - triplet_acc: 0.768 - ETA: 1:21 - loss: 0.7379 - triplet_acc: 0.769 - ETA: 1:21 - loss: 0.7337 - triplet_acc: 0.770 - ETA: 1:20 - loss: 0.7299 - triplet_acc: 0.771 - ETA: 1:19 - loss: 0.7324 - triplet_acc: 0.771 - ETA: 1:19 - loss: 0.7379 - triplet_acc: 0.770 - ETA: 1:18 - loss: 0.7406 - triplet_acc: 0.769 - ETA: 1:17 - loss: 0.7385 - triplet_acc: 0.770 - ETA: 1:17 - loss: 0.7346 - triplet_acc: 0.771 - ETA: 1:16 - loss: 0.7395 - triplet_acc: 0.769 - ETA: 1:15 - loss: 0.7392 - triplet_acc: 0.769 - ETA: 1:15 - loss: 0.7364 - triplet_acc: 0.769 - ETA: 1:14 - loss: 0.7325 - triplet_acc: 0.770 - ETA: 1:13 - loss: 0.7332 - triplet_acc: 0.770 - ETA: 1:13 - loss: 0.7309 - triplet_acc: 0.771 - ETA: 1:12 - loss: 0.7274 - triplet_acc: 0.771 - ETA: 1:11 - loss: 0.7237 - triplet_acc: 0.773 - ETA: 1:11 - loss: 0.7202 - triplet_acc: 0.773 - ETA: 1:10 - loss: 0.7196 - triplet_acc: 0.773 - ETA: 1:09 - loss: 0.7226 - triplet_acc: 0.771 - ETA: 1:09 - loss: 0.7205 - triplet_acc: 0.772 - ETA: 1:08 - loss: 0.7217 - triplet_acc: 0.773 - ETA: 1:07 - loss: 0.7199 - triplet_acc: 0.773 - ETA: 1:07 - loss: 0.7163 - triplet_acc: 0.775 - ETA: 1:06 - loss: 0.7138 - triplet_acc: 0.775 - ETA: 1:05 - loss: 0.7126 - triplet_acc: 0.775 - ETA: 1:05 - loss: 0.7143 - triplet_acc: 0.774 - ETA: 1:04 - loss: 0.7108 - triplet_acc: 0.775 - ETA: 1:03 - loss: 0.7112 - triplet_acc: 0.775 - ETA: 1:03 - loss: 0.7077 - triplet_acc: 0.776 - ETA: 1:02 - loss: 0.7043 - triplet_acc: 0.777 - ETA: 1:01 - loss: 0.7022 - triplet_acc: 0.777 - ETA: 1:01 - loss: 0.7020 - triplet_acc: 0.776 - ETA: 1:00 - loss: 0.7059 - triplet_acc: 0.775 - ETA: 59s - loss: 0.7032 - triplet_acc: 0.775 - ETA: 59s - loss: 0.7064 - triplet_acc: 0.77 - ETA: 58s - loss: 0.7032 - triplet_acc: 0.77 - ETA: 57s - loss: 0.7066 - triplet_acc: 0.77 - ETA: 56s - loss: 0.7077 - triplet_acc: 0.77 - ETA: 56s - loss: 0.7123 - triplet_acc: 0.77 - ETA: 55s - loss: 0.7096 - triplet_acc: 0.77 - ETA: 55s - loss: 0.7108 - triplet_acc: 0.77 - ETA: 54s - loss: 0.7076 - triplet_acc: 0.77 - ETA: 53s - loss: 0.7090 - triplet_acc: 0.77 - ETA: 53s - loss: 0.7058 - triplet_acc: 0.77 - ETA: 52s - loss: 0.7057 - triplet_acc: 0.77 - ETA: 51s - loss: 0.7032 - triplet_acc: 0.77 - ETA: 51s - loss: 0.7007 - triplet_acc: 0.77 - ETA: 50s - loss: 0.7023 - triplet_acc: 0.77 - ETA: 49s - loss: 0.7025 - triplet_acc: 0.77 - ETA: 48s - loss: 0.7058 - triplet_acc: 0.77 - ETA: 48s - loss: 0.7059 - triplet_acc: 0.77 - ETA: 47s - loss: 0.7057 - triplet_acc: 0.77 - ETA: 46s - loss: 0.7068 - triplet_acc: 0.77 - ETA: 46s - loss: 0.7168 - triplet_acc: 0.77 - ETA: 45s - loss: 0.7183 - triplet_acc: 0.77 - ETA: 44s - loss: 0.7173 - triplet_acc: 0.77 - ETA: 44s - loss: 0.7172 - triplet_acc: 0.77 - ETA: 43s - loss: 0.7161 - triplet_acc: 0.77 - ETA: 42s - loss: 0.7240 - triplet_acc: 0.76 - ETA: 42s - loss: 0.7236 - triplet_acc: 0.76 - ETA: 41s - loss: 0.7211 - triplet_acc: 0.77 - ETA: 40s - loss: 0.7258 - triplet_acc: 0.76 - ETA: 40s - loss: 0.7228 - triplet_acc: 0.76 - ETA: 39s - loss: 0.7198 - triplet_acc: 0.77 - ETA: 38s - loss: 0.7229 - triplet_acc: 0.76 - ETA: 38s - loss: 0.7225 - triplet_acc: 0.76 - ETA: 37s - loss: 0.7201 - triplet_acc: 0.76 - ETA: 36s - loss: 0.7232 - triplet_acc: 0.76 - ETA: 36s - loss: 0.7204 - triplet_acc: 0.76 - ETA: 35s - loss: 0.7230 - triplet_acc: 0.76 - ETA: 34s - loss: 0.7218 - triplet_acc: 0.76 - ETA: 34s - loss: 0.7202 - triplet_acc: 0.76 - ETA: 33s - loss: 0.7189 - triplet_acc: 0.76 - ETA: 32s - loss: 0.7167 - triplet_acc: 0.76 - ETA: 32s - loss: 0.7146 - triplet_acc: 0.76 - ETA: 31s - loss: 0.7122 - triplet_acc: 0.76 - ETA: 30s - loss: 0.7094 - triplet_acc: 0.77 - ETA: 30s - l ...
# Beginning epoch number: 10
# Current hard triplet ratio: 0.7904149766403304
# Epoch 1/1
#  11/300 [>.............................] - ETA: 3:33 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:26 - loss: 0.0702 - triplet_acc: 0.9500    - ETA: 3:20 - loss: 0.1440 - triplet_acc: 0.900 - ETA: 3:17 - loss: 0.2840 - triplet_acc: 0.875 - ETA: 3:18 - loss: 0.2744 - triplet_acc: 0.860 - ETA: 3:17 - loss: 0.3603 - triplet_acc: 0.833 - ETA: 3:18 - loss: 0.7990 - triplet_acc: 0.785 - ETA: 3:18 - loss: 0.8422 - triplet_acc: 0.762 - ETA: 3:17 - loss: 0.7495 - triplet_acc: 0.777 - ETA: 3:17 - loss: 0.7898 - triplet_acc: 0.750 - ETA: 3:16 - loss: 0.8348 - triplet_acc: 0.7364

# %%
from IPython.display import clear_output

for i in range(10):
    clear_output()
    print("Hello World!")

# %%
tot_loss = 0
mean_loss = 0

tot_acc = 0
mean_acc = 0

epoch = 1
max_epoch = 10
step = 1
max_step = 30
batch_size = 3*10

for images_batch,labels_batch in image_generator(filenames_test,labels_test,batch_size,use_aug=False):
    h = model.test_on_batch(images_batch,labels_batch)
    
    tot_loss += h[0]
    mean_loss = tot_loss/step
    tot_acc += h[1]
    mean_acc = tot_acc/step



    if step == max_step:
        break
    step+=1

print(
    "Test loss: " + str(mean_loss) + 
    ", test acc: " + str(mean_acc)
)
# Out:
# Test loss: 0.3988494137922923, test acc: 0.8899999936421712

# %%
# Training: Lowest level implementation

start_epoch = 43

max_epoch = 1000 + start_epoch

max_step = 300
max_step_test = 30
batch_size = 3*10


tot_loss_test = 0
mean_loss_test = 0

tot_acc_test = 0
mean_acc_test = 0

# Save
loss = []
val_loss = []
acc = []
val_acc = []

for epoch in range(start_epoch,max_epoch):
    
    step = 1
    
    tot_loss = 0
    mean_loss = 0

    tot_acc = 0
    mean_acc = 0
    
    # Training
    for images_batch,labels_batch in online_adaptive_hard_image_generator(
        filenames_train,
        labels_train,
        model,
        mean_acc,
        batch_size
    ):


        h = model.train_on_batch(images_batch,labels_batch)
        tot_loss += h[0]
        mean_loss = tot_loss/step
        tot_acc += h[1]
        mean_acc = tot_acc/step
        clear_output()

        #hard_triplet_ratio = np.exp(-mean_loss * 10 / batch_size)
        #hard_triplet_ratio = max(0,np.exp(mean_acc-0.3)-1)
        hard_triplet_ratio = max(0,1.2/(1+np.exp(-10*mean_acc+5.3))-0.19)
        print(
            "Epoch: " + str(epoch) + "/" + str(max_epoch) +
            ", step: " + str(step) + "/" + str(max_step) + 
            ", loss: " + str(mean_loss) + 
            ", acc: " + str(mean_acc) +
            ", hard_ratio: " + str(hard_triplet_ratio)
        )
        print(
            "Test loss: " + str(mean_loss_test) + 
            ", test acc: " + str(mean_acc_test)
        )

        if step == max_step:
            break
        step+=1
    
    loss += [mean_loss]
    acc += [mean_acc]
    
    # Testing
    step = 1
    
    tot_loss_test = 0
    mean_loss_test = 0

    tot_acc_test = 0
    mean_acc_test = 0
    
    for images_batch,labels_batch in image_generator(filenames_test,labels_test,batch_size,use_aug=False):
        h = model.test_on_batch(images_batch,labels_batch)

        tot_loss_test += h[0]
        mean_loss_test = tot_loss_test/step
        tot_acc_test += h[1]
        mean_acc_test = tot_acc_test/step

        if step == max_step_test:
            break
        step+=1
    
    val_loss += [mean_loss_test]
    val_acc += [mean_acc_test]
    
    # Save
    model.save(PATH_MODEL + '2019.05.05.dogfacenet_v25.'+str(epoch)+'.h5')
    history_ = np.array([loss,val_loss,acc,val_acc])
    np.save(PATH_SAVE+'2019.05.05.dogfacenet_v25.'+str(epoch)+'.h5',history_)
#     np.savetxt(PATH_SAVE+'2019.04.29.dogfacenet_v12.'+str(epoch)+'.h5.txt',history_)
# Out:
# Epoch: 60/1043, step: 3/300, loss: 1.0217269659042358, acc: 0.8888888955116272, hard_ratio: 0.9777365934595517
# Test loss: 0.4846224496761958, test acc: 0.8266666601101558
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-c4bf940e120d> in <module>()
#      38         model,
#      39         mean_acc,
# ---> 40         batch_size
#      41     ):
#      42
#
# <ipython-input-16-73f670d5d28c> in online_adaptive_hard_image_generator(filenames, labels, model, acc, use_aug, batch_size, nbof_subclasses, datagen)
#      66         i_triplet = load_images(f_triplet)
#      67         if use_aug:
# ---> 68             i_triplet = apply_transform(i_triplet, datagen)
#      69
#      70         # Modif for michael loss
#
# D:\PROGRAMMATION\Python\DogFaceNet\dogfacenet\triplets_processing.py in apply_transform(images, datagen)
#      45         -images of the same shape of the inputs but transformed
#      46     """
# ---> 47     for x in datagen.flow(images, batch_size=len(images), shuffle=False):
#      48         return x
#      49
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in __next__(self, *args, **kwargs)
#      98
#      99     def __next__(self, *args, **kwargs):
# --> 100         return self.next(*args, **kwargs)
#     101
#     102     def next(self):
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in next(self)
#     110         # The transformation of images is not under thread lock
#     111         # so it can be done in parallel
# --> 112         return self._get_batches_of_transformed_samples(index_array)
#     113
#     114     def _get_batches_of_transformed_samples(self, index_array):
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\numpy_array_iterator.py in _get_batches_of_transformed_samples(self, index_array)
#     151             params = self.image_data_generator.get_random_transform(x.shape)
#     152             x = self.image_data_generator.apply_transform(
# --> 153                 x.astype(self.dtype), params)
#     154             x = self.image_data_generator.standardize(x)
#     155             batch_x[i] = x
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py in apply_transform(self, x, transform_parameters)
#     851                                    fill_mode=self.fill_mode,
#     852                                    cval=self.cval,
# --> 853                                    order=self.interpolation_order)
#     854
#     855         if transform_parameters.get('channel_shift_intensity') is not None:
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\affine_transformations.py in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#     328             order=order,
#     329             mode=fill_mode,
# --> 330             cval=cval) for x_channel in x]
#     331         x = np.stack(channel_images, axis=0)
#     332         x = np.rollaxis(x, 0, channel_axis + 1)
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image\affine_transformations.py in <listcomp>(.0)
#     328             order=order,
#     329             mode=fill_mode,
# --> 330             cval=cval) for x_channel in x]
#     331         x = np.stack(channel_images, axis=0)
#     332         x = np.rollaxis(x, 0, channel_axis + 1)
#
# ~\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     478     else:
#     479         _nd_image.geometric_transform(filtered, None, None, matrix, offset,
# --> 480                                       output, order, mode, cval, None, None)
#     481     return output
#     482
#
# KeyboardInterrupt:

# %%
# With online hard triplet generation
crt_loss = 0.95
batch_size = 3*10
# start = 92
for i in range(1000):
    print("Beginning epoch number: "+str(i))

    hard_triplet_ratio = np.exp(-crt_loss * 10 / batch_size)
    nbof_hard_triplets = int(batch_size//3 * hard_triplet_ratio)
    
    print("Current hard triplet ratio: " + str(hard_triplet_ratio))
    
    histories += [model.fit_generator(
        online_adaptive_hard_image_generator(filenames_train,labels_train,model,crt_loss,batch_size),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,batch_size,use_aug=False),
        validation_steps=30
#         verbose=0,
#         callbacks=[TQDMNotebookCallback()]
    )]
    
    crt_loss = histories[-1].history['loss'][0]
    
    model.save(PATH_MODEL + '2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5')
    
    loss = np.empty(0)
    val_loss = np.empty(0)
    acc = np.empty(0)
    val_acc = np.empty(0)

    for history in histories:
        loss = np.append(loss,history.history['loss'])
        val_loss = np.append(val_loss,history.history['val_loss'])
        acc = np.append(acc,history.history['triplet_acc'])
        val_acc = np.append(val_acc,history.history['val_triplet_acc'])


    history_ = np.array([loss,val_loss,acc,val_acc])
    np.save(PATH_SAVE+'2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5',history_)
    np.savetxt(PATH_SAVE+'2019.04.22.dogfacenet_v26.'+str(i+start+1)+'.h5',history_)
# Out:
# Beginning epoch number: 0
# Current hard triplet ratio: 0.728573572511393
# Epoch 1/1
# 168/300 [===============>..............] - ETA: 6:26 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 4:35 - loss: 0.2493 - triplet_acc: 0.9500    - ETA: 4:20 - loss: 0.1662 - triplet_acc: 0.966 - ETA: 4:21 - loss: 0.1247 - triplet_acc: 0.975 - ETA: 4:15 - loss: 0.1208 - triplet_acc: 0.960 - ETA: 4:21 - loss: 0.4839 - triplet_acc: 0.866 - ETA: 4:16 - loss: 0.4275 - triplet_acc: 0.871 - ETA: 4:13 - loss: 0.6380 - triplet_acc: 0.850 - ETA: 4:10 - loss: 0.7454 - triplet_acc: 0.822 - ETA: 4:08 - loss: 0.7816 - triplet_acc: 0.790 - ETA: 4:07 - loss: 0.7574 - triplet_acc: 0.790 - ETA: 4:05 - loss: 0.7414 - triplet_acc: 0.791 - ETA: 4:00 - loss: 0.7089 - triplet_acc: 0.800 - ETA: 3:59 - loss: 0.6636 - triplet_acc: 0.807 - ETA: 3:57 - loss: 0.6489 - triplet_acc: 0.806 - ETA: 3:55 - loss: 0.6409 - triplet_acc: 0.806 - ETA: 3:53 - loss: 0.6116 - triplet_acc: 0.805 - ETA: 3:52 - loss: 0.5964 - triplet_acc: 0.805 - ETA: 3:49 - loss: 0.5730 - triplet_acc: 0.810 - ETA: 3:48 - loss: 0.6161 - triplet_acc: 0.800 - ETA: 3:46 - loss: 0.6401 - triplet_acc: 0.785 - ETA: 3:45 - loss: 0.6247 - triplet_acc: 0.790 - ETA: 3:43 - loss: 0.6591 - triplet_acc: 0.778 - ETA: 3:41 - loss: 0.6785 - triplet_acc: 0.766 - ETA: 3:41 - loss: 0.7043 - triplet_acc: 0.760 - ETA: 3:41 - loss: 0.7091 - triplet_acc: 0.761 - ETA: 3:39 - loss: 0.6856 - triplet_acc: 0.763 - ETA: 3:39 - loss: 0.7099 - triplet_acc: 0.760 - ETA: 3:36 - loss: 0.6854 - triplet_acc: 0.769 - ETA: 3:35 - loss: 0.6692 - triplet_acc: 0.773 - ETA: 3:34 - loss: 0.6749 - triplet_acc: 0.771 - ETA: 3:32 - loss: 0.7146 - triplet_acc: 0.762 - ETA: 3:31 - loss: 0.7113 - triplet_acc: 0.766 - ETA: 3:29 - loss: 0.6965 - triplet_acc: 0.770 - ETA: 3:28 - loss: 0.6815 - triplet_acc: 0.774 - ETA: 3:27 - loss: 0.7136 - triplet_acc: 0.769 - ETA: 3:26 - loss: 0.6944 - triplet_acc: 0.775 - ETA: 3:25 - loss: 0.6950 - triplet_acc: 0.771 - ETA: 3:25 - loss: 0.6823 - triplet_acc: 0.771 - ETA: 3:24 - loss: 0.6911 - triplet_acc: 0.772 - ETA: 3:22 - loss: 0.6861 - triplet_acc: 0.770 - ETA: 3:22 - loss: 0.6698 - triplet_acc: 0.776 - ETA: 3:21 - loss: 0.6733 - triplet_acc: 0.779 - ETA: 3:20 - loss: 0.6646 - triplet_acc: 0.781 - ETA: 3:19 - loss: 0.6837 - triplet_acc: 0.777 - ETA: 3:18 - loss: 0.7074 - triplet_acc: 0.767 - ETA: 3:17 - loss: 0.6985 - triplet_acc: 0.768 - ETA: 3:16 - loss: 0.7183 - triplet_acc: 0.762 - ETA: 3:15 - loss: 0.7552 - triplet_acc: 0.759 - ETA: 3:14 - loss: 0.7411 - triplet_acc: 0.762 - ETA: 3:13 - loss: 0.7836 - triplet_acc: 0.758 - ETA: 3:12 - loss: 0.7686 - triplet_acc: 0.763 - ETA: 3:11 - loss: 0.7718 - triplet_acc: 0.758 - ETA: 3:10 - loss: 0.7874 - triplet_acc: 0.755 - ETA: 3:10 - loss: 0.7832 - triplet_acc: 0.756 - ETA: 3:08 - loss: 0.7826 - triplet_acc: 0.755 - ETA: 3:07 - loss: 0.7800 - triplet_acc: 0.754 - ETA: 3:06 - loss: 0.7665 - triplet_acc: 0.758 - ETA: 3:05 - loss: 0.7630 - triplet_acc: 0.755 - ETA: 3:04 - loss: 0.7536 - triplet_acc: 0.758 - ETA: 3:03 - loss: 0.7716 - triplet_acc: 0.755 - ETA: 3:02 - loss: 0.7664 - triplet_acc: 0.758 - ETA: 3:01 - loss: 0.7712 - triplet_acc: 0.757 - ETA: 3:01 - loss: 0.7684 - triplet_acc: 0.757 - ETA: 3:00 - loss: 0.7809 - triplet_acc: 0.753 - ETA: 2:59 - loss: 0.7691 - triplet_acc: 0.757 - ETA: 2:58 - loss: 0.7611 - triplet_acc: 0.756 - ETA: 2:58 - loss: 0.7537 - triplet_acc: 0.758 - ETA: 2:57 - loss: 0.7550 - triplet_acc: 0.756 - ETA: 2:56 - loss: 0.7504 - triplet_acc: 0.757 - ETA: 2:55 - loss: 0.7635 - triplet_acc: 0.754 - ETA: 2:54 - loss: 0.7550 - triplet_acc: 0.756 - ETA: 2:53 - loss: 0.7905 - triplet_acc: 0.754 - ETA: 2:53 - loss: 0.7827 - triplet_acc: 0.754 - ETA: 2:52 - loss: 0.7814 - triplet_acc: 0.753 - ETA: 2:51 - loss: 0.7743 - triplet_acc: 0.753 - ETA: 2:50 - loss: 0.7787 - triplet_acc: 0.751 - ETA: 2:49 - loss: 0.7688 - triplet_acc: 0.753 - ETA: 2:48 - loss: 0.7610 - triplet_acc: 0.753 - ETA: 2:47 - loss: 0.7601 - triplet_acc: 0.750 - ETA: 2:47 - loss: 0.7594 - triplet_acc: 0.750 - ETA: 2:46 - loss: 0.7589 - triplet_acc: 0.751 - ETA: 2:45 - l ...
# Beginning epoch number: 1
# Current hard triplet ratio: 0.774913686875288
# Epoch 1/1
# 170/300 [================>.............] - ETA: 4:03 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:52 - loss: 0.2562 - triplet_acc: 0.9000    - ETA: 3:47 - loss: 0.1708 - triplet_acc: 0.933 - ETA: 3:40 - loss: 0.1559 - triplet_acc: 0.900 - ETA: 3:39 - loss: 0.3150 - triplet_acc: 0.860 - ETA: 3:39 - loss: 0.5145 - triplet_acc: 0.833 - ETA: 3:37 - loss: 0.5132 - triplet_acc: 0.828 - ETA: 3:34 - loss: 0.6207 - triplet_acc: 0.812 - ETA: 3:34 - loss: 0.6159 - triplet_acc: 0.811 - ETA: 3:33 - loss: 0.6394 - triplet_acc: 0.810 - ETA: 3:32 - loss: 0.6287 - triplet_acc: 0.809 - ETA: 3:32 - loss: 0.6220 - triplet_acc: 0.816 - ETA: 3:31 - loss: 0.6144 - triplet_acc: 0.807 - ETA: 3:30 - loss: 0.5785 - triplet_acc: 0.814 - ETA: 3:29 - loss: 0.5427 - triplet_acc: 0.820 - ETA: 3:29 - loss: 0.5174 - triplet_acc: 0.825 - ETA: 3:28 - loss: 0.5455 - triplet_acc: 0.817 - ETA: 3:27 - loss: 0.5235 - triplet_acc: 0.822 - ETA: 3:26 - loss: 0.5301 - triplet_acc: 0.821 - ETA: 3:25 - loss: 0.5428 - triplet_acc: 0.820 - ETA: 3:24 - loss: 0.6021 - triplet_acc: 0.804 - ETA: 3:22 - loss: 0.5880 - triplet_acc: 0.809 - ETA: 3:21 - loss: 0.5850 - triplet_acc: 0.808 - ETA: 3:23 - loss: 0.6274 - triplet_acc: 0.804 - ETA: 3:23 - loss: 0.6214 - triplet_acc: 0.792 - ETA: 3:21 - loss: 0.6208 - triplet_acc: 0.784 - ETA: 3:20 - loss: 0.6259 - triplet_acc: 0.785 - ETA: 3:20 - loss: 0.6466 - triplet_acc: 0.778 - ETA: 3:18 - loss: 0.6507 - triplet_acc: 0.775 - ETA: 3:17 - loss: 0.6516 - triplet_acc: 0.773 - ETA: 3:17 - loss: 0.6571 - triplet_acc: 0.771 - ETA: 3:16 - loss: 0.6571 - triplet_acc: 0.775 - ETA: 3:15 - loss: 0.6474 - triplet_acc: 0.775 - ETA: 3:14 - loss: 0.6576 - triplet_acc: 0.767 - ETA: 3:12 - loss: 0.6617 - triplet_acc: 0.762 - ETA: 3:11 - loss: 0.6648 - triplet_acc: 0.758 - ETA: 3:11 - loss: 0.6929 - triplet_acc: 0.754 - ETA: 3:10 - loss: 0.6783 - triplet_acc: 0.757 - ETA: 3:10 - loss: 0.6841 - triplet_acc: 0.756 - ETA: 3:09 - loss: 0.7343 - triplet_acc: 0.742 - ETA: 3:09 - loss: 0.7201 - triplet_acc: 0.746 - ETA: 3:09 - loss: 0.7128 - triplet_acc: 0.747 - ETA: 3:08 - loss: 0.7019 - triplet_acc: 0.751 - ETA: 3:08 - loss: 0.6865 - triplet_acc: 0.754 - ETA: 3:08 - loss: 0.7278 - triplet_acc: 0.753 - ETA: 3:08 - loss: 0.7251 - triplet_acc: 0.750 - ETA: 3:07 - loss: 0.7199 - triplet_acc: 0.751 - ETA: 3:06 - loss: 0.7095 - triplet_acc: 0.754 - ETA: 3:06 - loss: 0.6987 - triplet_acc: 0.753 - ETA: 3:05 - loss: 0.6974 - triplet_acc: 0.752 - ETA: 3:04 - loss: 0.7045 - triplet_acc: 0.747 - ETA: 3:03 - loss: 0.6930 - triplet_acc: 0.750 - ETA: 3:03 - loss: 0.6934 - triplet_acc: 0.745 - ETA: 3:02 - loss: 0.6910 - triplet_acc: 0.746 - ETA: 3:01 - loss: 0.6838 - triplet_acc: 0.747 - ETA: 3:00 - loss: 0.6717 - triplet_acc: 0.750 - ETA: 2:59 - loss: 0.6741 - triplet_acc: 0.750 - ETA: 2:58 - loss: 0.6849 - triplet_acc: 0.750 - ETA: 2:58 - loss: 0.6947 - triplet_acc: 0.749 - ETA: 2:57 - loss: 0.6859 - triplet_acc: 0.751 - ETA: 2:56 - loss: 0.6850 - triplet_acc: 0.750 - ETA: 2:56 - loss: 0.6917 - triplet_acc: 0.751 - ETA: 2:55 - loss: 0.6880 - triplet_acc: 0.750 - ETA: 2:54 - loss: 0.6942 - triplet_acc: 0.750 - ETA: 2:54 - loss: 0.6835 - triplet_acc: 0.753 - ETA: 2:53 - loss: 0.6846 - triplet_acc: 0.751 - ETA: 2:52 - loss: 0.6744 - triplet_acc: 0.755 - ETA: 2:51 - loss: 0.6723 - triplet_acc: 0.755 - ETA: 2:50 - loss: 0.6626 - triplet_acc: 0.758 - ETA: 2:50 - loss: 0.6623 - triplet_acc: 0.757 - ETA: 2:49 - loss: 0.6649 - triplet_acc: 0.756 - ETA: 2:49 - loss: 0.6559 - triplet_acc: 0.758 - ETA: 2:48 - loss: 0.6495 - triplet_acc: 0.760 - ETA: 2:47 - loss: 0.6422 - triplet_acc: 0.762 - ETA: 2:46 - loss: 0.6338 - triplet_acc: 0.764 - ETA: 2:45 - loss: 0.6265 - triplet_acc: 0.765 - ETA: 2:45 - loss: 0.6213 - triplet_acc: 0.766 - ETA: 2:44 - loss: 0.6314 - triplet_acc: 0.761 - ETA: 2:43 - loss: 0.6332 - triplet_acc: 0.762 - ETA: 2:43 - loss: 0.6404 - triplet_acc: 0.760 - ETA: 2:42 - loss: 0.6325 - triplet_acc: 0.763 - ETA: 2:41 - loss: 0.6333 - triplet_acc: 0.762 - ETA: 2:41 - l ...
# 300/300 [==============================] - ETA: 1:35 - loss: 0.6914 - triplet_acc: 0.748 - ETA: 1:35 - loss: 0.6932 - triplet_acc: 0.748 - ETA: 1:34 - loss: 0.6905 - triplet_acc: 0.748 - ETA: 1:33 - loss: 0.6878 - triplet_acc: 0.748 - ETA: 1:32 - loss: 0.6883 - triplet_acc: 0.749 - ETA: 1:32 - loss: 0.6936 - triplet_acc: 0.748 - ETA: 1:31 - loss: 0.6896 - triplet_acc: 0.749 - ETA: 1:30 - loss: 0.6904 - triplet_acc: 0.749 - ETA: 1:29 - loss: 0.6871 - triplet_acc: 0.750 - ETA: 1:29 - loss: 0.6883 - triplet_acc: 0.750 - ETA: 1:28 - loss: 0.6883 - triplet_acc: 0.750 - ETA: 1:27 - loss: 0.6967 - triplet_acc: 0.749 - ETA: 1:26 - loss: 0.6943 - triplet_acc: 0.750 - ETA: 1:26 - loss: 0.6945 - triplet_acc: 0.750 - ETA: 1:25 - loss: 0.6918 - triplet_acc: 0.750 - ETA: 1:24 - loss: 0.6914 - triplet_acc: 0.750 - ETA: 1:23 - loss: 0.6884 - triplet_acc: 0.751 - ETA: 1:23 - loss: 0.6857 - triplet_acc: 0.752 - ETA: 1:22 - loss: 0.6858 - triplet_acc: 0.752 - ETA: 1:21 - loss: 0.6917 - triplet_acc: 0.750 - ETA: 1:20 - loss: 0.6964 - triplet_acc: 0.749 - ETA: 1:20 - loss: 0.6963 - triplet_acc: 0.749 - ETA: 1:19 - loss: 0.6973 - triplet_acc: 0.748 - ETA: 1:18 - loss: 0.6990 - triplet_acc: 0.747 - ETA: 1:17 - loss: 0.6990 - triplet_acc: 0.748 - ETA: 1:17 - loss: 0.6977 - triplet_acc: 0.748 - ETA: 1:16 - loss: 0.6953 - triplet_acc: 0.748 - ETA: 1:15 - loss: 0.6994 - triplet_acc: 0.748 - ETA: 1:14 - loss: 0.7070 - triplet_acc: 0.745 - ETA: 1:14 - loss: 0.7066 - triplet_acc: 0.745 - ETA: 1:13 - loss: 0.7055 - triplet_acc: 0.745 - ETA: 1:12 - loss: 0.7090 - triplet_acc: 0.745 - ETA: 1:11 - loss: 0.7067 - triplet_acc: 0.745 - ETA: 1:11 - loss: 0.7078 - triplet_acc: 0.744 - ETA: 1:10 - loss: 0.7076 - triplet_acc: 0.744 - ETA: 1:09 - loss: 0.7087 - triplet_acc: 0.743 - ETA: 1:08 - loss: 0.7178 - triplet_acc: 0.743 - ETA: 1:08 - loss: 0.7167 - triplet_acc: 0.743 - ETA: 1:07 - loss: 0.7135 - triplet_acc: 0.744 - ETA: 1:06 - loss: 0.7124 - triplet_acc: 0.744 - ETA: 1:05 - loss: 0.7141 - triplet_acc: 0.744 - ETA: 1:05 - loss: 0.7111 - triplet_acc: 0.744 - ETA: 1:04 - loss: 0.7152 - triplet_acc: 0.743 - ETA: 1:03 - loss: 0.7208 - triplet_acc: 0.742 - ETA: 1:02 - loss: 0.7223 - triplet_acc: 0.742 - ETA: 1:02 - loss: 0.7210 - triplet_acc: 0.742 - ETA: 1:01 - loss: 0.7211 - triplet_acc: 0.741 - ETA: 1:00 - loss: 0.7189 - triplet_acc: 0.742 - ETA: 59s - loss: 0.7157 - triplet_acc: 0.743 - ETA: 59s - loss: 0.7148 - triplet_acc: 0.74 - ETA: 58s - loss: 0.7142 - triplet_acc: 0.74 - ETA: 57s - loss: 0.7126 - triplet_acc: 0.74 - ETA: 56s - loss: 0.7094 - triplet_acc: 0.74 - ETA: 56s - loss: 0.7107 - triplet_acc: 0.74 - ETA: 55s - loss: 0.7104 - triplet_acc: 0.74 - ETA: 54s - loss: 0.7077 - triplet_acc: 0.74 - ETA: 53s - loss: 0.7074 - triplet_acc: 0.74 - ETA: 53s - loss: 0.7087 - triplet_acc: 0.74 - ETA: 52s - loss: 0.7105 - triplet_acc: 0.74 - ETA: 51s - loss: 0.7096 - triplet_acc: 0.74 - ETA: 51s - loss: 0.7090 - triplet_acc: 0.74 - ETA: 50s - loss: 0.7064 - triplet_acc: 0.74 - ETA: 49s - loss: 0.7034 - triplet_acc: 0.74 - ETA: 48s - loss: 0.7024 - triplet_acc: 0.74 - ETA: 48s - loss: 0.7001 - triplet_acc: 0.74 - ETA: 47s - loss: 0.6976 - triplet_acc: 0.74 - ETA: 46s - loss: 0.6954 - triplet_acc: 0.74 - ETA: 45s - loss: 0.6924 - triplet_acc: 0.74 - ETA: 45s - loss: 0.7034 - triplet_acc: 0.74 - ETA: 44s - loss: 0.7025 - triplet_acc: 0.74 - ETA: 43s - loss: 0.7038 - triplet_acc: 0.74 - ETA: 42s - loss: 0.7022 - triplet_acc: 0.74 - ETA: 42s - loss: 0.7044 - triplet_acc: 0.74 - ETA: 41s - loss: 0.7019 - triplet_acc: 0.74 - ETA: 40s - loss: 0.7029 - triplet_acc: 0.74 - ETA: 39s - loss: 0.7050 - triplet_acc: 0.74 - ETA: 39s - loss: 0.7120 - triplet_acc: 0.74 - ETA: 38s - loss: 0.7102 - triplet_acc: 0.74 - ETA: 37s - loss: 0.7095 - triplet_acc: 0.74 - ETA: 36s - loss: 0.7117 - triplet_acc: 0.74 - ETA: 36s - loss: 0.7088 - triplet_acc: 0.74 - ETA: 35s - loss: 0.7088 - triplet_acc: 0.74 - ETA: 34s - loss: 0.7100 - triplet_acc: 0.74 - ETA: 33s - loss: 0.7079 - triplet_acc: 0.7 ...
# Beginning epoch number: 2
# Current hard triplet ratio: 0.7899714783732993
# Epoch 1/1
# 170/300 [================>.............] - ETA: 4:06 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:51 - loss: 0.2890 - triplet_acc: 0.8000    - ETA: 3:43 - loss: 0.5086 - triplet_acc: 0.800 - ETA: 3:36 - loss: 0.3815 - triplet_acc: 0.850 - ETA: 3:36 - loss: 0.3402 - triplet_acc: 0.840 - ETA: 3:34 - loss: 0.9124 - triplet_acc: 0.750 - ETA: 3:31 - loss: 0.8675 - triplet_acc: 0.757 - ETA: 3:32 - loss: 0.8375 - triplet_acc: 0.750 - ETA: 3:30 - loss: 0.8515 - triplet_acc: 0.700 - ETA: 3:28 - loss: 0.8748 - triplet_acc: 0.700 - ETA: 3:28 - loss: 0.9040 - triplet_acc: 0.681 - ETA: 3:27 - loss: 0.9193 - triplet_acc: 0.675 - ETA: 3:26 - loss: 0.9023 - triplet_acc: 0.684 - ETA: 3:24 - loss: 0.8549 - triplet_acc: 0.685 - ETA: 3:23 - loss: 0.8763 - triplet_acc: 0.680 - ETA: 3:23 - loss: 0.8751 - triplet_acc: 0.668 - ETA: 3:22 - loss: 0.8431 - triplet_acc: 0.682 - ETA: 3:22 - loss: 0.9037 - triplet_acc: 0.683 - ETA: 3:21 - loss: 0.8562 - triplet_acc: 0.700 - ETA: 3:20 - loss: 0.9321 - triplet_acc: 0.700 - ETA: 3:20 - loss: 0.9134 - triplet_acc: 0.704 - ETA: 3:20 - loss: 0.9706 - triplet_acc: 0.709 - ETA: 3:19 - loss: 0.9343 - triplet_acc: 0.717 - ETA: 3:18 - loss: 0.8954 - triplet_acc: 0.729 - ETA: 3:17 - loss: 0.8663 - triplet_acc: 0.736 - ETA: 3:17 - loss: 0.8988 - triplet_acc: 0.734 - ETA: 3:16 - loss: 0.8781 - triplet_acc: 0.733 - ETA: 3:15 - loss: 0.8559 - triplet_acc: 0.739 - ETA: 3:16 - loss: 0.8846 - triplet_acc: 0.731 - ETA: 3:15 - loss: 0.8622 - triplet_acc: 0.733 - ETA: 3:14 - loss: 0.8344 - triplet_acc: 0.741 - ETA: 3:13 - loss: 0.8364 - triplet_acc: 0.734 - ETA: 3:12 - loss: 0.8111 - triplet_acc: 0.742 - ETA: 3:11 - loss: 0.7958 - triplet_acc: 0.744 - ETA: 3:11 - loss: 0.7812 - triplet_acc: 0.742 - ETA: 3:10 - loss: 0.7675 - triplet_acc: 0.744 - ETA: 3:09 - loss: 0.7686 - triplet_acc: 0.745 - ETA: 3:08 - loss: 0.7640 - triplet_acc: 0.742 - ETA: 3:09 - loss: 0.7640 - triplet_acc: 0.738 - ETA: 3:09 - loss: 0.7574 - triplet_acc: 0.737 - ETA: 3:08 - loss: 0.7720 - triplet_acc: 0.731 - ETA: 3:07 - loss: 0.7593 - triplet_acc: 0.733 - ETA: 3:06 - loss: 0.7427 - triplet_acc: 0.737 - ETA: 3:05 - loss: 0.7306 - triplet_acc: 0.740 - ETA: 3:04 - loss: 0.7201 - triplet_acc: 0.744 - ETA: 3:04 - loss: 0.7236 - triplet_acc: 0.745 - ETA: 3:04 - loss: 0.7107 - triplet_acc: 0.748 - ETA: 3:03 - loss: 0.7030 - triplet_acc: 0.750 - ETA: 3:03 - loss: 0.6886 - triplet_acc: 0.755 - ETA: 3:02 - loss: 0.6873 - triplet_acc: 0.754 - ETA: 3:01 - loss: 0.6873 - triplet_acc: 0.754 - ETA: 3:01 - loss: 0.6935 - triplet_acc: 0.753 - ETA: 3:00 - loss: 0.6864 - triplet_acc: 0.752 - ETA: 2:59 - loss: 0.6758 - triplet_acc: 0.755 - ETA: 2:58 - loss: 0.6724 - triplet_acc: 0.754 - ETA: 2:58 - loss: 0.6710 - triplet_acc: 0.753 - ETA: 2:57 - loss: 0.6787 - triplet_acc: 0.750 - ETA: 2:56 - loss: 0.6848 - triplet_acc: 0.751 - ETA: 2:56 - loss: 0.6986 - triplet_acc: 0.747 - ETA: 2:55 - loss: 0.6959 - triplet_acc: 0.748 - ETA: 2:54 - loss: 0.7013 - triplet_acc: 0.747 - ETA: 2:54 - loss: 0.6906 - triplet_acc: 0.750 - ETA: 2:53 - loss: 0.6829 - triplet_acc: 0.752 - ETA: 2:52 - loss: 0.6749 - triplet_acc: 0.754 - ETA: 2:51 - loss: 0.6688 - triplet_acc: 0.755 - ETA: 2:50 - loss: 0.6643 - triplet_acc: 0.756 - ETA: 2:50 - loss: 0.6836 - triplet_acc: 0.749 - ETA: 2:49 - loss: 0.6810 - triplet_acc: 0.750 - ETA: 2:48 - loss: 0.6748 - triplet_acc: 0.752 - ETA: 2:48 - loss: 0.6750 - triplet_acc: 0.754 - ETA: 2:47 - loss: 0.6734 - triplet_acc: 0.754 - ETA: 2:46 - loss: 0.6699 - triplet_acc: 0.754 - ETA: 2:46 - loss: 0.6785 - triplet_acc: 0.753 - ETA: 2:45 - loss: 0.6757 - triplet_acc: 0.755 - ETA: 2:44 - loss: 0.6828 - triplet_acc: 0.754 - ETA: 2:43 - loss: 0.6738 - triplet_acc: 0.757 - ETA: 2:42 - loss: 0.6651 - triplet_acc: 0.761 - ETA: 2:42 - loss: 0.6671 - triplet_acc: 0.759 - ETA: 2:41 - loss: 0.6682 - triplet_acc: 0.758 - ETA: 2:40 - loss: 0.6618 - triplet_acc: 0.760 - ETA: 2:39 - loss: 0.6633 - triplet_acc: 0.758 - ETA: 2:39 - loss: 0.6596 - triplet_acc: 0.758 - ETA: 2:38 - l ...
# Beginning epoch number: 3
# Current hard triplet ratio: 0.8118086457836757
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:59 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:59 - loss: 1.8141 - triplet_acc: 0.7000    - ETA: 3:53 - loss: 1.3086 - triplet_acc: 0.733 - ETA: 3:46 - loss: 1.7688 - triplet_acc: 0.650 - ETA: 3:42 - loss: 1.6541 - triplet_acc: 0.680 - ETA: 3:38 - loss: 1.4602 - triplet_acc: 0.700 - ETA: 3:39 - loss: 1.4910 - triplet_acc: 0.642 - ETA: 3:36 - loss: 1.4297 - triplet_acc: 0.650 - ETA: 3:33 - loss: 1.2930 - triplet_acc: 0.666 - ETA: 3:32 - loss: 1.3518 - triplet_acc: 0.660 - ETA: 3:31 - loss: 1.2397 - triplet_acc: 0.681 - ETA: 3:30 - loss: 1.1872 - triplet_acc: 0.683 - ETA: 3:30 - loss: 1.1566 - triplet_acc: 0.684 - ETA: 3:29 - loss: 1.0740 - triplet_acc: 0.707 - ETA: 3:28 - loss: 1.1047 - triplet_acc: 0.700 - ETA: 3:27 - loss: 1.1290 - triplet_acc: 0.675 - ETA: 3:26 - loss: 1.1670 - triplet_acc: 0.664 - ETA: 3:26 - loss: 1.1237 - triplet_acc: 0.672 - ETA: 3:24 - loss: 1.1137 - triplet_acc: 0.678 - ETA: 3:24 - loss: 1.0827 - triplet_acc: 0.675 - ETA: 3:23 - loss: 1.0738 - triplet_acc: 0.671 - ETA: 3:22 - loss: 1.0588 - triplet_acc: 0.677 - ETA: 3:22 - loss: 1.0171 - triplet_acc: 0.687 - ETA: 3:21 - loss: 1.0315 - triplet_acc: 0.679 - ETA: 3:21 - loss: 1.0109 - triplet_acc: 0.680 - ETA: 3:19 - loss: 1.0008 - triplet_acc: 0.669 - ETA: 3:18 - loss: 0.9918 - triplet_acc: 0.674 - ETA: 3:17 - loss: 0.9752 - triplet_acc: 0.675 - ETA: 3:16 - loss: 0.9751 - triplet_acc: 0.672 - ETA: 3:15 - loss: 0.9469 - triplet_acc: 0.680 - ETA: 3:15 - loss: 0.9463 - triplet_acc: 0.677 - ETA: 3:15 - loss: 0.9202 - triplet_acc: 0.681 - ETA: 3:14 - loss: 1.0112 - triplet_acc: 0.666 - ETA: 3:14 - loss: 0.9901 - triplet_acc: 0.673 - ETA: 3:13 - loss: 0.9820 - triplet_acc: 0.677 - ETA: 3:12 - loss: 0.9547 - triplet_acc: 0.686 - ETA: 3:11 - loss: 0.9520 - triplet_acc: 0.683 - ETA: 3:10 - loss: 0.9290 - triplet_acc: 0.689 - ETA: 3:10 - loss: 0.9099 - triplet_acc: 0.692 - ETA: 3:09 - loss: 0.9061 - triplet_acc: 0.692 - ETA: 3:09 - loss: 0.9700 - triplet_acc: 0.685 - ETA: 3:09 - loss: 0.9832 - triplet_acc: 0.683 - ETA: 3:08 - loss: 1.0369 - triplet_acc: 0.676 - ETA: 3:07 - loss: 1.0211 - triplet_acc: 0.679 - ETA: 3:07 - loss: 0.9984 - triplet_acc: 0.686 - ETA: 3:06 - loss: 0.9767 - triplet_acc: 0.693 - ETA: 3:05 - loss: 0.9666 - triplet_acc: 0.695 - ETA: 3:05 - loss: 0.9599 - triplet_acc: 0.695 - ETA: 3:04 - loss: 0.9531 - triplet_acc: 0.693 - ETA: 3:03 - loss: 0.9341 - triplet_acc: 0.700 - ETA: 3:03 - loss: 0.9272 - triplet_acc: 0.702 - ETA: 3:02 - loss: 0.9321 - triplet_acc: 0.700 - ETA: 3:01 - loss: 0.9285 - triplet_acc: 0.700 - ETA: 3:00 - loss: 0.9190 - triplet_acc: 0.701 - ETA: 3:00 - loss: 0.9244 - triplet_acc: 0.701 - ETA: 2:59 - loss: 0.9337 - triplet_acc: 0.701 - ETA: 2:59 - loss: 0.9212 - triplet_acc: 0.703 - ETA: 2:58 - loss: 0.9282 - triplet_acc: 0.703 - ETA: 2:57 - loss: 0.9154 - triplet_acc: 0.706 - ETA: 2:57 - loss: 0.9193 - triplet_acc: 0.706 - ETA: 2:56 - loss: 0.9193 - triplet_acc: 0.706 - ETA: 2:55 - loss: 0.9044 - triplet_acc: 0.711 - ETA: 2:54 - loss: 0.8901 - triplet_acc: 0.715 - ETA: 2:54 - loss: 0.8762 - triplet_acc: 0.720 - ETA: 2:53 - loss: 0.8870 - triplet_acc: 0.721 - ETA: 2:52 - loss: 0.8925 - triplet_acc: 0.724 - ETA: 2:51 - loss: 0.8885 - triplet_acc: 0.726 - ETA: 2:50 - loss: 0.8855 - triplet_acc: 0.723 - ETA: 2:49 - loss: 0.8821 - triplet_acc: 0.721 - ETA: 2:48 - loss: 0.8824 - triplet_acc: 0.722 - ETA: 2:48 - loss: 0.8733 - triplet_acc: 0.723 - ETA: 2:47 - loss: 0.8626 - triplet_acc: 0.723 - ETA: 2:46 - loss: 0.8711 - triplet_acc: 0.719 - ETA: 2:46 - loss: 0.8669 - triplet_acc: 0.720 - ETA: 2:45 - loss: 0.8593 - triplet_acc: 0.722 - ETA: 2:44 - loss: 0.8741 - triplet_acc: 0.719 - ETA: 2:43 - loss: 0.8634 - triplet_acc: 0.722 - ETA: 2:42 - loss: 0.8602 - triplet_acc: 0.723 - ETA: 2:42 - loss: 0.8760 - triplet_acc: 0.717 - ETA: 2:41 - loss: 0.8696 - triplet_acc: 0.720 - ETA: 2:40 - loss: 0.8785 - triplet_acc: 0.717 - ETA: 2:39 - loss: 0.8750 - triplet_acc: 0.714 - ETA: 2:39 - l ...
# 300/300 [==============================] - ETA: 1:34 - loss: 0.8285 - triplet_acc: 0.721 - ETA: 1:33 - loss: 0.8281 - triplet_acc: 0.722 - ETA: 1:33 - loss: 0.8294 - triplet_acc: 0.721 - ETA: 1:32 - loss: 0.8353 - triplet_acc: 0.720 - ETA: 1:31 - loss: 0.8349 - triplet_acc: 0.719 - ETA: 1:30 - loss: 0.8370 - triplet_acc: 0.718 - ETA: 1:30 - loss: 0.8369 - triplet_acc: 0.718 - ETA: 1:29 - loss: 0.8402 - triplet_acc: 0.719 - ETA: 1:28 - loss: 0.8363 - triplet_acc: 0.720 - ETA: 1:28 - loss: 0.8415 - triplet_acc: 0.719 - ETA: 1:27 - loss: 0.8431 - triplet_acc: 0.719 - ETA: 1:26 - loss: 0.8385 - triplet_acc: 0.721 - ETA: 1:25 - loss: 0.8351 - triplet_acc: 0.722 - ETA: 1:25 - loss: 0.8392 - triplet_acc: 0.721 - ETA: 1:24 - loss: 0.8403 - triplet_acc: 0.721 - ETA: 1:23 - loss: 0.8383 - triplet_acc: 0.722 - ETA: 1:22 - loss: 0.8366 - triplet_acc: 0.722 - ETA: 1:22 - loss: 0.8354 - triplet_acc: 0.722 - ETA: 1:21 - loss: 0.8353 - triplet_acc: 0.722 - ETA: 1:20 - loss: 0.8356 - triplet_acc: 0.722 - ETA: 1:20 - loss: 0.8393 - triplet_acc: 0.721 - ETA: 1:19 - loss: 0.8450 - triplet_acc: 0.719 - ETA: 1:18 - loss: 0.8467 - triplet_acc: 0.719 - ETA: 1:17 - loss: 0.8456 - triplet_acc: 0.719 - ETA: 1:17 - loss: 0.8416 - triplet_acc: 0.720 - ETA: 1:16 - loss: 0.8383 - triplet_acc: 0.721 - ETA: 1:15 - loss: 0.8377 - triplet_acc: 0.721 - ETA: 1:14 - loss: 0.8348 - triplet_acc: 0.721 - ETA: 1:14 - loss: 0.8336 - triplet_acc: 0.722 - ETA: 1:13 - loss: 0.8332 - triplet_acc: 0.722 - ETA: 1:12 - loss: 0.8311 - triplet_acc: 0.722 - ETA: 1:12 - loss: 0.8298 - triplet_acc: 0.721 - ETA: 1:11 - loss: 0.8355 - triplet_acc: 0.720 - ETA: 1:10 - loss: 0.8402 - triplet_acc: 0.719 - ETA: 1:09 - loss: 0.8575 - triplet_acc: 0.718 - ETA: 1:09 - loss: 0.8583 - triplet_acc: 0.718 - ETA: 1:08 - loss: 0.8578 - triplet_acc: 0.718 - ETA: 1:07 - loss: 0.8556 - triplet_acc: 0.719 - ETA: 1:06 - loss: 0.8530 - triplet_acc: 0.720 - ETA: 1:06 - loss: 0.8523 - triplet_acc: 0.720 - ETA: 1:05 - loss: 0.8493 - triplet_acc: 0.720 - ETA: 1:04 - loss: 0.8495 - triplet_acc: 0.720 - ETA: 1:03 - loss: 0.8524 - triplet_acc: 0.719 - ETA: 1:03 - loss: 0.8557 - triplet_acc: 0.718 - ETA: 1:02 - loss: 0.8518 - triplet_acc: 0.720 - ETA: 1:01 - loss: 0.8511 - triplet_acc: 0.719 - ETA: 1:00 - loss: 0.8564 - triplet_acc: 0.718 - ETA: 1:00 - loss: 0.8536 - triplet_acc: 0.718 - ETA: 59s - loss: 0.8503 - triplet_acc: 0.719 - ETA: 58s - loss: 0.8475 - triplet_acc: 0.72 - ETA: 58s - loss: 0.8445 - triplet_acc: 0.72 - ETA: 57s - loss: 0.8432 - triplet_acc: 0.72 - ETA: 56s - loss: 0.8418 - triplet_acc: 0.72 - ETA: 55s - loss: 0.8415 - triplet_acc: 0.72 - ETA: 55s - loss: 0.8451 - triplet_acc: 0.71 - ETA: 54s - loss: 0.8528 - triplet_acc: 0.71 - ETA: 53s - loss: 0.8514 - triplet_acc: 0.71 - ETA: 52s - loss: 0.8491 - triplet_acc: 0.71 - ETA: 52s - loss: 0.8462 - triplet_acc: 0.71 - ETA: 51s - loss: 0.8436 - triplet_acc: 0.72 - ETA: 50s - loss: 0.8447 - triplet_acc: 0.72 - ETA: 49s - loss: 0.8411 - triplet_acc: 0.72 - ETA: 49s - loss: 0.8396 - triplet_acc: 0.72 - ETA: 48s - loss: 0.8394 - triplet_acc: 0.71 - ETA: 47s - loss: 0.8358 - triplet_acc: 0.72 - ETA: 46s - loss: 0.8401 - triplet_acc: 0.71 - ETA: 46s - loss: 0.8412 - triplet_acc: 0.71 - ETA: 45s - loss: 0.8430 - triplet_acc: 0.71 - ETA: 44s - loss: 0.8408 - triplet_acc: 0.72 - ETA: 44s - loss: 0.8385 - triplet_acc: 0.72 - ETA: 43s - loss: 0.8353 - triplet_acc: 0.72 - ETA: 42s - loss: 0.8348 - triplet_acc: 0.72 - ETA: 41s - loss: 0.8381 - triplet_acc: 0.72 - ETA: 41s - loss: 0.8390 - triplet_acc: 0.72 - ETA: 40s - loss: 0.8398 - triplet_acc: 0.72 - ETA: 39s - loss: 0.8389 - triplet_acc: 0.72 - ETA: 38s - loss: 0.8400 - triplet_acc: 0.72 - ETA: 38s - loss: 0.8382 - triplet_acc: 0.72 - ETA: 37s - loss: 0.8353 - triplet_acc: 0.72 - ETA: 36s - loss: 0.8356 - triplet_acc: 0.72 - ETA: 35s - loss: 0.8339 - triplet_acc: 0.71 - ETA: 35s - loss: 0.8379 - triplet_acc: 0.71 - ETA: 34s - loss: 0.8570 - triplet_acc: 0.71 - ETA: 33s - loss: 0.8567 - triplet_acc: 0.7 ...
# Beginning epoch number: 4
# Current hard triplet ratio: 0.7492048346074947
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:42 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:38 - loss: 0.4441 - triplet_acc: 0.9000    - ETA: 3:38 - loss: 0.7031 - triplet_acc: 0.800 - ETA: 3:41 - loss: 0.6853 - triplet_acc: 0.825 - ETA: 3:41 - loss: 0.8385 - triplet_acc: 0.780 - ETA: 3:39 - loss: 0.6988 - triplet_acc: 0.816 - ETA: 3:43 - loss: 0.7620 - triplet_acc: 0.814 - ETA: 3:41 - loss: 0.9055 - triplet_acc: 0.800 - ETA: 3:39 - loss: 0.8918 - triplet_acc: 0.788 - ETA: 3:36 - loss: 0.8077 - triplet_acc: 0.800 - ETA: 3:34 - loss: 0.7342 - triplet_acc: 0.818 - ETA: 3:32 - loss: 0.7141 - triplet_acc: 0.816 - ETA: 3:32 - loss: 0.6743 - triplet_acc: 0.815 - ETA: 3:32 - loss: 0.6667 - triplet_acc: 0.814 - ETA: 3:30 - loss: 0.6706 - triplet_acc: 0.813 - ETA: 3:29 - loss: 0.6359 - triplet_acc: 0.812 - ETA: 3:27 - loss: 0.6579 - triplet_acc: 0.811 - ETA: 3:27 - loss: 0.6331 - triplet_acc: 0.816 - ETA: 3:25 - loss: 0.6466 - triplet_acc: 0.805 - ETA: 3:24 - loss: 0.6621 - triplet_acc: 0.805 - ETA: 3:23 - loss: 0.6576 - triplet_acc: 0.800 - ETA: 3:23 - loss: 0.6621 - triplet_acc: 0.800 - ETA: 3:24 - loss: 0.7155 - triplet_acc: 0.787 - ETA: 3:22 - loss: 0.6944 - triplet_acc: 0.787 - ETA: 3:22 - loss: 0.7613 - triplet_acc: 0.776 - ETA: 3:22 - loss: 0.7423 - triplet_acc: 0.776 - ETA: 3:21 - loss: 0.7591 - triplet_acc: 0.770 - ETA: 3:20 - loss: 0.7476 - triplet_acc: 0.764 - ETA: 3:19 - loss: 0.7218 - triplet_acc: 0.772 - ETA: 3:18 - loss: 0.6986 - triplet_acc: 0.776 - ETA: 3:17 - loss: 0.7061 - triplet_acc: 0.774 - ETA: 3:16 - loss: 0.7076 - triplet_acc: 0.775 - ETA: 3:16 - loss: 0.6950 - triplet_acc: 0.775 - ETA: 3:15 - loss: 0.7050 - triplet_acc: 0.776 - ETA: 3:13 - loss: 0.6879 - triplet_acc: 0.780 - ETA: 3:13 - loss: 0.6748 - triplet_acc: 0.780 - ETA: 3:12 - loss: 0.6839 - triplet_acc: 0.778 - ETA: 3:11 - loss: 0.6919 - triplet_acc: 0.776 - ETA: 3:10 - loss: 0.6984 - triplet_acc: 0.774 - ETA: 3:10 - loss: 0.7286 - triplet_acc: 0.770 - ETA: 3:09 - loss: 0.7328 - triplet_acc: 0.768 - ETA: 3:08 - loss: 0.7269 - triplet_acc: 0.766 - ETA: 3:08 - loss: 0.7214 - triplet_acc: 0.767 - ETA: 3:07 - loss: 0.7117 - triplet_acc: 0.768 - ETA: 3:06 - loss: 0.7048 - triplet_acc: 0.768 - ETA: 3:05 - loss: 0.7102 - triplet_acc: 0.767 - ETA: 3:04 - loss: 0.7091 - triplet_acc: 0.766 - ETA: 3:04 - loss: 0.6971 - triplet_acc: 0.766 - ETA: 3:03 - loss: 0.6998 - triplet_acc: 0.767 - ETA: 3:02 - loss: 0.7255 - triplet_acc: 0.766 - ETA: 3:01 - loss: 0.7275 - triplet_acc: 0.764 - ETA: 3:00 - loss: 0.7336 - triplet_acc: 0.765 - ETA: 3:00 - loss: 0.7243 - triplet_acc: 0.766 - ETA: 3:00 - loss: 0.7290 - triplet_acc: 0.764 - ETA: 2:59 - loss: 0.7350 - triplet_acc: 0.763 - ETA: 2:58 - loss: 0.7435 - triplet_acc: 0.764 - ETA: 2:58 - loss: 0.7407 - triplet_acc: 0.763 - ETA: 2:56 - loss: 0.7331 - triplet_acc: 0.763 - ETA: 2:56 - loss: 0.7288 - triplet_acc: 0.766 - ETA: 2:55 - loss: 0.7221 - triplet_acc: 0.765 - ETA: 2:54 - loss: 0.7463 - triplet_acc: 0.760 - ETA: 2:53 - loss: 0.7544 - triplet_acc: 0.759 - ETA: 2:52 - loss: 0.7487 - triplet_acc: 0.758 - ETA: 2:52 - loss: 0.7506 - triplet_acc: 0.757 - ETA: 2:51 - loss: 0.7533 - triplet_acc: 0.756 - ETA: 2:50 - loss: 0.7446 - triplet_acc: 0.759 - ETA: 2:49 - loss: 0.7335 - triplet_acc: 0.762 - ETA: 2:48 - loss: 0.7327 - triplet_acc: 0.761 - ETA: 2:47 - loss: 0.7271 - triplet_acc: 0.763 - ETA: 2:46 - loss: 0.7167 - triplet_acc: 0.767 - ETA: 2:46 - loss: 0.7118 - triplet_acc: 0.767 - ETA: 2:45 - loss: 0.7068 - triplet_acc: 0.768 - ETA: 2:44 - loss: 0.7222 - triplet_acc: 0.764 - ETA: 2:43 - loss: 0.7237 - triplet_acc: 0.763 - ETA: 2:42 - loss: 0.7248 - triplet_acc: 0.761 - ETA: 2:42 - loss: 0.7219 - triplet_acc: 0.761 - ETA: 2:41 - loss: 0.7289 - triplet_acc: 0.761 - ETA: 2:40 - loss: 0.7217 - triplet_acc: 0.760 - ETA: 2:40 - loss: 0.7220 - triplet_acc: 0.760 - ETA: 2:39 - loss: 0.7409 - triplet_acc: 0.758 - ETA: 2:38 - loss: 0.7484 - triplet_acc: 0.758 - ETA: 2:38 - loss: 0.7393 - triplet_acc: 0.761 - ETA: 2:37 - l ...
# Beginning epoch number: 5
# Current hard triplet ratio: 0.7808715765260779
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:45 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:53 - loss: 0.4401 - triplet_acc: 0.8500    - ETA: 3:40 - loss: 0.4247 - triplet_acc: 0.833 - ETA: 3:35 - loss: 0.7395 - triplet_acc: 0.750 - ETA: 3:32 - loss: 0.8441 - triplet_acc: 0.740 - ETA: 3:34 - loss: 0.7931 - triplet_acc: 0.733 - ETA: 3:35 - loss: 0.7854 - triplet_acc: 0.728 - ETA: 3:41 - loss: 0.7539 - triplet_acc: 0.737 - ETA: 3:39 - loss: 0.6998 - triplet_acc: 0.744 - ETA: 3:36 - loss: 0.6373 - triplet_acc: 0.760 - ETA: 3:37 - loss: 0.6602 - triplet_acc: 0.754 - ETA: 3:34 - loss: 0.6740 - triplet_acc: 0.741 - ETA: 3:33 - loss: 0.6282 - triplet_acc: 0.753 - ETA: 3:31 - loss: 0.6221 - triplet_acc: 0.757 - ETA: 3:31 - loss: 0.6107 - triplet_acc: 0.760 - ETA: 3:30 - loss: 0.5906 - triplet_acc: 0.756 - ETA: 3:29 - loss: 0.6557 - triplet_acc: 0.747 - ETA: 3:28 - loss: 0.6524 - triplet_acc: 0.744 - ETA: 3:26 - loss: 0.6537 - triplet_acc: 0.742 - ETA: 3:25 - loss: 0.6891 - triplet_acc: 0.735 - ETA: 3:23 - loss: 0.6565 - triplet_acc: 0.738 - ETA: 3:23 - loss: 0.6594 - triplet_acc: 0.736 - ETA: 3:22 - loss: 0.6599 - triplet_acc: 0.730 - ETA: 3:20 - loss: 0.6593 - triplet_acc: 0.729 - ETA: 3:19 - loss: 0.6710 - triplet_acc: 0.728 - ETA: 3:19 - loss: 0.6608 - triplet_acc: 0.726 - ETA: 3:18 - loss: 0.6453 - triplet_acc: 0.729 - ETA: 3:17 - loss: 0.6222 - triplet_acc: 0.739 - ETA: 3:15 - loss: 0.6044 - triplet_acc: 0.744 - ETA: 3:14 - loss: 0.6111 - triplet_acc: 0.743 - ETA: 3:15 - loss: 0.5985 - triplet_acc: 0.745 - ETA: 3:14 - loss: 0.6071 - triplet_acc: 0.740 - ETA: 3:14 - loss: 0.5981 - triplet_acc: 0.745 - ETA: 3:14 - loss: 0.5928 - triplet_acc: 0.747 - ETA: 3:14 - loss: 0.5931 - triplet_acc: 0.742 - ETA: 3:13 - loss: 0.5869 - triplet_acc: 0.744 - ETA: 3:12 - loss: 0.5758 - triplet_acc: 0.743 - ETA: 3:12 - loss: 0.5823 - triplet_acc: 0.744 - ETA: 3:11 - loss: 0.5912 - triplet_acc: 0.743 - ETA: 3:11 - loss: 0.5766 - triplet_acc: 0.747 - ETA: 3:10 - loss: 0.5723 - triplet_acc: 0.748 - ETA: 3:09 - loss: 0.5739 - triplet_acc: 0.742 - ETA: 3:08 - loss: 0.5614 - triplet_acc: 0.746 - ETA: 3:07 - loss: 0.5729 - triplet_acc: 0.745 - ETA: 3:06 - loss: 0.5691 - triplet_acc: 0.744 - ETA: 3:05 - loss: 0.5586 - triplet_acc: 0.747 - ETA: 3:04 - loss: 0.5676 - triplet_acc: 0.746 - ETA: 3:03 - loss: 0.5800 - triplet_acc: 0.745 - ETA: 3:03 - loss: 0.5751 - triplet_acc: 0.749 - ETA: 3:02 - loss: 0.5636 - triplet_acc: 0.754 - ETA: 3:01 - loss: 0.5626 - triplet_acc: 0.756 - ETA: 3:00 - loss: 0.5594 - triplet_acc: 0.759 - ETA: 3:00 - loss: 0.5626 - triplet_acc: 0.754 - ETA: 2:59 - loss: 0.5564 - triplet_acc: 0.755 - ETA: 2:58 - loss: 0.5680 - triplet_acc: 0.752 - ETA: 2:57 - loss: 0.6081 - triplet_acc: 0.746 - ETA: 2:57 - loss: 0.6039 - triplet_acc: 0.745 - ETA: 2:56 - loss: 0.6225 - triplet_acc: 0.743 - ETA: 2:55 - loss: 0.6181 - triplet_acc: 0.745 - ETA: 2:55 - loss: 0.6089 - triplet_acc: 0.748 - ETA: 2:54 - loss: 0.6326 - triplet_acc: 0.747 - ETA: 2:54 - loss: 0.6310 - triplet_acc: 0.745 - ETA: 2:53 - loss: 0.6292 - triplet_acc: 0.746 - ETA: 2:52 - loss: 0.6335 - triplet_acc: 0.743 - ETA: 2:51 - loss: 0.6240 - triplet_acc: 0.746 - ETA: 2:51 - loss: 0.6288 - triplet_acc: 0.745 - ETA: 2:50 - loss: 0.6378 - triplet_acc: 0.747 - ETA: 2:49 - loss: 0.6331 - triplet_acc: 0.748 - ETA: 2:49 - loss: 0.6607 - triplet_acc: 0.744 - ETA: 2:48 - loss: 0.6677 - triplet_acc: 0.744 - ETA: 2:48 - loss: 0.6860 - triplet_acc: 0.742 - ETA: 2:47 - loss: 0.6789 - triplet_acc: 0.741 - ETA: 2:46 - loss: 0.6696 - triplet_acc: 0.745 - ETA: 2:45 - loss: 0.6625 - triplet_acc: 0.747 - ETA: 2:45 - loss: 0.6537 - triplet_acc: 0.750 - ETA: 2:44 - loss: 0.6732 - triplet_acc: 0.748 - ETA: 2:43 - loss: 0.6668 - triplet_acc: 0.750 - ETA: 2:43 - loss: 0.6700 - triplet_acc: 0.746 - ETA: 2:42 - loss: 0.6680 - triplet_acc: 0.744 - ETA: 2:41 - loss: 0.6669 - triplet_acc: 0.745 - ETA: 2:41 - loss: 0.6689 - triplet_acc: 0.744 - ETA: 2:40 - loss: 0.6608 - triplet_acc: 0.747 - ETA: 2:39 - l ...
# 300/300 [==============================] - ETA: 1:37 - loss: 0.7146 - triplet_acc: 0.742 - ETA: 1:36 - loss: 0.7131 - triplet_acc: 0.742 - ETA: 1:36 - loss: 0.7132 - triplet_acc: 0.742 - ETA: 1:35 - loss: 0.7146 - triplet_acc: 0.742 - ETA: 1:34 - loss: 0.7105 - triplet_acc: 0.743 - ETA: 1:33 - loss: 0.7065 - triplet_acc: 0.744 - ETA: 1:33 - loss: 0.7052 - triplet_acc: 0.744 - ETA: 1:32 - loss: 0.7021 - triplet_acc: 0.745 - ETA: 1:31 - loss: 0.7004 - triplet_acc: 0.745 - ETA: 1:30 - loss: 0.6969 - triplet_acc: 0.746 - ETA: 1:30 - loss: 0.6931 - triplet_acc: 0.747 - ETA: 1:29 - loss: 0.6934 - triplet_acc: 0.747 - ETA: 1:28 - loss: 0.6924 - triplet_acc: 0.748 - ETA: 1:27 - loss: 0.6931 - triplet_acc: 0.747 - ETA: 1:27 - loss: 0.6897 - triplet_acc: 0.748 - ETA: 1:26 - loss: 0.6916 - triplet_acc: 0.748 - ETA: 1:25 - loss: 0.6886 - triplet_acc: 0.749 - ETA: 1:24 - loss: 0.6849 - triplet_acc: 0.750 - ETA: 1:23 - loss: 0.6935 - triplet_acc: 0.749 - ETA: 1:23 - loss: 0.6925 - triplet_acc: 0.749 - ETA: 1:22 - loss: 0.6905 - triplet_acc: 0.750 - ETA: 1:21 - loss: 0.6894 - triplet_acc: 0.750 - ETA: 1:21 - loss: 0.6867 - triplet_acc: 0.750 - ETA: 1:20 - loss: 0.6834 - triplet_acc: 0.751 - ETA: 1:19 - loss: 0.6809 - triplet_acc: 0.751 - ETA: 1:18 - loss: 0.6795 - triplet_acc: 0.751 - ETA: 1:17 - loss: 0.6789 - triplet_acc: 0.751 - ETA: 1:17 - loss: 0.6755 - triplet_acc: 0.753 - ETA: 1:16 - loss: 0.6742 - triplet_acc: 0.753 - ETA: 1:15 - loss: 0.6723 - triplet_acc: 0.754 - ETA: 1:14 - loss: 0.6720 - triplet_acc: 0.754 - ETA: 1:14 - loss: 0.6715 - triplet_acc: 0.755 - ETA: 1:13 - loss: 0.6782 - triplet_acc: 0.754 - ETA: 1:12 - loss: 0.6790 - triplet_acc: 0.753 - ETA: 1:11 - loss: 0.6779 - triplet_acc: 0.752 - ETA: 1:11 - loss: 0.6792 - triplet_acc: 0.752 - ETA: 1:10 - loss: 0.6890 - triplet_acc: 0.751 - ETA: 1:09 - loss: 0.6860 - triplet_acc: 0.751 - ETA: 1:08 - loss: 0.6909 - triplet_acc: 0.750 - ETA: 1:08 - loss: 0.6939 - triplet_acc: 0.749 - ETA: 1:07 - loss: 0.6930 - triplet_acc: 0.749 - ETA: 1:06 - loss: 0.6904 - triplet_acc: 0.750 - ETA: 1:05 - loss: 0.6878 - triplet_acc: 0.749 - ETA: 1:05 - loss: 0.6972 - triplet_acc: 0.748 - ETA: 1:04 - loss: 0.6940 - triplet_acc: 0.749 - ETA: 1:03 - loss: 0.6925 - triplet_acc: 0.750 - ETA: 1:02 - loss: 0.6894 - triplet_acc: 0.750 - ETA: 1:02 - loss: 0.6873 - triplet_acc: 0.751 - ETA: 1:01 - loss: 0.6854 - triplet_acc: 0.752 - ETA: 1:00 - loss: 0.6835 - triplet_acc: 0.752 - ETA: 59s - loss: 0.6995 - triplet_acc: 0.751 - ETA: 59s - loss: 0.6996 - triplet_acc: 0.75 - ETA: 58s - loss: 0.6978 - triplet_acc: 0.75 - ETA: 57s - loss: 0.6983 - triplet_acc: 0.75 - ETA: 56s - loss: 0.6952 - triplet_acc: 0.75 - ETA: 56s - loss: 0.6940 - triplet_acc: 0.75 - ETA: 55s - loss: 0.6936 - triplet_acc: 0.75 - ETA: 54s - loss: 0.6943 - triplet_acc: 0.75 - ETA: 53s - loss: 0.6913 - triplet_acc: 0.75 - ETA: 52s - loss: 0.6903 - triplet_acc: 0.75 - ETA: 52s - loss: 0.6925 - triplet_acc: 0.75 - ETA: 51s - loss: 0.6919 - triplet_acc: 0.75 - ETA: 50s - loss: 0.6928 - triplet_acc: 0.75 - ETA: 49s - loss: 0.6954 - triplet_acc: 0.75 - ETA: 49s - loss: 0.6951 - triplet_acc: 0.75 - ETA: 48s - loss: 0.6985 - triplet_acc: 0.75 - ETA: 47s - loss: 0.6959 - triplet_acc: 0.75 - ETA: 46s - loss: 0.6930 - triplet_acc: 0.75 - ETA: 46s - loss: 0.6908 - triplet_acc: 0.75 - ETA: 45s - loss: 0.6886 - triplet_acc: 0.75 - ETA: 44s - loss: 0.6858 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6899 - triplet_acc: 0.75 - ETA: 43s - loss: 0.6913 - triplet_acc: 0.75 - ETA: 42s - loss: 0.6903 - triplet_acc: 0.75 - ETA: 41s - loss: 0.6883 - triplet_acc: 0.75 - ETA: 40s - loss: 0.6869 - triplet_acc: 0.75 - ETA: 40s - loss: 0.6862 - triplet_acc: 0.75 - ETA: 39s - loss: 0.6836 - triplet_acc: 0.75 - ETA: 38s - loss: 0.6834 - triplet_acc: 0.75 - ETA: 37s - loss: 0.6823 - triplet_acc: 0.75 - ETA: 36s - loss: 0.6884 - triplet_acc: 0.75 - ETA: 36s - loss: 0.6939 - triplet_acc: 0.75 - ETA: 35s - loss: 0.6929 - triplet_acc: 0.75 - ETA: 34s - loss: 0.6934 - triplet_acc: ...
# Beginning epoch number: 6
# Current hard triplet ratio: 0.7913545114597021
# Epoch 1/1
# 170/300 [================>.............] - ETA: 4:13 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:51 - loss: 0.1002 - triplet_acc: 0.8500    - ETA: 3:44 - loss: 0.2294 - triplet_acc: 0.833 - ETA: 3:45 - loss: 0.4281 - triplet_acc: 0.775 - ETA: 3:42 - loss: 0.3425 - triplet_acc: 0.820 - ETA: 3:42 - loss: 0.4784 - triplet_acc: 0.800 - ETA: 3:41 - loss: 0.4869 - triplet_acc: 0.785 - ETA: 3:38 - loss: 0.5116 - triplet_acc: 0.787 - ETA: 3:36 - loss: 0.4862 - triplet_acc: 0.788 - ETA: 3:35 - loss: 0.4608 - triplet_acc: 0.790 - ETA: 3:32 - loss: 0.4732 - triplet_acc: 0.781 - ETA: 3:32 - loss: 0.4803 - triplet_acc: 0.783 - ETA: 3:31 - loss: 0.4662 - triplet_acc: 0.792 - ETA: 3:30 - loss: 0.4934 - triplet_acc: 0.785 - ETA: 3:28 - loss: 0.4906 - triplet_acc: 0.793 - ETA: 3:28 - loss: 0.5297 - triplet_acc: 0.781 - ETA: 3:28 - loss: 0.5414 - triplet_acc: 0.782 - ETA: 3:27 - loss: 0.5219 - triplet_acc: 0.788 - ETA: 3:26 - loss: 0.6067 - triplet_acc: 0.778 - ETA: 3:26 - loss: 0.5972 - triplet_acc: 0.780 - ETA: 3:25 - loss: 0.5878 - triplet_acc: 0.785 - ETA: 3:25 - loss: 0.5625 - triplet_acc: 0.790 - ETA: 3:23 - loss: 0.5581 - triplet_acc: 0.791 - ETA: 3:23 - loss: 0.5866 - triplet_acc: 0.791 - ETA: 3:24 - loss: 0.6010 - triplet_acc: 0.788 - ETA: 3:25 - loss: 0.6342 - triplet_acc: 0.780 - ETA: 3:26 - loss: 0.6339 - triplet_acc: 0.777 - ETA: 3:25 - loss: 0.6192 - triplet_acc: 0.778 - ETA: 3:26 - loss: 0.6194 - triplet_acc: 0.775 - ETA: 3:24 - loss: 0.6065 - triplet_acc: 0.776 - ETA: 3:23 - loss: 0.5870 - triplet_acc: 0.783 - ETA: 3:22 - loss: 0.5963 - triplet_acc: 0.781 - ETA: 3:21 - loss: 0.5824 - triplet_acc: 0.784 - ETA: 3:20 - loss: 0.5810 - triplet_acc: 0.788 - ETA: 3:19 - loss: 0.6230 - triplet_acc: 0.782 - ETA: 3:18 - loss: 0.6261 - triplet_acc: 0.786 - ETA: 3:17 - loss: 0.6266 - triplet_acc: 0.778 - ETA: 3:16 - loss: 0.6511 - triplet_acc: 0.773 - ETA: 3:16 - loss: 0.6674 - triplet_acc: 0.769 - ETA: 3:15 - loss: 0.6561 - triplet_acc: 0.772 - ETA: 3:14 - loss: 0.6552 - triplet_acc: 0.768 - ETA: 3:13 - loss: 0.6396 - triplet_acc: 0.773 - ETA: 3:12 - loss: 0.6368 - triplet_acc: 0.772 - ETA: 3:11 - loss: 0.6223 - triplet_acc: 0.777 - ETA: 3:10 - loss: 0.6320 - triplet_acc: 0.780 - ETA: 3:09 - loss: 0.6565 - triplet_acc: 0.767 - ETA: 3:09 - loss: 0.6931 - triplet_acc: 0.763 - ETA: 3:08 - loss: 0.6868 - triplet_acc: 0.762 - ETA: 3:07 - loss: 0.6765 - triplet_acc: 0.763 - ETA: 3:06 - loss: 0.6700 - triplet_acc: 0.764 - ETA: 3:05 - loss: 0.6936 - triplet_acc: 0.760 - ETA: 3:04 - loss: 0.6803 - triplet_acc: 0.765 - ETA: 3:03 - loss: 0.6803 - triplet_acc: 0.766 - ETA: 3:02 - loss: 0.6743 - triplet_acc: 0.768 - ETA: 3:02 - loss: 0.6804 - triplet_acc: 0.763 - ETA: 3:01 - loss: 0.6871 - triplet_acc: 0.764 - ETA: 3:00 - loss: 0.6872 - triplet_acc: 0.763 - ETA: 2:59 - loss: 0.6998 - triplet_acc: 0.760 - ETA: 2:59 - loss: 0.7329 - triplet_acc: 0.757 - ETA: 2:58 - loss: 0.7303 - triplet_acc: 0.760 - ETA: 2:57 - loss: 0.7460 - triplet_acc: 0.757 - ETA: 2:57 - loss: 0.7565 - triplet_acc: 0.753 - ETA: 2:56 - loss: 0.7523 - triplet_acc: 0.755 - ETA: 2:55 - loss: 0.7471 - triplet_acc: 0.757 - ETA: 2:54 - loss: 0.7596 - triplet_acc: 0.756 - ETA: 2:53 - loss: 0.7678 - triplet_acc: 0.757 - ETA: 2:52 - loss: 0.7579 - triplet_acc: 0.759 - ETA: 2:52 - loss: 0.7585 - triplet_acc: 0.760 - ETA: 2:51 - loss: 0.7866 - triplet_acc: 0.760 - ETA: 2:50 - loss: 0.7802 - triplet_acc: 0.761 - ETA: 2:49 - loss: 0.8071 - triplet_acc: 0.760 - ETA: 2:48 - loss: 0.8181 - triplet_acc: 0.758 - ETA: 2:48 - loss: 0.8069 - triplet_acc: 0.761 - ETA: 2:47 - loss: 0.8024 - triplet_acc: 0.762 - ETA: 2:46 - loss: 0.8055 - triplet_acc: 0.762 - ETA: 2:45 - loss: 0.8245 - triplet_acc: 0.757 - ETA: 2:45 - loss: 0.8207 - triplet_acc: 0.758 - ETA: 2:44 - loss: 0.8300 - triplet_acc: 0.755 - ETA: 2:43 - loss: 0.8195 - triplet_acc: 0.758 - ETA: 2:42 - loss: 0.8148 - triplet_acc: 0.758 - ETA: 2:41 - loss: 0.8157 - triplet_acc: 0.758 - ETA: 2:41 - loss: 0.8119 - triplet_acc: 0.758 - ETA: 2:40 - l ...
# Beginning epoch number: 7
# Current hard triplet ratio: 0.7741410974257624
# Epoch 1/1
# 170/300 [================>.............] - ETA: 4:11 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:48 - loss: 0.0449 - triplet_acc: 0.9500    - ETA: 3:40 - loss: 0.2177 - triplet_acc: 0.900 - ETA: 3:38 - loss: 0.3846 - triplet_acc: 0.875 - ETA: 3:36 - loss: 0.3239 - triplet_acc: 0.880 - ETA: 3:37 - loss: 0.5098 - triplet_acc: 0.816 - ETA: 3:35 - loss: 0.4746 - triplet_acc: 0.828 - ETA: 3:32 - loss: 0.4342 - triplet_acc: 0.837 - ETA: 3:32 - loss: 0.5013 - triplet_acc: 0.811 - ETA: 3:32 - loss: 0.4672 - triplet_acc: 0.820 - ETA: 3:32 - loss: 0.4248 - triplet_acc: 0.836 - ETA: 3:30 - loss: 0.4203 - triplet_acc: 0.841 - ETA: 3:29 - loss: 0.4147 - triplet_acc: 0.846 - ETA: 3:28 - loss: 0.3936 - triplet_acc: 0.842 - ETA: 3:27 - loss: 0.3676 - triplet_acc: 0.846 - ETA: 3:26 - loss: 0.3489 - triplet_acc: 0.850 - ETA: 3:24 - loss: 0.4029 - triplet_acc: 0.829 - ETA: 3:23 - loss: 0.3831 - triplet_acc: 0.833 - ETA: 3:22 - loss: 0.3765 - triplet_acc: 0.836 - ETA: 3:21 - loss: 0.3786 - triplet_acc: 0.835 - ETA: 3:21 - loss: 0.3681 - triplet_acc: 0.838 - ETA: 3:20 - loss: 0.3754 - triplet_acc: 0.836 - ETA: 3:20 - loss: 0.3848 - triplet_acc: 0.834 - ETA: 3:19 - loss: 0.3818 - triplet_acc: 0.837 - ETA: 3:19 - loss: 0.3668 - triplet_acc: 0.840 - ETA: 3:18 - loss: 0.4546 - triplet_acc: 0.826 - ETA: 3:17 - loss: 0.4633 - triplet_acc: 0.825 - ETA: 3:16 - loss: 0.4599 - triplet_acc: 0.825 - ETA: 3:15 - loss: 0.4588 - triplet_acc: 0.824 - ETA: 3:14 - loss: 0.4476 - triplet_acc: 0.826 - ETA: 3:13 - loss: 0.4615 - triplet_acc: 0.825 - ETA: 3:13 - loss: 0.4609 - triplet_acc: 0.825 - ETA: 3:13 - loss: 0.4903 - triplet_acc: 0.818 - ETA: 3:12 - loss: 0.4978 - triplet_acc: 0.811 - ETA: 3:11 - loss: 0.5046 - triplet_acc: 0.808 - ETA: 3:11 - loss: 0.5005 - triplet_acc: 0.811 - ETA: 3:10 - loss: 0.5139 - triplet_acc: 0.805 - ETA: 3:10 - loss: 0.5142 - triplet_acc: 0.800 - ETA: 3:09 - loss: 0.5156 - triplet_acc: 0.794 - ETA: 3:08 - loss: 0.5200 - triplet_acc: 0.795 - ETA: 3:07 - loss: 0.5114 - triplet_acc: 0.795 - ETA: 3:07 - loss: 0.5237 - triplet_acc: 0.788 - ETA: 3:07 - loss: 0.5372 - triplet_acc: 0.781 - ETA: 3:06 - loss: 0.5305 - triplet_acc: 0.781 - ETA: 3:06 - loss: 0.5456 - triplet_acc: 0.777 - ETA: 3:05 - loss: 0.5469 - triplet_acc: 0.776 - ETA: 3:04 - loss: 0.5440 - triplet_acc: 0.776 - ETA: 3:04 - loss: 0.5481 - triplet_acc: 0.775 - ETA: 3:03 - loss: 0.5725 - triplet_acc: 0.771 - ETA: 3:03 - loss: 0.5672 - triplet_acc: 0.772 - ETA: 3:02 - loss: 0.5673 - triplet_acc: 0.772 - ETA: 3:01 - loss: 0.5659 - triplet_acc: 0.767 - ETA: 3:00 - loss: 0.5643 - triplet_acc: 0.767 - ETA: 3:00 - loss: 0.5681 - triplet_acc: 0.766 - ETA: 2:59 - loss: 0.5762 - triplet_acc: 0.767 - ETA: 2:58 - loss: 0.5923 - triplet_acc: 0.764 - ETA: 2:57 - loss: 0.6128 - triplet_acc: 0.757 - ETA: 2:56 - loss: 0.6302 - triplet_acc: 0.755 - ETA: 2:56 - loss: 0.6312 - triplet_acc: 0.755 - ETA: 2:55 - loss: 0.6369 - triplet_acc: 0.753 - ETA: 2:54 - loss: 0.6578 - triplet_acc: 0.749 - ETA: 2:53 - loss: 0.6690 - triplet_acc: 0.748 - ETA: 2:53 - loss: 0.6606 - triplet_acc: 0.750 - ETA: 2:52 - loss: 0.6616 - triplet_acc: 0.751 - ETA: 2:51 - loss: 0.6534 - triplet_acc: 0.753 - ETA: 2:50 - loss: 0.6481 - triplet_acc: 0.754 - ETA: 2:49 - loss: 0.6403 - triplet_acc: 0.756 - ETA: 2:49 - loss: 0.6415 - triplet_acc: 0.755 - ETA: 2:48 - loss: 0.6480 - triplet_acc: 0.755 - ETA: 2:48 - loss: 0.6546 - triplet_acc: 0.754 - ETA: 2:47 - loss: 0.6601 - triplet_acc: 0.756 - ETA: 2:46 - loss: 0.6579 - triplet_acc: 0.756 - ETA: 2:45 - loss: 0.6761 - triplet_acc: 0.756 - ETA: 2:44 - loss: 0.6848 - triplet_acc: 0.754 - ETA: 2:44 - loss: 0.6859 - triplet_acc: 0.753 - ETA: 2:43 - loss: 0.6836 - triplet_acc: 0.753 - ETA: 2:43 - loss: 0.7134 - triplet_acc: 0.750 - ETA: 2:42 - loss: 0.7043 - triplet_acc: 0.753 - ETA: 2:41 - loss: 0.7037 - triplet_acc: 0.751 - ETA: 2:41 - loss: 0.7055 - triplet_acc: 0.751 - ETA: 2:40 - loss: 0.7035 - triplet_acc: 0.751 - ETA: 2:39 - loss: 0.7037 - triplet_acc: 0.751 - ETA: 2:39 - l ...
# ...
# 300/300 [==============================] - ETA: 1:33 - loss: 0.6514 - triplet_acc: 0.766 - ETA: 1:33 - loss: 0.6523 - triplet_acc: 0.766 - ETA: 1:32 - loss: 0.6590 - triplet_acc: 0.764 - ETA: 1:31 - loss: 0.6568 - triplet_acc: 0.765 - ETA: 1:30 - loss: 0.6542 - triplet_acc: 0.766 - ETA: 1:30 - loss: 0.6649 - triplet_acc: 0.764 - ETA: 1:29 - loss: 0.6611 - triplet_acc: 0.766 - ETA: 1:28 - loss: 0.6669 - triplet_acc: 0.765 - ETA: 1:27 - loss: 0.6656 - triplet_acc: 0.766 - ETA: 1:27 - loss: 0.6670 - triplet_acc: 0.766 - ETA: 1:26 - loss: 0.6687 - triplet_acc: 0.766 - ETA: 1:25 - loss: 0.6679 - triplet_acc: 0.765 - ETA: 1:25 - loss: 0.6658 - triplet_acc: 0.766 - ETA: 1:24 - loss: 0.6661 - triplet_acc: 0.765 - ETA: 1:24 - loss: 0.6644 - triplet_acc: 0.765 - ETA: 1:23 - loss: 0.6643 - triplet_acc: 0.766 - ETA: 1:22 - loss: 0.6701 - triplet_acc: 0.765 - ETA: 1:21 - loss: 0.6682 - triplet_acc: 0.766 - ETA: 1:21 - loss: 0.6664 - triplet_acc: 0.766 - ETA: 1:20 - loss: 0.6684 - triplet_acc: 0.765 - ETA: 1:19 - loss: 0.6658 - triplet_acc: 0.766 - ETA: 1:19 - loss: 0.6635 - triplet_acc: 0.765 - ETA: 1:18 - loss: 0.6623 - triplet_acc: 0.766 - ETA: 1:17 - loss: 0.6608 - triplet_acc: 0.767 - ETA: 1:16 - loss: 0.6598 - triplet_acc: 0.767 - ETA: 1:16 - loss: 0.6576 - triplet_acc: 0.768 - ETA: 1:15 - loss: 0.6596 - triplet_acc: 0.768 - ETA: 1:14 - loss: 0.6630 - triplet_acc: 0.767 - ETA: 1:14 - loss: 0.6645 - triplet_acc: 0.767 - ETA: 1:13 - loss: 0.6679 - triplet_acc: 0.766 - ETA: 1:12 - loss: 0.6684 - triplet_acc: 0.765 - ETA: 1:11 - loss: 0.6654 - triplet_acc: 0.766 - ETA: 1:11 - loss: 0.6635 - triplet_acc: 0.766 - ETA: 1:10 - loss: 0.6602 - triplet_acc: 0.767 - ETA: 1:09 - loss: 0.6590 - triplet_acc: 0.767 - ETA: 1:08 - loss: 0.6563 - triplet_acc: 0.768 - ETA: 1:08 - loss: 0.6544 - triplet_acc: 0.767 - ETA: 1:07 - loss: 0.6586 - triplet_acc: 0.766 - ETA: 1:06 - loss: 0.6554 - triplet_acc: 0.767 - ETA: 1:05 - loss: 0.6525 - triplet_acc: 0.768 - ETA: 1:05 - loss: 0.6523 - triplet_acc: 0.767 - ETA: 1:04 - loss: 0.6501 - triplet_acc: 0.767 - ETA: 1:03 - loss: 0.6483 - triplet_acc: 0.767 - ETA: 1:03 - loss: 0.6478 - triplet_acc: 0.767 - ETA: 1:02 - loss: 0.6482 - triplet_acc: 0.767 - ETA: 1:01 - loss: 0.6503 - triplet_acc: 0.767 - ETA: 1:00 - loss: 0.6500 - triplet_acc: 0.767 - ETA: 1:00 - loss: 0.6505 - triplet_acc: 0.766 - ETA: 59s - loss: 0.6505 - triplet_acc: 0.766 - ETA: 58s - loss: 0.6549 - triplet_acc: 0.76 - ETA: 57s - loss: 0.6547 - triplet_acc: 0.76 - ETA: 57s - loss: 0.6518 - triplet_acc: 0.76 - ETA: 56s - loss: 0.6511 - triplet_acc: 0.76 - ETA: 55s - loss: 0.6510 - triplet_acc: 0.76 - ETA: 55s - loss: 0.6512 - triplet_acc: 0.76 - ETA: 54s - loss: 0.6483 - triplet_acc: 0.76 - ETA: 53s - loss: 0.6523 - triplet_acc: 0.76 - ETA: 52s - loss: 0.6508 - triplet_acc: 0.76 - ETA: 52s - loss: 0.6529 - triplet_acc: 0.76 - ETA: 51s - loss: 0.6501 - triplet_acc: 0.76 - ETA: 50s - loss: 0.6490 - triplet_acc: 0.76 - ETA: 49s - loss: 0.6471 - triplet_acc: 0.76 - ETA: 49s - loss: 0.6493 - triplet_acc: 0.76 - ETA: 48s - loss: 0.6505 - triplet_acc: 0.76 - ETA: 47s - loss: 0.6501 - triplet_acc: 0.76 - ETA: 47s - loss: 0.6533 - triplet_acc: 0.76 - ETA: 46s - loss: 0.6546 - triplet_acc: 0.76 - ETA: 45s - loss: 0.6559 - triplet_acc: 0.76 - ETA: 44s - loss: 0.6573 - triplet_acc: 0.76 - ETA: 44s - loss: 0.6579 - triplet_acc: 0.76 - ETA: 43s - loss: 0.6611 - triplet_acc: 0.76 - ETA: 42s - loss: 0.6592 - triplet_acc: 0.76 - ETA: 41s - loss: 0.6572 - triplet_acc: 0.76 - ETA: 41s - loss: 0.6610 - triplet_acc: 0.76 - ETA: 40s - loss: 0.6616 - triplet_acc: 0.76 - ETA: 39s - loss: 0.6612 - triplet_acc: 0.76 - ETA: 38s - loss: 0.6604 - triplet_acc: 0.76 - ETA: 38s - loss: 0.6620 - triplet_acc: 0.76 - ETA: 37s - loss: 0.6621 - triplet_acc: 0.76 - ETA: 36s - loss: 0.6617 - triplet_acc: 0.76 - ETA: 36s - loss: 0.6591 - triplet_acc: 0.76 - ETA: 35s - loss: 0.6591 - triplet_acc: 0.76 - ETA: 34s - loss: 0.6594 - triplet_acc: 0.76 - ETA: 33s - loss: 0.6600 - triplet_acc: 0.7 ...
# Beginning epoch number: 10
# Current hard triplet ratio: 0.8000897994615794
# Epoch 1/1
# 170/300 [================>.............] - ETA: 3:42 - loss: 0.3134 - triplet_acc: 0.900 - ETA: 3:41 - loss: 0.5707 - triplet_acc: 0.700 - ETA: 3:34 - loss: 0.8160 - triplet_acc: 0.700 - ETA: 3:32 - loss: 1.0508 - triplet_acc: 0.650 - ETA: 3:32 - loss: 1.0268 - triplet_acc: 0.640 - ETA: 3:30 - loss: 0.9464 - triplet_acc: 0.666 - ETA: 3:33 - loss: 1.0910 - triplet_acc: 0.671 - ETA: 3:33 - loss: 1.0515 - triplet_acc: 0.675 - ETA: 3:33 - loss: 0.9408 - triplet_acc: 0.700 - ETA: 3:31 - loss: 0.8853 - triplet_acc: 0.710 - ETA: 3:31 - loss: 0.8949 - triplet_acc: 0.700 - ETA: 3:31 - loss: 0.8504 - triplet_acc: 0.700 - ETA: 3:30 - loss: 0.9219 - triplet_acc: 0.692 - ETA: 3:30 - loss: 0.9623 - triplet_acc: 0.685 - ETA: 3:29 - loss: 0.9732 - triplet_acc: 0.673 - ETA: 3:27 - loss: 0.9758 - triplet_acc: 0.668 - ETA: 3:25 - loss: 0.9548 - triplet_acc: 0.670 - ETA: 3:24 - loss: 0.9789 - triplet_acc: 0.666 - ETA: 3:24 - loss: 0.9446 - triplet_acc: 0.678 - ETA: 3:23 - loss: 0.8973 - triplet_acc: 0.695 - ETA: 3:23 - loss: 0.8946 - triplet_acc: 0.695 - ETA: 3:21 - loss: 0.8540 - triplet_acc: 0.709 - ETA: 3:20 - loss: 0.8458 - triplet_acc: 0.717 - ETA: 3:20 - loss: 0.8826 - triplet_acc: 0.712 - ETA: 3:20 - loss: 0.8799 - triplet_acc: 0.716 - ETA: 3:19 - loss: 0.8511 - triplet_acc: 0.719 - ETA: 3:18 - loss: 0.8416 - triplet_acc: 0.722 - ETA: 3:17 - loss: 0.8132 - triplet_acc: 0.725 - ETA: 3:17 - loss: 0.7885 - triplet_acc: 0.731 - ETA: 3:17 - loss: 0.7820 - triplet_acc: 0.733 - ETA: 3:16 - loss: 0.7701 - triplet_acc: 0.735 - ETA: 3:14 - loss: 0.7460 - triplet_acc: 0.743 - ETA: 3:13 - loss: 0.7326 - triplet_acc: 0.745 - ETA: 3:13 - loss: 0.7110 - triplet_acc: 0.752 - ETA: 3:13 - loss: 0.7066 - triplet_acc: 0.751 - ETA: 3:12 - loss: 0.7114 - triplet_acc: 0.755 - ETA: 3:11 - loss: 0.6939 - triplet_acc: 0.754 - ETA: 3:10 - loss: 0.6818 - triplet_acc: 0.755 - ETA: 3:10 - loss: 0.6774 - triplet_acc: 0.753 - ETA: 3:09 - loss: 0.6834 - triplet_acc: 0.752 - ETA: 3:08 - loss: 0.6725 - triplet_acc: 0.756 - ETA: 3:07 - loss: 0.6584 - triplet_acc: 0.759 - ETA: 3:06 - loss: 0.6437 - triplet_acc: 0.762 - ETA: 3:05 - loss: 0.6435 - triplet_acc: 0.763 - ETA: 3:04 - loss: 0.6695 - triplet_acc: 0.760 - ETA: 3:04 - loss: 0.6716 - triplet_acc: 0.754 - ETA: 3:03 - loss: 0.6943 - triplet_acc: 0.748 - ETA: 3:02 - loss: 0.7004 - triplet_acc: 0.747 - ETA: 3:01 - loss: 0.6884 - triplet_acc: 0.751 - ETA: 3:01 - loss: 0.6784 - triplet_acc: 0.754 - ETA: 3:00 - loss: 0.6828 - triplet_acc: 0.752 - ETA: 2:59 - loss: 0.6824 - triplet_acc: 0.753 - ETA: 2:58 - loss: 0.6953 - triplet_acc: 0.749 - ETA: 2:58 - loss: 0.7128 - triplet_acc: 0.744 - ETA: 2:57 - loss: 0.7007 - triplet_acc: 0.747 - ETA: 2:57 - loss: 0.6977 - triplet_acc: 0.746 - ETA: 2:56 - loss: 0.6932 - triplet_acc: 0.743 - ETA: 2:56 - loss: 0.7458 - triplet_acc: 0.741 - ETA: 2:55 - loss: 0.7664 - triplet_acc: 0.735 - ETA: 2:54 - loss: 0.7615 - triplet_acc: 0.735 - ETA: 2:54 - loss: 0.7740 - triplet_acc: 0.732 - ETA: 2:53 - loss: 0.7671 - triplet_acc: 0.733 - ETA: 2:52 - loss: 0.7807 - triplet_acc: 0.731 - ETA: 2:51 - loss: 0.7709 - triplet_acc: 0.734 - ETA: 2:50 - loss: 0.7743 - triplet_acc: 0.735 - ETA: 2:50 - loss: 0.7803 - triplet_acc: 0.736 - ETA: 2:50 - loss: 0.7803 - triplet_acc: 0.734 - ETA: 2:49 - loss: 0.7735 - triplet_acc: 0.735 - ETA: 2:49 - loss: 0.7714 - triplet_acc: 0.736 - ETA: 2:48 - loss: 0.7605 - triplet_acc: 0.738 - ETA: 2:47 - loss: 0.7863 - triplet_acc: 0.736 - ETA: 2:46 - loss: 0.7988 - triplet_acc: 0.733 - ETA: 2:46 - loss: 0.8158 - triplet_acc: 0.728 - ETA: 2:45 - loss: 0.8125 - triplet_acc: 0.731 - ETA: 2:44 - loss: 0.8153 - triplet_acc: 0.729 - ETA: 2:43 - loss: 0.8133 - triplet_acc: 0.728 - ETA: 2:43 - loss: 0.8111 - triplet_acc: 0.729 - ETA: 2:42 - loss: 0.8159 - triplet_acc: 0.729 - ETA: 2:41 - loss: 0.8142 - triplet_acc: 0.729 - ETA: 2:40 - loss: 0.8158 - triplet_acc: 0.731 - ETA: 2:39 - loss: 0.8129 - triplet_acc: 0.732 - ETA: 2:39 - loss: 0.8099 - triplet_acc: 0.731 - ETA: 2:38 - loss: 0.8 ...
# Beginning epoch number: 11
# Current hard triplet ratio: 0.7558339955686624
# Epoch 1/1
#  79/300 [======>.......................] - ETA: 3:53 - loss: 0.0000e+00 - triplet_acc: 1.000 - ETA: 3:41 - loss: 0.5546 - triplet_acc: 0.9000    - ETA: 3:43 - loss: 0.7595 - triplet_acc: 0.800 - ETA: 3:34 - loss: 0.6300 - triplet_acc: 0.825 - ETA: 3:33 - loss: 0.7962 - triplet_acc: 0.760 - ETA: 3:33 - loss: 1.0098 - triplet_acc: 0.733 - ETA: 3:31 - loss: 0.8655 - triplet_acc: 0.771 - ETA: 3:30 - loss: 0.8863 - triplet_acc: 0.762 - ETA: 3:30 - loss: 0.8791 - triplet_acc: 0.755 - ETA: 3:29 - loss: 0.8076 - triplet_acc: 0.770 - ETA: 3:30 - loss: 0.7342 - triplet_acc: 0.790 - ETA: 3:28 - loss: 0.7359 - triplet_acc: 0.800 - ETA: 3:27 - loss: 0.7458 - triplet_acc: 0.800 - ETA: 3:26 - loss: 0.7671 - triplet_acc: 0.800 - ETA: 3:25 - loss: 0.7220 - triplet_acc: 0.806 - ETA: 3:24 - loss: 0.7145 - triplet_acc: 0.806 - ETA: 3:24 - loss: 0.7027 - triplet_acc: 0.805 - ETA: 3:23 - loss: 0.6637 - triplet_acc: 0.816 - ETA: 3:23 - loss: 0.6671 - triplet_acc: 0.810 - ETA: 3:24 - loss: 0.6469 - triplet_acc: 0.810 - ETA: 3:23 - loss: 0.6546 - triplet_acc: 0.809 - ETA: 3:22 - loss: 0.6279 - triplet_acc: 0.809 - ETA: 3:21 - loss: 0.6006 - triplet_acc: 0.817 - ETA: 3:20 - loss: 0.6103 - triplet_acc: 0.816 - ETA: 3:19 - loss: 0.6033 - triplet_acc: 0.816 - ETA: 3:19 - loss: 0.5915 - triplet_acc: 0.811 - ETA: 3:18 - loss: 0.5937 - triplet_acc: 0.807 - ETA: 3:18 - loss: 0.5749 - triplet_acc: 0.810 - ETA: 3:18 - loss: 0.5912 - triplet_acc: 0.806 - ETA: 3:18 - loss: 0.5752 - triplet_acc: 0.810 - ETA: 3:17 - loss: 0.5761 - triplet_acc: 0.809 - ETA: 3:16 - loss: 0.5796 - triplet_acc: 0.812 - ETA: 3:15 - loss: 0.5629 - triplet_acc: 0.815 - ETA: 3:14 - loss: 0.5463 - triplet_acc: 0.820 - ETA: 3:13 - loss: 0.5312 - triplet_acc: 0.822 - ETA: 3:13 - loss: 0.5240 - triplet_acc: 0.822 - ETA: 3:12 - loss: 0.5098 - triplet_acc: 0.827 - ETA: 3:12 - loss: 0.5276 - triplet_acc: 0.826 - ETA: 3:12 - loss: 0.5321 - triplet_acc: 0.823 - ETA: 3:12 - loss: 0.5456 - triplet_acc: 0.820 - ETA: 3:11 - loss: 0.5358 - triplet_acc: 0.822 - ETA: 3:11 - loss: 0.5398 - triplet_acc: 0.821 - ETA: 3:10 - loss: 0.5411 - triplet_acc: 0.820 - ETA: 3:09 - loss: 0.5304 - triplet_acc: 0.820 - ETA: 3:08 - loss: 0.5297 - triplet_acc: 0.817 - ETA: 3:08 - loss: 0.5181 - triplet_acc: 0.821 - ETA: 3:07 - loss: 0.5071 - triplet_acc: 0.825 - ETA: 3:06 - loss: 0.5043 - triplet_acc: 0.825 - ETA: 3:06 - loss: 0.4940 - triplet_acc: 0.828 - ETA: 3:05 - loss: 0.4896 - triplet_acc: 0.830 - ETA: 3:04 - loss: 0.4899 - triplet_acc: 0.825 - ETA: 3:03 - loss: 0.5283 - triplet_acc: 0.819 - ETA: 3:03 - loss: 0.5444 - triplet_acc: 0.813 - ETA: 3:02 - loss: 0.5400 - triplet_acc: 0.814 - ETA: 3:01 - loss: 0.5368 - triplet_acc: 0.816 - ETA: 3:00 - loss: 0.5305 - triplet_acc: 0.817 - ETA: 2:59 - loss: 0.5212 - triplet_acc: 0.821 - ETA: 2:58 - loss: 0.5204 - triplet_acc: 0.817 - ETA: 2:57 - loss: 0.5116 - triplet_acc: 0.820 - ETA: 2:57 - loss: 0.5429 - triplet_acc: 0.813 - ETA: 2:56 - loss: 0.5340 - triplet_acc: 0.816 - ETA: 2:55 - loss: 0.5365 - triplet_acc: 0.814 - ETA: 2:55 - loss: 0.5333 - triplet_acc: 0.815 - ETA: 2:54 - loss: 0.5384 - triplet_acc: 0.812 - ETA: 2:53 - loss: 0.5334 - triplet_acc: 0.813 - ETA: 2:53 - loss: 0.5387 - triplet_acc: 0.812 - ETA: 2:52 - loss: 0.5330 - triplet_acc: 0.813 - ETA: 2:51 - loss: 0.5371 - triplet_acc: 0.811 - ETA: 2:50 - loss: 0.5348 - triplet_acc: 0.810 - ETA: 2:50 - loss: 0.5362 - triplet_acc: 0.810 - ETA: 2:49 - loss: 0.5326 - triplet_acc: 0.811 - ETA: 2:48 - loss: 0.5369 - triplet_acc: 0.808 - ETA: 2:48 - loss: 0.5501 - triplet_acc: 0.805 - ETA: 2:47 - loss: 0.5438 - triplet_acc: 0.806 - ETA: 2:46 - loss: 0.5403 - triplet_acc: 0.808 - ETA: 2:46 - loss: 0.5455 - triplet_acc: 0.806 - ETA: 2:45 - loss: 0.5546 - triplet_acc: 0.805 - ETA: 2:45 - loss: 0.5543 - triplet_acc: 0.802 - ETA: 2:44 - loss: 0.5491 - triplet_acc: 0.8038

# %%
histories = []

# %%
# With online hard triplet generation
crt_acc = 0.8
start = 0
for i in range(1000):
    print("Beginning epoch number: "+str(i))
#     if crt_acc < 0.7:
#         print("Mode 1")
#         histories += [model.fit_generator(
#             online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=False, use_neg=False, use_pos=False),
#             steps_per_epoch=300,
#             epochs=1,
#             validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
#             validation_steps=30
#         )]
#     if crt_acc < 0.78:
#         print("Mode 2")
#         histories += [model.fit_generator(
#             online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=True, use_neg=False, use_pos=True),
#             steps_per_epoch=300,
#             epochs=1,
#             validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
#             validation_steps=30
#         )]
#     else:
    print("Mode 3")
    histories += [model.fit_generator(
        online_hard_image_generator(filenames_train,labels_train,model,3*20, use_aug=True, use_neg=False, use_pos=False),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
        validation_steps=30
    )]
    
    crt_acc = histories[-1].history['triplet_acc'][0]
    
    model.save(PATH_MODEL + '2019.05.05.dogfacenet_v25.'+str(start+i)+'.h5')
    
    loss = np.empty(0)
    val_loss = np.empty(0)
    acc = np.empty(0)
    val_acc = np.empty(0)

    for history in histories:
        loss = np.append(loss,history.history['loss'])
        val_loss = np.append(val_loss,history.history['val_loss'])
        acc = np.append(acc,history.history['triplet_acc'])
        val_acc = np.append(val_acc,history.history['val_triplet_acc'])


    history_ = np.array([loss,val_loss,acc,val_acc])
    np.save(PATH_SAVE+'2019.05.05.dogfacenet_v25.'+str(start+i)+'.h5',history_)
# Out:
# Beginning epoch number: 0
# Mode 3
# Epoch 1/1
# 169/300 [===============>..............] - ETA: 8:10 - loss: 5.8369 - triplet_acc: 0.050 - ETA: 5:51 - loss: 6.1105 - triplet_acc: 0.075 - ETA: 5:35 - loss: 5.7595 - triplet_acc: 0.150 - ETA: 5:19 - loss: 5.7650 - triplet_acc: 0.137 - ETA: 5:08 - loss: 5.4040 - triplet_acc: 0.180 - ETA: 5:05 - loss: 5.3923 - triplet_acc: 0.191 - ETA: 5:02 - loss: 5.4001 - triplet_acc: 0.200 - ETA: 5:00 - loss: 5.4399 - triplet_acc: 0.193 - ETA: 4:59 - loss: 5.4346 - triplet_acc: 0.200 - ETA: 4:55 - loss: 5.4132 - triplet_acc: 0.200 - ETA: 4:52 - loss: 5.4849 - triplet_acc: 0.209 - ETA: 4:51 - loss: 5.4359 - triplet_acc: 0.220 - ETA: 4:48 - loss: 5.4437 - triplet_acc: 0.219 - ETA: 4:46 - loss: 5.4011 - triplet_acc: 0.228 - ETA: 4:44 - loss: 5.3595 - triplet_acc: 0.233 - ETA: 4:43 - loss: 5.2989 - triplet_acc: 0.243 - ETA: 4:42 - loss: 5.1905 - triplet_acc: 0.250 - ETA: 4:40 - loss: 5.1513 - triplet_acc: 0.261 - ETA: 4:40 - loss: 5.1566 - triplet_acc: 0.271 - ETA: 4:38 - loss: 5.1176 - triplet_acc: 0.282 - ETA: 4:38 - loss: 5.0761 - triplet_acc: 0.288 - ETA: 4:37 - loss: 5.2357 - triplet_acc: 0.284 - ETA: 4:36 - loss: 5.2918 - triplet_acc: 0.280 - ETA: 4:36 - loss: 5.2251 - triplet_acc: 0.283 - ETA: 4:34 - loss: 5.2142 - triplet_acc: 0.278 - ETA: 4:33 - loss: 5.3206 - triplet_acc: 0.271 - ETA: 4:33 - loss: 5.3519 - triplet_acc: 0.275 - ETA: 4:31 - loss: 5.3561 - triplet_acc: 0.276 - ETA: 4:30 - loss: 5.3519 - triplet_acc: 0.270 - ETA: 4:28 - loss: 5.3122 - triplet_acc: 0.270 - ETA: 4:27 - loss: 5.3460 - triplet_acc: 0.266 - ETA: 4:27 - loss: 5.3185 - triplet_acc: 0.265 - ETA: 4:26 - loss: 5.3345 - triplet_acc: 0.263 - ETA: 4:24 - loss: 5.3730 - triplet_acc: 0.261 - ETA: 4:23 - loss: 5.4285 - triplet_acc: 0.258 - ETA: 4:22 - loss: 5.3774 - triplet_acc: 0.259 - ETA: 4:21 - loss: 5.3706 - triplet_acc: 0.259 - ETA: 4:20 - loss: 5.3180 - triplet_acc: 0.261 - ETA: 4:18 - loss: 5.2532 - triplet_acc: 0.270 - ETA: 4:17 - loss: 5.2619 - triplet_acc: 0.273 - ETA: 4:16 - loss: 5.3276 - triplet_acc: 0.269 - ETA: 4:16 - loss: 5.3363 - triplet_acc: 0.269 - ETA: 4:15 - loss: 5.2629 - triplet_acc: 0.277 - ETA: 4:14 - loss: 5.2774 - triplet_acc: 0.278 - ETA: 4:12 - loss: 5.3373 - triplet_acc: 0.275 - ETA: 4:11 - loss: 5.3126 - triplet_acc: 0.275 - ETA: 4:10 - loss: 5.2730 - triplet_acc: 0.276 - ETA: 4:08 - loss: 5.2209 - triplet_acc: 0.283 - ETA: 4:07 - loss: 5.1826 - triplet_acc: 0.285 - ETA: 4:07 - loss: 5.1362 - triplet_acc: 0.287 - ETA: 4:05 - loss: 5.1281 - triplet_acc: 0.288 - ETA: 4:04 - loss: 5.1841 - triplet_acc: 0.287 - ETA: 4:03 - loss: 5.1470 - triplet_acc: 0.290 - ETA: 4:03 - loss: 5.1193 - triplet_acc: 0.291 - ETA: 4:02 - loss: 5.0588 - triplet_acc: 0.298 - ETA: 4:01 - loss: 5.0114 - triplet_acc: 0.303 - ETA: 4:00 - loss: 5.0159 - triplet_acc: 0.305 - ETA: 3:59 - loss: 5.0118 - triplet_acc: 0.304 - ETA: 3:58 - loss: 4.9988 - triplet_acc: 0.305 - ETA: 3:57 - loss: 4.9682 - triplet_acc: 0.308 - ETA: 3:56 - loss: 4.9562 - triplet_acc: 0.309 - ETA: 3:55 - loss: 4.9222 - triplet_acc: 0.314 - ETA: 3:54 - loss: 4.9075 - triplet_acc: 0.315 - ETA: 3:52 - loss: 4.8959 - triplet_acc: 0.317 - ETA: 3:52 - loss: 4.8829 - triplet_acc: 0.320 - ETA: 3:51 - loss: 4.8720 - triplet_acc: 0.320 - ETA: 3:50 - loss: 4.8766 - triplet_acc: 0.320 - ETA: 3:50 - loss: 4.8486 - triplet_acc: 0.321 - ETA: 3:49 - loss: 4.8441 - triplet_acc: 0.322 - ETA: 3:48 - loss: 4.8313 - triplet_acc: 0.322 - ETA: 3:47 - loss: 4.8059 - triplet_acc: 0.326 - ETA: 3:46 - loss: 4.7979 - triplet_acc: 0.329 - ETA: 3:46 - loss: 4.7875 - triplet_acc: 0.332 - ETA: 3:44 - loss: 4.7882 - triplet_acc: 0.333 - ETA: 3:44 - loss: 4.7581 - triplet_acc: 0.336 - ETA: 3:43 - loss: 4.7899 - triplet_acc: 0.334 - ETA: 3:42 - loss: 4.7533 - triplet_acc: 0.337 - ETA: 3:41 - loss: 4.7569 - triplet_acc: 0.338 - ETA: 3:40 - loss: 4.7474 - triplet_acc: 0.340 - ETA: 3:39 - loss: 4.7364 - triplet_acc: 0.340 - ETA: 3:38 - loss: 4.7225 - triplet_acc: 0.343 - ETA: 3:37 - loss: 4.7151 - triplet_acc: 0.344 - ETA: 3:36 - loss: 4.7 ...
# Beginning epoch number: 1
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 6:13 - loss: 3.3072 - triplet_acc: 0.250 - ETA: 6:03 - loss: 3.1705 - triplet_acc: 0.325 - ETA: 5:54 - loss: 2.8312 - triplet_acc: 0.416 - ETA: 5:41 - loss: 2.9531 - triplet_acc: 0.437 - ETA: 5:34 - loss: 3.0480 - triplet_acc: 0.450 - ETA: 5:31 - loss: 2.8265 - triplet_acc: 0.491 - ETA: 5:23 - loss: 2.7206 - triplet_acc: 0.500 - ETA: 5:18 - loss: 2.7548 - triplet_acc: 0.487 - ETA: 5:12 - loss: 2.6662 - triplet_acc: 0.494 - ETA: 5:08 - loss: 2.5071 - triplet_acc: 0.515 - ETA: 5:05 - loss: 2.5089 - triplet_acc: 0.522 - ETA: 5:05 - loss: 2.4364 - triplet_acc: 0.529 - ETA: 5:05 - loss: 2.5814 - triplet_acc: 0.511 - ETA: 5:03 - loss: 2.5319 - triplet_acc: 0.521 - ETA: 5:01 - loss: 2.5127 - triplet_acc: 0.523 - ETA: 5:00 - loss: 2.5457 - triplet_acc: 0.528 - ETA: 4:57 - loss: 2.5525 - triplet_acc: 0.535 - ETA: 4:56 - loss: 2.5439 - triplet_acc: 0.533 - ETA: 4:56 - loss: 2.4927 - triplet_acc: 0.544 - ETA: 4:56 - loss: 2.6480 - triplet_acc: 0.545 - ETA: 4:57 - loss: 2.6048 - triplet_acc: 0.554 - ETA: 4:55 - loss: 2.7007 - triplet_acc: 0.547 - ETA: 4:55 - loss: 2.7130 - triplet_acc: 0.539 - ETA: 4:57 - loss: 2.7504 - triplet_acc: 0.535 - ETA: 4:54 - loss: 2.7502 - triplet_acc: 0.538 - ETA: 4:52 - loss: 2.7694 - triplet_acc: 0.532 - ETA: 4:51 - loss: 2.8003 - triplet_acc: 0.533 - ETA: 4:48 - loss: 2.8107 - triplet_acc: 0.532 - ETA: 4:47 - loss: 2.7776 - triplet_acc: 0.534 - ETA: 4:45 - loss: 2.8467 - triplet_acc: 0.531 - ETA: 4:43 - loss: 2.8936 - triplet_acc: 0.529 - ETA: 4:41 - loss: 2.9041 - triplet_acc: 0.529 - ETA: 4:42 - loss: 2.8893 - triplet_acc: 0.531 - ETA: 4:40 - loss: 2.9158 - triplet_acc: 0.529 - ETA: 4:38 - loss: 2.9156 - triplet_acc: 0.531 - ETA: 4:36 - loss: 2.8628 - triplet_acc: 0.534 - ETA: 4:35 - loss: 2.8391 - triplet_acc: 0.537 - ETA: 4:34 - loss: 2.8564 - triplet_acc: 0.538 - ETA: 4:33 - loss: 2.8525 - triplet_acc: 0.542 - ETA: 4:33 - loss: 2.8367 - triplet_acc: 0.542 - ETA: 4:32 - loss: 2.8877 - triplet_acc: 0.543 - ETA: 4:30 - loss: 2.8849 - triplet_acc: 0.546 - ETA: 4:29 - loss: 2.9056 - triplet_acc: 0.543 - ETA: 4:27 - loss: 2.8931 - triplet_acc: 0.544 - ETA: 4:25 - loss: 2.9657 - triplet_acc: 0.540 - ETA: 4:24 - loss: 2.9888 - triplet_acc: 0.538 - ETA: 4:22 - loss: 2.9355 - triplet_acc: 0.544 - ETA: 4:21 - loss: 2.9137 - triplet_acc: 0.544 - ETA: 4:21 - loss: 2.9541 - triplet_acc: 0.541 - ETA: 4:19 - loss: 2.9762 - triplet_acc: 0.538 - ETA: 4:18 - loss: 2.9707 - triplet_acc: 0.535 - ETA: 4:17 - loss: 2.9695 - triplet_acc: 0.535 - ETA: 4:16 - loss: 2.9880 - triplet_acc: 0.534 - ETA: 4:15 - loss: 2.9967 - triplet_acc: 0.531 - ETA: 4:13 - loss: 3.0126 - triplet_acc: 0.530 - ETA: 4:12 - loss: 2.9865 - triplet_acc: 0.533 - ETA: 4:11 - loss: 3.0496 - triplet_acc: 0.530 - ETA: 4:10 - loss: 3.0573 - triplet_acc: 0.527 - ETA: 4:09 - loss: 3.0496 - triplet_acc: 0.528 - ETA: 4:08 - loss: 3.0463 - triplet_acc: 0.527 - ETA: 4:07 - loss: 3.0228 - triplet_acc: 0.527 - ETA: 4:05 - loss: 3.0459 - triplet_acc: 0.523 - ETA: 4:04 - loss: 3.0666 - triplet_acc: 0.522 - ETA: 4:03 - loss: 3.0573 - triplet_acc: 0.521 - ETA: 4:03 - loss: 3.0550 - triplet_acc: 0.522 - ETA: 4:02 - loss: 3.0605 - triplet_acc: 0.522 - ETA: 4:01 - loss: 3.0374 - triplet_acc: 0.523 - ETA: 4:00 - loss: 3.0583 - triplet_acc: 0.523 - ETA: 3:59 - loss: 3.0535 - triplet_acc: 0.522 - ETA: 3:57 - loss: 3.0703 - triplet_acc: 0.523 - ETA: 3:56 - loss: 3.0594 - triplet_acc: 0.526 - ETA: 3:55 - loss: 3.0685 - triplet_acc: 0.523 - ETA: 3:54 - loss: 3.0605 - triplet_acc: 0.524 - ETA: 3:53 - loss: 3.0565 - triplet_acc: 0.525 - ETA: 3:51 - loss: 3.0438 - triplet_acc: 0.525 - ETA: 3:50 - loss: 3.0285 - triplet_acc: 0.525 - ETA: 3:49 - loss: 3.0124 - triplet_acc: 0.526 - ETA: 3:48 - loss: 2.9984 - triplet_acc: 0.525 - ETA: 3:46 - loss: 2.9799 - triplet_acc: 0.527 - ETA: 3:45 - loss: 2.9808 - triplet_acc: 0.526 - ETA: 3:45 - loss: 2.9929 - triplet_acc: 0.524 - ETA: 3:43 - loss: 2.9721 - triplet_acc: 0.526 - ETA: 3:42 - loss: 2.9 ...
# 300/300 [==============================] - ETA: 2:11 - loss: 2.9817 - triplet_acc: 0.526 - ETA: 2:10 - loss: 2.9741 - triplet_acc: 0.527 - ETA: 2:09 - loss: 2.9714 - triplet_acc: 0.526 - ETA: 2:08 - loss: 2.9652 - triplet_acc: 0.527 - ETA: 2:07 - loss: 2.9610 - triplet_acc: 0.527 - ETA: 2:06 - loss: 2.9716 - triplet_acc: 0.527 - ETA: 2:05 - loss: 2.9675 - triplet_acc: 0.527 - ETA: 2:04 - loss: 2.9626 - triplet_acc: 0.527 - ETA: 2:03 - loss: 2.9659 - triplet_acc: 0.526 - ETA: 2:02 - loss: 2.9618 - triplet_acc: 0.526 - ETA: 2:01 - loss: 2.9576 - triplet_acc: 0.526 - ETA: 2:00 - loss: 2.9526 - triplet_acc: 0.527 - ETA: 1:59 - loss: 2.9517 - triplet_acc: 0.527 - ETA: 1:58 - loss: 2.9444 - triplet_acc: 0.528 - ETA: 1:57 - loss: 2.9502 - triplet_acc: 0.527 - ETA: 1:56 - loss: 2.9406 - triplet_acc: 0.529 - ETA: 1:55 - loss: 2.9414 - triplet_acc: 0.529 - ETA: 1:54 - loss: 2.9342 - triplet_acc: 0.529 - ETA: 1:53 - loss: 2.9407 - triplet_acc: 0.528 - ETA: 1:52 - loss: 2.9302 - triplet_acc: 0.529 - ETA: 1:51 - loss: 2.9408 - triplet_acc: 0.528 - ETA: 1:50 - loss: 2.9443 - triplet_acc: 0.528 - ETA: 1:49 - loss: 2.9369 - triplet_acc: 0.528 - ETA: 1:48 - loss: 2.9336 - triplet_acc: 0.529 - ETA: 1:47 - loss: 2.9485 - triplet_acc: 0.527 - ETA: 1:46 - loss: 2.9475 - triplet_acc: 0.528 - ETA: 1:45 - loss: 2.9465 - triplet_acc: 0.528 - ETA: 1:44 - loss: 2.9436 - triplet_acc: 0.529 - ETA: 1:43 - loss: 2.9423 - triplet_acc: 0.529 - ETA: 1:42 - loss: 2.9395 - triplet_acc: 0.529 - ETA: 1:40 - loss: 2.9346 - triplet_acc: 0.530 - ETA: 1:39 - loss: 2.9476 - triplet_acc: 0.530 - ETA: 1:38 - loss: 2.9534 - triplet_acc: 0.529 - ETA: 1:37 - loss: 2.9491 - triplet_acc: 0.529 - ETA: 1:36 - loss: 2.9539 - triplet_acc: 0.529 - ETA: 1:35 - loss: 2.9504 - triplet_acc: 0.529 - ETA: 1:34 - loss: 2.9486 - triplet_acc: 0.529 - ETA: 1:33 - loss: 2.9511 - triplet_acc: 0.528 - ETA: 1:32 - loss: 2.9514 - triplet_acc: 0.528 - ETA: 1:31 - loss: 2.9462 - triplet_acc: 0.529 - ETA: 1:30 - loss: 2.9414 - triplet_acc: 0.528 - ETA: 1:29 - loss: 2.9385 - triplet_acc: 0.529 - ETA: 1:28 - loss: 2.9385 - triplet_acc: 0.529 - ETA: 1:27 - loss: 2.9300 - triplet_acc: 0.530 - ETA: 1:26 - loss: 2.9279 - triplet_acc: 0.530 - ETA: 1:25 - loss: 2.9229 - triplet_acc: 0.531 - ETA: 1:24 - loss: 2.9295 - triplet_acc: 0.530 - ETA: 1:23 - loss: 2.9228 - triplet_acc: 0.530 - ETA: 1:22 - loss: 2.9185 - triplet_acc: 0.531 - ETA: 1:21 - loss: 2.9112 - triplet_acc: 0.532 - ETA: 1:20 - loss: 2.9111 - triplet_acc: 0.531 - ETA: 1:19 - loss: 2.9124 - triplet_acc: 0.531 - ETA: 1:18 - loss: 2.9139 - triplet_acc: 0.531 - ETA: 1:17 - loss: 2.9076 - triplet_acc: 0.532 - ETA: 1:16 - loss: 2.9050 - triplet_acc: 0.532 - ETA: 1:15 - loss: 2.8994 - triplet_acc: 0.533 - ETA: 1:14 - loss: 2.9032 - triplet_acc: 0.533 - ETA: 1:13 - loss: 2.9010 - triplet_acc: 0.534 - ETA: 1:12 - loss: 2.9081 - triplet_acc: 0.534 - ETA: 1:11 - loss: 2.9041 - triplet_acc: 0.535 - ETA: 1:10 - loss: 2.9048 - triplet_acc: 0.534 - ETA: 1:09 - loss: 2.8982 - triplet_acc: 0.536 - ETA: 1:08 - loss: 2.8970 - triplet_acc: 0.536 - ETA: 1:07 - loss: 2.8918 - triplet_acc: 0.537 - ETA: 1:06 - loss: 2.8936 - triplet_acc: 0.537 - ETA: 1:05 - loss: 2.8859 - triplet_acc: 0.538 - ETA: 1:04 - loss: 2.8829 - triplet_acc: 0.538 - ETA: 1:03 - loss: 2.8725 - triplet_acc: 0.539 - ETA: 1:02 - loss: 2.8705 - triplet_acc: 0.539 - ETA: 1:01 - loss: 2.8649 - triplet_acc: 0.540 - ETA: 1:00 - loss: 2.8682 - triplet_acc: 0.539 - ETA: 59s - loss: 2.8736 - triplet_acc: 0.539 - ETA: 58s - loss: 2.8678 - triplet_acc: 0.53 - ETA: 57s - loss: 2.8617 - triplet_acc: 0.54 - ETA: 56s - loss: 2.8625 - triplet_acc: 0.54 - ETA: 55s - loss: 2.8631 - triplet_acc: 0.54 - ETA: 54s - loss: 2.8639 - triplet_acc: 0.54 - ETA: 53s - loss: 2.8623 - triplet_acc: 0.54 - ETA: 52s - loss: 2.8601 - triplet_acc: 0.54 - ETA: 51s - loss: 2.8585 - triplet_acc: 0.54 - ETA: 50s - loss: 2.8539 - triplet_acc: 0.54 - ETA: 49s - loss: 2.8542 - triplet_acc: 0.54 - ETA: 48s - loss: 2.8566 - triplet_acc: 0.5 ...
# Beginning epoch number: 2
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:17 - loss: 2.5541 - triplet_acc: 0.450 - ETA: 5:07 - loss: 1.8821 - triplet_acc: 0.600 - ETA: 5:04 - loss: 2.1490 - triplet_acc: 0.600 - ETA: 4:55 - loss: 2.2220 - triplet_acc: 0.587 - ETA: 4:54 - loss: 2.3170 - triplet_acc: 0.600 - ETA: 4:48 - loss: 2.6476 - triplet_acc: 0.566 - ETA: 4:46 - loss: 2.5439 - triplet_acc: 0.571 - ETA: 4:46 - loss: 2.4574 - triplet_acc: 0.562 - ETA: 4:45 - loss: 2.6570 - triplet_acc: 0.561 - ETA: 4:42 - loss: 2.7236 - triplet_acc: 0.555 - ETA: 4:41 - loss: 2.6587 - triplet_acc: 0.563 - ETA: 4:41 - loss: 2.6314 - triplet_acc: 0.566 - ETA: 4:40 - loss: 2.6480 - triplet_acc: 0.576 - ETA: 4:40 - loss: 2.6242 - triplet_acc: 0.571 - ETA: 4:38 - loss: 2.6000 - triplet_acc: 0.560 - ETA: 4:36 - loss: 2.6448 - triplet_acc: 0.550 - ETA: 4:35 - loss: 2.7040 - triplet_acc: 0.547 - ETA: 4:33 - loss: 2.6399 - triplet_acc: 0.555 - ETA: 4:32 - loss: 2.5805 - triplet_acc: 0.552 - ETA: 4:33 - loss: 2.6161 - triplet_acc: 0.547 - ETA: 4:31 - loss: 2.7153 - triplet_acc: 0.542 - ETA: 4:30 - loss: 2.6997 - triplet_acc: 0.540 - ETA: 4:29 - loss: 2.6746 - triplet_acc: 0.545 - ETA: 4:28 - loss: 2.6737 - triplet_acc: 0.541 - ETA: 4:27 - loss: 2.7425 - triplet_acc: 0.540 - ETA: 4:25 - loss: 2.7076 - triplet_acc: 0.546 - ETA: 4:24 - loss: 2.6403 - triplet_acc: 0.551 - ETA: 4:22 - loss: 2.6729 - triplet_acc: 0.548 - ETA: 4:20 - loss: 2.6912 - triplet_acc: 0.546 - ETA: 4:20 - loss: 2.6205 - triplet_acc: 0.558 - ETA: 4:18 - loss: 2.5909 - triplet_acc: 0.564 - ETA: 4:18 - loss: 2.5478 - triplet_acc: 0.568 - ETA: 4:16 - loss: 2.6065 - triplet_acc: 0.568 - ETA: 4:16 - loss: 2.6028 - triplet_acc: 0.566 - ETA: 4:15 - loss: 2.6305 - triplet_acc: 0.567 - ETA: 4:13 - loss: 2.6985 - triplet_acc: 0.563 - ETA: 4:13 - loss: 2.6911 - triplet_acc: 0.566 - ETA: 4:12 - loss: 2.7140 - triplet_acc: 0.563 - ETA: 4:10 - loss: 2.7299 - triplet_acc: 0.560 - ETA: 4:09 - loss: 2.6953 - triplet_acc: 0.566 - ETA: 4:08 - loss: 2.6743 - triplet_acc: 0.567 - ETA: 4:07 - loss: 2.6767 - triplet_acc: 0.566 - ETA: 4:05 - loss: 2.7124 - triplet_acc: 0.559 - ETA: 4:04 - loss: 2.6845 - triplet_acc: 0.561 - ETA: 4:03 - loss: 2.6840 - triplet_acc: 0.562 - ETA: 4:02 - loss: 2.6820 - triplet_acc: 0.559 - ETA: 4:01 - loss: 2.6726 - triplet_acc: 0.558 - ETA: 4:00 - loss: 2.6624 - triplet_acc: 0.559 - ETA: 3:59 - loss: 2.6826 - triplet_acc: 0.559 - ETA: 3:58 - loss: 2.6660 - triplet_acc: 0.561 - ETA: 3:58 - loss: 2.6596 - triplet_acc: 0.560 - ETA: 3:57 - loss: 2.6669 - triplet_acc: 0.559 - ETA: 3:57 - loss: 2.6727 - triplet_acc: 0.557 - ETA: 3:56 - loss: 2.7753 - triplet_acc: 0.551 - ETA: 3:55 - loss: 2.7502 - triplet_acc: 0.554 - ETA: 3:54 - loss: 2.7163 - triplet_acc: 0.557 - ETA: 3:53 - loss: 2.7430 - triplet_acc: 0.557 - ETA: 3:52 - loss: 2.7381 - triplet_acc: 0.558 - ETA: 3:51 - loss: 2.7065 - triplet_acc: 0.560 - ETA: 3:50 - loss: 2.6938 - triplet_acc: 0.559 - ETA: 3:50 - loss: 2.6837 - triplet_acc: 0.559 - ETA: 3:48 - loss: 2.6846 - triplet_acc: 0.559 - ETA: 3:47 - loss: 2.6704 - triplet_acc: 0.562 - ETA: 3:47 - loss: 2.6774 - triplet_acc: 0.560 - ETA: 3:46 - loss: 2.7012 - triplet_acc: 0.556 - ETA: 3:45 - loss: 2.7104 - triplet_acc: 0.554 - ETA: 3:45 - loss: 2.7021 - triplet_acc: 0.554 - ETA: 3:44 - loss: 2.7018 - triplet_acc: 0.555 - ETA: 3:43 - loss: 2.7215 - triplet_acc: 0.556 - ETA: 3:42 - loss: 2.7272 - triplet_acc: 0.556 - ETA: 3:41 - loss: 2.7311 - triplet_acc: 0.553 - ETA: 3:40 - loss: 2.7146 - triplet_acc: 0.554 - ETA: 3:39 - loss: 2.7078 - triplet_acc: 0.553 - ETA: 3:38 - loss: 2.7015 - triplet_acc: 0.555 - ETA: 3:37 - loss: 2.6976 - triplet_acc: 0.556 - ETA: 3:36 - loss: 2.7197 - triplet_acc: 0.556 - ETA: 3:35 - loss: 2.7044 - triplet_acc: 0.557 - ETA: 3:34 - loss: 2.7108 - triplet_acc: 0.557 - ETA: 3:33 - loss: 2.7076 - triplet_acc: 0.557 - ETA: 3:32 - loss: 2.7136 - triplet_acc: 0.558 - ETA: 3:31 - loss: 2.7071 - triplet_acc: 0.560 - ETA: 3:30 - loss: 2.7154 - triplet_acc: 0.559 - ETA: 3:29 - loss: 2.7 ...
# Beginning epoch number: 3
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:39 - loss: 0.8750 - triplet_acc: 0.700 - ETA: 5:06 - loss: 1.8654 - triplet_acc: 0.600 - ETA: 5:01 - loss: 1.8376 - triplet_acc: 0.583 - ETA: 5:01 - loss: 1.4832 - triplet_acc: 0.625 - ETA: 4:54 - loss: 2.0827 - triplet_acc: 0.590 - ETA: 4:55 - loss: 2.1666 - triplet_acc: 0.600 - ETA: 5:01 - loss: 2.3695 - triplet_acc: 0.592 - ETA: 4:58 - loss: 2.3091 - triplet_acc: 0.600 - ETA: 5:03 - loss: 2.2643 - triplet_acc: 0.611 - ETA: 5:02 - loss: 2.1541 - triplet_acc: 0.625 - ETA: 5:01 - loss: 2.2229 - triplet_acc: 0.622 - ETA: 4:57 - loss: 2.1065 - triplet_acc: 0.633 - ETA: 4:55 - loss: 2.2123 - triplet_acc: 0.638 - ETA: 4:55 - loss: 2.3398 - triplet_acc: 0.628 - ETA: 4:56 - loss: 2.4699 - triplet_acc: 0.620 - ETA: 4:53 - loss: 2.3694 - triplet_acc: 0.628 - ETA: 4:52 - loss: 2.4290 - triplet_acc: 0.623 - ETA: 4:53 - loss: 2.4273 - triplet_acc: 0.627 - ETA: 4:52 - loss: 2.5284 - triplet_acc: 0.628 - ETA: 4:51 - loss: 2.4850 - triplet_acc: 0.632 - ETA: 4:50 - loss: 2.5460 - triplet_acc: 0.628 - ETA: 4:50 - loss: 2.5951 - triplet_acc: 0.622 - ETA: 4:51 - loss: 2.5556 - triplet_acc: 0.628 - ETA: 4:51 - loss: 2.5338 - triplet_acc: 0.627 - ETA: 4:51 - loss: 2.5905 - triplet_acc: 0.626 - ETA: 4:49 - loss: 2.5471 - triplet_acc: 0.626 - ETA: 4:48 - loss: 2.5761 - triplet_acc: 0.620 - ETA: 4:46 - loss: 2.5514 - triplet_acc: 0.625 - ETA: 4:45 - loss: 2.5353 - triplet_acc: 0.625 - ETA: 4:43 - loss: 2.5810 - triplet_acc: 0.620 - ETA: 4:43 - loss: 2.5536 - triplet_acc: 0.622 - ETA: 4:41 - loss: 2.5786 - triplet_acc: 0.614 - ETA: 4:39 - loss: 2.5474 - triplet_acc: 0.616 - ETA: 4:39 - loss: 2.5715 - triplet_acc: 0.611 - ETA: 4:38 - loss: 2.5317 - triplet_acc: 0.614 - ETA: 4:36 - loss: 2.5259 - triplet_acc: 0.613 - ETA: 4:34 - loss: 2.5918 - triplet_acc: 0.609 - ETA: 4:32 - loss: 2.5967 - triplet_acc: 0.607 - ETA: 4:31 - loss: 2.6082 - triplet_acc: 0.606 - ETA: 4:31 - loss: 2.5985 - triplet_acc: 0.606 - ETA: 4:30 - loss: 2.5640 - triplet_acc: 0.608 - ETA: 4:29 - loss: 2.5581 - triplet_acc: 0.608 - ETA: 4:29 - loss: 2.5346 - triplet_acc: 0.611 - ETA: 4:28 - loss: 2.5260 - triplet_acc: 0.612 - ETA: 4:27 - loss: 2.5392 - triplet_acc: 0.610 - ETA: 4:25 - loss: 2.5359 - triplet_acc: 0.609 - ETA: 4:25 - loss: 2.5209 - triplet_acc: 0.609 - ETA: 4:23 - loss: 2.5241 - triplet_acc: 0.609 - ETA: 4:22 - loss: 2.5045 - triplet_acc: 0.610 - ETA: 4:20 - loss: 2.4955 - triplet_acc: 0.613 - ETA: 4:19 - loss: 2.4992 - triplet_acc: 0.613 - ETA: 4:17 - loss: 2.4821 - triplet_acc: 0.614 - ETA: 4:16 - loss: 2.4582 - triplet_acc: 0.617 - ETA: 4:15 - loss: 2.4230 - triplet_acc: 0.618 - ETA: 4:14 - loss: 2.4297 - triplet_acc: 0.617 - ETA: 4:13 - loss: 2.4221 - triplet_acc: 0.617 - ETA: 4:11 - loss: 2.4182 - triplet_acc: 0.616 - ETA: 4:10 - loss: 2.4085 - triplet_acc: 0.616 - ETA: 4:09 - loss: 2.3949 - triplet_acc: 0.616 - ETA: 4:08 - loss: 2.4204 - triplet_acc: 0.615 - ETA: 4:06 - loss: 2.4221 - triplet_acc: 0.614 - ETA: 4:05 - loss: 2.4260 - triplet_acc: 0.615 - ETA: 4:04 - loss: 2.4206 - triplet_acc: 0.613 - ETA: 4:03 - loss: 2.4083 - triplet_acc: 0.613 - ETA: 4:03 - loss: 2.4015 - triplet_acc: 0.614 - ETA: 4:01 - loss: 2.3904 - triplet_acc: 0.615 - ETA: 4:01 - loss: 2.3824 - triplet_acc: 0.616 - ETA: 4:00 - loss: 2.3700 - triplet_acc: 0.616 - ETA: 3:58 - loss: 2.3529 - triplet_acc: 0.618 - ETA: 3:57 - loss: 2.3614 - triplet_acc: 0.617 - ETA: 3:55 - loss: 2.3535 - triplet_acc: 0.617 - ETA: 3:55 - loss: 2.3702 - triplet_acc: 0.614 - ETA: 3:54 - loss: 2.3789 - triplet_acc: 0.613 - ETA: 3:53 - loss: 2.3755 - triplet_acc: 0.614 - ETA: 3:51 - loss: 2.3593 - triplet_acc: 0.615 - ETA: 3:50 - loss: 2.3594 - triplet_acc: 0.613 - ETA: 3:50 - loss: 2.3603 - triplet_acc: 0.614 - ETA: 3:49 - loss: 2.3513 - triplet_acc: 0.614 - ETA: 3:48 - loss: 2.3532 - triplet_acc: 0.612 - ETA: 3:46 - loss: 2.3554 - triplet_acc: 0.612 - ETA: 3:45 - loss: 2.3478 - triplet_acc: 0.614 - ETA: 3:44 - loss: 2.3457 - triplet_acc: 0.614 - ETA: 3:43 - loss: 2.3 ...
# 300/300 [==============================] - ETA: 2:10 - loss: 2.3652 - triplet_acc: 0.615 - ETA: 2:09 - loss: 2.3554 - triplet_acc: 0.616 - ETA: 2:08 - loss: 2.3561 - triplet_acc: 0.616 - ETA: 2:07 - loss: 2.3566 - triplet_acc: 0.617 - ETA: 2:06 - loss: 2.3500 - triplet_acc: 0.617 - ETA: 2:05 - loss: 2.3393 - triplet_acc: 0.619 - ETA: 2:04 - loss: 2.3324 - triplet_acc: 0.620 - ETA: 2:03 - loss: 2.3350 - triplet_acc: 0.620 - ETA: 2:02 - loss: 2.3340 - triplet_acc: 0.620 - ETA: 2:01 - loss: 2.3374 - triplet_acc: 0.619 - ETA: 2:00 - loss: 2.3335 - triplet_acc: 0.619 - ETA: 1:59 - loss: 2.3424 - triplet_acc: 0.619 - ETA: 1:58 - loss: 2.3379 - triplet_acc: 0.619 - ETA: 1:57 - loss: 2.3401 - triplet_acc: 0.619 - ETA: 1:56 - loss: 2.3495 - triplet_acc: 0.618 - ETA: 1:55 - loss: 2.3515 - triplet_acc: 0.618 - ETA: 1:54 - loss: 2.3589 - triplet_acc: 0.616 - ETA: 1:52 - loss: 2.3562 - triplet_acc: 0.617 - ETA: 1:51 - loss: 2.3532 - triplet_acc: 0.617 - ETA: 1:50 - loss: 2.3608 - triplet_acc: 0.616 - ETA: 1:49 - loss: 2.3539 - triplet_acc: 0.617 - ETA: 1:48 - loss: 2.3587 - triplet_acc: 0.616 - ETA: 1:47 - loss: 2.3653 - triplet_acc: 0.616 - ETA: 1:46 - loss: 2.3690 - triplet_acc: 0.616 - ETA: 1:45 - loss: 2.3644 - triplet_acc: 0.617 - ETA: 1:44 - loss: 2.3640 - triplet_acc: 0.617 - ETA: 1:43 - loss: 2.3668 - triplet_acc: 0.617 - ETA: 1:42 - loss: 2.3706 - triplet_acc: 0.617 - ETA: 1:41 - loss: 2.3685 - triplet_acc: 0.617 - ETA: 1:40 - loss: 2.3618 - triplet_acc: 0.618 - ETA: 1:39 - loss: 2.3683 - triplet_acc: 0.617 - ETA: 1:38 - loss: 2.3655 - triplet_acc: 0.618 - ETA: 1:37 - loss: 2.3664 - triplet_acc: 0.619 - ETA: 1:36 - loss: 2.3740 - triplet_acc: 0.618 - ETA: 1:35 - loss: 2.3751 - triplet_acc: 0.618 - ETA: 1:34 - loss: 2.3713 - triplet_acc: 0.618 - ETA: 1:33 - loss: 2.3727 - triplet_acc: 0.619 - ETA: 1:32 - loss: 2.3747 - triplet_acc: 0.618 - ETA: 1:31 - loss: 2.3874 - triplet_acc: 0.617 - ETA: 1:30 - loss: 2.3797 - triplet_acc: 0.618 - ETA: 1:29 - loss: 2.3798 - triplet_acc: 0.618 - ETA: 1:28 - loss: 2.3910 - triplet_acc: 0.616 - ETA: 1:27 - loss: 2.3939 - triplet_acc: 0.617 - ETA: 1:26 - loss: 2.3901 - triplet_acc: 0.617 - ETA: 1:25 - loss: 2.3960 - triplet_acc: 0.616 - ETA: 1:24 - loss: 2.3996 - triplet_acc: 0.615 - ETA: 1:23 - loss: 2.4044 - triplet_acc: 0.615 - ETA: 1:22 - loss: 2.4009 - triplet_acc: 0.616 - ETA: 1:21 - loss: 2.4047 - triplet_acc: 0.615 - ETA: 1:20 - loss: 2.4145 - triplet_acc: 0.614 - ETA: 1:19 - loss: 2.4231 - triplet_acc: 0.613 - ETA: 1:18 - loss: 2.4243 - triplet_acc: 0.613 - ETA: 1:17 - loss: 2.4206 - triplet_acc: 0.613 - ETA: 1:16 - loss: 2.4137 - triplet_acc: 0.614 - ETA: 1:15 - loss: 2.4206 - triplet_acc: 0.614 - ETA: 1:14 - loss: 2.4224 - triplet_acc: 0.613 - ETA: 1:13 - loss: 2.4246 - triplet_acc: 0.613 - ETA: 1:12 - loss: 2.4256 - triplet_acc: 0.612 - ETA: 1:11 - loss: 2.4242 - triplet_acc: 0.611 - ETA: 1:10 - loss: 2.4243 - triplet_acc: 0.612 - ETA: 1:09 - loss: 2.4244 - triplet_acc: 0.612 - ETA: 1:08 - loss: 2.4207 - triplet_acc: 0.612 - ETA: 1:07 - loss: 2.4220 - triplet_acc: 0.612 - ETA: 1:06 - loss: 2.4185 - triplet_acc: 0.612 - ETA: 1:05 - loss: 2.4132 - triplet_acc: 0.613 - ETA: 1:04 - loss: 2.4172 - triplet_acc: 0.612 - ETA: 1:03 - loss: 2.4140 - triplet_acc: 0.612 - ETA: 1:02 - loss: 2.4091 - triplet_acc: 0.612 - ETA: 1:01 - loss: 2.4124 - triplet_acc: 0.612 - ETA: 1:00 - loss: 2.4089 - triplet_acc: 0.612 - ETA: 59s - loss: 2.4025 - triplet_acc: 0.613 - ETA: 58s - loss: 2.4118 - triplet_acc: 0.61 - ETA: 57s - loss: 2.4188 - triplet_acc: 0.61 - ETA: 56s - loss: 2.4103 - triplet_acc: 0.61 - ETA: 55s - loss: 2.4114 - triplet_acc: 0.61 - ETA: 54s - loss: 2.4152 - triplet_acc: 0.61 - ETA: 53s - loss: 2.4124 - triplet_acc: 0.61 - ETA: 52s - loss: 2.4061 - triplet_acc: 0.61 - ETA: 51s - loss: 2.3994 - triplet_acc: 0.61 - ETA: 50s - loss: 2.4109 - triplet_acc: 0.61 - ETA: 49s - loss: 2.4155 - triplet_acc: 0.61 - ETA: 48s - loss: 2.4138 - triplet_acc: 0.61 - ETA: 47s - loss: 2.4173 - triplet_acc: 0.61  ...
# Beginning epoch number: 4
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:31 - loss: 3.0346 - triplet_acc: 0.500 - ETA: 5:21 - loss: 2.8539 - triplet_acc: 0.500 - ETA: 5:09 - loss: 2.2166 - triplet_acc: 0.566 - ETA: 4:58 - loss: 1.9554 - triplet_acc: 0.575 - ETA: 4:53 - loss: 1.9607 - triplet_acc: 0.600 - ETA: 4:48 - loss: 2.0199 - triplet_acc: 0.591 - ETA: 4:53 - loss: 2.1359 - triplet_acc: 0.585 - ETA: 4:56 - loss: 2.4638 - triplet_acc: 0.575 - ETA: 4:55 - loss: 2.5467 - triplet_acc: 0.572 - ETA: 4:54 - loss: 2.4554 - triplet_acc: 0.585 - ETA: 4:52 - loss: 2.6377 - triplet_acc: 0.572 - ETA: 4:52 - loss: 2.7770 - triplet_acc: 0.562 - ETA: 4:51 - loss: 2.7583 - triplet_acc: 0.569 - ETA: 4:48 - loss: 2.7678 - triplet_acc: 0.567 - ETA: 4:47 - loss: 2.7781 - triplet_acc: 0.560 - ETA: 4:46 - loss: 2.6445 - triplet_acc: 0.578 - ETA: 4:45 - loss: 2.6044 - triplet_acc: 0.582 - ETA: 4:43 - loss: 2.6273 - triplet_acc: 0.575 - ETA: 4:41 - loss: 2.6345 - triplet_acc: 0.573 - ETA: 4:40 - loss: 2.5339 - triplet_acc: 0.582 - ETA: 4:40 - loss: 2.4918 - triplet_acc: 0.585 - ETA: 4:38 - loss: 2.4387 - triplet_acc: 0.586 - ETA: 4:37 - loss: 2.4708 - triplet_acc: 0.587 - ETA: 4:35 - loss: 2.4636 - triplet_acc: 0.585 - ETA: 4:34 - loss: 2.4375 - triplet_acc: 0.592 - ETA: 4:33 - loss: 2.4542 - triplet_acc: 0.588 - ETA: 4:31 - loss: 2.4253 - triplet_acc: 0.596 - ETA: 4:29 - loss: 2.4265 - triplet_acc: 0.594 - ETA: 4:27 - loss: 2.4680 - triplet_acc: 0.594 - ETA: 4:27 - loss: 2.4311 - triplet_acc: 0.596 - ETA: 4:25 - loss: 2.4496 - triplet_acc: 0.591 - ETA: 4:24 - loss: 2.3955 - triplet_acc: 0.596 - ETA: 4:23 - loss: 2.3547 - triplet_acc: 0.603 - ETA: 4:21 - loss: 2.3011 - triplet_acc: 0.608 - ETA: 4:21 - loss: 2.3173 - triplet_acc: 0.604 - ETA: 4:20 - loss: 2.2873 - triplet_acc: 0.601 - ETA: 4:18 - loss: 2.2656 - triplet_acc: 0.606 - ETA: 4:17 - loss: 2.2711 - triplet_acc: 0.609 - ETA: 4:16 - loss: 2.2548 - triplet_acc: 0.609 - ETA: 4:15 - loss: 2.2264 - triplet_acc: 0.610 - ETA: 4:14 - loss: 2.2023 - triplet_acc: 0.612 - ETA: 4:12 - loss: 2.2441 - triplet_acc: 0.610 - ETA: 4:12 - loss: 2.2361 - triplet_acc: 0.609 - ETA: 4:11 - loss: 2.3029 - triplet_acc: 0.605 - ETA: 4:10 - loss: 2.2667 - triplet_acc: 0.606 - ETA: 4:09 - loss: 2.2852 - triplet_acc: 0.607 - ETA: 4:08 - loss: 2.2909 - triplet_acc: 0.606 - ETA: 4:07 - loss: 2.2721 - triplet_acc: 0.607 - ETA: 4:06 - loss: 2.3169 - triplet_acc: 0.601 - ETA: 4:05 - loss: 2.3336 - triplet_acc: 0.601 - ETA: 4:04 - loss: 2.3104 - triplet_acc: 0.603 - ETA: 4:02 - loss: 2.3138 - triplet_acc: 0.605 - ETA: 4:02 - loss: 2.3015 - triplet_acc: 0.607 - ETA: 4:01 - loss: 2.3267 - triplet_acc: 0.604 - ETA: 4:00 - loss: 2.3151 - triplet_acc: 0.606 - ETA: 3:59 - loss: 2.3234 - triplet_acc: 0.605 - ETA: 3:58 - loss: 2.3121 - triplet_acc: 0.604 - ETA: 3:56 - loss: 2.2994 - triplet_acc: 0.607 - ETA: 3:56 - loss: 2.2994 - triplet_acc: 0.607 - ETA: 3:55 - loss: 2.3281 - triplet_acc: 0.606 - ETA: 3:54 - loss: 2.3326 - triplet_acc: 0.605 - ETA: 3:53 - loss: 2.3331 - triplet_acc: 0.607 - ETA: 3:51 - loss: 2.3273 - triplet_acc: 0.608 - ETA: 3:51 - loss: 2.3055 - triplet_acc: 0.612 - ETA: 3:50 - loss: 2.3062 - triplet_acc: 0.613 - ETA: 3:49 - loss: 2.2996 - triplet_acc: 0.615 - ETA: 3:47 - loss: 2.2995 - triplet_acc: 0.615 - ETA: 3:46 - loss: 2.2753 - triplet_acc: 0.618 - ETA: 3:45 - loss: 2.2642 - triplet_acc: 0.621 - ETA: 3:45 - loss: 2.2623 - triplet_acc: 0.622 - ETA: 3:43 - loss: 2.2711 - triplet_acc: 0.620 - ETA: 3:42 - loss: 2.2505 - triplet_acc: 0.622 - ETA: 3:41 - loss: 2.2413 - triplet_acc: 0.624 - ETA: 3:41 - loss: 2.2264 - triplet_acc: 0.624 - ETA: 3:40 - loss: 2.2272 - triplet_acc: 0.625 - ETA: 3:39 - loss: 2.2279 - triplet_acc: 0.626 - ETA: 3:37 - loss: 2.2063 - triplet_acc: 0.629 - ETA: 3:37 - loss: 2.1950 - triplet_acc: 0.630 - ETA: 3:35 - loss: 2.2146 - triplet_acc: 0.628 - ETA: 3:34 - loss: 2.2290 - triplet_acc: 0.627 - ETA: 3:33 - loss: 2.2054 - triplet_acc: 0.630 - ETA: 3:32 - loss: 2.1936 - triplet_acc: 0.631 - ETA: 3:32 - loss: 2.1 ...
# Beginning epoch number: 5
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:17 - loss: 1.2966 - triplet_acc: 0.700 - ETA: 5:33 - loss: 1.6840 - triplet_acc: 0.675 - ETA: 5:13 - loss: 1.6067 - triplet_acc: 0.700 - ETA: 5:11 - loss: 1.8808 - triplet_acc: 0.662 - ETA: 5:03 - loss: 2.0551 - triplet_acc: 0.670 - ETA: 5:04 - loss: 2.1753 - triplet_acc: 0.675 - ETA: 4:58 - loss: 1.9173 - triplet_acc: 0.692 - ETA: 4:52 - loss: 1.7994 - triplet_acc: 0.706 - ETA: 4:50 - loss: 1.7777 - triplet_acc: 0.700 - ETA: 4:47 - loss: 1.9439 - triplet_acc: 0.680 - ETA: 4:46 - loss: 2.2202 - triplet_acc: 0.654 - ETA: 4:45 - loss: 2.0882 - triplet_acc: 0.670 - ETA: 4:42 - loss: 2.1426 - triplet_acc: 0.665 - ETA: 4:40 - loss: 2.1329 - triplet_acc: 0.667 - ETA: 4:37 - loss: 2.1775 - triplet_acc: 0.670 - ETA: 4:38 - loss: 2.1463 - triplet_acc: 0.675 - ETA: 4:35 - loss: 2.1830 - triplet_acc: 0.667 - ETA: 4:34 - loss: 2.1572 - triplet_acc: 0.666 - ETA: 4:32 - loss: 2.1030 - triplet_acc: 0.671 - ETA: 4:31 - loss: 2.0583 - triplet_acc: 0.677 - ETA: 4:32 - loss: 2.1139 - triplet_acc: 0.671 - ETA: 4:32 - loss: 2.1108 - triplet_acc: 0.665 - ETA: 4:31 - loss: 2.1374 - triplet_acc: 0.660 - ETA: 4:30 - loss: 2.0996 - triplet_acc: 0.662 - ETA: 4:30 - loss: 2.0482 - triplet_acc: 0.668 - ETA: 4:28 - loss: 2.0051 - triplet_acc: 0.667 - ETA: 4:28 - loss: 2.0039 - triplet_acc: 0.670 - ETA: 4:27 - loss: 1.9613 - triplet_acc: 0.673 - ETA: 4:25 - loss: 1.9187 - triplet_acc: 0.677 - ETA: 4:25 - loss: 1.9369 - triplet_acc: 0.678 - ETA: 4:23 - loss: 1.9325 - triplet_acc: 0.675 - ETA: 4:22 - loss: 2.0058 - triplet_acc: 0.671 - ETA: 4:22 - loss: 1.9658 - triplet_acc: 0.678 - ETA: 4:21 - loss: 1.9560 - triplet_acc: 0.675 - ETA: 4:20 - loss: 1.9265 - triplet_acc: 0.677 - ETA: 4:19 - loss: 1.9077 - triplet_acc: 0.679 - ETA: 4:18 - loss: 1.8846 - triplet_acc: 0.679 - ETA: 4:17 - loss: 1.8595 - triplet_acc: 0.684 - ETA: 4:16 - loss: 1.8618 - triplet_acc: 0.684 - ETA: 4:16 - loss: 1.8644 - triplet_acc: 0.686 - ETA: 4:14 - loss: 1.8774 - triplet_acc: 0.681 - ETA: 4:13 - loss: 1.8569 - triplet_acc: 0.681 - ETA: 4:12 - loss: 1.8404 - triplet_acc: 0.683 - ETA: 4:11 - loss: 1.8410 - triplet_acc: 0.684 - ETA: 4:10 - loss: 1.8274 - triplet_acc: 0.686 - ETA: 4:08 - loss: 1.8020 - triplet_acc: 0.688 - ETA: 4:07 - loss: 1.8244 - triplet_acc: 0.685 - ETA: 4:06 - loss: 1.8058 - triplet_acc: 0.686 - ETA: 4:05 - loss: 1.8446 - triplet_acc: 0.682 - ETA: 4:04 - loss: 1.9090 - triplet_acc: 0.680 - ETA: 4:03 - loss: 1.9138 - triplet_acc: 0.680 - ETA: 4:02 - loss: 1.9405 - triplet_acc: 0.680 - ETA: 4:01 - loss: 1.9297 - triplet_acc: 0.684 - ETA: 4:01 - loss: 1.8981 - triplet_acc: 0.686 - ETA: 4:00 - loss: 1.9350 - triplet_acc: 0.680 - ETA: 3:58 - loss: 1.9250 - triplet_acc: 0.681 - ETA: 3:57 - loss: 1.9429 - triplet_acc: 0.680 - ETA: 3:57 - loss: 1.9760 - triplet_acc: 0.676 - ETA: 3:56 - loss: 1.9701 - triplet_acc: 0.678 - ETA: 3:55 - loss: 1.9502 - triplet_acc: 0.679 - ETA: 3:54 - loss: 1.9299 - triplet_acc: 0.682 - ETA: 3:53 - loss: 1.9251 - triplet_acc: 0.681 - ETA: 3:52 - loss: 1.9291 - triplet_acc: 0.681 - ETA: 3:51 - loss: 1.9157 - triplet_acc: 0.680 - ETA: 3:50 - loss: 1.9259 - triplet_acc: 0.678 - ETA: 3:49 - loss: 1.9209 - triplet_acc: 0.679 - ETA: 3:48 - loss: 1.9276 - triplet_acc: 0.676 - ETA: 3:47 - loss: 1.9376 - triplet_acc: 0.676 - ETA: 3:46 - loss: 1.9219 - triplet_acc: 0.677 - ETA: 3:45 - loss: 1.9303 - triplet_acc: 0.677 - ETA: 3:44 - loss: 1.9539 - triplet_acc: 0.675 - ETA: 3:43 - loss: 1.9739 - triplet_acc: 0.672 - ETA: 3:42 - loss: 1.9624 - triplet_acc: 0.674 - ETA: 3:40 - loss: 1.9662 - triplet_acc: 0.674 - ETA: 3:39 - loss: 1.9514 - triplet_acc: 0.675 - ETA: 3:38 - loss: 1.9696 - triplet_acc: 0.673 - ETA: 3:38 - loss: 1.9542 - triplet_acc: 0.675 - ETA: 3:37 - loss: 1.9519 - triplet_acc: 0.675 - ETA: 3:35 - loss: 1.9465 - triplet_acc: 0.674 - ETA: 3:34 - loss: 1.9459 - triplet_acc: 0.674 - ETA: 3:33 - loss: 1.9411 - triplet_acc: 0.674 - ETA: 3:33 - loss: 1.9434 - triplet_acc: 0.675 - ETA: 3:32 - loss: 1.9 ...
# 300/300 [==============================] - ETA: 2:09 - loss: 2.0311 - triplet_acc: 0.663 - ETA: 2:08 - loss: 2.0265 - triplet_acc: 0.663 - ETA: 2:07 - loss: 2.0226 - triplet_acc: 0.663 - ETA: 2:06 - loss: 2.0138 - triplet_acc: 0.664 - ETA: 2:05 - loss: 2.0133 - triplet_acc: 0.664 - ETA: 2:04 - loss: 2.0167 - triplet_acc: 0.664 - ETA: 2:03 - loss: 2.0165 - triplet_acc: 0.664 - ETA: 2:02 - loss: 2.0349 - triplet_acc: 0.662 - ETA: 2:01 - loss: 2.0449 - triplet_acc: 0.662 - ETA: 2:00 - loss: 2.0554 - triplet_acc: 0.660 - ETA: 1:59 - loss: 2.0503 - triplet_acc: 0.660 - ETA: 1:58 - loss: 2.0522 - triplet_acc: 0.660 - ETA: 1:57 - loss: 2.0467 - triplet_acc: 0.660 - ETA: 1:56 - loss: 2.0463 - triplet_acc: 0.660 - ETA: 1:55 - loss: 2.0485 - triplet_acc: 0.660 - ETA: 1:54 - loss: 2.0464 - triplet_acc: 0.659 - ETA: 1:53 - loss: 2.0427 - triplet_acc: 0.659 - ETA: 1:52 - loss: 2.0496 - triplet_acc: 0.658 - ETA: 1:51 - loss: 2.0463 - triplet_acc: 0.659 - ETA: 1:50 - loss: 2.0464 - triplet_acc: 0.659 - ETA: 1:49 - loss: 2.0423 - triplet_acc: 0.659 - ETA: 1:48 - loss: 2.0482 - triplet_acc: 0.659 - ETA: 1:47 - loss: 2.0453 - triplet_acc: 0.659 - ETA: 1:46 - loss: 2.0452 - triplet_acc: 0.660 - ETA: 1:45 - loss: 2.0457 - triplet_acc: 0.660 - ETA: 1:44 - loss: 2.0382 - triplet_acc: 0.660 - ETA: 1:43 - loss: 2.0339 - triplet_acc: 0.661 - ETA: 1:42 - loss: 2.0375 - triplet_acc: 0.661 - ETA: 1:41 - loss: 2.0406 - triplet_acc: 0.661 - ETA: 1:40 - loss: 2.0556 - triplet_acc: 0.660 - ETA: 1:39 - loss: 2.0529 - triplet_acc: 0.660 - ETA: 1:38 - loss: 2.0480 - triplet_acc: 0.661 - ETA: 1:37 - loss: 2.0431 - triplet_acc: 0.661 - ETA: 1:36 - loss: 2.0524 - triplet_acc: 0.660 - ETA: 1:35 - loss: 2.0486 - triplet_acc: 0.661 - ETA: 1:34 - loss: 2.0475 - triplet_acc: 0.661 - ETA: 1:33 - loss: 2.0505 - triplet_acc: 0.661 - ETA: 1:32 - loss: 2.0492 - triplet_acc: 0.661 - ETA: 1:31 - loss: 2.0538 - triplet_acc: 0.660 - ETA: 1:31 - loss: 2.0463 - triplet_acc: 0.661 - ETA: 1:30 - loss: 2.0486 - triplet_acc: 0.661 - ETA: 1:29 - loss: 2.0569 - triplet_acc: 0.661 - ETA: 1:28 - loss: 2.0682 - triplet_acc: 0.661 - ETA: 1:26 - loss: 2.0774 - triplet_acc: 0.661 - ETA: 1:25 - loss: 2.0753 - triplet_acc: 0.661 - ETA: 1:24 - loss: 2.0716 - triplet_acc: 0.662 - ETA: 1:23 - loss: 2.0728 - triplet_acc: 0.662 - ETA: 1:23 - loss: 2.0750 - triplet_acc: 0.661 - ETA: 1:21 - loss: 2.0772 - triplet_acc: 0.661 - ETA: 1:20 - loss: 2.0716 - triplet_acc: 0.662 - ETA: 1:19 - loss: 2.0649 - triplet_acc: 0.663 - ETA: 1:18 - loss: 2.0640 - triplet_acc: 0.663 - ETA: 1:17 - loss: 2.0644 - triplet_acc: 0.663 - ETA: 1:16 - loss: 2.0641 - triplet_acc: 0.662 - ETA: 1:15 - loss: 2.0684 - triplet_acc: 0.661 - ETA: 1:14 - loss: 2.0633 - triplet_acc: 0.662 - ETA: 1:13 - loss: 2.0609 - triplet_acc: 0.662 - ETA: 1:12 - loss: 2.0569 - triplet_acc: 0.663 - ETA: 1:11 - loss: 2.0569 - triplet_acc: 0.662 - ETA: 1:10 - loss: 2.0572 - triplet_acc: 0.662 - ETA: 1:09 - loss: 2.0568 - triplet_acc: 0.662 - ETA: 1:08 - loss: 2.0669 - triplet_acc: 0.661 - ETA: 1:07 - loss: 2.0639 - triplet_acc: 0.661 - ETA: 1:06 - loss: 2.0593 - triplet_acc: 0.662 - ETA: 1:05 - loss: 2.0609 - triplet_acc: 0.661 - ETA: 1:04 - loss: 2.0591 - triplet_acc: 0.662 - ETA: 1:03 - loss: 2.0597 - triplet_acc: 0.662 - ETA: 1:02 - loss: 2.0598 - triplet_acc: 0.662 - ETA: 1:01 - loss: 2.0579 - triplet_acc: 0.662 - ETA: 1:00 - loss: 2.0571 - triplet_acc: 0.662 - ETA: 59s - loss: 2.0515 - triplet_acc: 0.663 - ETA: 58s - loss: 2.0502 - triplet_acc: 0.66 - ETA: 57s - loss: 2.0532 - triplet_acc: 0.66 - ETA: 56s - loss: 2.0508 - triplet_acc: 0.66 - ETA: 55s - loss: 2.0462 - triplet_acc: 0.66 - ETA: 54s - loss: 2.0549 - triplet_acc: 0.66 - ETA: 53s - loss: 2.0568 - triplet_acc: 0.66 - ETA: 52s - loss: 2.0708 - triplet_acc: 0.66 - ETA: 51s - loss: 2.0730 - triplet_acc: 0.66 - ETA: 50s - loss: 2.0730 - triplet_acc: 0.66 - ETA: 49s - loss: 2.0748 - triplet_acc: 0.66 - ETA: 48s - loss: 2.0768 - triplet_acc: 0.66 - ETA: 47s - loss: 2.0719 - triplet_acc: 0.66  ...
# Beginning epoch number: 6
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:22 - loss: 3.7538 - triplet_acc: 0.500 - ETA: 5:00 - loss: 3.6343 - triplet_acc: 0.550 - ETA: 4:54 - loss: 3.0496 - triplet_acc: 0.583 - ETA: 4:49 - loss: 2.8405 - triplet_acc: 0.612 - ETA: 4:50 - loss: 2.4682 - triplet_acc: 0.640 - ETA: 4:47 - loss: 2.6551 - triplet_acc: 0.641 - ETA: 4:43 - loss: 2.6289 - triplet_acc: 0.635 - ETA: 4:41 - loss: 2.6796 - triplet_acc: 0.643 - ETA: 4:39 - loss: 2.5683 - triplet_acc: 0.638 - ETA: 4:40 - loss: 2.4646 - triplet_acc: 0.640 - ETA: 4:38 - loss: 2.3199 - triplet_acc: 0.663 - ETA: 4:37 - loss: 2.2734 - triplet_acc: 0.666 - ETA: 4:36 - loss: 2.3280 - triplet_acc: 0.653 - ETA: 4:34 - loss: 2.2793 - triplet_acc: 0.653 - ETA: 4:32 - loss: 2.2149 - triplet_acc: 0.653 - ETA: 4:30 - loss: 2.1885 - triplet_acc: 0.640 - ETA: 4:30 - loss: 2.2193 - triplet_acc: 0.632 - ETA: 4:28 - loss: 2.2097 - triplet_acc: 0.636 - ETA: 4:27 - loss: 2.1752 - triplet_acc: 0.636 - ETA: 4:26 - loss: 2.1029 - triplet_acc: 0.642 - ETA: 4:25 - loss: 2.0757 - triplet_acc: 0.642 - ETA: 4:26 - loss: 2.0789 - triplet_acc: 0.638 - ETA: 4:27 - loss: 2.0672 - triplet_acc: 0.639 - ETA: 4:28 - loss: 2.0546 - triplet_acc: 0.645 - ETA: 4:28 - loss: 2.0736 - triplet_acc: 0.650 - ETA: 4:27 - loss: 2.0421 - triplet_acc: 0.653 - ETA: 4:27 - loss: 2.0313 - triplet_acc: 0.657 - ETA: 4:27 - loss: 2.0183 - triplet_acc: 0.655 - ETA: 4:27 - loss: 2.0278 - triplet_acc: 0.653 - ETA: 4:28 - loss: 1.9928 - triplet_acc: 0.658 - ETA: 4:27 - loss: 2.0381 - triplet_acc: 0.654 - ETA: 4:26 - loss: 2.0445 - triplet_acc: 0.650 - ETA: 4:25 - loss: 2.0419 - triplet_acc: 0.653 - ETA: 4:24 - loss: 2.0135 - triplet_acc: 0.654 - ETA: 4:23 - loss: 2.0413 - triplet_acc: 0.654 - ETA: 4:23 - loss: 2.0206 - triplet_acc: 0.656 - ETA: 4:23 - loss: 2.0285 - triplet_acc: 0.656 - ETA: 4:22 - loss: 2.0080 - triplet_acc: 0.657 - ETA: 4:21 - loss: 1.9999 - triplet_acc: 0.659 - ETA: 4:20 - loss: 1.9917 - triplet_acc: 0.662 - ETA: 4:20 - loss: 1.9875 - triplet_acc: 0.663 - ETA: 4:19 - loss: 1.9863 - triplet_acc: 0.661 - ETA: 4:18 - loss: 2.0712 - triplet_acc: 0.659 - ETA: 4:16 - loss: 2.0986 - triplet_acc: 0.658 - ETA: 4:15 - loss: 2.0865 - triplet_acc: 0.660 - ETA: 4:14 - loss: 2.0934 - triplet_acc: 0.658 - ETA: 4:14 - loss: 2.1139 - triplet_acc: 0.655 - ETA: 4:13 - loss: 2.1070 - triplet_acc: 0.657 - ETA: 4:12 - loss: 2.1715 - triplet_acc: 0.652 - ETA: 4:11 - loss: 2.1695 - triplet_acc: 0.651 - ETA: 4:10 - loss: 2.1335 - triplet_acc: 0.653 - ETA: 4:09 - loss: 2.1317 - triplet_acc: 0.656 - ETA: 4:08 - loss: 2.1235 - triplet_acc: 0.657 - ETA: 4:08 - loss: 2.1605 - triplet_acc: 0.651 - ETA: 4:07 - loss: 2.1481 - triplet_acc: 0.651 - ETA: 4:06 - loss: 2.1462 - triplet_acc: 0.653 - ETA: 4:05 - loss: 2.1667 - triplet_acc: 0.652 - ETA: 4:04 - loss: 2.1744 - triplet_acc: 0.651 - ETA: 4:03 - loss: 2.2196 - triplet_acc: 0.649 - ETA: 4:01 - loss: 2.2254 - triplet_acc: 0.647 - ETA: 4:00 - loss: 2.2143 - triplet_acc: 0.648 - ETA: 3:59 - loss: 2.2133 - triplet_acc: 0.648 - ETA: 3:57 - loss: 2.2092 - triplet_acc: 0.648 - ETA: 3:56 - loss: 2.1959 - triplet_acc: 0.652 - ETA: 3:55 - loss: 2.1788 - triplet_acc: 0.653 - ETA: 3:54 - loss: 2.1714 - triplet_acc: 0.653 - ETA: 3:52 - loss: 2.1697 - triplet_acc: 0.655 - ETA: 3:51 - loss: 2.1939 - triplet_acc: 0.653 - ETA: 3:50 - loss: 2.1790 - triplet_acc: 0.654 - ETA: 3:49 - loss: 2.1802 - triplet_acc: 0.656 - ETA: 3:48 - loss: 2.1585 - triplet_acc: 0.659 - ETA: 3:47 - loss: 2.1536 - triplet_acc: 0.660 - ETA: 3:46 - loss: 2.1314 - triplet_acc: 0.663 - ETA: 3:45 - loss: 2.1342 - triplet_acc: 0.664 - ETA: 3:44 - loss: 2.1276 - triplet_acc: 0.665 - ETA: 3:43 - loss: 2.1382 - triplet_acc: 0.664 - ETA: 3:42 - loss: 2.1416 - triplet_acc: 0.664 - ETA: 3:41 - loss: 2.1291 - triplet_acc: 0.666 - ETA: 3:40 - loss: 2.1150 - triplet_acc: 0.665 - ETA: 3:39 - loss: 2.0961 - triplet_acc: 0.668 - ETA: 3:38 - loss: 2.0889 - triplet_acc: 0.667 - ETA: 3:37 - loss: 2.0677 - triplet_acc: 0.668 - ETA: 3:36 - loss: 2.0 ...
# Beginning epoch number: 7
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:36 - loss: 0.9279 - triplet_acc: 0.750 - ETA: 5:11 - loss: 2.0730 - triplet_acc: 0.650 - ETA: 5:04 - loss: 1.8315 - triplet_acc: 0.700 - ETA: 4:55 - loss: 1.8727 - triplet_acc: 0.700 - ETA: 4:52 - loss: 2.0353 - triplet_acc: 0.690 - ETA: 4:49 - loss: 2.1425 - triplet_acc: 0.666 - ETA: 4:51 - loss: 2.0662 - triplet_acc: 0.664 - ETA: 4:52 - loss: 2.0198 - triplet_acc: 0.668 - ETA: 4:52 - loss: 2.0279 - triplet_acc: 0.666 - ETA: 4:50 - loss: 2.0915 - triplet_acc: 0.670 - ETA: 4:49 - loss: 2.0385 - triplet_acc: 0.672 - ETA: 4:46 - loss: 2.0633 - triplet_acc: 0.679 - ETA: 4:44 - loss: 2.0467 - triplet_acc: 0.673 - ETA: 4:41 - loss: 1.9886 - triplet_acc: 0.671 - ETA: 4:38 - loss: 2.0498 - triplet_acc: 0.663 - ETA: 4:36 - loss: 1.9628 - triplet_acc: 0.675 - ETA: 4:34 - loss: 1.9629 - triplet_acc: 0.676 - ETA: 4:32 - loss: 1.9812 - triplet_acc: 0.677 - ETA: 4:31 - loss: 1.9445 - triplet_acc: 0.686 - ETA: 4:33 - loss: 1.9099 - triplet_acc: 0.692 - ETA: 4:31 - loss: 1.8743 - triplet_acc: 0.695 - ETA: 4:31 - loss: 1.8589 - triplet_acc: 0.695 - ETA: 4:29 - loss: 1.8310 - triplet_acc: 0.693 - ETA: 4:28 - loss: 1.7952 - triplet_acc: 0.695 - ETA: 4:27 - loss: 1.8099 - triplet_acc: 0.692 - ETA: 4:26 - loss: 1.8074 - triplet_acc: 0.698 - ETA: 4:25 - loss: 1.7709 - triplet_acc: 0.701 - ETA: 4:24 - loss: 1.7605 - triplet_acc: 0.703 - ETA: 4:23 - loss: 1.7580 - triplet_acc: 0.705 - ETA: 4:22 - loss: 1.7244 - triplet_acc: 0.708 - ETA: 4:21 - loss: 1.6927 - triplet_acc: 0.708 - ETA: 4:20 - loss: 1.6967 - triplet_acc: 0.709 - ETA: 4:18 - loss: 1.7075 - triplet_acc: 0.709 - ETA: 4:17 - loss: 1.6918 - triplet_acc: 0.711 - ETA: 4:16 - loss: 1.7240 - triplet_acc: 0.711 - ETA: 4:15 - loss: 1.7048 - triplet_acc: 0.711 - ETA: 4:14 - loss: 1.7296 - triplet_acc: 0.713 - ETA: 4:13 - loss: 1.7188 - triplet_acc: 0.713 - ETA: 4:11 - loss: 1.6844 - triplet_acc: 0.716 - ETA: 4:10 - loss: 1.6685 - triplet_acc: 0.717 - ETA: 4:09 - loss: 1.6745 - triplet_acc: 0.715 - ETA: 4:08 - loss: 1.6497 - triplet_acc: 0.717 - ETA: 4:07 - loss: 1.6765 - triplet_acc: 0.715 - ETA: 4:06 - loss: 1.6450 - triplet_acc: 0.719 - ETA: 4:06 - loss: 1.6501 - triplet_acc: 0.720 - ETA: 4:05 - loss: 1.6524 - triplet_acc: 0.720 - ETA: 4:04 - loss: 1.6508 - triplet_acc: 0.717 - ETA: 4:03 - loss: 1.6549 - triplet_acc: 0.717 - ETA: 4:02 - loss: 1.6535 - triplet_acc: 0.717 - ETA: 4:01 - loss: 1.6492 - triplet_acc: 0.719 - ETA: 4:01 - loss: 1.6515 - triplet_acc: 0.717 - ETA: 4:00 - loss: 1.6839 - triplet_acc: 0.716 - ETA: 3:58 - loss: 1.6739 - triplet_acc: 0.717 - ETA: 3:57 - loss: 1.6510 - triplet_acc: 0.720 - ETA: 3:57 - loss: 1.6945 - triplet_acc: 0.717 - ETA: 3:56 - loss: 1.6880 - triplet_acc: 0.717 - ETA: 3:55 - loss: 1.7000 - triplet_acc: 0.715 - ETA: 3:54 - loss: 1.7009 - triplet_acc: 0.714 - ETA: 3:53 - loss: 1.6881 - triplet_acc: 0.716 - ETA: 3:52 - loss: 1.6724 - triplet_acc: 0.717 - ETA: 3:51 - loss: 1.6549 - triplet_acc: 0.719 - ETA: 3:50 - loss: 1.6316 - triplet_acc: 0.723 - ETA: 3:49 - loss: 1.6311 - triplet_acc: 0.724 - ETA: 3:48 - loss: 1.6220 - triplet_acc: 0.726 - ETA: 3:46 - loss: 1.6180 - triplet_acc: 0.727 - ETA: 3:45 - loss: 1.6205 - triplet_acc: 0.728 - ETA: 3:44 - loss: 1.6443 - triplet_acc: 0.726 - ETA: 3:44 - loss: 1.6490 - triplet_acc: 0.725 - ETA: 3:43 - loss: 1.7053 - triplet_acc: 0.724 - ETA: 3:42 - loss: 1.7484 - triplet_acc: 0.722 - ETA: 3:41 - loss: 1.7397 - triplet_acc: 0.721 - ETA: 3:40 - loss: 1.7403 - triplet_acc: 0.722 - ETA: 3:39 - loss: 1.7437 - triplet_acc: 0.722 - ETA: 3:38 - loss: 1.7367 - triplet_acc: 0.723 - ETA: 3:37 - loss: 1.7255 - triplet_acc: 0.724 - ETA: 3:36 - loss: 1.7279 - triplet_acc: 0.722 - ETA: 3:35 - loss: 1.7272 - triplet_acc: 0.722 - ETA: 3:35 - loss: 1.7215 - triplet_acc: 0.723 - ETA: 3:34 - loss: 1.7177 - triplet_acc: 0.722 - ETA: 3:33 - loss: 1.7308 - triplet_acc: 0.721 - ETA: 3:32 - loss: 1.7292 - triplet_acc: 0.720 - ETA: 3:32 - loss: 1.7415 - triplet_acc: 0.720 - ETA: 3:31 - loss: 1.7 ...
# ...
# Beginning epoch number: 11
# Mode 3
# Epoch 1/1
# 170/300 [================>.............] - ETA: 5:17 - loss: 1.4588 - triplet_acc: 0.800 - ETA: 4:55 - loss: 1.3364 - triplet_acc: 0.775 - ETA: 4:56 - loss: 1.5327 - triplet_acc: 0.783 - ETA: 4:50 - loss: 1.5149 - triplet_acc: 0.750 - ETA: 4:44 - loss: 1.8248 - triplet_acc: 0.710 - ETA: 4:42 - loss: 1.6670 - triplet_acc: 0.725 - ETA: 4:40 - loss: 1.6318 - triplet_acc: 0.728 - ETA: 4:40 - loss: 1.6158 - triplet_acc: 0.731 - ETA: 4:38 - loss: 1.5836 - triplet_acc: 0.727 - ETA: 4:35 - loss: 1.4830 - triplet_acc: 0.735 - ETA: 4:34 - loss: 1.4906 - triplet_acc: 0.740 - ETA: 4:33 - loss: 1.3712 - triplet_acc: 0.758 - ETA: 4:32 - loss: 1.5401 - triplet_acc: 0.753 - ETA: 4:31 - loss: 1.5511 - triplet_acc: 0.757 - ETA: 4:30 - loss: 1.5280 - triplet_acc: 0.753 - ETA: 4:28 - loss: 1.4541 - triplet_acc: 0.765 - ETA: 4:26 - loss: 1.4229 - triplet_acc: 0.767 - ETA: 4:25 - loss: 1.3871 - triplet_acc: 0.769 - ETA: 4:24 - loss: 1.3788 - triplet_acc: 0.768 - ETA: 4:23 - loss: 1.3673 - triplet_acc: 0.767 - ETA: 4:23 - loss: 1.4389 - triplet_acc: 0.757 - ETA: 4:22 - loss: 1.4338 - triplet_acc: 0.756 - ETA: 4:20 - loss: 1.3997 - triplet_acc: 0.758 - ETA: 4:21 - loss: 1.3698 - triplet_acc: 0.762 - ETA: 4:21 - loss: 1.4376 - triplet_acc: 0.754 - ETA: 4:20 - loss: 1.4261 - triplet_acc: 0.751 - ETA: 4:19 - loss: 1.4799 - triplet_acc: 0.748 - ETA: 4:17 - loss: 1.4832 - triplet_acc: 0.748 - ETA: 4:17 - loss: 1.4903 - triplet_acc: 0.746 - ETA: 4:15 - loss: 1.5237 - triplet_acc: 0.738 - ETA: 4:14 - loss: 1.5128 - triplet_acc: 0.740 - ETA: 4:14 - loss: 1.5148 - triplet_acc: 0.735 - ETA: 4:13 - loss: 1.5405 - triplet_acc: 0.733 - ETA: 4:12 - loss: 1.5631 - triplet_acc: 0.729 - ETA: 4:11 - loss: 1.5789 - triplet_acc: 0.727 - ETA: 4:10 - loss: 1.5675 - triplet_acc: 0.727 - ETA: 4:09 - loss: 1.5971 - triplet_acc: 0.725 - ETA: 4:08 - loss: 1.6261 - triplet_acc: 0.722 - ETA: 4:07 - loss: 1.6507 - triplet_acc: 0.721 - ETA: 4:06 - loss: 1.6282 - triplet_acc: 0.725 - ETA: 4:05 - loss: 1.5969 - triplet_acc: 0.729 - ETA: 4:04 - loss: 1.6018 - triplet_acc: 0.728 - ETA: 4:04 - loss: 1.5788 - triplet_acc: 0.732 - ETA: 4:02 - loss: 1.5583 - triplet_acc: 0.735 - ETA: 4:02 - loss: 1.5408 - triplet_acc: 0.737 - ETA: 4:01 - loss: 1.5163 - triplet_acc: 0.741 - ETA: 4:00 - loss: 1.5050 - triplet_acc: 0.744 - ETA: 3:59 - loss: 1.5106 - triplet_acc: 0.743 - ETA: 3:58 - loss: 1.5313 - triplet_acc: 0.742 - ETA: 3:57 - loss: 1.5083 - triplet_acc: 0.746 - ETA: 3:56 - loss: 1.5156 - triplet_acc: 0.746 - ETA: 3:55 - loss: 1.5156 - triplet_acc: 0.748 - ETA: 3:54 - loss: 1.4943 - triplet_acc: 0.750 - ETA: 3:53 - loss: 1.4936 - triplet_acc: 0.750 - ETA: 3:53 - loss: 1.5094 - triplet_acc: 0.749 - ETA: 3:52 - loss: 1.5205 - triplet_acc: 0.749 - ETA: 3:51 - loss: 1.5246 - triplet_acc: 0.747 - ETA: 3:50 - loss: 1.5301 - triplet_acc: 0.747 - ETA: 3:49 - loss: 1.5237 - triplet_acc: 0.746 - ETA: 3:48 - loss: 1.5193 - triplet_acc: 0.745 - ETA: 3:47 - loss: 1.5050 - triplet_acc: 0.746 - ETA: 3:46 - loss: 1.5206 - triplet_acc: 0.747 - ETA: 3:45 - loss: 1.5155 - triplet_acc: 0.747 - ETA: 3:44 - loss: 1.5183 - triplet_acc: 0.747 - ETA: 3:43 - loss: 1.5244 - triplet_acc: 0.747 - ETA: 3:42 - loss: 1.5171 - triplet_acc: 0.747 - ETA: 3:41 - loss: 1.5213 - triplet_acc: 0.747 - ETA: 3:41 - loss: 1.5319 - triplet_acc: 0.747 - ETA: 3:40 - loss: 1.5297 - triplet_acc: 0.747 - ETA: 3:38 - loss: 1.5131 - triplet_acc: 0.749 - ETA: 3:37 - loss: 1.4936 - triplet_acc: 0.752 - ETA: 3:36 - loss: 1.4759 - triplet_acc: 0.754 - ETA: 3:35 - loss: 1.4814 - triplet_acc: 0.753 - ETA: 3:34 - loss: 1.4671 - triplet_acc: 0.755 - ETA: 3:33 - loss: 1.4582 - triplet_acc: 0.755 - ETA: 3:32 - loss: 1.4512 - triplet_acc: 0.756 - ETA: 3:31 - loss: 1.4515 - triplet_acc: 0.757 - ETA: 3:30 - loss: 1.4453 - triplet_acc: 0.757 - ETA: 3:29 - loss: 1.4610 - triplet_acc: 0.757 - ETA: 3:28 - loss: 1.4521 - triplet_acc: 0.757 - ETA: 3:27 - loss: 1.4437 - triplet_acc: 0.758 - ETA: 3:26 - loss: 1.4645 - triplet_acc: 0.757 - ETA: 3:25 - loss: 1.4 ...
# 300/300 [==============================] - ETA: 2:02 - loss: 1.5131 - triplet_acc: 0.762 - ETA: 2:01 - loss: 1.5067 - triplet_acc: 0.763 - ETA: 2:00 - loss: 1.5168 - triplet_acc: 0.762 - ETA: 1:59 - loss: 1.5277 - triplet_acc: 0.761 - ETA: 1:58 - loss: 1.5316 - triplet_acc: 0.760 - ETA: 1:57 - loss: 1.5375 - triplet_acc: 0.760 - ETA: 1:56 - loss: 1.5319 - triplet_acc: 0.761 - ETA: 1:55 - loss: 1.5344 - triplet_acc: 0.761 - ETA: 1:54 - loss: 1.5284 - triplet_acc: 0.761 - ETA: 1:53 - loss: 1.5269 - triplet_acc: 0.761 - ETA: 1:52 - loss: 1.5279 - triplet_acc: 0.761 - ETA: 1:52 - loss: 1.5220 - triplet_acc: 0.762 - ETA: 1:51 - loss: 1.5236 - triplet_acc: 0.761 - ETA: 1:50 - loss: 1.5239 - triplet_acc: 0.761 - ETA: 1:49 - loss: 1.5303 - triplet_acc: 0.760 - ETA: 1:48 - loss: 1.5296 - triplet_acc: 0.759 - ETA: 1:47 - loss: 1.5290 - triplet_acc: 0.759 - ETA: 1:46 - loss: 1.5262 - triplet_acc: 0.760 - ETA: 1:45 - loss: 1.5297 - triplet_acc: 0.759 - ETA: 1:44 - loss: 1.5274 - triplet_acc: 0.759 - ETA: 1:43 - loss: 1.5290 - triplet_acc: 0.759 - ETA: 1:42 - loss: 1.5281 - triplet_acc: 0.759 - ETA: 1:41 - loss: 1.5351 - triplet_acc: 0.758 - ETA: 1:40 - loss: 1.5335 - triplet_acc: 0.759 - ETA: 1:40 - loss: 1.5319 - triplet_acc: 0.759 - ETA: 1:39 - loss: 1.5275 - triplet_acc: 0.759 - ETA: 1:38 - loss: 1.5242 - triplet_acc: 0.759 - ETA: 1:37 - loss: 1.5242 - triplet_acc: 0.759 - ETA: 1:36 - loss: 1.5355 - triplet_acc: 0.758 - ETA: 1:35 - loss: 1.5366 - triplet_acc: 0.757 - ETA: 1:34 - loss: 1.5619 - triplet_acc: 0.756 - ETA: 1:33 - loss: 1.5661 - triplet_acc: 0.756 - ETA: 1:32 - loss: 1.5661 - triplet_acc: 0.756 - ETA: 1:31 - loss: 1.5661 - triplet_acc: 0.755 - ETA: 1:30 - loss: 1.5603 - triplet_acc: 0.756 - ETA: 1:29 - loss: 1.5574 - triplet_acc: 0.756 - ETA: 1:28 - loss: 1.5536 - triplet_acc: 0.756 - ETA: 1:27 - loss: 1.5551 - triplet_acc: 0.755 - ETA: 1:26 - loss: 1.5539 - triplet_acc: 0.756 - ETA: 1:25 - loss: 1.5542 - triplet_acc: 0.756 - ETA: 1:24 - loss: 1.5548 - triplet_acc: 0.756 - ETA: 1:23 - loss: 1.5538 - triplet_acc: 0.756 - ETA: 1:22 - loss: 1.5507 - triplet_acc: 0.756 - ETA: 1:21 - loss: 1.5519 - triplet_acc: 0.756 - ETA: 1:21 - loss: 1.5596 - triplet_acc: 0.756 - ETA: 1:20 - loss: 1.5635 - triplet_acc: 0.755 - ETA: 1:19 - loss: 1.5608 - triplet_acc: 0.756 - ETA: 1:18 - loss: 1.5576 - triplet_acc: 0.756 - ETA: 1:17 - loss: 1.5506 - triplet_acc: 0.757 - ETA: 1:16 - loss: 1.5465 - triplet_acc: 0.757 - ETA: 1:15 - loss: 1.5508 - triplet_acc: 0.756 - ETA: 1:14 - loss: 1.5509 - triplet_acc: 0.757 - ETA: 1:13 - loss: 1.5508 - triplet_acc: 0.757 - ETA: 1:12 - loss: 1.5505 - triplet_acc: 0.756 - ETA: 1:11 - loss: 1.5473 - triplet_acc: 0.757 - ETA: 1:10 - loss: 1.5515 - triplet_acc: 0.756 - ETA: 1:09 - loss: 1.5524 - triplet_acc: 0.755 - ETA: 1:08 - loss: 1.5545 - triplet_acc: 0.755 - ETA: 1:07 - loss: 1.5552 - triplet_acc: 0.754 - ETA: 1:06 - loss: 1.5550 - triplet_acc: 0.754 - ETA: 1:05 - loss: 1.5564 - triplet_acc: 0.754 - ETA: 1:04 - loss: 1.5599 - triplet_acc: 0.753 - ETA: 1:03 - loss: 1.5598 - triplet_acc: 0.753 - ETA: 1:02 - loss: 1.5635 - triplet_acc: 0.752 - ETA: 1:02 - loss: 1.5643 - triplet_acc: 0.752 - ETA: 1:01 - loss: 1.5689 - triplet_acc: 0.752 - ETA: 1:00 - loss: 1.5681 - triplet_acc: 0.752 - ETA: 59s - loss: 1.5659 - triplet_acc: 0.752 - ETA: 58s - loss: 1.5710 - triplet_acc: 0.75 - ETA: 57s - loss: 1.5767 - triplet_acc: 0.75 - ETA: 56s - loss: 1.5746 - triplet_acc: 0.75 - ETA: 55s - loss: 1.5782 - triplet_acc: 0.75 - ETA: 54s - loss: 1.5744 - triplet_acc: 0.75 - ETA: 53s - loss: 1.5766 - triplet_acc: 0.75 - ETA: 52s - loss: 1.5740 - triplet_acc: 0.75 - ETA: 51s - loss: 1.5742 - triplet_acc: 0.75 - ETA: 50s - loss: 1.5688 - triplet_acc: 0.75 - ETA: 49s - loss: 1.5739 - triplet_acc: 0.75 - ETA: 48s - loss: 1.5711 - triplet_acc: 0.75 - ETA: 47s - loss: 1.5696 - triplet_acc: 0.75 - ETA: 46s - loss: 1.5742 - triplet_acc: 0.75 - ETA: 45s - loss: 1.5798 - triplet_acc: 0.75 - ETA: 44s - loss: 1.5815 - triplet_acc: 0.75 - ETA: ...
# Beginning epoch number: 12
# Mode 3
# Epoch 1/1
#  89/300 [=======>......................] - ETA: 6:15 - loss: 2.2557 - triplet_acc: 0.600 - ETA: 5:47 - loss: 2.1327 - triplet_acc: 0.650 - ETA: 5:37 - loss: 1.8328 - triplet_acc: 0.650 - ETA: 5:31 - loss: 1.8587 - triplet_acc: 0.675 - ETA: 5:28 - loss: 1.7764 - triplet_acc: 0.690 - ETA: 5:26 - loss: 1.7016 - triplet_acc: 0.691 - ETA: 5:29 - loss: 1.6094 - triplet_acc: 0.692 - ETA: 5:31 - loss: 1.4922 - triplet_acc: 0.718 - ETA: 5:31 - loss: 1.4520 - triplet_acc: 0.722 - ETA: 5:24 - loss: 1.4626 - triplet_acc: 0.730 - ETA: 5:19 - loss: 1.5202 - triplet_acc: 0.727 - ETA: 5:13 - loss: 1.5570 - triplet_acc: 0.725 - ETA: 5:10 - loss: 1.4792 - triplet_acc: 0.730 - ETA: 5:08 - loss: 1.5392 - triplet_acc: 0.717 - ETA: 5:06 - loss: 1.5380 - triplet_acc: 0.716 - ETA: 5:03 - loss: 1.5035 - triplet_acc: 0.721 - ETA: 5:00 - loss: 1.4738 - triplet_acc: 0.726 - ETA: 4:58 - loss: 1.4408 - triplet_acc: 0.730 - ETA: 4:55 - loss: 1.5095 - triplet_acc: 0.715 - ETA: 4:53 - loss: 1.4941 - triplet_acc: 0.722 - ETA: 4:51 - loss: 1.4920 - triplet_acc: 0.726 - ETA: 4:51 - loss: 1.4569 - triplet_acc: 0.734 - ETA: 4:49 - loss: 1.4637 - triplet_acc: 0.732 - ETA: 4:47 - loss: 1.4591 - triplet_acc: 0.731 - ETA: 4:45 - loss: 1.4747 - triplet_acc: 0.726 - ETA: 4:43 - loss: 1.5117 - triplet_acc: 0.723 - ETA: 4:41 - loss: 1.4975 - triplet_acc: 0.724 - ETA: 4:39 - loss: 1.4843 - triplet_acc: 0.728 - ETA: 4:39 - loss: 1.5277 - triplet_acc: 0.724 - ETA: 4:37 - loss: 1.4956 - triplet_acc: 0.728 - ETA: 4:35 - loss: 1.5093 - triplet_acc: 0.730 - ETA: 4:34 - loss: 1.5617 - triplet_acc: 0.728 - ETA: 4:32 - loss: 1.5856 - triplet_acc: 0.730 - ETA: 4:30 - loss: 1.6059 - triplet_acc: 0.729 - ETA: 4:29 - loss: 1.5660 - triplet_acc: 0.734 - ETA: 4:27 - loss: 1.5584 - triplet_acc: 0.737 - ETA: 4:26 - loss: 1.5620 - triplet_acc: 0.737 - ETA: 4:24 - loss: 1.5650 - triplet_acc: 0.738 - ETA: 4:23 - loss: 1.5622 - triplet_acc: 0.735 - ETA: 4:22 - loss: 1.5386 - triplet_acc: 0.738 - ETA: 4:20 - loss: 1.5432 - triplet_acc: 0.739 - ETA: 4:19 - loss: 1.5501 - triplet_acc: 0.735 - ETA: 4:17 - loss: 1.5410 - triplet_acc: 0.736 - ETA: 4:16 - loss: 1.5537 - triplet_acc: 0.734 - ETA: 4:14 - loss: 1.5598 - triplet_acc: 0.733 - ETA: 4:13 - loss: 1.5583 - triplet_acc: 0.732 - ETA: 4:12 - loss: 1.6019 - triplet_acc: 0.728 - ETA: 4:10 - loss: 1.6345 - triplet_acc: 0.726 - ETA: 4:09 - loss: 1.6602 - triplet_acc: 0.723 - ETA: 4:08 - loss: 1.6523 - triplet_acc: 0.725 - ETA: 4:07 - loss: 1.6522 - triplet_acc: 0.722 - ETA: 4:06 - loss: 1.6429 - triplet_acc: 0.724 - ETA: 4:05 - loss: 1.6139 - triplet_acc: 0.728 - ETA: 4:04 - loss: 1.6511 - triplet_acc: 0.724 - ETA: 4:03 - loss: 1.6464 - triplet_acc: 0.724 - ETA: 4:03 - loss: 1.6466 - triplet_acc: 0.720 - ETA: 4:01 - loss: 1.6384 - triplet_acc: 0.721 - ETA: 4:01 - loss: 1.6256 - triplet_acc: 0.720 - ETA: 3:59 - loss: 1.6176 - triplet_acc: 0.721 - ETA: 3:59 - loss: 1.6279 - triplet_acc: 0.720 - ETA: 3:57 - loss: 1.6257 - triplet_acc: 0.719 - ETA: 3:56 - loss: 1.6093 - triplet_acc: 0.721 - ETA: 3:55 - loss: 1.6000 - triplet_acc: 0.722 - ETA: 3:55 - loss: 1.6281 - triplet_acc: 0.719 - ETA: 3:54 - loss: 1.6432 - triplet_acc: 0.719 - ETA: 3:53 - loss: 1.6410 - triplet_acc: 0.718 - ETA: 3:52 - loss: 1.6865 - triplet_acc: 0.717 - ETA: 3:50 - loss: 1.6995 - triplet_acc: 0.716 - ETA: 3:49 - loss: 1.6861 - triplet_acc: 0.716 - ETA: 3:48 - loss: 1.6987 - triplet_acc: 0.715 - ETA: 3:47 - loss: 1.6864 - triplet_acc: 0.714 - ETA: 3:46 - loss: 1.6777 - triplet_acc: 0.716 - ETA: 3:45 - loss: 1.6684 - triplet_acc: 0.717 - ETA: 3:44 - loss: 1.6605 - triplet_acc: 0.718 - ETA: 3:43 - loss: 1.6518 - triplet_acc: 0.719 - ETA: 3:43 - loss: 1.6454 - triplet_acc: 0.720 - ETA: 3:42 - loss: 1.6317 - triplet_acc: 0.722 - ETA: 3:41 - loss: 1.6388 - triplet_acc: 0.723 - ETA: 3:40 - loss: 1.6471 - triplet_acc: 0.722 - ETA: 3:40 - loss: 1.6437 - triplet_acc: 0.721 - ETA: 3:39 - loss: 1.6379 - triplet_acc: 0.722 - ETA: 3:38 - loss: 1.6344 - triplet_acc: 0.722 - ETA: 3:37 - loss: 1.6 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a8d2788bf739> in <module>()
#      29         epochs=1,
#      30         validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
# ---> 31         validation_steps=30
#      32     )]
#      33
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     145       batch_index = 0
#     146       while steps_done < steps_per_epoch:
# --> 147         generator_output = next(output_generator)
#     148
#     149         if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\data_utils.py in get(self)
#     823           raise StopIteration()
#     824         else:
# --> 825           time.sleep(self.wait_time)
#     826
#     827     # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %%
# With super hard triplet generation
#for i in range(1000):
predict_train = model.predict_generator(predict_generator(filenames_train, 32),
                              steps=np.ceil(len(filenames_train)/32))
histories += [model.fit_generator(
    hard_image_generator(filenames_train,labels_train,predict_train,3*20,use_aug=False),
    steps_per_epoch=1,
    epochs=1,
    validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
    validation_steps=30
)]
# model.save(PATH_MODEL + '2019.04.17.dogfacenet_v12.lfw.'+str(i+6)+'.h5')
# Out:
# Epoch 1/1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d41c0ac6b62c> in <module>()
#       8     epochs=1,
#       9     validation_data=image_generator(filenames_test,labels_test,3*20,use_aug=False),
# ---> 10     validation_steps=30
#      11 )]
#      12 # model.save(PATH_MODEL + '2019.04.17.dogfacenet_v12.lfw.'+str(i+6)+'.h5')
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1926     # Validate and standardize user data.
#    1927     x, y, sample_weights = self._standardize_user_data(
# -> 1928         x, y, sample_weight=sample_weight, class_weight=class_weight)
#    1929
#    1930     if context.executing_eagerly():
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split)
#     990         x, y, sample_weight = next_element
#     991     x, y, sample_weights = self._standardize_weights(x, y, sample_weight,
# --> 992                                                      class_weight, batch_size)
#     993     return x, y, sample_weights
#     994
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_weights(self, x, y, sample_weight, class_weight, batch_size)
#    1115         feed_input_shapes,
#    1116         check_batch_axis=False,  # Don't enforce the batch size.
# -> 1117         exception_prefix='input')
#    1118
#    1119     if y is not None:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     321                            ': expected ' + names[i] + ' to have ' +
#     322                            str(len(shape)) + ' dimensions, but got array '
# --> 323                            'with shape ' + str(data_shape))
#     324         if not check_batch_axis:
#     325           data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_1 to have 4 dimensions, but got array with shape (60, 1)

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(1)+'.h5')

# %%
# Without hard triplet generation
#histories = []
for i in range(30):
    print("Epoch: " + str(i))
    histories += [model.fit_generator(
        image_generator(filenames_train,labels_train,3*10),
        steps_per_epoch=300,
        epochs=1,
        validation_data=image_generator(filenames_test,labels_test,3*10,False),
        validation_steps=30
    )]
# Out:
# Epoch: 0
# Epoch 1/1
#   5/300 [..............................] - ETA: 3:35 - loss: 1.6450 - triplet_acc: 0.300 - ETA: 3:01 - loss: 2.7761 - triplet_acc: 0.250 - ETA: 2:55 - loss: 2.5234 - triplet_acc: 0.266 - ETA: 2:48 - loss: 2.3990 - triplet_acc: 0.250 - ETA: 2:45 - loss: 2.2797 - triplet_acc: 0.2800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ba50f63981d4> in <module>()
#       8         epochs=1,
#       9         validation_data=image_generator(filenames_test,labels_test,3*10,False),
# ---> 10         validation_steps=30
#      11     )]
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# c:\users\guillaume\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.npy',history_)
np.savetxt(PATH_SAVE+'2018.04.12.dogfacenet_v12.lfw.1.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
model.save(PATH_MODEL + '2019.04.12.dogfacenet_v12.lfw.'+str(0)+'.h5')

# %%
# dogfacenet_v24
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,64,128,256,512]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v23
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(64, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [64,128,512,1024]:
    # Batch normalization layer
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    for i in range(2):
        gsize = layer//32
        branch = []
        for group in range(32):
            x = Conv2D(gsize, (1, 1), use_bias=False, padding='same')(r)
            x = BatchNormalization()(x)
            
            x = Conv2D(gsize, (3, 3), use_bias=False, activation='relu', padding='same')(x)
            x = BatchNormalization()(x)
            x = Dropout(0.5)(x)
            
            branch += [x]
        
        x = Concatenate()(branch)
        x = Conv2D(layer, (1, 1), use_bias=False, activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        r = Dropout(0.25)(x)
    

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v18
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

for layer in [32,32,64,128,512]:
    
    for channel in range(4):
    x = Conv2D(layer, (3, 3), strides=(2,2), use_bias=False, activation='relu', padding='same')(x)
    r = BatchNormalization()(x)
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    r = Add()([r,x])
    r = Dropout(0.25)(r)
    
    x = Conv2D(layer, (3, 3), use_bias=False, activation='relu', padding='same')(r)
    x = BatchNormalization()(x)
    x = Add()([r,x])
    x = Dropout(0.25)(x)
    
    #model.add(Dropout(0.25))

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
#model.add(Dense(1024, activation='relu'))
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v20
# close to official resnet with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(16, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [16,32,64,128,512,1024]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # Resnet blocks
    for j in range(2):
        x = Conv2D(layer, (1, 1), padding='same')(r)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer, (3, 3), padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
# dogfacenet_v21
# close to official resneXt with identity blocks
emb_size = 32

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Add, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Lambda, BatchNormalization

inputs = Input(shape=(104, 104, 3))

x = Conv2D(32, (7, 7), use_bias=False, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)

layers = [32,64,128,512,1024,2048]

for i in range(len(layers)-1):
    layer = layers[i]
    layer2 = layers[i+1]
    
    x = Conv2D(layer2, (3, 3), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    r = Activation('relu')(x)
    
    # ResneXt blocks, group 16
    for j in range(2):
        ksize = layer//16
        branch_res = []
        
        for k in range(16):
            x = Conv2D(ksize, (1, 1), padding='same')(r)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)

            x = Conv2D(ksize, (3, 3), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            x = Dropout(0.5)(x)
            
            branch_res += [x]
        
        x = Concatenate()(branch_res)
        x = Conv2D(layer2, (1, 1), padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Add()([r,x])
        x = Activation('relu')(x)
        r = Dropout(0.25)(x)

x = GlobalAveragePooling2D()(r)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(emb_size, use_bias=False)(x)
outputs = Lambda(lambda x: tf.nn.l2_normalize(x,axis=-1))(x)

model = tf.keras.Model(inputs,outputs)

model.compile(loss=triplet,
              optimizer='adam',
              metrics=[triplet_acc])
model.summary()

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.20.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug_2.16.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
model.evaluate(triplet_test,y_triplet_test, batch_size=63)

# %%
from IPython.display import FileLink

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.3.2.h5')

# %%
FileLink(PATH_MODEL + '2019.02.28.dogfacenet_v12.hard_triplet.alpha.0.50.h5')

# %%
FileLink(PATH_SAVE + '2018.02.27.dogfacenet_v11.hard_triplet.data_aug.10.a_0.3.npy')

# %%
model.save(PATH_MODEL + '2019.02.12.hard_triplet_trained.data_aug.0.h5')

# %%
triplet_train, y_triplet_train = define_triplets(images_train,labels_train)
triplet_test, y_triplet_test = define_triplets(images_test,labels_test,1000*3)

# %%
print(str((3*len(predict_train)+3*(nbof_classes//10 + 1),h,w,c)))

# %%
del new_images_train
del new_labels_train
del predict_train
del triplet_train, y_triplet_train
gc.collect()

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

# %%
histories = []

# %%
for i in range(6):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories += [history]

# %%
model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(1)+'.h5')

# %%
histories2 = [histories[i] for i in range(29)]

# %%
model = tf.keras.models.load_model(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5', custom_objects={'triplet':triplet,'triplet_acc':triplet_acc})

# %%
for i in range(2):
    history = model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    histories2 += [history]
model.save(PATH_MODEL + '2019.02.27.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(16)+'.h5')

# %%
histories = histories[:-2]

# %%
model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(0.0001),
              metrics=[triplet_acc])

# %% [markdown]
# - 14*3 epochs with lr=0.001
# - 4*3 epochs with lr=0.0005
# - 4*3 epochs with lr=0.0003
# - 4*1 epochs with lr=0.0001

# %%
 model.save(PATH_MODEL + '2019.02.28.dogfacenet_v22.hard_triplet.alpha.0.3.'+str(l)+'.h5')

# %%
histories = []

# %%
epochs = [14,4,4,4]
lr = [0.001,0.0005,0.0003,0.0001]
for l in range(1,len(lr)):
    model.compile(loss=triplet,
              optimizer=tf.keras.optimizers.Adam(lr[l]),
              metrics=[triplet_acc])
    for k in range(epochs[l]):
        epoch_nb = k+sum(epochs[:l])
        print("Beginning epoch number: "+str(epoch_nb)+", over "+str(sum(epochs))+" epochs. \n")

        
        new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
        predict_train=model.predict(new_images_train)
        triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train,10,3)

        for i in range(6):
            history = model.fit(
                triplet_train,
                y_triplet_train,
                batch_size = 21*3,
                epochs = 1,
                validation_data=(triplet_test,y_triplet_test),
                shuffle=False
            )
            histories += [history]
        
        del new_images_train, new_labels_train, predict_train, triplet_train, y_triplet_train
        gc.collect()
        model.save(PATH_MODEL + '2019.04.08.dogfacenet_v12.'+str(k)+'.h5')

        loss = np.empty(0)
        val_loss = np.empty(0)
        acc = np.empty(0)
        val_acc = np.empty(0)

        for history in histories:
            loss = np.append(loss,history.history['loss'])
            val_loss = np.append(val_loss,history.history['val_loss'])
            acc = np.append(acc,history.history['triplet_acc'])
            val_acc = np.append(val_acc,history.history['val_triplet_acc'])


        history_ = np.array([loss,val_loss,acc,val_acc])
        np.save(PATH_SAVE+'2019.04.08.dogfacenet_v12.npy',history_)
        np.savetxt(PATH_SAVE+'2019.04.08.dogfacenet_v12.txt',history_)

# %%
model.save(PATH_MODEL + '2019.02.28.dogfacenet_v24.hard_triplet.alpha.0.3.'+str(0)+'.h5')

# %%
history_ = np.load(PATH_SAVE+'2018.02.28.dogfacenet_v12.hard_triplet.data_aug.5.a_0.3.npy')

# %%
loss,val_loss,acc,val_acc = history_

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for history in histories:
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])

    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.28.dogfacenet_v24.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,8,1))
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.yticks(np.arange(0,1.1,0.1))
plt.legend()

# %%
for i in range(5):
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

    model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = 1,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )

    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.'+str(i+16)+'.h5')

# %%
new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
predict_train=model.predict(new_images_train)
triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
history=model.fit(
    triplet_train,
    y_triplet_train,
    batch_size = 21*3,
    epochs = 1,
    validation_data=(triplet_test,y_triplet_test),
    shuffle=False
)

# %%
model.save(PATH_MODEL + '2019.02.14.dogfacenet_v11.hard_triplet_trained.data_aug.6.h5')

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

loss = np.append(loss,history.history['loss'])
val_loss = np.append(val_loss,history.history['val_loss'])
acc = np.append(acc,history.history['triplet_acc'])
val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.12.dogfacenet_v6.hard_triplet.data_aug.0.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
histories = []
nbof_cycles = 9
for i in range(0,nbof_cycles,1):

    history=model.fit(
        triplet_train,
        y_triplet_train,
        batch_size = 21*3,
        epochs = nbof_cycles-i,
        validation_data=(triplet_test,y_triplet_test),
        shuffle=False
    )
    
    histories += [history]
    model.save(PATH_MODEL + '2019.02.14.dogfacenet_v10.hard_triplet_trained.data_aug.' + str(i+1) + '.h5')
    
    new_images_train, new_labels_train = shuffle_classes(images_train,labels_train)
    predict_train=model.predict(new_images_train)
    triplet_train, y_triplet_train = define_hard_triplets(new_images_train,new_labels_train,predict_train)

# %%
loss = np.empty(0)
val_loss = np.empty(0)
acc = np.empty(0)
val_acc = np.empty(0)

for i in range(len(histories)):
    history = histories[i]
    
    loss = np.append(loss,history.history['loss'])
    val_loss = np.append(val_loss,history.history['val_loss'])
    acc = np.append(acc,history.history['triplet_acc'])
    val_acc = np.append(val_acc,history.history['val_triplet_acc'])
    
    
history_ = np.array([loss,val_loss,acc,val_acc])
np.save(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.npy',history_)
np.savetxt(PATH_SAVE+'2018.02.13.dogfacenet_v9.hard_triplet.2.a_0.3.txt',history_)

epochs = np.arange(len(loss))
fig = plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs,loss, '-o', label="loss")
plt.plot(epochs,val_loss, '-o', label="val_loss")
plt.xlabel("Number of epochs")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,acc, '-o', label="acc")
plt.plot(epochs,val_acc, '-o', label="val_acc")
plt.xlabel("Number of epochs")
plt.legend()

# %%
# Test on new triplet integrity
print(new_y_triplet_train[-30:])
t = np.equal(new_y_triplet_train[0::3],new_y_triplet_train[1::3])
print(t)
np.sum(t.astype(np.float32))/len(t)

# %% [markdown]
# ### Evaluate it

# %% [markdown]
# #### Evaluate on verification task

# %%
NBOF_PAIRS = 5000
#NBOF_PAIRS = len(images_test)

# Create pairs
h,w,c = SIZE
pairs = np.empty((NBOF_PAIRS*2,h,w,c))
issame = np.empty(NBOF_PAIRS)
class_test = np.unique(labels_test)
for i in range(NBOF_PAIRS):
    alea = np.random.rand()
    # Pair of different dogs
    if alea < 0.5:
        # Chose the classes:
        class1 = np.random.randint(len(class_test))
        class2 = np.random.randint(len(class_test))
        while class1==class2:
            class2 = np.random.randint(len(class_test))
            
        # Extract images of this class:
        images_class1 = images_test[np.equal(labels_test,class1)]
        images_class2 = images_test[np.equal(labels_test,class2)]
        
        # Chose an image amoung these selected images
        pairs[i*2] = images_class1[np.random.randint(len(images_class1))]
        pairs[i*2+1] = images_class2[np.random.randint(len(images_class2))]
        issame[i] = 0
    # Pair of same dogs
    else:
        # Chose a class
        clas = np.random.randint(len(class_test))
        images_class = images_test[np.equal(labels_test,clas)]
        
        # Select two images from this class
        idx_image1 = np.random.randint(len(images_class))
        idx_image2 = np.random.randint(len(images_class))
        while idx_image1 == idx_image2:
            idx_image2 = np.random.randint(len(images_class))
        
        pairs[i*2] = images_class[idx_image1]
        pairs[i*2+1] = images_class[idx_image2]
        issame[i] = 1

# %%
# Test: Check the pairs
s = 10
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(5,3*n))
for i in range(s,s+n):
    plt.subplot(n,2,2*(i-s)+1)
    plt.imshow(pairs[2*i]*0.5+0.5)
    plt.subplot(n,2,2*(i-s)+2)
    plt.imshow(pairs[2*i+1]*0.5+0.5)

# %%
predict=model.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)


best = 0
best_t = 0
thresholds = np.arange(0.001,4,0.001)
for i in tqdm_notebook(range(len(thresholds))):
    less = np.less(dist, thresholds[i])
    acc = np.logical_not(np.logical_xor(less, issame))
    acc = acc.astype(float)
    out = np.sum(acc)
    out = out/len(acc)
    if out > best:
        best_t = thresholds[i]
        best = out

print("Best threshold: " + str(best_t))
print("Best accuracy: " + str(best))

# %%
# False accepted examples and False rejected examples
t = 0.68
fa = []
fr = []
for i in range(len(dist)):
    # false accepted
    if issame[i] == 0 and dist[i]<t:
        fa += [i]
    if issame[i] == 1 and dist[i]>t:
        fr += [i]

# %%
# Test: Look at wrong pairs
s = 10
sr = 20
n = 5
print(issame[s:(n+s)])
fig = plt.figure(figsize=(11,2.8*n))
for i in range(s,s+n):
    # False accepted
    plt.subplot(n,4,4*(i-s)+1)
    plt.imshow(pairs[2*fa[i+s]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+2)
    plt.imshow(pairs[2*fa[i+s]+1])
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(n,4,4*(i-s)+3)
    plt.imshow(pairs[2*fr[i+sr]])
    plt.xticks([])
    plt.yticks([])
    plt.subplot(n,4,4*(i-s)+4)
    plt.imshow(pairs[2*fr[i+sr]+1])
    plt.xticks([])
    plt.yticks([])

# %%
len(fa)

# %%
len(fr)

# %%
threshold = 0.3
less = np.less(dist, threshold)
acc = np.logical_not(np.logical_xor(less, issame))
acc = acc.astype(float)
out = np.sum(acc)
out = out/len(acc)

print("Accuracy: " + str(out))

# %% [markdown]
# ### ROC curve

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(pairs)
# Separates the pairs
emb1 = predict[0::2]
emb2 = predict[1::2]

# Computes distance between pairs
diff = np.square(emb1-emb2)
dist = np.sum(diff,1)

# Computes the ROC depending on different thresholds

thresholds = np.arange(0.001,4,0.001)
tprs = np.empty(len(thresholds))
fprs = np.empty(len(thresholds))

p = np.sum(issame.astype(float))
n = np.sum(np.logical_not(issame).astype(float))

for i in tqdm_notebook(range(len(thresholds))):
    logical_pred = np.less(dist, thresholds[i])
    tp = np.sum(np.logical_and(logical_pred,issame).astype(float))
    fp = np.sum(np.logical_and(logical_pred,np.logical_not(issame)).astype(float))
    tprs[i] = tp/p
    fprs[i] = fp/n

# %%
np.save('roc_dogfacenet_v11.npy', [tprs, fprs])

# %%
tprs2,fprs2 = np.load('roc_dogfacenet_v12.npy')

# %%
plt.figure(figsize=(5,5))
plt.plot(fprs,tprs,label="VGG-like")
plt.plot(fprs2,tprs2,label="ResNet-like")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
#plt.title("ROC curve")

# %% [markdown]
# ### Second verification task: IN or OUT? actually I think that this task doesn't make any sense

# %%
pred_test = model.predict(images_test)

# %%
nbof_try = 30 # We will do many try on the test dataset to obtain a more precize accuracy

for propo in [0.5,0.6,0.7,0.8,0.9]:
    print("Current propotion of classes considered: " + str(propo))
    
    mean_acc = 0
    max_acc = 0
    min_acc = 1
    mean_t = 0
    
    for _ in tqdm_notebook(range(nbof_try)):
        nbof_kimages=int(propo*len(np.unique(labels_test)))
        kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
        y_kimages = np.unique(labels_test)[:nbof_kimages]

        others_pred = np.copy(pred_test)
        y_others = np.copy(labels_test)

        for i in range(nbof_kimages):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
            choice = np.random.randint(len(keep_classes_images))

            kpred[i] = others_pred[keep_classes_images[choice]]

            others_pred = np.delete(others_pred,keep_classes_images[choice],0)
            y_others = np.delete(y_others,keep_classes_images[choice],0)

        # We find the best threshold for this dataset
        best_acc = 0
        best_t = 0.01
        for threshold in np.arange(0.01,1,0.01):

            acc = 0

            class_pred = np.empty(len(others_pred))

            for i in range(len(others_pred)):
                # computes distance with the key dataset
                dist = np.sum(np.square(kpred-others_pred[i]),1)
                if np.min(dist) < threshold:
                    if y_others[i] in y_kimages:
                        acc += 1
                else:
                    if not y_others[i] in y_kimages:
                        acc += 1
            acc /= len(others_pred)

            if acc > best_acc:
                best_acc = acc
                best_t = threshold

        mean_acc += best_acc
        mean_t += best_t
        
        if best_acc > max_acc:
            max_acc = best_acc
        if best_acc < min_acc:
            min_acc = best_acc
        
    mean_acc /= nbof_try
    
    mean_t /= nbof_try
    print("Mean accuracy for in/out: " + str(mean_acc))
    print("Max accuracy for in/out: " + str(max_acc))
    print("Min accuracy for in/out: " + str(min_acc))
    print("Mean threshold for in/out: " + str(mean_t))

# %% [markdown]
# ### Face clustering

# %%
mod = tf.keras.Model(model.layers[0].input, model.layers[-1].output)
predict=mod.predict(images_test)

# %%
predict=model.predict(images_test)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=len(np.unique(labels_test)),max_iter=2000, random_state=0,tol=0.2).fit(predict)

# %%
images_cluster = [images_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]
labels_cluster = [labels_test[np.equal(kmeans.labels_,i)] for i in range(len(labels_test))]

# %%
len(images_train)

# %%
len(images_test)

# %%
i = 10
length = len(images_cluster[i])
fig=plt.figure(figsize=(5,5))
for j in range(3):
    for k in range(3):
        plt.subplot(3,3,j*3+k+1)
        plt.imshow(images_cluster[i][j*3+k])
        plt.xticks([])
        plt.yticks([])
#fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.1000.png')

# %%
for i in range(len(images_cluster)):
    length = len(images_cluster[i])
    if length > 0:
        print(labels_cluster[i])
        fig=plt.figure(figsize=(length*2,2))
        for j in range(length):
            plt.subplot(1,length,j+1)
            plt.imshow(images_cluster[i][j])
            plt.xticks([])
            plt.yticks([])
        plt.show()
        #fig.savefig('D:/CREATIONS/PAPERS/DogFaceNet/clustering/dfn12.clustering.'+str(i)+'.png')

# %% [markdown]
# ### Recognition: K-NN
# m is the number of images that are going to be selected for k-NN "training".

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
for m in range(1,5):
    
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)
    
    # Model prediction on the reduce dataset
    new_pred_test = model.predict(new_images_test)

    nbof_test = 1000
    mean_acc = 0
    mini = 1
    maxi = 0
    
    # Definition of K
    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # I select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)
        acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
nbof_test = 1000
mean_acc = 0
mini = 1
maxi = 0
if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# ### Recognition: k-NN top 1/2/3/4/5

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
count_im_c = np.zeros(len(np.unique(labels_test)))
for i in range(len(labels_test)):
    count_im_c[int(labels_test[i])] += 1
print("Number of images per classes:")
count_im_c

# %%
max_rk = 5 # Top "max_rk" accuracy

for m in range(1,5):
    # First we drop the classes with less than m images per class:
    to_drop = []
    for i in range(len(count_im_c)):
        if count_im_c[i] <= m:
            to_drop += [i]
    new_labels_test = np.copy(labels_test)
    new_images_test = np.copy(images_test)
    for i in range(len(to_drop)):
        idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
        new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
        new_images_test=np.delete(new_images_test, idx_to_drop, 0)
    np.unique(new_labels_test)

    new_pred_test = model.predict(new_images_test)

    nbof_test = 100
    mean_acc = 0
    mini = 1
    maxi = 0

    if m == 1:
        K = 1
    else:
        K = m+1

    for _ in tqdm_notebook(range(nbof_test)):
        # Second we select m images per classes for k-NN training
        nbof_kimages=m*len(np.unique(new_labels_test))
        kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
        y_kimages = np.empty(nbof_kimages, dtype=int)
        y_kuniques = np.unique(new_labels_test)
        for i in range(len(y_kuniques)):
            for j in range(m):
                y_kimages[i*m+j] = y_kuniques[i]

        others_pred = np.copy(new_pred_test)
        y_others = np.copy(new_labels_test)

        for i in range(len(y_kuniques)):
            keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
            choices = np.empty(0,dtype=int)

            if len(keep_classes_images) <= m:
                print("Bug!")
                break

            for j in range(m):
                choice = np.random.randint(len(keep_classes_images))
                while choice in choices:
                    choice = np.random.randint(len(keep_classes_images))
                choices=np.append(choices,choice)
            #print(choices)
            for j in range(m):
                kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

            others_pred = np.delete(others_pred,keep_classes_images[choices],0)
            y_others = np.delete(y_others,keep_classes_images[choices],0)

        neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
        neigh.fit(kpred, y_kimages)

        rk1_pred_y_others = neigh.predict(others_pred)
        pred_y_others = np.zeros((len(others_pred),max_rk))
        for i in range(len(pred_y_others)):
            pred_y_others[i][0] = rk1_pred_y_others[i]

        for i in range(1,max_rk):
            for j in range(len(pred_y_others)):
                previous_pred = [pred_y_others[j][k] for k in range(0,i)]
                to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
                for k in range(1,len(previous_pred)):
                    to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
                new_kpred = kpred[to_keep]
                new_y_kimages = y_kimages[to_keep]

                neigh.fit(new_kpred, new_y_kimages)

                pred_y_others[j][i] = neigh.predict([others_pred[j]])

        #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
        acc = 0
        for i in range(len(pred_y_others)):
            if y_others[i] in pred_y_others[i]:
                acc += 1
        acc /= len(pred_y_others)

        if mini > acc:
            mini = acc
        if maxi < acc:
            maxi = acc

        mean_acc += acc
    mean_acc /= nbof_test
    print("Mean accuracy: " + str(mean_acc))
    print("Maximum accuracy: " + str(maxi))
    print("Minimum accuracy: " + str(mini))

# %%
m = 2
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

new_pred_test = model.predict(new_images_test)

# %%
nbof_test = 100
mean_acc = 0
mini = 1
maxi = 0
max_rk = 5

if m == 1:
    K = 1
else:
    K = m+1

for _ in tqdm_notebook(range(nbof_test)):
    # Second we select m images per classes for k-NN training
    nbof_kimages=m*len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.empty(nbof_kimages, dtype=int)
    y_kuniques = np.unique(new_labels_test)
    for i in range(len(y_kuniques)):
        for j in range(m):
            y_kimages[i*m+j] = y_kuniques[i]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(len(y_kuniques)):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*m],y_others)]
        choices = np.empty(0,dtype=int)

        if len(keep_classes_images) <= m:
            print("Bug!")
            break

        for j in range(m):
            choice = np.random.randint(len(keep_classes_images))
            while choice in choices:
                choice = np.random.randint(len(keep_classes_images))
            choices=np.append(choices,choice)
        #print(choices)
        for j in range(m):
            kpred[i*m+j] = others_pred[keep_classes_images[choices[j]]]

        others_pred = np.delete(others_pred,keep_classes_images[choices],0)
        y_others = np.delete(y_others,keep_classes_images[choices],0)

    neigh = KNeighborsClassifier(n_neighbors=K, weights='distance')
    neigh.fit(kpred, y_kimages)
    
    rk1_pred_y_others = neigh.predict(others_pred)
    pred_y_others = np.zeros((len(others_pred),max_rk))
    for i in range(len(pred_y_others)):
        pred_y_others[i][0] = rk1_pred_y_others[i]

    for i in range(1,max_rk):
        for j in range(len(pred_y_others)):
            previous_pred = [pred_y_others[j][k] for k in range(0,i)]
            to_keep = np.logical_not(np.equal(previous_pred[0],y_kimages))
            for k in range(1,len(previous_pred)):
                to_keep = np.logical_and(to_keep, np.logical_not(np.equal(previous_pred[k],y_kimages)))
            new_kpred = kpred[to_keep]
            new_y_kimages = y_kimages[to_keep]
            
            neigh.fit(new_kpred, new_y_kimages)
    
            pred_y_others[j][i] = neigh.predict([others_pred[j]])

    #acc = np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    acc = 0
    for i in range(len(pred_y_others)):
        if y_others[i] in pred_y_others[i]:
            acc += 1
    acc /= len(pred_y_others)
    
    if mini > acc:
        mini = acc
    if maxi < acc:
        maxi = acc
    
    mean_acc += acc
mean_acc /= nbof_test
print("Mean accuracy: " + str(mean_acc))
print("Maximum accuracy: " + str(maxi))
print("Minimum accuracy: " + str(mini))

# %% [markdown]
# #### k-NN test part

# %%
m = 3
# First we drop the classes with less than m images per class:
to_drop = []
for i in range(len(count_im_c)):
    if count_im_c[i] <= m:
        to_drop += [i]
new_labels_test = np.copy(labels_test)
new_images_test = np.copy(images_test)
for i in range(len(to_drop)):
    idx_to_drop = np.arange(len(new_labels_test))[np.equal(to_drop[i],new_labels_test)]
    new_labels_test=np.delete(new_labels_test, idx_to_drop, 0)
    new_images_test=np.delete(new_images_test, idx_to_drop, 0)
np.unique(new_labels_test)

# %%
new_pred_test = model.predict(new_images_test)

# %%
# Second we select m images per classes for k-NN training
nbof_kimages=m*len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.empty(nbof_kimages, dtype=int)
y_kuniques = np.unique(new_labels_test)
for i in range(len(y_kuniques)):
    for j in range(m):
        y_kimages[i*2+j] = y_kuniques[i]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(len(y_kuniques)):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i*2],y_others)]
    choices = np.empty(0,dtype=int)
    
    if len(keep_classes_images) <= m:
        print("Bug!")
        break
        
    for j in range(m):
        choice = np.random.randint(len(keep_classes_images))
        while choice in choices:
            choice = np.random.randint(len(keep_classes_images))
        choices=np.append(choices,choice)
    #print(choices)
    for j in range(m):
        kpred[i*2+j] = others_pred[keep_classes_images[choices[j]]]

    others_pred = np.delete(others_pred,keep_classes_images[choices],0)
    y_others = np.delete(y_others,keep_classes_images[choices],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=m+1, weights='distance')
neigh.fit(kpred, y_kimages)
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(new_labels_test))
    kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
    y_kimages = np.unique(new_labels_test)[:nbof_kimages]

    others_pred = np.copy(new_pred_test)
    y_others = np.copy(new_labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh = KNeighborsClassifier(n_neighbors=1)
    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
n = 1000
mean_acc = 0

for j in tqdm_notebook(range(n)):
    nbof_kimages=len(np.unique(labels_test))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)

    neigh.fit(kpred, y_kimages) 

    mean_acc += np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)
    
mean_acc /= n
mean_acc

# %%
nbof_kimages=len(np.unique(new_labels_test))
kpred=np.empty((nbof_kimages,new_pred_test.shape[-1]))
y_kimages = np.unique(new_labels_test)[:nbof_kimages]

others_pred = np.copy(new_pred_test)
y_others = np.copy(new_labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(kpred, y_kimages)

# %%
np.sum(np.equal(y_others,neigh.predict(others_pred)))/len(y_others)

# %%
mean_acc = 0
nbof_try = 1 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = y_others[i]
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %%
def find_n_mins(t,n):
    idx_mins = []
    mins = []
    for i in range(n):
        idx_crt_min = 0
        crt_min = t[0]
        for j in range(1,len(t)):
            if t[j] < crt_min:
                crt_min = t[j]
                idx_crt_min = j
        idx_mins += [idx_crt_min]
        mins += [crt_min]
        t = t[:idx_crt_min] + t[idx_crt_min+1:]
    return idx_mins, mins

# %% [markdown]
# ### Recognition: One-shot learning (deprecated: use the above part with M=1 instead)

# %%
pred_test = model.predict(images_test)

# %%
mean_acc = 0
nbof_try = 1000 # We will do many try on the test dataset to obtain a more precize accuracy

for k in tqdm_notebook(range(nbof_try)):
    nbof_kimages=int(1.0*len(np.unique(labels_test)))
    kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
    y_kimages = np.unique(labels_test)[:nbof_kimages]

    others_pred = np.copy(pred_test)
    y_others = np.copy(labels_test)

    for i in range(nbof_kimages):
        keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
        choice = np.random.randint(len(keep_classes_images))

        kpred[i] = others_pred[keep_classes_images[choice]]

        others_pred = np.delete(others_pred,keep_classes_images[choice],0)
        y_others = np.delete(y_others,keep_classes_images[choice],0)
    
    threshold = 0.6

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = 1
#             if y_others[i] in y_kimages:
#                 acc += 1
            if np.argmin(dist)==y_others[i]:
                acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1

    acc /= len(others_pred)
    
    mean_acc += acc
    
mean_acc /= nbof_try
print("Mean accuracy for a one shot learner: " + str(mean_acc))

# %% [markdown]
# #### Test for one-shot learning:

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kimages=np.empty((nbof_kimages,h,w,c))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others = np.copy(images_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kimages[i] = others[keep_classes_images[choice]]
    
    others = np.delete(others,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

kpred = model.predict(kimages)

# Prediction for every other pictures
others_pred = model.predict(others)

# %%
pred_test = model.predict(images_test)

# %%
# To train a one-shot learner on the test dataset:
#  -we randomly select key images: one picture per classes among 80% of the classes
#  -we take a new picture
#  -we check if the dog if the dog is known or not:
#   computes the distance between the embedding vector and every embeddings saved in
#   the dataset and compares the given distance with a threshold
#  -if not, return -1
#  -if yes, return the corresponding class

# Note: for the test we could have compute the prediction for every pictures and
# then separate key frames from the others but we played RP here :)




# We randomly select key images: one picture per classes among 80% of the classes
nbof_kimages=int(0.8*len(np.unique(labels_test)))
kpred=np.empty((nbof_kimages,pred_test.shape[-1]))
y_kimages = np.unique(labels_test)[:nbof_kimages]

others_pred = np.copy(pred_test)
y_others = np.copy(labels_test)

for i in range(nbof_kimages):
    keep_classes_images = np.arange(len(y_others))[np.equal(y_kimages[i],y_others)]
    choice = np.random.randint(len(keep_classes_images))
    
    kpred[i] = others_pred[keep_classes_images[choice]]
    
    others_pred = np.delete(others_pred,keep_classes_images[choice],0)
    y_others = np.delete(y_others,keep_classes_images[choice],0)

# %%
# we will use the best threshold find on verification task
threshold = 0.3

# for i in range(len(others_pred)):

acc = 0

class_pred = np.empty(len(others_pred))

for i in range(len(others_pred)):
    # computes distance with the key dataset
    dist = np.sum(np.square(kpred-others_pred[i]),1)
    if np.min(dist) < threshold:
        class_pred[i] = np.argmin(dist)
        if np.argmin(dist)==y_others[i]:
            acc += 1
    else:
        class_pred[i] = -1
        if not y_others[i] in y_kimages:
            acc += 1
        
acc /= len(others_pred)
acc

# %%
# we will find the best threshold for verification
best_acc = 0
best_t = 0.001
for threshold in np.arange(0.001,1,0.001):

    acc = 0

    class_pred = np.empty(len(others_pred))

    for i in range(len(others_pred)):
        # computes distance with the key dataset
        dist = np.sum(np.square(kpred-others_pred[i]),1)
        if np.min(dist) < threshold:
            class_pred[i] = np.argmin(dist)
            if np.argmin(dist)==y_others[i]:
                acc += 1
#             if y_others[i] in y_kimages:
#                 acc += 1
        else:
            class_pred[i] = -1
            if not y_others[i] in y_kimages:
                acc += 1
    acc /= len(others_pred)
    
    if acc > best_acc:
        best_acc = acc
        best_t = threshold


print(best_acc)
print(best_t)

# %%
plt.figure(figsize=(8,5))
for i in range(38):
    plt.subplot(5,8,i+1)
    plt.imshow(kimages[i])

# %%
plt.figure(figsize=(13,18))
for i in range(13*18):
    plt.subplot(18,13,i+1)
    plt.imshow(others[i])

# %% [markdown]
# ### Recognition: Re-training

# %%
s = 30.
m = 0.3
def cosine(y_true,y_pred):
    
    exp_s = K.exp(s * y_pred)
    exp_s_m = K.exp(s * (y_pred - m))
    
    masked_exp_s_m = exp_s_m * y_true
    
    inv_mask = 1. - y_true
    masked_exp_s = exp_s * inv_mask
    
    den = K.sum(masked_exp_s + masked_exp_s_m, axis=-1, keepdims=True)
    out = masked_exp_s_m / den
    out = K.sum(out,axis=-1)
    ret = - K.log(out)
    ret = K.sum(ret)
    return ret

# %%
class Cosine(tf.keras.layers.Layer):

    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(Cosine, self).__init__(**kwargs)

    def build(self, input_shape):
        shape = tf.TensorShape((input_shape[-1],self.output_dim))

        self.kernel = self.add_weight(name='kernel', 
                                      shape=shape,
                                      initializer='uniform',
                                      trainable=True)
        super(Cosine, self).build(input_shape)

    def call(self, x):
        x = tf.math.l2_normalize(x, axis=-1)
        w = tf.math.l2_normalize(self.kernel, axis=0)
        
        return K.dot(x, w)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

# %%
labels_test_exp = tf.keras.utils.to_categorical(labels_test)

# %%
#out = tf.keras.layers.Dense(128, activation='relu')(model.output)
out = Cosine(len(labels_test_exp[0]))(model.output)
#out = tf.keras.layers.Dense(24, activation='softmax')(out)
recog = tf.keras.Model(model.input,out)
for layer in model.layers: layer.trainable = False
recog.compile(tf.keras.optimizers.Adam(),loss=cosine,metrics=['accuracy'])

# %%
recog.fit(images_test,labels_test_exp,batch_size=64,epochs=30)

# %% [markdown]
# ### Observation on the heatmap

# %%
model.layers

# %%
mod3 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict3 = mod3.predict(images_train[0:100:10])

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(10,10,i*10+1)
    sk.io.imshow(images_train[i*10])
    
    for j in range(9):
        pred3 = np.mean(predict3[i][:,:,j*25:j*25+3],axis=-1)
        plt.subplot(10,10,i*10+2+j)
        sk.io.imshow(images_train[i*10])
        plt.imshow(pred3,cmap='plasma')

# %%
s = 100
mod1 = tf.keras.Model(model.layers[0].input, model.layers[1].output)
predict1 = mod1.predict(images_train[0+s:100+s:10])

mod2 = tf.keras.Model(model.layers[0].input, model.layers[9].output)
predict2 = mod2.predict(images_train[0+s:100+s:10])

mod3 = tf.keras.Model(model.layers[0].input, model.layers[14].output)
predict3 = mod3.predict(images_train[0+s:100+s:10])

plt.figure(figsize=(9,20))
for i in range(10):
    pred1 = np.mean(predict1[i],axis=-1)
    pred2 = np.mean(predict2[i],axis=-1)
    pred3 = np.mean(predict3[i],axis=-1)

    
    plt.subplot(10,4,i*4+1)
    sk.io.imshow(images_train[i*10 + s])
    plt.subplot(10,4,i*4+2)
    plt.imshow(pred1,cmap='plasma')
    plt.subplot(10,4,i*4+3)
    plt.imshow(pred2,cmap='plasma')
    plt.subplot(10,4,i*4+4)
    plt.imshow(pred3,cmap='plasma')

# %%
history = model.fit_generator(
    train_datagen.flow(images_train,labels_train,batch_size = 64),
    epochs = 12,
    validation_data=(images_valid,labels_valid)
)

# %%
model.save('../output/model/dogfacenet_v6_cosine.h5')
